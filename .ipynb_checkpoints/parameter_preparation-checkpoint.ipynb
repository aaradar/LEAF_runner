# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
from pathlib import Path

project_root = Path.cwd()
sys.path.insert(0, str(project_root))

from prepare_params import prepare_production_params

print("Modules imported successfully")
print(f"Current working directory: {os.getcwd()}")


kml = "Sample Points\AfforestationSItesFixed.kml"
shp = "Sample Points\FieldPoints32_2018.shp"
tmx = "Sample Points\TMX\TML_pipeline_100mbuffer.kml"
cbc = "Sample Points\ColdwaterBCregion.kml"
ls_mgrs = "S2A_OPER_GIP_TILPAR_MPC.kml"
s2_mgrs = "sentinel-2-grid.parquet"
print(kml)
print(shp)
print(tmx)
print(cbc)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Modules imported successfully
# Current working directory: C:\Users\aradar\LEAF Files\LEAF_runner
# Sample Points\AfforestationSItesFixed.kml
# Sample Points\FieldPoints32_2018.shp
# Sample Points\TMX\TML_pipeline_100mbuffer.kml
# Sample Points\ColdwaterBCregion.kml

# %%
# Use Case: Generate monthly mosaics
# Customize these parameters as needed:

ProdParams = {
    # ============ REQUIRED PARAMETERS ============
    'sensor': 'S2_SR',                    # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR', 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'nbYears': -1,            # positive int for annual product, or negative int for monthly product
    #'year': 2023,                          # CHANGE THIS: Year to process
    #'months': [8,9,10],                   # CHANGE THIS: Months to process (1-12)
    
    
    # ============ REGION PARAMETERS ============
    'regions': kml,  # CHANGE THIS: Path to your KML/SHP file
    'file_variables': ['TARGET_FID', 'AsssD_1', 'AsssD_2'], # CHANGE THIS: id, start_date, end_date (None for dates if they don't exist)
    #'file_variables': ['id', 'begin', 'end'], # for pipelines file
    #'file_variables': ['system:index', None, None], # for cold water file
    'regions_start_index': 1,              # CHANGE THIS: Start at this region index
    'regions_end_index': 1,             # CHANGE THIS: End at this index (None = all)

    # ============ TILES PARAMETERS ============
    's2_grid_path': s2_mgrs,
    'mode': 'tiles', #regions or tiles
    'subdivide_tiles': False, # Whether to subdivide tiles into smaller regions (only applicable if mode is 'tiles')
    
    # ============ BUFFER PARAMETERS ============
    #'spatial_buffer_m': -10,             # UNCOMMENT & CHANGE: Buffer in meters around regions
    #'temporal_buffer': [[50, 90], [-10, 10]],          # UNCOMMENT & CHANGE: [days_before, days_after]
    'temporal_buffer': [["2017-08-01", "2017-08-31"]],
    'num_years': 3,
    
    
    # ============ OUTPUT PARAMETERS ============
    'resolution': 30,                      # Resolution in meters
    'projection': 'EPSG:3979',             # Coordinate projection
    'IncludeAngles': False,
    'prod_names': ['mosaic'],    #['mosaic', 'LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'out_folder': 'E:\\TestingLEAF\\kiyo_30m',
    'out_datatype': 'int16',

    # ============ CSV OUTPUT (NEW) ============
    'output_type': 'geotiff',        # <-- switch from GeoTIFF to CSV
    'csv_scale': 10,             # optional: same as resolution, explicit here for clarity
    'csv_dropNulls': True,       # optional: skip masked/nodata pixels (mirrors GEE dropNulls)
    'csv_max_pixels': 100_000,   # optional: lower this first for a quick test
}

CompParams = {
  "number_workers":10,    
  "debug"       : True,
  "entire_tile" : False,
  "nodes"       : 1,
  "node_memory" : "50G",
  'chunk_size': {'x': 512, 'y': 512}
}


print("\nconfigured")
# Out:
# configured

# %%
# Run the parameter preparation
result = prepare_production_params(ProdParams, CompParams)
'''
if result:
    print("\n" + "="*80)
    print(" SUCCESS - Parameters validated and ready!")
    print("="*80)
    print(f"\n Summary:")
    print(f"  Regions: {len(result['ProdParams']['regions'])}")
    print(f"  Time windows: {len(result['ProdParams']['start_dates'])}")
    print(f"  Total tasks: {len(result['ProdParams']['regions']) * len(result['ProdParams']['start_dates'])}")
    print(f"  Output folder: {result['ProdParams']['out_folder']}")
    print(f"\n Processing log saved to: {result['ProdParams']['out_folder']}/polygon_processing_log.csv")
    print("\n" + "="*80)
    print("Next step: Call Production.py with the validated parameters")
    print("="*80)
else:
    print("\n" + "="*80)
    print(" FAILED - Parameter validation failed")
    print("="*80)
    print("Check the error messages above for details.") '''
# Out:
# ================================================================================
# PARAMETER PREPARATION
# ================================================================================
#
# Step 1/4: Validating input parameters...
# ✓ All parameters valid
#
# Step 2/4: Loading regions from files...
# <handle_regions_from_file> Detected file-based regions input: Sample Points\AfforestationSItesFixed.kml
# <handle_regions_from_file> Loading regions...
# <handle_regions_from_file> Resolving Sentinel-2 tiles...
#   Loading S2 tile grid from: C:\Users\aradar\LEAF Files\LEAF_runner\source\sentinel-2-grid.parquet
#     Loaded parquet (56686 tiles)
#   Pre-filtered to 2 candidate S2 tiles in bounding box
#   Filtering to first match only (one tile per source region)...
#   Tile name column: 'tile'
#   Resolved 4 Sentinel-2 tile(s) covering 1 selected region(s)
# <handle_regions_from_file> Override mode: Setting all regions to 1 date window(s)
# <handle_regions_from_file> Region tile_17TNK_NW: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Region tile_17TNK_NE: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Region tile_17TNK_SW: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Region tile_17TNK_SE: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Region region1: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Expanding region dates across 3 years...
# <handle_regions_from_file> Region tile_17TNK_NW: Expanded from 1 to 3 date windows (3 years)
# <handle_regions_from_file> Region tile_17TNK_NE: Expanded from 1 to 3 date windows (3 years)
# <handle_regions_from_file> Region tile_17TNK_SW: Expanded from 1 to 3 date windows (3 years)
# <handle_regions_from_file> Region tile_17TNK_SE: Expanded from 1 to 3 date windows (3 years)
# <handle_regions_from_file> Region region1: Expanded from 1 to 3 date windows (3 years)
# <handle_regions_from_file> Loaded 4 regions from file
#
# Step 3/4: Skipping temporal window generation (no year/months or start_dates/end_dates found)
#            Region-specific dates from file will be used if available.
#
# Step 4/4: Validating polygons...
#
# ================================================================================
# POLYGON VALIDATION AND FILTERING
# ================================================================================
#
# Polygon validation log saved to: E:\TestingLEAF\kiyo_30m\polygon_processing_log.csv
#
# Validation Summary:
#    Total regions: 4
#    Valid for processing: 4
#    Skipped (zero area): 0
#
# Proceeding with 4 valid region(s) out of 4 total
# ================================================================================
#
#
# ================================================================================
# PARAMETER PREPARATION COMPLETE
# ================================================================================
# Regions: 4
# Start Time windows: {'tile_17TNK_NW': ['2017-08-01', '2018-08-01', '2019-08-01'], 'tile_17TNK_NE': ['2017-08-01', '2018-08-01', '2019-08-01'], 'tile_17TNK_SW': ['2017-08-01', '2018-08-01', '2019-08-01'], 'tile_17TNK_SE': ['2017-08-01', '2018-08-01', '2019-08-01']}
# End Time windows: {'tile_17TNK_NW': ['2017-08-31', '2018-08-31', '2019-08-31'], 'tile_17TNK_NE': ['2017-08-31', '2018-08-31', '2019-08-31'], 'tile_17TNK_SW': ['2017-08-31', '2018-08-31', '2019-08-31'], 'tile_17TNK_SE': ['2017-08-31', '2018-08-31', '2019-08-31']}
# ================================================================================
#
#
# <prepare_production_params> Added properties to regions:
# {
#   "sensor": "S2_SR",
#   "unit": 2,
#   "nbYears": -1,
#   "file_variables": [
#     "TARGET_FID",
#     "AsssD_1",
#     "AsssD_2"
#   ],
#   "regions_start_index": 1,
#   "regions_end_index": 1,
#   "s2_grid_path": "sentinel-2-grid.parquet",
#   "mode": "tiles",
#   "subdivide_tiles": true,
#   "temporal_buffer": [
#     [
#       "2017-08-01",
#       "2017-08-31"
#     ]
#   ],
#   "num_years": 3,
#   "resolution": 30,
#   "projection": "EPSG:3979",
#   "IncludeAngles": false,
#   "prod_names": [
#     "mosaic"
#   ],
#   "out_folder": "E:\\TestingLEAF\\kiyo_30m",
#   "out_datatype": "int16",
#   "output_type": "geotiff",
#   "csv_scale": 10,
#   "csv_dropNulls": true,
#   "csv_max_pixels": 100000,
#   "regions_ref": {
#     "region1": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -80.2866384110016,
#             44.3533435417762
#           ],
#           [
#             -80.2864858239462,
#             44.353000698271
#           ],
#           [
#             -80.2868313289172,
#             44.3529866183925
#           ],
#           [
#             -80.2871254773415,
#             44.3529366809224
#           ],
#           [
#             -80.2874977225433,
#             44.3529180592246
#           ],
#           [
#             -80.2876405698119,
#             44.3529059627622
#           ],
#           [
#             -80.2879206306362,
#             44.3528989373857
#           ],
#           [
#             -80.2880395541161,
#             44.3528827993289
#           ],
#           [
#             -80.2880782566738,
#             44.352880279965
#           ],
#           [
#             -80.2882027280036,
#             44.353154957613
#           ],
#           [
#             -80.288085927134,
#             44.3531261618167
#           ],
#           [
#             -80.287951530048,
#             44.3531125098555
#           ],
#           [
#             -80.2878832692439,
#             44.3531281508011
#           ],
#           [
#             -80.287738989293,
#             44.3532215337679
#           ],
#           [
#             -80.2877249039523,
#             44.3532644472593
#           ],
#           [
#             -80.287558824637,
#             44.3533088522111
#           ],
#           [
#             -80.2874518606506,
#             44.3533270111586
#           ],
#           [
#             -80.2871598357525,
#             44.3533320137857
#           ],
#           [
#             -80.2866384110016,
#             44.3533435417762
#           ]
#         ]
#       ]
#     }
#   },
#   "region_start_dates_ref": {
#     "region1": [
#       "2017-08-01",
#       "2018-08-01",
#       "2019-08-01"
#     ]
#   },
#   "region_end_dates_ref": {
#     "region1": [
#       "2017-08-31",
#       "2018-08-31",
#       "2019-08-31"
#     ]
#   }
# }
# {'tile_17TNK_NW': ['2017-08-01', '2018-08-01', '2019-08-01'], 'tile_17TNK_NE': ['2017-08-01', '2018-08-01', '2019-08-01'], 'tile_17TNK_SW': ['2017-08-01', '2018-08-01', '2019-08-01'], 'tile_17TNK_SE': ['2017-08-01', '2018-08-01', '2019-08-01']}
# {'tile_17TNK_NW': ['2017-08-31', '2018-08-31', '2019-08-31'], 'tile_17TNK_NE': ['2017-08-31', '2018-08-31', '2019-08-31'], 'tile_17TNK_SW': ['2017-08-31', '2018-08-31', '2019-08-31'], 'tile_17TNK_SE': ['2017-08-31', '2018-08-31', '2019-08-31']}
# '\nif result:\n    print("\n" + "="*80)\n    print(" SUCCESS - Parameters validated and ready!")\n    print("="*80)\n    print(f"\n Summary:")\n    print(f"  Regions: {len(result[\'ProdParams\'][\'regions\'])}")\n    print(f"  Time windows: {len(result[\'ProdParams\'][\'start_dates\'])}")\n    print(f"  Total tasks: {len(result[\'ProdParams\'][\'regions\']) * len(result[\'ProdParams\'][\'start_dates\'])}")\n    print(f"  Output folder: {result[\'ProdParams\'][\'out_folder\']}")\n    print(f"\n Processing log saved to: {result[\'ProdParams\'][\'out_folder\']}/polygon_processing_log.csv")\n    print("\n" + "="*80)\n    print("Next step: Call Production.py with the validated parameters")\n    print("="*80)\nelse:\n    print("\n" + "="*80)\n    print(" FAILED - Parameter validation failed")\n    print("="*80)\n    print("Check the error messages above for details.") '

# %%
# View processing log (if pandas is available)
try:
    import pandas as pd
    if result and result['processing_log'] is not None:
        print("\n Processing Log Preview:")
        print("=" * 80)
        display(result['processing_log'].head(10))
        print(f"\nTotal entries: {len(result['processing_log'])}")
except ImportError:
    print("pandas not available - install it to view the processing log in this cell")
    print("You can still view the CSV file directly in the output folder")
# Out:
#  Processing Log Preview:
# ================================================================================
#        region_id  area_m2  will_process status skip_reason
# 0  tile_17TNK_NW  1082.28          True  VALID         N/A
# 1  tile_17TNK_NE  1509.70          True  VALID         N/A
# 2  tile_17TNK_SW  1473.76          True  VALID         N/A
# 3  tile_17TNK_SE  1139.76          True  VALID         N/A
# Total entries: 4

# %%
import os
import sys
import geopandas as gpd

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

print(ProdParams)
# Out:
# {'sensor': 'S2_SR', 'unit': 2, 'nbYears': -1, 'regions': {'tile_17TNK_NW': {'type': 'Polygon', 'coordinates': [[[-80.2874518606506, 44.3533270111586], [-80.2873442759749, 44.35332919745388], [-80.2873442759749, 44.353111910870595], [-80.28818322119149, 44.353111910870595], [-80.2882027280036, 44.353154957613], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586]]]}, 'tile_17TNK_NE': {'type': 'Polygon', 'coordinates': [[[-80.2865353205907, 44.353111910870595], [-80.2873442759749, 44.353111910870595], [-80.2873442759749, 44.35332919745388], [-80.2866384110016, 44.3533435417762], [-80.2865353205907, 44.353111910870595]]]}, 'tile_17TNK_SW': {'type': 'Polygon', 'coordinates': [[[-80.2880782566738, 44.352880279965], [-80.28818322119149, 44.353111910870595], [-80.2873442759749, 44.353111910870595], [-80.2873442759749, 44.35292363260223], [-80.2876405698119, 44.3529059627622], [-80.2880782566738, 44.352880279965]]]}, 'tile_17TNK_SE': {'type': 'Polygon', 'coordinates': [[[-80.2871254773415, 44.3529366809224], [-80.2873442759749, 44.35292363260223], [-80.2873442759749, 44.353111910870595], [-80.2865353205907, 44.353111910870595], [-80.2864858239462, 44.353000698271], [-80.2871254773415, 44.3529366809224]]]}, 'properties': {'sensor': 'S2_SR', 'unit': 2, 'nbYears': -1, 'file_variables': ['TARGET_FID', 'AsssD_1', 'AsssD_2'], 'regions_start_index': 1, 'regions_end_index': 1, 's2_grid_path': 'sentinel-2-grid.parquet', 'mode': 'tiles', 'subdivide_tiles': True, 'temporal_buffer': [['2017-08-01', '2017-08-31']], 'num_years': 3, 'resolution': 30, 'projection': 'EPSG:3979', 'IncludeAngles': False, 'prod_names': ['mosaic'], 'out_folder': 'E:\\TestingLEAF\\kiyo_30m', 'out_datatype': 'int16', 'output_type': 'geotiff', 'csv_scale': 10, 'csv_dropNulls': True, 'csv_max_pixels': 100000, 'regions_ref': {'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}}, 'region_start_dates_ref': {'region1': ['2017-08-01', '2018-08-01', '2019-08-01']}, 'region_end_dates_ref': {'region1': ['2017-08-31', '2018-08-31', '2019-08-31']}}}, 'file_variables': ['TARGET_FID', 'AsssD_1', 'AsssD_2'], 'regions_start_index': 1, 'regions_end_index': 1, 's2_grid_path': 'sentinel-2-grid.parquet', 'mode': 'tiles', 'subdivide_tiles': True, 'temporal_buffer': [['2017-08-01', '2017-08-31']], 'num_years': 3, 'resolution': 30, 'projection': 'EPSG:3979', 'IncludeAngles': False, 'prod_names': ['mosaic'], 'out_folder': 'E:\\TestingLEAF\\kiyo_30m', 'out_datatype': 'int16', 'output_type': 'geotiff', 'csv_scale': 10, 'csv_dropNulls': True, 'csv_max_pixels': 100000, 'regions_ref': {'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3 ...

# %%
main(ProdParams, CompParams)
# Out:
# <MosaicProduction> Injected placeholder dates for standardization: 2017-08-01 / 2017-08-31
# <MosaicProduction> User defined input parameters:
# sensor: S2_SR
# unit: 2
# nbYears: -1
# regions: {'tile_17TNK_NW': {'type': 'Polygon', 'coordinates': [[[-80.2874518606506, 44.3533270111586], [-80.2873442759749, 44.35332919745388], [-80.2873442759749, 44.353111910870595], [-80.28818322119149, 44.353111910870595], [-80.2882027280036, 44.353154957613], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586]]]}, 'tile_17TNK_NE': {'type': 'Polygon', 'coordinates': [[[-80.2865353205907, 44.353111910870595], [-80.2873442759749, 44.353111910870595], [-80.2873442759749, 44.35332919745388], [-80.2866384110016, 44.3533435417762], [-80.2865353205907, 44.353111910870595]]]}, 'tile_17TNK_SW': {'type': 'Polygon', 'coordinates': [[[-80.2880782566738, 44.352880279965], [-80.28818322119149, 44.353111910870595], [-80.2873442759749, 44.353111910870595], [-80.2873442759749, 44.35292363260223], [-80.2876405698119, 44.3529059627622], [-80.2880782566738, 44.352880279965]]]}, 'tile_17TNK_SE': {'type': 'Polygon', 'coordinates': [[[-80.2871254773415, 44.3529366809224], [-80.2873442759749, 44.35292363260223], [-80.2873442759749, 44.353111910870595], [-80.2865353205907, 44.353111910870595], [-80.2864858239462, 44.353000698271], [-80.2871254773415, 44.3529366809224]]]}}
# mode: tiles
# resolution: 30
# projection: EPSG:3979
# IncludeAngles: False
# prod_names: ['mosaic']
# out_folder: E:\TestingLEAF\kiyo_30m
# out_datatype: int16
# output_type: geotiff
# csv_scale: 10
# csv_dropNulls: True
# csv_max_pixels: 100000
# regions_ref: {'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}}
# region_start_dates: {'tile_17TNK_NW': ['2017-08-01', '2018-08-01', '2019-08-01'], 'tile_17TNK_NE': ['2017-08-01', '2018-08-01', '2019-08-01'], 'tile_17TNK_SW': ['2017-08-01', '2018-08-01', '2019-08-01'], 'tile_17TNK_SE': ['2017-08-01', '2018-08-01', '2019-08-01']}
# region_end_dates: {'tile_17TNK_NW': ['2017-08-31', '2018-08-31', '2019-08-31'], 'tile_17TNK_NE': ['2017-08-31', '2018-08-31', '2019-08-31'], 'tile_17TNK_SW': ['2017-08-31', '2018-08-31', '2019-08-31'], 'tile_17TNK_SE': ['2017-08-31', '2018-08-31', '2019-08-31']}
# region_start_dates_ref: {'region1': ['2017-08-01', '2018-08-01', '2019-08-01']}
# region_end_dates_ref: {'region1': ['2017-08-31', '2018-08-31', '2019-08-31']}
# start_dates: ['2017-08-01']
# end_dates: ['2017-08-31']
# monthly: False
# SsrData: {'NAME': 'S2_SR', 'SSR_CODE': 21, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], '10M_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'SIX_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'NoA_BANDS': ['red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'LEAF_BANDS': ['green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'GEE_NAME': 'COPERNICUS/S2_SR_HARMONIZED', 'CLOUD': 'CLOUDY_PIXEL_PERCENTAGE', 'SZA': 'view:sun_elevation', 'SAA': 'view:sun_azimuth', 'VZA': 'view:sun_elevation', 'VAA': 'view:sun_azimuth', 'BLU': 'blue', 'GRN': 'green', 'RED': 'red', 'NIR': 'nir08', 'SW1': 'swir16', 'SW2': 'swir22'}
# year: 2026
# out_location: drive
# months: []
# tile_names: []
# cloud_cover: 80
# export_style: separate
# current_time: 0
# scene_ID:
# current_region: tile_17TNK_NW
# Criteria: {'timeframe': '2017-08-01/2017-08-31', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-80.2874518606506, 44.3533270111586], [-80.2873442759749, 44.35332919745388], [-80.2873442759749, 44.353111910870595], [-80.28818322119149, 44.353111910870595], [-80.2882027280036, 44.353154957613], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586]]]}, 'catalog': 'https://earth-search.aws.element84.com/v1', 'collection': ['sentinel-2-l2a'], 'bands': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl']}
# standardized: True
# number_workers: 10
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 50G
# chunk_size: {'x': 512, 'y': 512}
#
# <MosaicProduction> Using region-specific dates for tile_17TNK_NW
#   Start dates: ['2017-08-01', '2018-08-01', '2019-08-01']
#   End dates: ['2017-08-31', '2018-08-31', '2019-08-31']
# <MosaicProduction> Processing tile_17TNK_NW | time window: 2017-08-01 / 2017-08-31
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': (((-80.2874518606506, 44.3533270111586), (-80.287558824637, 44.3533088522111), (-80.2882027280036, 44.353154957613), (-80.28818322119149, 44.353111910870595), (-80.2873442759749, 44.353111910870595), (-80.2873442759749, 44.35332919745388), (-80.2874518606506, 44.3533270111586)),)}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.01 minutes
#
# <one_mosaic> A total of 5 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2A_17TNK_20170830_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-80.96877845122341, 45.15382398153093], [-79.60360176290054, 45.14529082911873], [-79.62711829312833, 44.15712570786563], [-81.00023764531663, 44.16537549832127], [-81.00024132672165, 45.06113385809171], [-80.96877845122341, 45.15382398153093]]]}
# Bounding Box: [-81.00024132672165, 44.15712570786563, -79.60360176290054, 45.15382398153093]
# Datetime: 2017-08-30 16:19:15.785000+00:00
# cloud cover: 46.459384
# Properties:
#   <created>: 2022-11-03T15:15:03.739Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 46.459384
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:sun_azimuth>: 155.282149059598
#   <view:sun_elevation>: 51.7682587820714
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 0.103158
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.114172
#   <s2:cloud_shadow_percentage>: 0.694115
#   <s2:vegetation_percentage>: 18.715386
#   <s2:not_vegetated_percentage>: 2.207844
#   <s2:water_percentage>: 27.365333
#   <s2:unclassified_percentage>: 4.123029
#   <s2:medium_proba_clouds_percentage>: 9.44801
#   <s2:high_proba_clouds_percentage>: 36.856169
#   <s2:thin_cirrus_percentage>: 0.155206
#   <s2:snow_ice_percentage>: 0.320738
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 00.01
#   <s2:product_uri>: S2A_MSIL2A_20170830T160901_N0001_R140_T17TNK_20201025T005511.SAFE
#   <s2:generation_time>: 2020-10-25T00:55:11.420Z
#   <s2:datatake_id>: GS2A_20170830T160901_011434_N00.01
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_SHIT_20201025T005513_S20170830T161915_N00.01
#   <s2:granule_id>: S2A_OPER_MSI_L2A_TL_SHIT_20201025T005513_A011434_T17TNK_N00.01
#   <s2:reflectance_conversion_factor>: 0.979960213743031
#   <datetime>: 2017-08-30T16:19:15.785000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/cb7778c70db6470475b2c061b2ca32d7
#   <earthsearch:boa_offset_applied>: False
#   <processing:software>: {'sentinel2-to-stac': '0.1.0'}
#   <updated>: 2022-11-08T13:27:01.131Z
#   <proj:code>: EPSG:32617
#   <sza>: 38.2317412179286
#   <saa>: 155.282149059598
#   <vza>: 6.96020171398942
#   <vaa>: 106.200318867347
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 340B
# Dimensions:      (y: 2, x: 3)
# Coordinates:
#   * y            (y) float64 16B -3.838e+05 -3.838e+05
#   * x            (x) float64 24B 1.187e+06 1.187e+06 1.187e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2017-08-30T16:19:15.785000
# Data variables:
#     blue         (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     green        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     red          (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge1     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge2     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge3     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     nir08        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     swir16       (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     swir22       (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     scl          (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     date         (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     score        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score']
# <_get_tile_regions> 1 region(s) matched for tile tile_17TNK_NW (2017-08-01 – 2017-08-31)  [skipped: 0 date-mismatch, 0 out-of-bounds]
#
# <export_mosaic> tiles mode — exporting region: region1 (tile: tile_17TNK_NW)
# <_clip_mosaic_to_regions> Clipped mosaic → Frozen({'y': 2, 'x': 3})
# <export_geotiff> Wrote E:\TestingLEAF\kiyo_30m\S2_SR_region1_tile_17TNK_NW_2017-08-01_2017-08-31_scl_30m.tif
# <export_geotiff> Wrote E:\TestingLEAF\kiyo_30m\S2_SR_region1_tile_17TNK_NW_2017-08-01_2017-08-31_swir16_30m.tif
# <export_geotiff> Wrote E:\TestingLEAF\kiyo_30m\S2_SR_region1_tile_17TNK_NW_2017-08-01_2017-08-31_green_30m.tif
# <export_geotiff> Wrote E:\TestingLEAF\kiyo_30m\S2_SR_region1_tile_17TNK_NW_2017-08-01_2017-08-31_swir22_30m.tif
# <export_geotiff> Wrote E:\TestingLEAF\kiyo_30m\S2_SR_region1_tile_17TNK_NW_2017-08-01_2017-08-31_red_30m.tif
# <export_geotiff> Wrote E:\TestingLEAF\kiyo_30m\S2_SR_region1_tile_17TNK_NW_2017-08-01_2017-08-31_rededge1_30m.tif
# <export_geotiff> Wrote E:\TestingLEAF\kiyo_30m\S2_SR_region1_tile_17TNK_NW_2017-08-01_2017-08-31_nir08_30m.tif
# <export_geotiff> Wrote E:\TestingLEAF\kiyo_30m\S2_SR_region1_tile_17TNK_NW_2017-08-01_2017-08-31_date_30m.tif
# <export_geotiff> Wrote E:\TestingLEAF\kiyo_30m\S2_SR_region1_tile_17TNK_NW_2017-08-01_2017-08-31_rededge3_30m.tif
# <export_geotiff> Wrote E:\TestingLEAF\kiyo_30m\S2_SR_region1_tile_17TNK_NW_2017-08-01_2017-08-31_rededge2_30m.tif
# <export_geotiff> Wrote E:\TestingLEAF\kiyo_30m\S2_SR_region1_tile_17TNK_NW_2017-08-01_2017-08-31_blue_30m.tif
# <export_geotiff> Wrote E:\TestingLEAF\kiyo_30m\S2_SR_region1_tile_17TNK_NW_2017-08-01_2017-08-31_score_30m.tif
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.64 minutes >>>>>>
# File 'E:\TestingLEAF\kiyo_30m\log_1a56db9c-4743-425d-945e-81fba585d379.out' does not exist.
# Directory 'E:\TestingLEAF\kiyo_30m\dask_spill_1a56db9c-4743-425d-945e-81fba585d379' and its contents have been deleted.
# <MosaicProduction> Processing tile_17TNK_NW | time window: 2018-08-01 / 2018-08-31
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': (((-80.2874518606506, 44.3533270111586), (-80.287558824637, 44.3533088522111), (-80.2882027280036, 44.353154957613), (-80.28818322119149, 44.353111910870595), (-80.2873442759749, 44.353111910870595), (-80.2873442759749, 44.35332919745388), (-80.2874518606506, 44.3533270111586)),)}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.02 minutes
#
# <one_mosaic> A total of 19 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TNK_20180823_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-79.60360176290054, 45.14529082911873], [-79.60454539311509, 45.106607772875776], [-79.98819618345406, 44.16089474591046], [-81.00023764531663, 44.16537549832127], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.00024171761814, 44.16089474591046, -79.60360176290054, 45.153828248771845]
# Datetime: 2018-08-23 16:23:56.979000+00:00
# cloud cover: 13.672233
# Properties:
#   <created>: 2022-11-08T09:25:06.332Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 13.672233
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:sun_azimuth>: 157.096593911009
#   <view:sun_elevation>: 54.7490239225957
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 12.512898
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.37843
#   <s2:cloud_shadow_percentage>: 0.15281
#   <s2:vegetation_percentage>: 46.001202
#   <s2:not_vegetated_percentage>: 2.524133
#   <s2:water_percentage>: 35.528269
#   <s2:unclassified_percentage>: 1.742911
#   <s2:medium_proba_clouds_percentage>: 4.904326
#   <s2:high_proba_clouds_percentage>: 5.014096
#   <s2:thin_cirrus_percentage>: 3.75381
#   <s2:snow_ice_percentage>: 1.1e-05
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 00.01
#   <s2:product_uri>: S2B_MSIL2A_20180823T161819_N0001_R040_T17TNK_20200922T013729.SAFE
#   <s2:generation_time>: 2020-09-22T01:37:29.776Z
#   <s2:datatake_id>: GS2B_20180823T161819_007645_N00.01
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_SHIT_20200922T013731_S20180823T162356_N00.01
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_SHIT_20200922T013731_A007645_T17TNK_N00.01
#   <s2:reflectance_conversion_factor>: 0.976897734843365
#   <datetime>: 2018-08-23T16:23:56.979000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/07be4422539257706c3758c31622bb32
#   <earthsearch:boa_offset_applied>: False
#   <processing:software>: {'sentinel2-to-stac': '0.1.0'}
#   <updated>: 2022-11-08T09:25:06.332Z
#   <proj:code>: EPSG:32617
#   <sza>: 35.2509760774043
#   <saa>: 157.096593911009
#   <vza>: 8.14992849428792
#   <vaa>: 285.19325428423
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 340B
# Dimensions:      (y: 2, x: 3)
# Coordinates:
#   * y            (y) float64 16B -3.838e+05 -3.838e+05
#   * x            (x) float64 24B 1.187e+06 1.187e+06 1.187e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2018-08-23T16:23:56.979000
# Data variables:
#     blue         (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     green        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     red          (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge1     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge2     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge3     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     nir08        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     swir16       (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     swir22       (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     scl          (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     date         (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     score        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score']
# <_get_tile_regions> 0 region(s) matched for tile tile_17TNK_NW (2018-08-01 – 2018-08-31)  [skipped: 1 date-mismatch, 0 out-of-bounds]
# <export_mosaic> tiles mode: no matching regions found for this tile/time window — skipping export.
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.71 minutes >>>>>>
# File 'E:\TestingLEAF\kiyo_30m\log_c2d6bc4f-41d4-4b18-9b1f-48d876dfc681.out' does not exist.
# Directory 'E:\TestingLEAF\kiyo_30m\dask_spill_c2d6bc4f-41d4-4b18-9b1f-48d876dfc681' and its contents have been deleted.
# <MosaicProduction> Processing tile_17TNK_NW | time window: 2019-08-01 / 2019-08-31
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': (((-80.2874518606506, 44.3533270111586), (-80.287558824637, 44.3533088522111), (-80.2882027280036, 44.353154957613), (-80.28818322119149, 44.353111910870595), (-80.2873442759749, 44.353111910870595), (-80.2873442759749, 44.35332919745388), (-80.2874518606506, 44.3533270111586)),)}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.03 minutes
#
# <one_mosaic> A total of 24 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/thumbnail.jp2
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/1/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/1/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/1/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/1/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/1/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/1/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/1/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/1/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/1/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/1/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/1/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/1/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/1/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/1/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/1/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/1/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TNK_20190828_1_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-81.00023764893123, 44.16627582534749], [-80.00384297010301, 44.162112262356324], [-79.60568692253773, 45.145316309499854], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.00024171761814, 44.162112262356324, -79.60568692253773, 45.153828248771845]
# Datetime: 2019-08-28 16:31:01.203000+00:00
# cloud cover: 9.96357
# Properties:
#   <created>: 2024-08-25T23:35:45.291Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 9.96357
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:sun_azimuth>: 158.483378908935
#   <view:sun_elevation>: 53.2655309289599
#   <s2:degraded_msi_data_percentage>: 0.0128
#   <s2:nodata_pixel_percentage>: 13.703226
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.084752
#   <s2:cloud_shadow_percentage>: 7.347573
#   <s2:vegetation_percentage>: 35.055783
#   <s2:not_vegetated_percentage>: 2.590906
#   <s2:water_percentage>: 44.647759
#   <s2:unclassified_percentage>: 0.309655
#   <s2:medium_proba_clouds_percentage>: 4.902196
#   <s2:high_proba_clouds_percentage>: 4.689401
#   <s2:thin_cirrus_percentage>: 0.371973
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.00
#   <s2:product_uri>: S2B_MSIL2A_20190828T161839_N0500_R040_T17TNK_20230622T095720.SAFE
#   <s2:generation_time>: 2023-06-22T09:57:20.000000Z
#   <s2:datatake_id>: GS2B_20190828T161839_012936_N05.00
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_S2RP_20230622T095720_S20190828T162908_N05.00
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_S2RP_20230622T095720_A012936_T17TNK_N05.00
#   <s2:reflectance_conversion_factor>: 0.97883052972375
#   <datetime>: 2019-08-28T16:31:01.203000Z
#   <s2:sequence>: 1
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_1_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/bf09c69d08124166e4e53d03c89526ff
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.1'}
#   <updated>: 2024-08-25T23:35:45.291Z
#   <proj:code>: EPSG:32617
#   <sza>: 36.7344690710401
#   <saa>: 158.483378908935
#   <vza>: 8.19458288717236
#   <vaa>: 285.185462982632
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 340B
# Dimensions:      (y: 2, x: 3)
# Coordinates:
#   * y            (y) float64 16B -3.838e+05 -3.838e+05
#   * x            (x) float64 24B 1.187e+06 1.187e+06 1.187e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2019-08-28T16:31:01.203000
# Data variables:
#     blue         (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     green        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     red          (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge1     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge2     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge3     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     nir08        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     swir16       (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     swir22       (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     scl          (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     date         (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     score        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score']
# <_get_tile_regions> 0 region(s) matched for tile tile_17TNK_NW (2019-08-01 – 2019-08-31)  [skipped: 1 date-mismatch, 0 out-of-bounds]
# <export_mosaic> tiles mode: no matching regions found for this tile/time window — skipping export.
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.79 minutes >>>>>>
# File 'E:\TestingLEAF\kiyo_30m\log_444ed766-88dc-4c2b-9e5a-be91c9f75053.out' does not exist.
# Directory 'E:\TestingLEAF\kiyo_30m\dask_spill_444ed766-88dc-4c2b-9e5a-be91c9f75053' and its contents have been deleted.
#
# <MosaicProduction> Using region-specific dates for tile_17TNK_NE
#   Start dates: ['2017-08-01', '2018-08-01', '2019-08-01']
#   End dates: ['2017-08-31', '2018-08-31', '2019-08-31']
# <MosaicProduction> Processing tile_17TNK_NE | time window: 2017-08-01 / 2017-08-31
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': (((-80.2865353205907, 44.353111910870595), (-80.2866384110016, 44.3533435417762), (-80.2873442759749, 44.35332919745388), (-80.2873442759749, 44.353111910870595), (-80.2865353205907, 44.353111910870595)),)}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.01 minutes
#
# <one_mosaic> A total of 5 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/30/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2A_17TNK_20170830_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-80.96877845122341, 45.15382398153093], [-79.60360176290054, 45.14529082911873], [-79.62711829312833, 44.15712570786563], [-81.00023764531663, 44.16537549832127], [-81.00024132672165, 45.06113385809171], [-80.96877845122341, 45.15382398153093]]]}
# Bounding Box: [-81.00024132672165, 44.15712570786563, -79.60360176290054, 45.15382398153093]
# Datetime: 2017-08-30 16:19:15.785000+00:00
# cloud cover: 46.459384
# Properties:
#   <created>: 2022-11-03T15:15:03.739Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 46.459384
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:sun_azimuth>: 155.282149059598
#   <view:sun_elevation>: 51.7682587820714
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 0.103158
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.114172
#   <s2:cloud_shadow_percentage>: 0.694115
#   <s2:vegetation_percentage>: 18.715386
#   <s2:not_vegetated_percentage>: 2.207844
#   <s2:water_percentage>: 27.365333
#   <s2:unclassified_percentage>: 4.123029
#   <s2:medium_proba_clouds_percentage>: 9.44801
#   <s2:high_proba_clouds_percentage>: 36.856169
#   <s2:thin_cirrus_percentage>: 0.155206
#   <s2:snow_ice_percentage>: 0.320738
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 00.01
#   <s2:product_uri>: S2A_MSIL2A_20170830T160901_N0001_R140_T17TNK_20201025T005511.SAFE
#   <s2:generation_time>: 2020-10-25T00:55:11.420Z
#   <s2:datatake_id>: GS2A_20170830T160901_011434_N00.01
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_SHIT_20201025T005513_S20170830T161915_N00.01
#   <s2:granule_id>: S2A_OPER_MSI_L2A_TL_SHIT_20201025T005513_A011434_T17TNK_N00.01
#   <s2:reflectance_conversion_factor>: 0.979960213743031
#   <datetime>: 2017-08-30T16:19:15.785000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170830_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/cb7778c70db6470475b2c061b2ca32d7
#   <earthsearch:boa_offset_applied>: False
#   <processing:software>: {'sentinel2-to-stac': '0.1.0'}
#   <updated>: 2022-11-08T13:27:01.131Z
#   <proj:code>: EPSG:32617
#   <sza>: 38.2317412179286
#   <saa>: 155.282149059598
#   <vza>: 6.96020171398942
#   <vaa>: 106.200318867347
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 492B
# Dimensions:      (y: 3, x: 3)
# Coordinates:
#   * y            (y) float64 24B -3.838e+05 -3.838e+05 -3.838e+05
#   * x            (x) float64 24B 1.187e+06 1.187e+06 1.187e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2017-08-30T16:19:15.785000
# Data variables:
#     blue         (y, x) float32 36B dask.array<chunksize=(3, 3), meta=np.ndarray>
#     green        (y, x) float32 36B dask.array<chunksize=(3, 3), meta=np.ndarray>
#     red          (y, x) float32 36B dask.array<chunksize=(3, 3), meta=np.ndarray>
#     rededge1     (y, x) float32 36B dask.array<chunksize=(3, 3), meta=np.ndarray>
#     rededge2     (y, x) float32 36B dask.array<chunksize=(3, 3), meta=np.ndarray>
#     rededge3     (y, x) float32 36B dask.array<chunksize=(3, 3), meta=np.ndarray>
#     nir08        (y, x) float32 36B dask.array<chunksize=(3, 3), meta=np.ndarray>
#     swir16       (y, x) float32 36B dask.array<chunksize=(3, 3), meta=np.ndarray>
#     swir22       (y, x) float32 36B dask.array<chunksize=(3, 3), meta=np.ndarray>
#     scl          (y, x) float32 36B dask.array<chunksize=(3, 3), meta=np.ndarray>
#     date         (y, x) float32 36B dask.array<chunksize=(3, 3), meta=np.ndarray>
#     score        (y, x) float32 36B dask.array<chunksize=(3, 3), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score']
# <_get_tile_regions> 1 region(s) matched for tile tile_17TNK_NE (2017-08-01 – 2017-08-31)  [skipped: 0 date-mismatch, 0 out-of-bounds]
#
# ...
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/28/2/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/28/2/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/28/2/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/28/2/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/28/2/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/28/2/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/28/2/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2A_17TNK_20180828_2_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-81.00023807092832, 44.271099025119], [-80.93751642123925, 44.259677305045635], [-80.52407679905751, 44.16438417573828], [-80.01027367117105, 44.16108816129103], [-79.61026518678112, 45.145372121660685], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.00024171761814, 44.16108816129103, -79.61026518678112, 45.153828248771845]
# Datetime: 2018-08-28 16:30:55.302000+00:00
# cloud cover: 57.777601
# Properties:
#   <created>: 2024-02-07T07:39:41.081Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 57.777601
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:sun_azimuth>: 158.512722300223
#   <view:sun_elevation>: 53.1810431798555
#   <s2:degraded_msi_data_percentage>: 0.0249
#   <s2:nodata_pixel_percentage>: 15.882973
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.105057
#   <s2:cloud_shadow_percentage>: 0.375353
#   <s2:vegetation_percentage>: 16.988856
#   <s2:not_vegetated_percentage>: 0.693959
#   <s2:water_percentage>: 23.860823
#   <s2:unclassified_percentage>: 0.198352
#   <s2:medium_proba_clouds_percentage>: 19.081475
#   <s2:high_proba_clouds_percentage>: 9.201779
#   <s2:thin_cirrus_percentage>: 29.494348
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.00
#   <s2:product_uri>: S2A_MSIL2A_20180828T161901_N0500_R040_T17TNK_20230719T051128.SAFE
#   <s2:generation_time>: 2023-07-19T05:11:28.000000Z
#   <s2:datatake_id>: GS2A_20180828T161901_016625_N05.00
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_S2RP_20230719T051128_S20180828T162203_N05.00
#   <s2:granule_id>: S2A_OPER_MSI_L2A_TL_S2RP_20230719T051128_A016625_T17TNK_N05.00
#   <s2:reflectance_conversion_factor>: 0.978959625509504
#   <datetime>: 2018-08-28T16:30:55.302000Z
#   <s2:sequence>: 2
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2A_17TNK_20180828_2_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/01f16e4f55fec47f7977b766b8389765
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.1'}
#   <updated>: 2024-02-07T07:39:41.081Z
#   <proj:code>: EPSG:32617
#   <sza>: 36.8189568201445
#   <saa>: 158.512722300223
#   <vza>: 8.25727571900506
#   <vaa>: 286.003368833458
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 340B
# Dimensions:      (y: 2, x: 3)
# Coordinates:
#   * y            (y) float64 16B -3.838e+05 -3.838e+05
#   * x            (x) float64 24B 1.187e+06 1.187e+06 1.187e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2018-08-28T16:30:55.302000
# Data variables:
#     blue         (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     green        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     red          (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge1     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge2     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge3     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     nir08        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     swir16       (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     swir22       (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     scl          (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     date         (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     score        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score']
# <_get_tile_regions> 0 region(s) matched for tile tile_17TNK_SE (2018-08-01 – 2018-08-31)  [skipped: 1 date-mismatch, 0 out-of-bounds]
# <export_mosaic> tiles mode: no matching regions found for this tile/time window — skipping export.
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.70 minutes >>>>>>
# File 'E:\TestingLEAF\kiyo_30m\log_44a7ee5b-d7f1-4816-aadd-a81863804bcf.out' does not exist.
# Directory 'E:\TestingLEAF\kiyo_30m\dask_spill_44a7ee5b-d7f1-4816-aadd-a81863804bcf' and its contents have been deleted.
# <MosaicProduction> Processing tile_17TNK_SE | time window: 2019-08-01 / 2019-08-31
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': (((-80.2871254773415, 44.3529366809224), (-80.2864858239462, 44.353000698271), (-80.2865353205907, 44.353111910870595), (-80.2873442759749, 44.353111910870595), (-80.2873442759749, 44.35292363260223), (-80.2871254773415, 44.3529366809224)),)}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.03 minutes
#
# <one_mosaic> A total of 24 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/23/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/23/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/23/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/23/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/23/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/23/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/23/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/23/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/23/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/23/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/23/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/23/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/23/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/23/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/23/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/23/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2A_17TNK_20190823_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-79.6072133297161, 45.14533493784957], [-80.00752265936363, 44.16106429312094], [-81.00023764531663, 44.16537549832127], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.00024171761814, 44.16106429312094, -79.6072133297161, 45.153828248771845]
# Datetime: 2019-08-23 16:30:59.142000+00:00
# cloud cover: 14.817979
# Properties:
#   <created>: 2022-11-03T15:59:52.407Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 14.817979
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:sun_azimuth>: 157.099192969258
#   <view:sun_elevation>: 54.8364204422795
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 13.871619
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.306974
#   <s2:cloud_shadow_percentage>: 1.828055
#   <s2:vegetation_percentage>: 32.897553
#   <s2:not_vegetated_percentage>: 2.835009
#   <s2:water_percentage>: 44.710112
#   <s2:unclassified_percentage>: 2.566502
#   <s2:medium_proba_clouds_percentage>: 2.872637
#   <s2:high_proba_clouds_percentage>: 10.41821
#   <s2:thin_cirrus_percentage>: 1.527132
#   <s2:snow_ice_percentage>: 0.037817
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 02.13
#   <s2:product_uri>: S2A_MSIL2A_20190823T161901_N0213_R040_T17TNK_20190823T203526.SAFE
#   <s2:generation_time>: 2019-08-23T20:35:26.000000Z
#   <s2:datatake_id>: GS2A_20190823T161901_021773_N02.13
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_MTI__20190823T203526_S20190823T162521_N02.13
#   <s2:granule_id>: S2A_OPER_MSI_L2A_TL_MTI__20190823T203526_A021773_T17TNK_N02.13
#   <s2:reflectance_conversion_factor>: 0.976779042855307
#   <datetime>: 2019-08-23T16:30:59.142000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2A_17TNK_20190823_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/4a6babb0162321e78bbcd0b547aa4aa0
#   <earthsearch:boa_offset_applied>: False
#   <processing:software>: {'sentinel2-to-stac': '0.1.0'}
#   <updated>: 2022-11-08T09:39:10.502Z
#   <proj:code>: EPSG:32617
#   <sza>: 35.1635795577205
#   <saa>: 157.099192969258
#   <vza>: 8.19083802364553
#   <vaa>: 286.049664800876
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 340B
# Dimensions:      (y: 2, x: 3)
# Coordinates:
#   * y            (y) float64 16B -3.838e+05 -3.838e+05
#   * x            (x) float64 24B 1.187e+06 1.187e+06 1.187e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2019-08-23T16:30:59.142000
# Data variables:
#     blue         (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     green        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     red          (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge1     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge2     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge3     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     nir08        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     swir16       (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     swir22       (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     scl          (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     date         (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     score        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score']
# <_get_tile_regions> 0 region(s) matched for tile tile_17TNK_SE (2019-08-01 – 2019-08-31)  [skipped: 1 date-mismatch, 0 out-of-bounds]
# <export_mosaic> tiles mode: no matching regions found for this tile/time window — skipping export.
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.70 minutes >>>>>>
# File 'E:\TestingLEAF\kiyo_30m\log_f93678db-79de-49d0-8d1c-692b301a6b76.out' does not exist.
# Directory 'E:\TestingLEAF\kiyo_30m\dask_spill_f93678db-79de-49d0-8d1c-692b301a6b76' and its contents have been deleted.
