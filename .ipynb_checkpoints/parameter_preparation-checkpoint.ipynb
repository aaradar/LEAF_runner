# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
from pathlib import Path

project_root = Path.cwd()
sys.path.insert(0, str(project_root))

from prepare_params import prepare_production_params

print("Modules imported successfully")
print(f"Current working directory: {os.getcwd()}")


kml = "Sample Points\AfforestationSItesFixed.kml"
shp = "Sample Points\FieldPoints32_2018.shp"
tmx = "TMX\TML_pipeline_100mbuffer.kml"
cbc = "Sample Points\ColdwaterBCregion.kml"

print(kml)
print(shp)
print(tmx)
print(cbc)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Modules imported successfully
# Current working directory: C:\Users\aradar\LEAF Files\LEAF_runner
# Sample Points\AfforestationSItesFixed.kml
# Sample Points\FieldPoints32_2018.shp
# TMX\TML_pipeline_100mbuffer.kml
# Sample Points\ColdwaterBCregion.kml

# %%
# TEMPLATE 1: Single Year Monthly Mosaics
# Use Case: Generate monthly mosaics for specific months in one year
# Example: Summer months (June, July, August) of 2023
# Customize these parameters as needed:

ProdParams = {
    # ============ REQUIRED PARAMETERS ============
    'sensor': 'S2_SR',                    # Sensor type
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'nbYears': -1,            # positive int for annual product, or negative int for monthly product
    #'year': 2023,                          # CHANGE THIS: Year to process
    #'months': [8,9,10],                   # CHANGE THIS: Months to process (1-12)
    
    
    # ============ REGION PARAMETERS ============
    'regions':kml,  # CHANGE THIS: Path to your KML/SHP file
    'file_variables': ['TARGET_FID', 'AsssD_1', 'AsssD_2'], # CHANGE THIS: id, start_date, end_date (None for dates if they don't exist)
    #'file_variables': ['id', 'begin', 'end'],
    #'file_variables': ['system:index', None, None],
    'regions_start_index': 0,              # CHANGE THIS: Start at this region index
    'regions_end_index': 999,             # CHANGE THIS: End at this index (None = all)
    
    # ============ BUFFER PARAMETERS ============
    #'spatial_buffer_m': 0,             # UNCOMMENT & CHANGE: Buffer in meters around regions
    #'temporal_buffer': [[50, 90], [-10, 10], [100, 130]],          # UNCOMMENT & CHANGE: [days_before, days_after]
    'temporal_buffer': [["2020-05-01", "2020-05-31"]], #, ["2020-08-01", "2020-08-31"]],
    #'num_years': 3,
    
    
    # ============ OUTPUT PARAMETERS ============
    'resolution': 10,                      # Resolution in meters
    'projection': 'EPSG:3979',             # Coordinate projection
    'prod_names': ['fCOVER'],    #['LAI', 'FCOVER', 'fAPAR', 'Albedo'], 
    #'bands': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'],
    'out_folder': 'E:/S2_mosaics_runner_2026/afforestation/S2_may_2020_1000_regions_10m',
    'out_datatype': 'int16'
}

CompParams = {
  "number_workers":10,     
  "debug"       : True,
  "entire_tile" : False, 
  "nodes"       : 1,
  "node_memory" : "50G",
  'chunk_size': {'x': 512, 'y': 512}
}


print("\nconfigured")
# Out:
#   Cell In[14], line 37
#     }
#     ^
# SyntaxError: closing parenthesis '}' does not match opening parenthesis '[' on line 26

# %%
# Run the parameter preparation
result = prepare_production_params(ProdParams, CompParams)
'''
if result:
    print("\n" + "="*80)
    print(" SUCCESS - Parameters validated and ready!")
    print("="*80)
    print(f"\n Summary:")
    print(f"  Regions: {len(result['ProdParams']['regions'])}")
    print(f"  Time windows: {len(result['ProdParams']['start_dates'])}")
    print(f"  Total tasks: {len(result['ProdParams']['regions']) * len(result['ProdParams']['start_dates'])}")
    print(f"  Output folder: {result['ProdParams']['out_folder']}")
    print(f"\n Processing log saved to: {result['ProdParams']['out_folder']}/polygon_processing_log.csv")
    print("\n" + "="*80)
    print("Next step: Call Production.py with the validated parameters")
    print("="*80)
else:
    print("\n" + "="*80)
    print(" FAILED - Parameter validation failed")
    print("="*80)
    print("Check the error messages above for details.") '''
# Out:
# ================================================================================
# PARAMETER PREPARATION
# ================================================================================
#
# Step 1/4: Validating input parameters...
# ✓ All parameters valid
#
# Step 2/4: Loading regions from files...
# <handle_regions_from_file> Detected file-based regions input: Sample Points\ColdwaterBCregion.kml
# <handle_regions_from_file> Loading regions...
# <handle_regions_from_file> Override mode: Setting all regions to 2 date window(s)
# <handle_regions_from_file> Region region0: 2 windows [['2022-05-01', '2022-05-31'], ['2020-08-01', '2020-08-31']]
# <handle_regions_from_file> Loaded 1 regions from file
#
# Step 3/4: Skipping temporal window generation (no year/months or start_dates/end_dates found)
#            Region-specific dates from file will be used if available.
#
# Step 4/4: Validating polygons...
#
# ================================================================================
# POLYGON VALIDATION AND FILTERING
# ================================================================================
#
# Polygon validation log saved to: E:/S2_mosaics_runner_2026/Coldwater20/S2_2025_2020_mosaic3_10m\polygon_processing_log.csv
#
# Validation Summary:
#    Total regions: 1
#    Valid for processing: 1
#    Skipped (zero area): 0
#
# Proceeding with 1 valid region(s) out of 1 total
# ================================================================================
#
#
# ================================================================================
# PARAMETER PREPARATION COMPLETE
# ================================================================================
# Regions: 1
# Start Time windows: {'region0': ['2022-05-01', '2020-08-01']}
# End Time windows: {'region0': ['2022-05-31', '2020-08-31']}
# ================================================================================
# '\nif result:\n    print("\n" + "="*80)\n    print(" SUCCESS - Parameters validated and ready!")\n    print("="*80)\n    print(f"\n Summary:")\n    print(f"  Regions: {len(result[\'ProdParams\'][\'regions\'])}")\n    print(f"  Time windows: {len(result[\'ProdParams\'][\'start_dates\'])}")\n    print(f"  Total tasks: {len(result[\'ProdParams\'][\'regions\']) * len(result[\'ProdParams\'][\'start_dates\'])}")\n    print(f"  Output folder: {result[\'ProdParams\'][\'out_folder\']}")\n    print(f"\n Processing log saved to: {result[\'ProdParams\'][\'out_folder\']}/polygon_processing_log.csv")\n    print("\n" + "="*80)\n    print("Next step: Call Production.py with the validated parameters")\n    print("="*80)\nelse:\n    print("\n" + "="*80)\n    print(" FAILED - Parameter validation failed")\n    print("="*80)\n    print("Check the error messages above for details.") '

# %%
# View processing log (if pandas is available)
try:
    import pandas as pd
    if result and result['processing_log'] is not None:
        print("\n Processing Log Preview:")
        print("=" * 80)
        display(result['processing_log'].head(10))
        print(f"\nTotal entries: {len(result['processing_log'])}")
except ImportError:
    print("pandas not available - install it to view the processing log in this cell")
    print("You can still view the CSV file directly in the output folder")
# Out:
#  Processing Log Preview:
# ================================================================================
#   region_id      area_m2  will_process status skip_reason
# 0   region0  37913071.11          True  VALID         N/A
# Total entries: 1

# %%
import os
import sys
import geopandas as gpd

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

print(ProdParams)
# Out:
# {'sensor': 'S2_SR', 'unit': 2, 'nbYears': -1, 'regions': {'region0': {'type': 'Polygon', 'coordinates': [[[-120.83748713702258, 50.040446746261715], [-120.73897660873169, 50.040446746261715], [-120.73897660873169, 50.08882798523277], [-120.83748713702258, 50.08882798523277], [-120.83748713702258, 50.040446746261715]]]}}, 'file_variables': ['system:index', None, None], 'regions_start_index': 0, 'regions_end_index': None, 'temporal_buffer': [['2022-05-01', '2022-05-31'], ['2020-08-01', '2020-08-31']], 'resolution': 10, 'projection': 'EPSG:3979', 'prod_names': ['mosaic'], 'out_folder': 'E:/S2_mosaics_runner_2026/Coldwater20/S2_2025_2020_mosaic3_10m', 'out_datatype': 'int16', 'region_start_dates': {'region0': ['2022-05-01', '2020-08-01']}, 'region_end_dates': {'region0': ['2022-05-31', '2020-08-31']}}

# %%
main(ProdParams, CompParams)
# Out:
# <get_time_window> one of required keys is not exist to form time.
# <MosaicProduction> User defined input parameters:
# sensor: S2_SR
# unit: 2
# nbYears: -1
# regions: {'region0': {'type': 'Polygon', 'coordinates': [[[-120.83748713702258, 50.040446746261715], [-120.73897660873169, 50.040446746261715], [-120.73897660873169, 50.08882798523277], [-120.83748713702258, 50.08882798523277], [-120.83748713702258, 50.040446746261715]]]}}
# resolution: 10
# projection: EPSG:3979
# prod_names: ['mosaic']
# out_folder: E:/S2_mosaics_runner_2026/Coldwater20/S2_2025_2020_mosaic3_10m
# out_datatype: int16
# region_start_dates: {'region0': ['2022-05-01', '2020-08-01']}
# region_end_dates: {'region0': ['2022-05-31', '2020-08-31']}
# SsrData: {'NAME': 'S2_SR', 'SSR_CODE': 21, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], '10M_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'SIX_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'NoA_BANDS': ['red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'LEAF_BANDS': ['green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'GEE_NAME': 'COPERNICUS/S2_SR_HARMONIZED', 'CLOUD': 'CLOUDY_PIXEL_PERCENTAGE', 'SZA': 'view:sun_elevation', 'SAA': 'view:sun_azimuth', 'VZA': 'view:sun_elevation', 'VAA': 'view:sun_azimuth', 'BLU': 'blue', 'GRN': 'green', 'RED': 'red', 'NIR': 'nir08', 'SW1': 'swir16', 'SW2': 'swir22'}
# year: 2026
# out_location: drive
# IncludeAngles: False
# months: []
# tile_names: []
# cloud_cover: 80
# export_style: separate
# monthly: True
# current_time: 0
# scene_ID:
# current_region: region0
# Criteria: {'timeframe': 'None/None', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-120.83748713702258, 50.040446746261715], [-120.73897660873169, 50.040446746261715], [-120.73897660873169, 50.08882798523277], [-120.83748713702258, 50.08882798523277], [-120.83748713702258, 50.040446746261715]]]}, 'catalog': 'https://earth-search.aws.element84.com/v1', 'collection': ['sentinel-2-l2a'], 'bands': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl']}
# standardized: True
# number_workers: 10
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 50G
# chunk_size: {'x': 512, 'y': 512}
#
# <MosaicProduction> Using region-specific dates for region0
#   Start dates: ['2022-05-01', '2020-08-01']
#   End dates: ['2022-05-31', '2020-08-31']
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-120.83748713702258, 50.040446746261715], [-120.73897660873169, 50.040446746261715], [-120.73897660873169, 50.08882798523277], [-120.83748713702258, 50.08882798523277], [-120.83748713702258, 50.040446746261715]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.01 minutes
#
# <one_mosaic> A total of 5 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/10/U/FA/2022/5/25/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2022/5/25/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2022/5/25/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2022/5/25/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2022/5/25/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2022/5/25/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2022/5/25/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2022/5/25/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2022/5/25/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2022/5/25/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2022/5/25/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/10/U/FA/2022/5/25/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2022/5/25/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2022/5/25/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2022/5/25/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/10/U/FA/2022/5/25/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_10UFA_20220525_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-121.58863665342038, 50.54373001230752], [-120.04062857145159, 50.51466139257629], [-120.04948345489004, 50.37258241018982], [-120.45445262758166, 49.537747463231774], [-121.61727616803829, 49.557402491774354], [-121.58863665342038, 50.54373001230752]]]}
# Bounding Box: [-121.61727616803829, 49.537747463231774, -120.04062857145159, 50.54373001230752]
# Datetime: 2022-05-25 19:20:36.140000+00:00
# cloud cover: 66.732156
# Properties:
#   <created>: 2022-11-06T11:56:46.033Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 66.732156
#   <mgrs:utm_zone>: 10
#   <mgrs:latitude_band>: U
#   <mgrs:grid_square>: FA
#   <grid:code>: MGRS-10UFA
#   <view:sun_azimuth>: 161.252428654563
#   <view:sun_elevation>: 59.968939739213596
#   <s2:degraded_msi_data_percentage>: 0.022
#   <s2:nodata_pixel_percentage>: 9.921049
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 2.302186
#   <s2:cloud_shadow_percentage>: 2.488684
#   <s2:vegetation_percentage>: 11.324202
#   <s2:not_vegetated_percentage>: 11.132754
#   <s2:water_percentage>: 0.346749
#   <s2:unclassified_percentage>: 4.637257
#   <s2:medium_proba_clouds_percentage>: 16.447583
#   <s2:high_proba_clouds_percentage>: 33.224964
#   <s2:thin_cirrus_percentage>: 17.059611
#   <s2:snow_ice_percentage>: 1.036008
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 04.00
#   <s2:product_uri>: S2B_MSIL2A_20220525T190919_N0400_R056_T10UFA_20220525T222755.SAFE
#   <s2:generation_time>: 2022-05-25T22:27:55.000000Z
#   <s2:datatake_id>: GS2B_20220525T190919_027252_N04.00
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_2BPS_20220525T222755_S20220525T192017_N04.00
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_2BPS_20220525T222755_A027252_T10UFA_N04.00
#   <s2:reflectance_conversion_factor>: 0.976132415052025
#   <datetime>: 2022-05-25T19:20:36.140000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/10/U/FA/2022/5/S2B_10UFA_20220525_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/b07be077d6d45dcd04b73840384eb126
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.0'}
#   <updated>: 2022-11-06T11:56:46.033Z
#   <proj:code>: EPSG:32610
#   <sza>: 30.031060260786404
#   <saa>: 161.252428654563
#   <vza>: 8.02355689508259
#   <vaa>: 286.26595778903
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 32MB
# Dimensions:      (y: 770, x: 858)
# Coordinates:
#   * y            (y) float64 6kB 4.897e+05 4.897e+05 ... 4.821e+05 4.821e+05
#   * x            (x) float64 7kB -1.793e+06 -1.793e+06 ... -1.785e+06 -1.785e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2022-05-25T19:20:36.140000
# Data variables:
#     blue         (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     green        (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     red          (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     rededge1     (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     rededge2     (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     rededge3     (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     nir08        (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     swir16       (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     swir22       (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     scl          (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     date         (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     score        (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['10UFA']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\aradar\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\distributed\client.py:3164: UserWarning: Sending large graph of size 10.92 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score']
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.89 minutes >>>>>>
# File 'E:\S2_mosaics_runner_2026\Coldwater20\S2_2025_2020_mosaic3_10m\log_2ecac609-ad51-425a-ab4d-34095519fc5c.out' does not exist.
# Directory 'E:\S2_mosaics_runner_2026\Coldwater20\S2_2025_2020_mosaic3_10m\dask_spill_2ecac609-ad51-425a-ab4d-34095519fc5c' and its contents have been deleted.
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-120.83748713702258, 50.040446746261715], [-120.73897660873169, 50.040446746261715], [-120.73897660873169, 50.08882798523277], [-120.83748713702258, 50.08882798523277], [-120.83748713702258, 50.040446746261715]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.03 minutes
#
# <one_mosaic> A total of 20 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/10/U/FA/2020/8/18/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2020/8/18/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2020/8/18/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2020/8/18/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2020/8/18/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2020/8/18/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2020/8/18/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2020/8/18/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2020/8/18/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2020/8/18/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2020/8/18/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/10/U/FA/2020/8/18/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2020/8/18/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2020/8/18/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/10/U/FA/2020/8/18/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/10/U/FA/2020/8/18/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2A_10UFA_20200818_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-121.58863665342038, 50.54373001230752], [-120.04062857145159, 50.51466139257629], [-120.0496850082892, 50.369335055998086], [-120.14824193779609, 50.16482159327186], [-120.30579296093022, 49.84785766499275], [-120.453813306937, 49.53674394218606], [-121.61730156031695, 49.55650327842931], [-121.58863665342038, 50.54373001230752]]]}
# Bounding Box: [-121.61730156031695, 49.53674394218606, -120.04062857145159, 50.54373001230752]
# Datetime: 2020-08-18 19:20:41.759000+00:00
# cloud cover: 1.899982
# Properties:
#   <created>: 2022-11-06T11:17:43.109Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 1.899982
#   <mgrs:utm_zone>: 10
#   <mgrs:latitude_band>: U
#   <mgrs:grid_square>: FA
#   <grid:code>: MGRS-10UFA
#   <view:sun_azimuth>: 161.669728102033
#   <view:sun_elevation>: 51.521758362662
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 9.841066
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.813031
#   <s2:cloud_shadow_percentage>: 1.302775
#   <s2:vegetation_percentage>: 84.806699
#   <s2:not_vegetated_percentage>: 9.144008
#   <s2:water_percentage>: 0.970579
#   <s2:unclassified_percentage>: 1.050589
#   <s2:medium_proba_clouds_percentage>: 0.413403
#   <s2:high_proba_clouds_percentage>: 1.27654
#   <s2:thin_cirrus_percentage>: 0.210039
#   <s2:snow_ice_percentage>: 0.012339
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 02.14
#   <s2:product_uri>: S2A_MSIL2A_20200818T190921_N0214_R056_T10UFA_20200818T215854.SAFE
#   <s2:generation_time>: 2020-08-18T21:58:54.000000Z
#   <s2:datatake_id>: GS2A_20200818T190921_026937_N02.14
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_VGS1_20200818T215854_S20200818T191444_N02.14
#   <s2:granule_id>: S2A_OPER_MSI_L2A_TL_VGS1_20200818T215854_A026937_T10UFA_N02.14
#   <s2:reflectance_conversion_factor>: 0.975196193189691
#   <datetime>: 2020-08-18T19:20:41.759000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/10/U/FA/2020/8/S2A_10UFA_20200818_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/fd76239dfbe446266f48d0cb9057e1b3
#   <earthsearch:boa_offset_applied>: False
#   <processing:software>: {'sentinel2-to-stac': '0.1.0'}
#   <updated>: 2022-11-06T11:17:43.109Z
#   <proj:code>: EPSG:32610
#   <sza>: 38.478241637338
#   <saa>: 161.669728102033
#   <vza>: 8.02058211244013
#   <vaa>: 287.162323431312
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 32MB
# Dimensions:      (y: 770, x: 858)
# Coordinates:
#   * y            (y) float64 6kB 4.897e+05 4.897e+05 ... 4.821e+05 4.821e+05
#   * x            (x) float64 7kB -1.793e+06 -1.793e+06 ... -1.785e+06 -1.785e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2020-08-18T19:20:41.759000
# Data variables:
#     blue         (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     green        (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     red          (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     rededge1     (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     rededge2     (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     rededge3     (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     nir08        (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     swir16       (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     swir22       (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     scl          (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     date         (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     score        (y, x) float32 3MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['10UFA']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\aradar\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\distributed\client.py:3164: UserWarning: Sending large graph of size 14.75 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score']
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   1.44 minutes >>>>>>
# File 'E:\S2_mosaics_runner_2026\Coldwater20\S2_2025_2020_mosaic3_10m\log_806c710b-1898-47d8-92b0-2f224a7e85c9.out' does not exist.
# Directory 'E:\S2_mosaics_runner_2026\Coldwater20\S2_2025_2020_mosaic3_10m\dask_spill_806c710b-1898-47d8-92b0-2f224a7e85c9' and its contents have been deleted.
