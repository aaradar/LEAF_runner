# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
from pathlib import Path

project_root = Path.cwd()
sys.path.insert(0, str(project_root))

from prepare_params import prepare_production_params

print("Modules imported successfully")
print(f"Current working directory: {os.getcwd()}")


kml = "Sample Points\AfforestationSItesFixed.kml"
shp = "Sample Points\FieldPoints32_2018.shp"
tmx = "Sample Points\TMX\TML_pipeline_100mbuffer.kml"
cbc = "Sample Points\ColdwaterBCregion.kml"
ls_mgrs = "S2A_OPER_GIP_TILPAR_MPC.kml"
s2_mgrs = "sentinel-2-grid.parquet"
print(kml)
print(shp)
print(tmx)
print(cbc)
# Out:
# Modules imported successfully
# Current working directory: C:\Users\aradar\LEAF Files\LEAF_runner
# Sample Points\AfforestationSItesFixed.kml
# Sample Points\FieldPoints32_2018.shp
# Sample Points\TMX\TML_pipeline_100mbuffer.kml
# Sample Points\ColdwaterBCregion.kml

# %%
# Use Case: Generate monthly mosaics
# Customize these parameters as needed:

ProdParams = {
    # ============ REQUIRED PARAMETERS ============
    'sensor': 'S2_SR',                    # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR', 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'nbYears': -1,            # positive int for annual product, or negative int for monthly product
    #'year': 2023,                          # CHANGE THIS: Year to process
    #'months': [8,9,10],                   # CHANGE THIS: Months to process (1-12)
    
    
    # ============ REGION PARAMETERS ============
    'regions': kml,  # CHANGE THIS: Path to your KML/SHP file
    's2_grid_path': s2_mgrs,
    'mode': 'regions', #regions or tiles
    'subdivide_tiles': False, # Whether to subdivide tiles into smaller regions (only applicable if mode is 'tiles')
    'file_variables': ['TARGET_FID', 'AsssD_1', 'AsssD_2'], # CHANGE THIS: id, start_date, end_date (None for dates if they don't exist)
    #'file_variables': ['id', 'begin', 'end'],
    #'file_variables': ['system:index', None, None],
    'regions_start_index': 0,              # CHANGE THIS: Start at this region index
    'regions_end_index': 5,             # CHANGE THIS: End at this index (None = all)
    
    # ============ BUFFER PARAMETERS ============
    #'spatial_buffer_m': -10,             # UNCOMMENT & CHANGE: Buffer in meters around regions
    #'temporal_buffer': [[50, 90], [-10, 10]],          # UNCOMMENT & CHANGE: [days_before, days_after]
    'temporal_buffer': [["2025-08-01", "2025-08-31"]],
    #'num_years': 3,
    
    
    # ============ OUTPUT PARAMETERS ============
    'resolution': 10,                      # Resolution in meters
    'projection': 'EPSG:3979',             # Coordinate projection
    'IncludeAngles': False,
    'prod_names': ['mosaic'],    #['mosaic', 'LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'out_folder': 'E:\\User_Stories\\new_env_10m',
    'out_datatype': 'int16',

    # ============ CSV OUTPUT (NEW) ============
    'output_type': 'geotiff',        # <-- switch from GeoTIFF to CSV
    'csv_scale': 10,             # optional: same as resolution, explicit here for clarity
    'csv_dropNulls': True,       # optional: skip masked/nodata pixels (mirrors GEE dropNulls)
    'csv_max_pixels': 100_000,   # optional: lower this first for a quick test
}

CompParams = {
  "number_workers":10,    
  "debug"       : True,
  "entire_tile" : False,
  "nodes"       : 1,
  "node_memory" : "50G",
  'chunk_size': {'x': 512, 'y': 512}
}


print("\nconfigured")
# Out:
# configured

# %%
# Run the parameter preparation
result = prepare_production_params(ProdParams, CompParams)
'''
if result:
    print("\n" + "="*80)
    print(" SUCCESS - Parameters validated and ready!")
    print("="*80)
    print(f"\n Summary:")
    print(f"  Regions: {len(result['ProdParams']['regions'])}")
    print(f"  Time windows: {len(result['ProdParams']['start_dates'])}")
    print(f"  Total tasks: {len(result['ProdParams']['regions']) * len(result['ProdParams']['start_dates'])}")
    print(f"  Output folder: {result['ProdParams']['out_folder']}")
    print(f"\n Processing log saved to: {result['ProdParams']['out_folder']}/polygon_processing_log.csv")
    print("\n" + "="*80)
    print("Next step: Call Production.py with the validated parameters")
    print("="*80)
else:
    print("\n" + "="*80)
    print(" FAILED - Parameter validation failed")
    print("="*80)
    print("Check the error messages above for details.") '''
# Out:
# ================================================================================
# PARAMETER PREPARATION
# ================================================================================
#
# Step 1/4: Validating input parameters...
# ✓ All parameters valid
#
# Step 2/4: Loading regions from files...
# <handle_regions_from_file> Detected file-based regions input: Sample Points\AfforestationSItesFixed.kml
# <handle_regions_from_file> Loading regions...
# <handle_regions_from_file> Override mode: Setting all regions to 1 date window(s)
# <handle_regions_from_file> Region region0: 1 windows [['2025-08-01', '2025-08-31']]
# <handle_regions_from_file> Region region1: 1 windows [['2025-08-01', '2025-08-31']]
# <handle_regions_from_file> Region region2: 1 windows [['2025-08-01', '2025-08-31']]
# <handle_regions_from_file> Region region3: 1 windows [['2025-08-01', '2025-08-31']]
# <handle_regions_from_file> Region region4: 1 windows [['2025-08-01', '2025-08-31']]
# <handle_regions_from_file> Region region5: 1 windows [['2025-08-01', '2025-08-31']]
# <handle_regions_from_file> Region region0: 1 windows [['2025-08-01', '2025-08-31']]
# <handle_regions_from_file> Region region1: 1 windows [['2025-08-01', '2025-08-31']]
# <handle_regions_from_file> Region region2: 1 windows [['2025-08-01', '2025-08-31']]
# <handle_regions_from_file> Region region3: 1 windows [['2025-08-01', '2025-08-31']]
# <handle_regions_from_file> Region region4: 1 windows [['2025-08-01', '2025-08-31']]
# <handle_regions_from_file> Region region5: 1 windows [['2025-08-01', '2025-08-31']]
# <handle_regions_from_file> Loaded 6 regions from file
#
# Step 3/4: Skipping temporal window generation (no year/months or start_dates/end_dates found)
#            Region-specific dates from file will be used if available.
#
# Step 4/4: Validating polygons...
#
# ================================================================================
# POLYGON VALIDATION AND FILTERING
# ================================================================================
#
# Polygon validation log saved to: E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\polygon_processing_log.csv
#
# Validation Summary:
#    Total regions: 6
#    Valid for processing: 6
#    Skipped (zero area): 0
#
# Proceeding with 6 valid region(s) out of 6 total
# ================================================================================
#
#
# ================================================================================
# PARAMETER PREPARATION COMPLETE
# ================================================================================
# Regions: 6
# Start Time windows: {'region0': ['2025-08-01'], 'region1': ['2025-08-01'], 'region2': ['2025-08-01'], 'region3': ['2025-08-01'], 'region4': ['2025-08-01'], 'region5': ['2025-08-01']}
# End Time windows: {'region0': ['2025-08-31'], 'region1': ['2025-08-31'], 'region2': ['2025-08-31'], 'region3': ['2025-08-31'], 'region4': ['2025-08-31'], 'region5': ['2025-08-31']}
# ================================================================================
#
#
# <prepare_production_params> Added properties to regions:
# {
#   "sensor": "S2_SR",
#   "unit": 2,
#   "nbYears": -1,
#   "s2_grid_path": "sentinel-2-grid.parquet",
#   "mode": "regions",
#   "subdivide_tiles": false,
#   "file_variables": [
#     "TARGET_FID",
#     "AsssD_1",
#     "AsssD_2"
#   ],
#   "regions_start_index": 0,
#   "regions_end_index": 5,
#   "temporal_buffer": [
#     [
#       "2025-08-01",
#       "2025-08-31"
#     ]
#   ],
#   "resolution": 10,
#   "projection": "EPSG:3979",
#   "IncludeAngles": false,
#   "prod_names": [
#     "mosaic"
#   ],
#   "out_folder": "E:\\S2_mosaics_runner_2026\\test_10m\\5_regions_10m",
#   "out_datatype": "int16",
#   "output_type": "geotiff",
#   "csv_scale": 10,
#   "csv_dropNulls": true,
#   "csv_max_pixels": 100000,
#   "regions_ref": {
#     "region0": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -81.0143277776703,
#             44.792849553362
#           ],
#           [
#             -81.013046437586,
#             44.7928810241213
#           ],
#           [
#             -81.0130828894072,
#             44.7920357810087
#           ],
#           [
#             -81.0134196694422,
#             44.7918539873173
#           ],
#           [
#             -81.013283176937,
#             44.7913976888643
#           ],
#           [
#             -81.0142442205963,
#             44.7913333551658
#           ],
#           [
#             -81.0143277776703,
#             44.792849553362
#           ]
#         ]
#       ]
#     },
#     "region1": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -80.2866384110016,
#             44.3533435417762
#           ],
#           [
#             -80.2864858239462,
#             44.353000698271
#           ],
#           [
#             -80.2868313289172,
#             44.3529866183925
#           ],
#           [
#             -80.2871254773415,
#             44.3529366809224
#           ],
#           [
#             -80.2874977225433,
#             44.3529180592246
#           ],
#           [
#             -80.2876405698119,
#             44.3529059627622
#           ],
#           [
#             -80.2879206306362,
#             44.3528989373857
#           ],
#           [
#             -80.2880395541161,
#             44.3528827993289
#           ],
#           [
#             -80.2880782566738,
#             44.352880279965
#           ],
#           [
#             -80.2882027280036,
#             44.353154957613
#           ],
#           [
#             -80.288085927134,
#             44.3531261618167
#           ],
#           [
#             -80.287951530048,
#             44.3531125098555
#           ],
#           [
#             -80.2878832692439,
#             44.3531281508011
#           ],
#           [
#             -80.287738989293,
#             44.3532215337679
#           ],
#           [
#             -80.2877249039523,
#             44.3532644472593
#           ],
#           [
#             -80.287558824637,
#             44.3533088522111
#           ],
#           [
#             -80.2874518606506,
#             44.3533270111586
#           ],
#           [
#             -80.2871598357525,
#             44.3533320137857
#           ],
#           [
#             -80.2866384110016,
#             44.3533435417762
#           ]
#         ]
#       ]
#     },
#     "region2": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -80.529638877948,
#             44.5242213601121
#           ],
#           [
#             -80.5236686736853,
#             44.5252976281762
#           ],
#           [
#             -80.5234042910143,
#             44.5252538220711
#           ],
#           [
#             -80.5231938083608,
#             44.5249653160984
#           ],
#           [
#             -80.5230220292666,
#             44.5247919216231
#           ],
#           [
#             -80.5294731056627,
#             44.5235598453566
#           ],
#           [
#             -80.529638877948,
#             44.5242213601121
#           ]
#         ]
#       ]
#     },
#     "region3": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -80.3772169808165,
#             44.3239559238229
#           ],
#           [
#             -80.3778062318809,
#             44.3239281559541
#           ],
#           [
#             -80.3783858830901,
#             44.3257096706257
#           ],
#           [
#             -80.3764241776696,
#             44.3259233842728
#           ],
#           [
#             -80.376232840644,
#             44.3258912372486
#           ],
#           [
#             -80.3761778827904,
#             44.3258276760676
#           ],
#           [
#             -80.3757712939805,
#             44.325759362561
#           ],
#           [
#             -80.3752059343744,
#             44.3257911355417
#           ],
#           [
#             -80.3747978938721,
#             44.3239478686715
#           ],
#           [
#             -80.3765005174368,
#             44.3236001331235
#           ],
#           [
#             -80.3766048311268,
#             44.3237444227003
#           ],
#           [
#             -80.3766908273936,
#             44.3238675253118
#           ],
#           [
#             -80.3769060715396,
#             44.323903689341
#           ],
#           [
#             -80.3772169808165,
#             44.3239559238229
#           ]
#         ]
#       ]
#     },
#     "region4": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -80.4414758461818,
#             44.4468399119331
#           ],
#           [
#             -80.4399721805282,
#             44.4471867620164
#           ],
#           [
#             -80.4395657798354,
#             44.4447820571645
#           ],
#           [
#             -80.44099741403,
#             44.4444232095963
#           ],
#           [
#             -80.4414758461818,
#             44.4468399119331
#           ]
#         ]
#       ]
#     },
#     "region5": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -80.4421816733383,
#             44.4466135137253
#           ],
#           [
#             -80.4416845003799,
#             44.4468203876096
#           ],
#           [
#             -80.4411932481774,
#             44.444365318568
#           ],
#           [
#             -80.4415073722911,
#             44.4442547096037
#           ],
#           [
#             -80.4421816733383,
#             44.4466135137253
#           ]
#         ]
#       ]
#     }
#   },
#   "region_start_dates_ref": {
#     "region0": [
#       "2025-08-01"
#     ],
#     "region1": [
#       "2025-08-01"
#     ],
#     "region2": [
#       "2025-08-01"
#     ],
#     "region3": [
#       "2025-08-01"
#     ],
#     "region4": [
#       "2025-08-01"
#     ],
#     "region5": [
#       "2025-08-01"
#     ]
#   },
#   "region_end_dates_ref": {
#     "region0": [
#       "2025-08-31"
#     ],
#     "region1": [
#       "2025-08-31"
#     ],
#     "region2": [
#       "2025-08-31"
#     ],
#     "region3": [
#       "2025-08-31"
#     ],
#     "region4": [
#       "2025-08-31"
#     ],
#     "region5": [
#       "2025-08-31"
#     ]
#   }
# }
# '\nif result:\n    print("\n" + "="*80)\n    print(" SUCCESS - Parameters validated and ready!")\n    print("="*80)\n    print(f"\n Summary:")\n    print(f"  Regions: {len(result[\'ProdParams\'][\'regions\'])}")\n    print(f"  Time windows: {len(result[\'ProdParams\'][\'start_dates\'])}")\n    print(f"  Total tasks: {len(result[\'ProdParams\'][\'regions\']) * len(result[\'ProdParams\'][\'start_dates\'])}")\n    print(f"  Output folder: {result[\'ProdParams\'][\'out_folder\']}")\n    print(f"\n Processing log saved to: {result[\'ProdParams\'][\'out_folder\']}/polygon_processing_log.csv")\n    print("\n" + "="*80)\n    print("Next step: Call Production.py with the validated parameters")\n    print("="*80)\nelse:\n    print("\n" + "="*80)\n    print(" FAILED - Parameter validation failed")\n    print("="*80)\n    print("Check the error messages above for details.") '

# %%
# View processing log (if pandas is available)
try:
    import pandas as pd
    if result and result['processing_log'] is not None:
        print("\n Processing Log Preview:")
        print("=" * 80)
        display(result['processing_log'].head(10))
        print(f"\nTotal entries: {len(result['processing_log'])}")
except ImportError:
    print("pandas not available - install it to view the processing log in this cell")
    print("You can still view the CSV file directly in the output folder")
# Out:
#  Processing Log Preview:
# ================================================================================
#   region_id   area_m2  will_process status skip_reason
# 0   region0  14612.87          True  VALID         N/A
# 1   region1   4831.99          True  VALID         N/A
# 2   region2  36573.20          True  VALID         N/A
# 3   region3  54608.59          True  VALID         N/A
# 4   region4  32682.04          True  VALID         N/A
# 5   region5   9456.33          True  VALID         N/A
# Total entries: 6

# %%
import os
import sys
import geopandas as gpd

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

print(ProdParams)
# Out:
# {'sensor': 'S2_SR', 'unit': 2, 'nbYears': -1, 'regions': {'region0': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}, 'region2': {'type': 'Polygon', 'coordinates': [[[-80.529638877948, 44.5242213601121], [-80.5236686736853, 44.5252976281762], [-80.5234042910143, 44.5252538220711], [-80.5231938083608, 44.5249653160984], [-80.5230220292666, 44.5247919216231], [-80.5294731056627, 44.5235598453566], [-80.529638877948, 44.5242213601121]]]}, 'region3': {'type': 'Polygon', 'coordinates': [[[-80.3772169808165, 44.3239559238229], [-80.3778062318809, 44.3239281559541], [-80.3783858830901, 44.3257096706257], [-80.3764241776696, 44.3259233842728], [-80.376232840644, 44.3258912372486], [-80.3761778827904, 44.3258276760676], [-80.3757712939805, 44.325759362561], [-80.3752059343744, 44.3257911355417], [-80.3747978938721, 44.3239478686715], [-80.3765005174368, 44.3236001331235], [-80.3766048311268, 44.3237444227003], [-80.3766908273936, 44.3238675253118], [-80.3769060715396, 44.323903689341], [-80.3772169808165, 44.3239559238229]]]}, 'region4': {'type': 'Polygon', 'coordinates': [[[-80.4414758461818, 44.4468399119331], [-80.4399721805282, 44.4471867620164], [-80.4395657798354, 44.4447820571645], [-80.44099741403, 44.4444232095963], [-80.4414758461818, 44.4468399119331]]]}, 'region5': {'type': 'Polygon', 'coordinates': [[[-80.4421816733383, 44.4466135137253], [-80.4416845003799, 44.4468203876096], [-80.4411932481774, 44.444365318568], [-80.4415073722911, 44.4442547096037], [-80.4421816733383, 44.4466135137253]]]}, 'properties': {'sensor': 'S2_SR', 'unit': 2, 'nbYears': -1, 's2_grid_path': 'sentinel-2-grid.parquet', 'mode': 'regions', 'subdivide_tiles': False, 'file_variables': ['TARGET_FID', 'AsssD_1', 'AsssD_2'], 'regions_start_index': 0, 'regions_end_index': 5, 'temporal_buffer': [['2025-08-01', '2025-08-31']], 'resolution': 10, 'projection': 'EPSG:3979', 'IncludeAngles': False, 'prod_names': ['mosaic'], 'out_folder': 'E:\\S2_mosaics_runner_2026\\test_10m\\5_regions_10m', 'out_datatype': 'int16', 'output_type': 'geotiff', 'csv_scale': 10, 'csv_dropNulls': True, 'csv_max_pixels': 100000, 'regions_ref': {'region0': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], ...

# %%
main(ProdParams, CompParams)
# Out:
# <MosaicProduction> Injected placeholder dates for standardization: 2025-08-01 / 2025-08-31
# <MosaicProduction> User defined input parameters:
# sensor: S2_SR
# unit: 2
# nbYears: -1
# regions: {'region0': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}, 'region2': {'type': 'Polygon', 'coordinates': [[[-80.529638877948, 44.5242213601121], [-80.5236686736853, 44.5252976281762], [-80.5234042910143, 44.5252538220711], [-80.5231938083608, 44.5249653160984], [-80.5230220292666, 44.5247919216231], [-80.5294731056627, 44.5235598453566], [-80.529638877948, 44.5242213601121]]]}, 'region3': {'type': 'Polygon', 'coordinates': [[[-80.3772169808165, 44.3239559238229], [-80.3778062318809, 44.3239281559541], [-80.3783858830901, 44.3257096706257], [-80.3764241776696, 44.3259233842728], [-80.376232840644, 44.3258912372486], [-80.3761778827904, 44.3258276760676], [-80.3757712939805, 44.325759362561], [-80.3752059343744, 44.3257911355417], [-80.3747978938721, 44.3239478686715], [-80.3765005174368, 44.3236001331235], [-80.3766048311268, 44.3237444227003], [-80.3766908273936, 44.3238675253118], [-80.3769060715396, 44.323903689341], [-80.3772169808165, 44.3239559238229]]]}, 'region4': {'type': 'Polygon', 'coordinates': [[[-80.4414758461818, 44.4468399119331], [-80.4399721805282, 44.4471867620164], [-80.4395657798354, 44.4447820571645], [-80.44099741403, 44.4444232095963], [-80.4414758461818, 44.4468399119331]]]}, 'region5': {'type': 'Polygon', 'coordinates': [[[-80.4421816733383, 44.4466135137253], [-80.4416845003799, 44.4468203876096], [-80.4411932481774, 44.444365318568], [-80.4415073722911, 44.4442547096037], [-80.4421816733383, 44.4466135137253]]]}}
# mode: regions
# resolution: 10
# projection: EPSG:3979
# IncludeAngles: False
# prod_names: ['mosaic']
# out_folder: E:\S2_mosaics_runner_2026\test_10m\5_regions_10m
# out_datatype: int16
# output_type: geotiff
# csv_scale: 10
# csv_dropNulls: True
# csv_max_pixels: 100000
# regions_ref: {'region0': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}, 'region2': {'type': 'Polygon', 'coordinates': [[[-80.529638877948, 44.5242213601121], [-80.5236686736853, 44.5252976281762], [-80.5234042910143, 44.5252538220711], [-80.5231938083608, 44.5249653160984], [-80.5230220292666, 44.5247919216231], [-80.5294731056627, 44.5235598453566], [-80.529638877948, 44.5242213601121]]]}, 'region3': {'type': 'Polygon', 'coordinates': [[[-80.3772169808165, 44.3239559238229], [-80.3778062318809, 44.3239281559541], [-80.3783858830901, 44.3257096706257], [-80.3764241776696, 44.3259233842728], [-80.376232840644, 44.3258912372486], [-80.3761778827904, 44.3258276760676], [-80.3757712939805, 44.325759362561], [-80.3752059343744, 44.3257911355417], [-80.3747978938721, 44.3239478686715], [-80.3765005174368, 44.3236001331235], [-80.3766048311268, 44.3237444227003], [-80.3766908273936, 44.3238675253118], [-80.3769060715396, 44.323903689341], [-80.3772169808165, 44.3239559238229]]]}, 'region4': {'type': 'Polygon', 'coordinates': [[[-80.4414758461818, 44.4468399119331], [-80.4399721805282, 44.4471867620164], [-80.4395657798354, 44.4447820571645], [-80.44099741403, 44.4444232095963], [-80.4414758461818, 44.4468399119331]]]}, 'region5': {'type': 'Polygon', 'coordinates': [[[-80.4421816733383, 44.4466135137253], [-80.4416845003799, 44.4468203876096], [-80.4411932481774, 44.444365318568], [-80.4415073722911, 44.4442547096037], [-80.4421816733383, 44.4466135137253]]]}}
# region_start_dates_ref: {'region0': ['2025-08-01'], 'region1': ['2025-08-01'], 'region2': ['2025-08-01'], 'region3': ['2025-08-01'], 'region4': ['2025-08-01'], 'region5': ['2025-08-01']}
# region_end_dates_ref: {'region0': ['2025-08-31'], 'region1': ['2025-08-31'], 'region2': ['2025-08-31'], 'region3': ['2025-08-31'], 'region4': ['2025-08-31'], 'region5': ['2025-08-31']}
# region_start_dates: {'region0': ['2025-08-01'], 'region1': ['2025-08-01'], 'region2': ['2025-08-01'], 'region3': ['2025-08-01'], 'region4': ['2025-08-01'], 'region5': ['2025-08-01']}
# region_end_dates: {'region0': ['2025-08-31'], 'region1': ['2025-08-31'], 'region2': ['2025-08-31'], 'region3': ['2025-08-31'], 'region4': ['2025-08-31'], 'region5': ['2025-08-31']}
# start_dates: ['2025-08-01']
# end_dates: ['2025-08-31']
# monthly: False
# SsrData: {'NAME': 'S2_SR', 'SSR_CODE': 21, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], '10M_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'SIX_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'NoA_BANDS': ['red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'LEAF_BANDS': ['green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'GEE_NAME': 'COPERNICUS/S2_SR_HARMONIZED', 'CLOUD': 'CLOUDY_PIXEL_PERCENTAGE', 'SZA': 'view:sun_elevation', 'SAA': 'view:sun_azimuth', 'VZA': 'view:sun_elevation', 'VAA': 'view:sun_azimuth', 'BLU': 'blue', 'GRN': 'green', 'RED': 'red', 'NIR': 'nir08', 'SW1': 'swir16', 'SW2': 'swir22'}
# year: 2026
# out_location: drive
# months: []
# tile_names: []
# cloud_cover: 80
# export_style: separate
# current_time: 0
# scene_ID:
# current_region: region0
# Criteria: {'timeframe': '2025-08-01/2025-08-31', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'catalog': 'https://earth-search.aws.element84.com/v1', 'collection': ['sentinel-2-l2a'], 'bands': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl']}
# standardized: True
# number_workers: 10
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 50G
# chunk_size: {'x': 512, 'y': 512}
#
# <MosaicProduction> Using region-specific dates for region0
#   Start dates: ['2025-08-01']
#   End dates: ['2025-08-31']
# <MosaicProduction> Processing region0 | time window: 2025-08-01 / 2025-08-31
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': (((-81.0143277776703, 44.792849553362), (-81.0142442205963, 44.7913333551658), (-81.013283176937, 44.7913976888643), (-81.0134196694422, 44.7918539873173), (-81.0130828894072, 44.7920357810087), (-81.013046437586, 44.7928810241213), (-81.0143277776703, 44.792849553362)),)}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.02 minutes
#
# <one_mosaic> A total of 11 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/AOT.tif
# Asset key: blue, title: Blue - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/B02.tif
# Asset key: cloud, title: Cloud Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/qi/CLD_20m.jp2
# Asset key: coastal, title: Coastal - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/granule_metadata.xml
# Asset key: green, title: Green - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/B09.tif
# Asset key: product_metadata, title: None, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/product_metadata.xml
# Asset key: red, title: Red - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/B04.tif
# Asset key: rededge1, title: Red Edge 1 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/B05.tif
# Asset key: rededge2, title: Red Edge 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/B06.tif
# Asset key: rededge3, title: Red Edge 3 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/SCL.tif
# Asset key: snow, title: Snow Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/qi/SNW_20m.jp2
# Asset key: swir16, title: SWIR 1.6μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2.2μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/B12.tif
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/TCI.tif
# Asset key: wvp, title: Water Vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/WVP.tif
# Asset key: thumbnail, title: Thumbnail of preview image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A/preview.jpg
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/R20m/AOT.jp2
# Asset key: blue-jp2, title: Blue - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/R10m/B02.jp2
# Asset key: coastal-jp2, title: Coastal - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/R60m/B01.jp2
# Asset key: green-jp2, title: Green - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/R10m/B03.jp2
# Asset key: nir-jp2, title: NIR 1 - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/R10m/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/R20m/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/R60m/B09.jp2
# Asset key: red-jp2, title: Red - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/R10m/B04.jp2
# Asset key: rededge1-jp2, title: Red Edge 1 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/R20m/B05.jp2
# Asset key: rededge2-jp2, title: Red Edge 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/R20m/B06.jp2
# Asset key: rededge3-jp2, title: Red Edge 3 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/R20m/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/R20m/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1.6μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/R20m/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2.2μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/R20m/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/R10m/TCI.jp2
# Asset key: wvp-jp2, title: Water Vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2025/8/10/0/R20m/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2A_17TMK_20250810_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-80.9498289169547, 45.15381722928897], [-81.2818689590538, 44.16502777612428], [-80.87793799810343, 44.16531029102769], [-80.87584634429486, 45.15376076769412], [-80.9498289169547, 45.15381722928897]]]}
# Bounding Box: [-81.281869, 44.165028, -80.875846, 45.153817]
# Datetime: 2025-08-10 16:21:19.360000+00:00
# cloud cover: 51.240581
# Properties:
#   <created>: 2025-08-10T22:18:16.896Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 51.240581
#   <proj:centroid>: {'lat': 44.54573, 'lon': -81.0156}
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: MK
#   <grid:code>: MGRS-17TMK
#   <view:azimuth>: 108.541591204723
#   <view:incidence_angle>: 10.945981574603431
#   <view:sun_azimuth>: 147.553555954572
#   <view:sun_elevation>: 57.1313398609337
#   <s2:tile_id>: S2A_OPER_MSI_L2A_TL_2APS_20250810T210413_A052933_T17TMK_N05.11
#   <s2:degraded_msi_data_percentage>: 0.0558
#   <s2:nodata_pixel_percentage>: 82.585913
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 7.576883
#   <s2:vegetation_percentage>: 24.689676
#   <s2:not_vegetated_percentage>: 2.519404
#   <s2:water_percentage>: 13.447812
#   <s2:unclassified_percentage>: 0.518022
#   <s2:medium_proba_clouds_percentage>: 13.564377
#   <s2:high_proba_clouds_percentage>: 14.836615
#   <s2:thin_cirrus_percentage>: 22.839591
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2A_MSIL2A_20250810T161701_N0511_R140_T17TMK_20250810T210413.SAFE
#   <s2:generation_time>: 2025-08-10T21:04:13.000000Z
#   <s2:datatake_id>: GS2A_20250810T161701_052933_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_2APS_20250810T210413_S20250810T161702_N05.11
#   <s2:reflectance_conversion_factor>: 0.972348219154192
#   <datetime>: 2025-08-10T16:21:19.360000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/MK/2025/8/S2A_17TMK_20250810_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/a578296a4e25f6a15260070bbe31839e
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '2025.03.06'}
#   <updated>: 2025-08-10T22:18:16.896Z
#   <proj:code>: EPSG:32617
#   <sza>: 32.8686601390663
#   <saa>: 147.553555954572
#   <vza>: 10.9786722789746
#   <vaa>: 110.016752434811
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 13kB
# Dimensions:      (y: 21, x: 13)
# Coordinates:
#   * y            (y) float64 168B -3.484e+05 -3.484e+05 ... -3.486e+05
#   * x            (x) float64 104B 1.118e+06 1.118e+06 ... 1.118e+06 1.118e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-08-10T16:21:19.360000
# Data variables:
#     blue         (y, x) float32 1kB dask.array<chunksize=(21, 13), meta=np.ndarray>
#     green        (y, x) float32 1kB dask.array<chunksize=(21, 13), meta=np.ndarray>
#     red          (y, x) float32 1kB dask.array<chunksize=(21, 13), meta=np.ndarray>
#     rededge1     (y, x) float32 1kB dask.array<chunksize=(21, 13), meta=np.ndarray>
#     rededge2     (y, x) float32 1kB dask.array<chunksize=(21, 13), meta=np.ndarray>
#     rededge3     (y, x) float32 1kB dask.array<chunksize=(21, 13), meta=np.ndarray>
#     nir08        (y, x) float32 1kB dask.array<chunksize=(21, 13), meta=np.ndarray>
#     swir16       (y, x) float32 1kB dask.array<chunksize=(21, 13), meta=np.ndarray>
#     swir22       (y, x) float32 1kB dask.array<chunksize=(21, 13), meta=np.ndarray>
#     scl          (y, x) float32 1kB dask.array<chunksize=(21, 13), meta=np.ndarray>
#     date         (y, x) float32 1kB dask.array<chunksize=(21, 13), meta=np.ndarray>
#     score        (y, x) float32 1kB dask.array<chunksize=(21, 13), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TMK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\aradar\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\distributed\client.py:3164: UserWarning: Sending large graph of size 13.41 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score']
# <_clip_mosaic_to_regions> Clipped mosaic from Frozen({'y': 21, 'x': 13}) → Frozen({'y': 21, 'x': 13})  (mode=regions)
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region0_2025-08-01_2025-08-31_swir22_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region0_2025-08-01_2025-08-31_green_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region0_2025-08-01_2025-08-31_swir16_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region0_2025-08-01_2025-08-31_rededge3_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region0_2025-08-01_2025-08-31_rededge2_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region0_2025-08-01_2025-08-31_red_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region0_2025-08-01_2025-08-31_nir08_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region0_2025-08-01_2025-08-31_date_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region0_2025-08-01_2025-08-31_score_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region0_2025-08-01_2025-08-31_scl_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region0_2025-08-01_2025-08-31_blue_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region0_2025-08-01_2025-08-31_rededge1_10m.tif
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.97 minutes >>>>>>
# File 'E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\log_9b50b897-46c7-4aa2-9dab-314a9c475e5e.out' does not exist.
# Directory 'E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\dask_spill_9b50b897-46c7-4aa2-9dab-314a9c475e5e' and its contents have been deleted.
#
# <MosaicProduction> Using region-specific dates for region1
#   Start dates: ['2025-08-01']
#   End dates: ['2025-08-31']
# <MosaicProduction> Processing region1 | time window: 2025-08-01 / 2025-08-31
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': (((-80.2866384110016, 44.3533435417762), (-80.2871598357525, 44.3533320137857), (-80.2874518606506, 44.3533270111586), (-80.287558824637, 44.3533088522111), (-80.2877249039523, 44.3532644472593), (-80.287738989293, 44.3532215337679), (-80.2878832692439, 44.3531281508011), (-80.287951530048, 44.3531125098555), (-80.288085927134, 44.3531261618167), (-80.2882027280036, 44.353154957613), (-80.2880782566738, 44.352880279965), (-80.2880395541161, 44.3528827993289), (-80.2879206306362, 44.3528989373857), (-80.2876405698119, 44.3529059627622), (-80.2874977225433, 44.3529180592246), (-80.2871254773415, 44.3529366809224), (-80.2868313289172, 44.3529866183925), (-80.2864858239462, 44.353000698271), (-80.2866384110016, 44.3533435417762)),)}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.02 minutes
#
# <one_mosaic> A total of 12 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/AOT.tif
# Asset key: blue, title: Blue - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/B02.tif
# Asset key: cloud, title: Cloud Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/qi/CLD_20m.jp2
# Asset key: coastal, title: Coastal - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/granule_metadata.xml
# Asset key: green, title: Green - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/B03.tif
# Asset key: nir, title: NIR 1 - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/B08.tif
# Asset key: nir08, title: NIR 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/B09.tif
# Asset key: product_metadata, title: None, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/product_metadata.xml
# Asset key: red, title: Red - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/B04.tif
# Asset key: rededge1, title: Red Edge 1 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/B05.tif
# Asset key: rededge2, title: Red Edge 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/B06.tif
# Asset key: rededge3, title: Red Edge 3 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/SCL.tif
# Asset key: snow, title: Snow Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/qi/SNW_20m.jp2
# Asset key: swir16, title: SWIR 1.6μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/B11.tif
# Asset key: swir22, title: SWIR 2.2μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/B12.tif
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/TCI.tif
# Asset key: wvp, title: Water Vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/WVP.tif
# Asset key: thumbnail, title: Thumbnail of preview image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A/preview.jpg
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/R20m/AOT.jp2
# Asset key: blue-jp2, title: Blue - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/R10m/B02.jp2
# Asset key: coastal-jp2, title: Coastal - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/R60m/B01.jp2
# Asset key: green-jp2, title: Green - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/R10m/B03.jp2
# Asset key: nir-jp2, title: NIR 1 - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/R10m/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/R20m/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/R60m/B09.jp2
# Asset key: red-jp2, title: Red - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/R10m/B04.jp2
# Asset key: rededge1-jp2, title: Red Edge 1 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/R20m/B05.jp2
# Asset key: rededge2-jp2, title: Red Edge 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/R20m/B06.jp2
# Asset key: rededge3-jp2, title: Red Edge 3 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/R20m/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/R20m/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1.6μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/R20m/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2.2μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/R20m/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/R10m/TCI.jp2
# Asset key: wvp-jp2, title: Water Vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/13/1/R20m/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2A_17TNK_20250813_1_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-81.00023764893123, 44.1662758299769], [-79.98819323453682, 44.162334296304714], [-79.60826451038814, 45.09893098137437], [-79.60487459496446, 45.145306387491225], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.000242, 44.162334, -79.604875, 45.153828]
# Datetime: 2025-08-13 16:31:09.593000+00:00
# cloud cover: 23.19527
# Properties:
#   <created>: 2025-08-14T02:30:41.792Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 23.19527
#   <proj:centroid>: {'lat': 44.68384, 'lon': -80.38957}
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:azimuth>: 285.90755469732034
#   <view:incidence_angle>: 8.089988458741725
#   <view:sun_azimuth>: 154.626434649614
#   <view:sun_elevation>: 57.6140197221931
#   <s2:tile_id>: S2A_OPER_MSI_L2A_TL_2APS_20250814T005115_A052976_T17TNK_N05.11
#   <s2:degraded_msi_data_percentage>: 0.0408
#   <s2:nodata_pixel_percentage>: 12.553306
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 4.475989
#   <s2:vegetation_percentage>: 24.042977
#   <s2:not_vegetated_percentage>: 2.257624
#   <s2:water_percentage>: 44.988072
#   <s2:unclassified_percentage>: 0.948555
#   <s2:medium_proba_clouds_percentage>: 8.79453
#   <s2:high_proba_clouds_percentage>: 14.279264
#   <s2:thin_cirrus_percentage>: 0.121477
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2A_MSIL2A_20250813T162701_N0511_R040_T17TNK_20250814T005115.SAFE
#   <s2:generation_time>: 2025-08-14T00:51:15.000000Z
#   <s2:datatake_id>: GS2A_20250813T162701_052976_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_2APS_20250814T005115_S20250813T163011_N05.11
#   <s2:reflectance_conversion_factor>: 0.97327473033487
#   <datetime>: 2025-08-13T16:31:09.593000Z
#   <s2:sequence>: 1
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2A_17TNK_20250813_1_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/ec122b7cb7c4987c132ef2c41245527f
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '2025.03.06'}
#   <updated>: 2025-08-14T02:30:41.792Z
#   <proj:code>: EPSG:32617
#   <sza>: 32.3859802778069
#   <saa>: 154.626434649614
#   <vza>: 8.14404368760364
#   <vaa>: 285.996393506411
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 7kB
# Dimensions:      (y: 9, x: 15)
# Coordinates:
#   * y            (y) float64 72B -3.838e+05 -3.838e+05 ... -3.839e+05 -3.839e+05
#   * x            (x) float64 120B 1.187e+06 1.187e+06 ... 1.187e+06 1.187e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-08-13T16:31:09.593000
# Data variables:
#     blue         (y, x) float32 540B dask.array<chunksize=(9, 15), meta=np.ndarray>
#     green        (y, x) float32 540B dask.array<chunksize=(9, 15), meta=np.ndarray>
#     red          (y, x) float32 540B dask.array<chunksize=(9, 15), meta=np.ndarray>
#     rededge1     (y, x) float32 540B dask.array<chunksize=(9, 15), meta=np.ndarray>
#     rededge2     (y, x) float32 540B dask.array<chunksize=(9, 15), meta=np.ndarray>
#     rededge3     (y, x) float32 540B dask.array<chunksize=(9, 15), meta=np.ndarray>
#     nir08        (y, x) float32 540B dask.array<chunksize=(9, 15), meta=np.ndarray>
#     swir16       (y, x) float32 540B dask.array<chunksize=(9, 15), meta=np.ndarray>
#     swir22       (y, x) float32 540B dask.array<chunksize=(9, 15), meta=np.ndarray>
#     scl          (y, x) float32 540B dask.array<chunksize=(9, 15), meta=np.ndarray>
#     date         (y, x) float32 540B dask.array<chunksize=(9, 15), meta=np.ndarray>
#     score        (y, x) float32 540B dask.array<chunksize=(9, 15), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\aradar\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\distributed\client.py:3164: UserWarning: Sending large graph of size 14.08 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score']
# <_clip_mosaic_to_regions> Clipped mosaic from Frozen({'y': 9, 'x': 15}) → Frozen({'y': 9, 'x': 15})  (mode=regions)
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region1_2025-08-01_2025-08-31_swir22_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region1_2025-08-01_2025-08-31_green_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region1_2025-08-01_2025-08-31_swir16_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region1_2025-08-01_2025-08-31_rededge3_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region1_2025-08-01_2025-08-31_rededge2_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region1_2025-08-01_2025-08-31_red_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region1_2025-08-01_2025-08-31_nir08_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region1_2025-08-01_2025-08-31_date_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region1_2025-08-01_2025-08-31_score_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region1_2025-08-01_2025-08-31_scl_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region1_2025-08-01_2025-08-31_blue_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region1_2025-08-01_2025-08-31_rededge1_10m.tif
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   1.03 minutes >>>>>>
# File 'E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\log_e92584d4-bd81-4266-a7d8-c1586a0ccd53.out' does not exist.
# Directory 'E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\dask_spill_e92584d4-bd81-4266-a7d8-c1586a0ccd53' and its contents have been deleted.
#
# <MosaicProduction> Using region-specific dates for region2
#   Start dates: ['2025-08-01']
#   End dates: ['2025-08-31']
# <MosaicProduction> Processing region2 | time window: 2025-08-01 / 2025-08-31
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': (((-80.529638877948, 44.5242213601121), (-80.5294731056627, 44.5235598453566), (-80.5230220292666, 44.5247919216231), (-80.5231938083608, 44.5249653160984), (-80.5234042910143, 44.5252538220711), (-80.5236686736853, 44.5252976281762), (-80.529638877948, 44.5242213601121)),)}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.02 minutes
#
# <one_mosaic> A total of 12 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/AOT.tif
# Asset key: blue, title: Blue - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/B02.tif
# Asset key: cloud, title: Cloud Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/qi/CLD_20m.jp2
# Asset key: coastal, title: Coastal - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/granule_metadata.xml
# Asset key: green, title: Green - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/B09.tif
# Asset key: product_metadata, title: None, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/product_metadata.xml
# Asset key: red, title: Red - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/B04.tif
# Asset key: rededge1, title: Red Edge 1 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/B05.tif
# Asset key: rededge2, title: Red Edge 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/B06.tif
# Asset key: rededge3, title: Red Edge 3 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/SCL.tif
# Asset key: snow, title: Snow Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/qi/SNW_20m.jp2
# Asset key: swir16, title: SWIR 1.6μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2.2μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/B12.tif
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/TCI.tif
# Asset key: wvp, title: Water Vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/WVP.tif
# Asset key: thumbnail, title: Thumbnail of preview image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A/preview.jpg
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/R20m/AOT.jp2
# Asset key: blue-jp2, title: Blue - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/R10m/B02.jp2
# Asset key: coastal-jp2, title: Coastal - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/R60m/B01.jp2
# Asset key: green-jp2, title: Green - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/R10m/B03.jp2
# Asset key: nir-jp2, title: NIR 1 - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/R10m/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/R20m/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/R60m/B09.jp2
# Asset key: red-jp2, title: Red - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/R10m/B04.jp2
# Asset key: rededge1-jp2, title: Red Edge 1 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/R20m/B05.jp2
# Asset key: rededge2-jp2, title: Red Edge 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/R20m/B06.jp2
# Asset key: rededge3-jp2, title: Red Edge 3 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/R20m/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/R20m/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1.6μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/R20m/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2.2μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/R20m/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/R10m/TCI.jp2
# Asset key: wvp-jp2, title: Water Vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/11/0/R20m/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2C_17TNK_20250811_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-81.00023764893123, 44.1662758301286], [-80.00845182240846, 44.16251232713541], [-79.61026486620044, 45.14537211775901], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.000242, 44.162512, -79.610265, 45.153828]
# Datetime: 2025-08-11 16:31:16.076000+00:00
# cloud cover: 13.264659
# Properties:
#   <created>: 2025-08-11T21:05:55.040Z
#   <platform>: sentinel-2c
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 13.264659
#   <proj:centroid>: {'lat': 44.68449, 'lon': -80.39951}
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:azimuth>: 286.11105109762514
#   <view:incidence_angle>: 8.089694426956408
#   <view:sun_azimuth>: 154.157614837405
#   <view:sun_elevation>: 58.1702527178576
#   <s2:tile_id>: S2C_OPER_MSI_L2A_TL_2CPS_20250811T193713_A004872_T17TNK_N05.11
#   <s2:degraded_msi_data_percentage>: 0.0508
#   <s2:nodata_pixel_percentage>: 14.030364
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 7.223052
#   <s2:vegetation_percentage>: 31.598499
#   <s2:not_vegetated_percentage>: 2.459927
#   <s2:water_percentage>: 44.973338
#   <s2:unclassified_percentage>: 0.403974
#   <s2:medium_proba_clouds_percentage>: 6.120846
#   <s2:high_proba_clouds_percentage>: 7.135449
#   <s2:thin_cirrus_percentage>: 0.008363
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2C_MSIL2A_20250811T161851_N0511_R040_T17TNK_20250811T193713.SAFE
#   <s2:generation_time>: 2025-08-11T19:37:13.000000Z
#   <s2:datatake_id>: GS2C_20250811T161851_004872_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2C_OPER_MSI_L2A_DS_2CPS_20250811T193713_S20250811T162458_N05.11
#   <s2:reflectance_conversion_factor>: 0.972648661606819
#   <datetime>: 2025-08-11T16:31:16.076000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250811_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/984204db726e19f3fb226fc937314d58
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '2025.03.06'}
#   <updated>: 2025-08-11T21:05:55.040Z
#   <proj:code>: EPSG:32617
#   <sza>: 31.8297472821424
#   <saa>: 154.157614837405
#   <vza>: 8.15094562991442
#   <vaa>: 286.173356927241
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 78kB
# Dimensions:      (y: 31, x: 52)
# Coordinates:
#   * y            (y) float64 248B -3.692e+05 -3.692e+05 ... -3.695e+05
#   * x            (x) float64 416B 1.163e+06 1.163e+06 ... 1.163e+06 1.164e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-08-11T16:31:16.076000
# Data variables:
#     blue         (y, x) float32 6kB dask.array<chunksize=(31, 52), meta=np.ndarray>
#     green        (y, x) float32 6kB dask.array<chunksize=(31, 52), meta=np.ndarray>
#     red          (y, x) float32 6kB dask.array<chunksize=(31, 52), meta=np.ndarray>
#     rededge1     (y, x) float32 6kB dask.array<chunksize=(31, 52), meta=np.ndarray>
#     rededge2     (y, x) float32 6kB dask.array<chunksize=(31, 52), meta=np.ndarray>
#     rededge3     (y, x) float32 6kB dask.array<chunksize=(31, 52), meta=np.ndarray>
#     nir08        (y, x) float32 6kB dask.array<chunksize=(31, 52), meta=np.ndarray>
#     swir16       (y, x) float32 6kB dask.array<chunksize=(31, 52), meta=np.ndarray>
#     swir22       (y, x) float32 6kB dask.array<chunksize=(31, 52), meta=np.ndarray>
#     scl          (y, x) float32 6kB dask.array<chunksize=(31, 52), meta=np.ndarray>
#     date         (y, x) float32 6kB dask.array<chunksize=(31, 52), meta=np.ndarray>
#     score        (y, x) float32 6kB dask.array<chunksize=(31, 52), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\aradar\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\distributed\client.py:3164: UserWarning: Sending large graph of size 14.09 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score']
# <_clip_mosaic_to_regions> Clipped mosaic from Frozen({'y': 31, 'x': 52}) → Frozen({'y': 31, 'x': 52})  (mode=regions)
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region2_2025-08-01_2025-08-31_swir22_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region2_2025-08-01_2025-08-31_green_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region2_2025-08-01_2025-08-31_swir16_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region2_2025-08-01_2025-08-31_rededge3_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region2_2025-08-01_2025-08-31_rededge2_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region2_2025-08-01_2025-08-31_red_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region2_2025-08-01_2025-08-31_nir08_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region2_2025-08-01_2025-08-31_date_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region2_2025-08-01_2025-08-31_score_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region2_2025-08-01_2025-08-31_scl_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region2_2025-08-01_2025-08-31_blue_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region2_2025-08-01_2025-08-31_rededge1_10m.tif
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   1.02 minutes >>>>>>
# File 'E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\log_2215e220-340f-4465-b30b-fd138fd0befb.out' does not exist.
# Directory 'E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\dask_spill_2215e220-340f-4465-b30b-fd138fd0befb' and its contents have been deleted.
#
# <MosaicProduction> Using region-specific dates for region3
#   Start dates: ['2025-08-01']
#   End dates: ['2025-08-31']
# <MosaicProduction> Processing region3 | time window: 2025-08-01 / 2025-08-31
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': (((-80.3772169808165, 44.3239559238229), (-80.3769060715396, 44.323903689341), (-80.3766908273936, 44.3238675253118), (-80.3766048311268, 44.3237444227003), (-80.3765005174368, 44.3236001331235), (-80.3747978938721, 44.3239478686715), (-80.3752059343744, 44.3257911355417), (-80.3757712939805, 44.325759362561), (-80.3761778827904, 44.3258276760676), (-80.376232840644, 44.3258912372486), (-80.3764241776696, 44.3259233842728), (-80.3783858830901, 44.3257096706257), (-80.3778062318809, 44.3239281559541), (-80.3772169808165, 44.3239559238229)),)}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.01 minutes
#
# <one_mosaic> A total of 12 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/AOT.tif
# Asset key: blue, title: Blue - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B02.tif
# Asset key: cloud, title: Cloud Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/21/0/qi/CLD_20m.jp2
# Asset key: coastal, title: Coastal - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250821_0_L2A/granule_metadata.xml
# ...
#     green        (y, x) float32 3kB dask.array<chunksize=(34, 22), meta=np.ndarray>
#     red          (y, x) float32 3kB dask.array<chunksize=(34, 22), meta=np.ndarray>
#     rededge1     (y, x) float32 3kB dask.array<chunksize=(34, 22), meta=np.ndarray>
#     rededge2     (y, x) float32 3kB dask.array<chunksize=(34, 22), meta=np.ndarray>
#     rededge3     (y, x) float32 3kB dask.array<chunksize=(34, 22), meta=np.ndarray>
#     nir08        (y, x) float32 3kB dask.array<chunksize=(34, 22), meta=np.ndarray>
#     swir16       (y, x) float32 3kB dask.array<chunksize=(34, 22), meta=np.ndarray>
#     swir22       (y, x) float32 3kB dask.array<chunksize=(34, 22), meta=np.ndarray>
#     scl          (y, x) float32 3kB dask.array<chunksize=(34, 22), meta=np.ndarray>
#     date         (y, x) float32 3kB dask.array<chunksize=(34, 22), meta=np.ndarray>
#     score        (y, x) float32 3kB dask.array<chunksize=(34, 22), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\aradar\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\distributed\client.py:3164: UserWarning: Sending large graph of size 14.09 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score']
# <_clip_mosaic_to_regions> Clipped mosaic from Frozen({'y': 34, 'x': 22}) → Frozen({'y': 34, 'x': 22})  (mode=regions)
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region4_2025-08-01_2025-08-31_swir22_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region4_2025-08-01_2025-08-31_green_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region4_2025-08-01_2025-08-31_swir16_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region4_2025-08-01_2025-08-31_rededge3_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region4_2025-08-01_2025-08-31_rededge2_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region4_2025-08-01_2025-08-31_red_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region4_2025-08-01_2025-08-31_nir08_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region4_2025-08-01_2025-08-31_date_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region4_2025-08-01_2025-08-31_score_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region4_2025-08-01_2025-08-31_scl_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region4_2025-08-01_2025-08-31_blue_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region4_2025-08-01_2025-08-31_rededge1_10m.tif
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.87 minutes >>>>>>
# File 'E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\log_1034a56a-8031-443e-9f60-6e0feffad5e5.out' does not exist.
# Directory 'E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\dask_spill_1034a56a-8031-443e-9f60-6e0feffad5e5' and its contents have been deleted.
#
# <MosaicProduction> Using region-specific dates for region5
#   Start dates: ['2025-08-01']
#   End dates: ['2025-08-31']
# <MosaicProduction> Processing region5 | time window: 2025-08-01 / 2025-08-31
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': (((-80.4421816733383, 44.4466135137253), (-80.4415073722911, 44.4442547096037), (-80.4411932481774, 44.444365318568), (-80.4416845003799, 44.4468203876096), (-80.4421816733383, 44.4466135137253)),)}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.01 minutes
#
# <one_mosaic> A total of 12 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/AOT.tif
# Asset key: blue, title: Blue - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/B02.tif
# Asset key: cloud, title: Cloud Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/qi/CLD_20m.jp2
# Asset key: coastal, title: Coastal - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/granule_metadata.xml
# Asset key: green, title: Green - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/B09.tif
# Asset key: product_metadata, title: None, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/product_metadata.xml
# Asset key: red, title: Red - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/B04.tif
# Asset key: rededge1, title: Red Edge 1 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/B05.tif
# Asset key: rededge2, title: Red Edge 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/B06.tif
# Asset key: rededge3, title: Red Edge 3 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/SCL.tif
# Asset key: snow, title: Snow Probabilities, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/qi/SNW_20m.jp2
# Asset key: swir16, title: SWIR 1.6μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2.2μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/B12.tif
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/TCI.tif
# Asset key: wvp, title: Water Vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/WVP.tif
# Asset key: thumbnail, title: Thumbnail of preview image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A/preview.jpg
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/R20m/AOT.jp2
# Asset key: blue-jp2, title: Blue - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/R10m/B02.jp2
# Asset key: coastal-jp2, title: Coastal - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/R60m/B01.jp2
# Asset key: green-jp2, title: Green - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/R10m/B03.jp2
# Asset key: nir-jp2, title: NIR 1 - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/R10m/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/R20m/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/R60m/B09.jp2
# Asset key: red-jp2, title: Red - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/R10m/B04.jp2
# Asset key: rededge1-jp2, title: Red Edge 1 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/R20m/B05.jp2
# Asset key: rededge2-jp2, title: Red Edge 2 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/R20m/B06.jp2
# Asset key: rededge3-jp2, title: Red Edge 3 - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/R20m/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/R20m/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1.6μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/R20m/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2.2μm - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/R20m/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/R10m/TCI.jp2
# Asset key: wvp-jp2, title: Water Vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2025/8/31/0/R20m/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2C_17TNK_20250831_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-81.00023764893123, 44.16627582538338], [-80.01809807516764, 44.16223586048863], [-79.61942079374613, 45.14548318393572], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.000242, 44.162236, -79.619421, 45.153828]
# Datetime: 2025-08-31 16:31:15.606000+00:00
# cloud cover: 5.440506
# Properties:
#   <created>: 2025-08-31T21:26:49.007Z
#   <platform>: sentinel-2c
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 5.440506
#   <proj:centroid>: {'lat': 44.6847, 'lon': -80.40411}
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:azimuth>: 286.19230871286646
#   <view:incidence_angle>: 8.11625554795771
#   <view:sun_azimuth>: 159.532545078383
#   <view:sun_elevation>: 52.116865706862
#   <s2:tile_id>: S2C_OPER_MSI_L2A_TL_2CPS_20250831T195114_A005158_T17TNK_N05.11
#   <s2:degraded_msi_data_percentage>: 0.0171
#   <s2:nodata_pixel_percentage>: 14.70037
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 5.294866
#   <s2:vegetation_percentage>: 38.384548
#   <s2:not_vegetated_percentage>: 3.341685
#   <s2:water_percentage>: 47.187424
#   <s2:unclassified_percentage>: 0.275957
#   <s2:medium_proba_clouds_percentage>: 2.787327
#   <s2:high_proba_clouds_percentage>: 2.511564
#   <s2:thin_cirrus_percentage>: 0.141614
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2C_MSIL2A_20250831T161921_N0511_R040_T17TNK_20250831T195114.SAFE
#   <s2:generation_time>: 2025-08-31T19:51:14.000000Z
#   <s2:datatake_id>: GS2C_20250831T161921_005158_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2C_OPER_MSI_L2A_DS_2CPS_20250831T195114_S20250831T162512_N05.11
#   <s2:reflectance_conversion_factor>: 0.980225195416855
#   <datetime>: 2025-08-31T16:31:15.606000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2025/8/S2C_17TNK_20250831_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/9cc2d1079e685feb775934a49bef407a
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '2025.03.06'}
#   <updated>: 2025-08-31T21:26:49.007Z
#   <proj:code>: EPSG:32617
#   <sza>: 37.883134293138
#   <saa>: 159.532545078383
#   <vza>: 8.18209716186402
#   <vaa>: 286.335721707434
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 21kB
# Dimensions:      (y: 29, x: 15)
# Coordinates:
#   * y            (y) float64 232B -3.763e+05 -3.763e+05 ... -3.766e+05
#   * x            (x) float64 120B 1.172e+06 1.172e+06 ... 1.172e+06 1.172e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-08-31T16:31:15.606000
# Data variables:
#     blue         (y, x) float32 2kB dask.array<chunksize=(29, 15), meta=np.ndarray>
#     green        (y, x) float32 2kB dask.array<chunksize=(29, 15), meta=np.ndarray>
#     red          (y, x) float32 2kB dask.array<chunksize=(29, 15), meta=np.ndarray>
#     rededge1     (y, x) float32 2kB dask.array<chunksize=(29, 15), meta=np.ndarray>
#     rededge2     (y, x) float32 2kB dask.array<chunksize=(29, 15), meta=np.ndarray>
#     rededge3     (y, x) float32 2kB dask.array<chunksize=(29, 15), meta=np.ndarray>
#     nir08        (y, x) float32 2kB dask.array<chunksize=(29, 15), meta=np.ndarray>
#     swir16       (y, x) float32 2kB dask.array<chunksize=(29, 15), meta=np.ndarray>
#     swir22       (y, x) float32 2kB dask.array<chunksize=(29, 15), meta=np.ndarray>
#     scl          (y, x) float32 2kB dask.array<chunksize=(29, 15), meta=np.ndarray>
#     date         (y, x) float32 2kB dask.array<chunksize=(29, 15), meta=np.ndarray>
#     score        (y, x) float32 2kB dask.array<chunksize=(29, 15), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\aradar\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\distributed\client.py:3164: UserWarning: Sending large graph of size 14.08 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score']
# <_clip_mosaic_to_regions> Clipped mosaic from Frozen({'y': 29, 'x': 15}) → Frozen({'y': 29, 'x': 15})  (mode=regions)
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region5_2025-08-01_2025-08-31_swir22_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region5_2025-08-01_2025-08-31_green_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region5_2025-08-01_2025-08-31_swir16_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region5_2025-08-01_2025-08-31_rededge3_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region5_2025-08-01_2025-08-31_rededge2_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region5_2025-08-01_2025-08-31_red_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region5_2025-08-01_2025-08-31_nir08_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region5_2025-08-01_2025-08-31_date_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region5_2025-08-01_2025-08-31_score_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region5_2025-08-01_2025-08-31_scl_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region5_2025-08-01_2025-08-31_blue_10m.tif
# <export_geotiff> Wrote E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\S2_SR_region5_2025-08-01_2025-08-31_rededge1_10m.tif
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.86 minutes >>>>>>
# File 'E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\log_35f4aaf4-18a9-4364-824e-9e29fb16552e.out' does not exist.
# Directory 'E:\S2_mosaics_runner_2026\test_10m\5_regions_10m\dask_spill_35f4aaf4-18a9-4364-824e-9e29fb16552e' and its contents have been deleted.
