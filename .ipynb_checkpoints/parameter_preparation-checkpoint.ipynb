# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
from pathlib import Path

project_root = Path.cwd()
sys.path.insert(0, str(project_root))

from prepare_params import prepare_production_params

print("Modules imported successfully")
print(f"Current working directory: {os.getcwd()}")


kml = "Sample Points\AfforestationSItesFixed.kml"
shp = "Sample Points\FieldPoints32_2018.shp"
tmx = "Sample Points\TMX\TML_pipeline_100mbuffer.kml"
cbc = "Sample Points\ColdwaterBCregion.kml"
ls_mgrs = "S2A_OPER_GIP_TILPAR_MPC.kml"
s2_mgrs = "sentinel-2-grid.parquet"
print(kml)
print(shp)
print(tmx)
print(cbc)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Modules imported successfully
# Current working directory: C:\Users\aradar\LEAF Files\LEAF_runner
# Sample Points\AfforestationSItesFixed.kml
# Sample Points\FieldPoints32_2018.shp
# Sample Points\TMX\TML_pipeline_100mbuffer.kml
# Sample Points\ColdwaterBCregion.kml

# %%
# Use Case: Generate monthly mosaics
# Customize these parameters as needed:

ProdParams = {
    # ============ REQUIRED PARAMETERS ============
    'sensor': 'S2_SR',                    # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR', 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'nbYears': -1,            # positive int for annual product, or negative int for monthly product
    #'year': 2023,                          # CHANGE THIS: Year to process
    #'months': [8,9,10],                   # CHANGE THIS: Months to process (1-12)
    
    
    # ============ REGION PARAMETERS ============
    'regions': kml,  # CHANGE THIS: Path to your KML/SHP file
    'file_variables': ['TARGET_FID', 'AsssD_1', 'AsssD_2'], # CHANGE THIS: id, start_date, end_date (None for dates if they don't exist)
    #'file_variables': ['id', 'begin', 'end'], # for pipelines file
    #'file_variables': ['system:index', None, None], # for cold water file
    'regions_start_index': 0,              # CHANGE THIS: Start at this region index
    'regions_end_index': 5,             # CHANGE THIS: End at this index (None = all)

    # ============ TILES PARAMETERS ============
    's2_grid_path': s2_mgrs,
    'mode': 'tiles', #regions or tiles
    'subdivide_tiles': False, # Whether to subdivide tiles into smaller regions (only applicable if mode is 'tiles')
    
    # ============ BUFFER PARAMETERS ============
    #'spatial_buffer_m': -10,             # UNCOMMENT & CHANGE: Buffer in meters around regions
    #'temporal_buffer': [[50, 90], [-10, 10]],          # UNCOMMENT & CHANGE: [days_before, days_after]
    'temporal_buffer': [["2017-08-01", "2017-08-31"]],
    'num_years': 2,
    
    
    # ============ OUTPUT PARAMETERS ============
    'resolution': 30,                      # Resolution in meters
    'projection': 'EPSG:3979',             # Coordinate projection
    'IncludeAngles': False,
    'prod_names': ['fCOVER'],    #['mosaic', 'LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'out_folder': 'E:\\TestingLEAFFinal\\regions_geotiff_30m',
    'out_datatype': 'int16',

    # ============ CSV OUTPUT (NEW) ============
    'output_type': 'geotiff',        # <-- switch from GeoTIFF to CSV
    'csv_scale': 30,             # optional: same as resolution, explicit here for clarity
    'csv_dropNulls': True,       # optional: skip masked/nodata pixels (mirrors GEE dropNulls)
    'csv_max_pixels': 100_000,   # optional: lower this first for a quick test
}

CompParams = {
  "number_workers":10,    
  "debug"       : True,
  "entire_tile" : False,
  "nodes"       : 1,
  "node_memory" : "50G",
  'chunk_size': {'x': 512, 'y': 512}
}


print("\nconfigured")
# Out:
# configured

# %%
# Run the parameter preparation
result = prepare_production_params(ProdParams, CompParams)
'''
if result:
    print("\n" + "="*80)
    print(" SUCCESS - Parameters validated and ready!")
    print("="*80)
    print(f"\n Summary:")
    print(f"  Regions: {len(result['ProdParams']['regions'])}")
    print(f"  Time windows: {len(result['ProdParams']['start_dates'])}")
    print(f"  Total tasks: {len(result['ProdParams']['regions']) * len(result['ProdParams']['start_dates'])}")
    print(f"  Output folder: {result['ProdParams']['out_folder']}")
    print(f"\n Processing log saved to: {result['ProdParams']['out_folder']}/polygon_processing_log.csv")
    print("\n" + "="*80)
    print("Next step: Call Production.py with the validated parameters")
    print("="*80)
else:
    print("\n" + "="*80)
    print(" FAILED - Parameter validation failed")
    print("="*80)
    print("Check the error messages above for details.") '''
# Out:
# ================================================================================
# PARAMETER PREPARATION
# ================================================================================
#
# Step 1/4: Validating input parameters...
# ✓ All parameters valid
#
# Step 2/4: Loading regions from files...
# <handle_regions_from_file> Detected file-based regions input: Sample Points\AfforestationSItesFixed.kml
# <handle_regions_from_file> Loading regions...
# <handle_regions_from_file> Override mode: Setting all regions to 1 date window(s)
# <handle_regions_from_file> Region region0: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Region region1: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Region region0: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Region region1: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Expanding region dates across 2 years...
# <handle_regions_from_file> Region region0: Expanded from 1 to 2 date windows (2 years)
# <handle_regions_from_file> Region region1: Expanded from 1 to 2 date windows (2 years)
# <handle_regions_from_file> Region region0: Expanded from 1 to 2 date windows (2 years)
# <handle_regions_from_file> Region region1: Expanded from 1 to 2 date windows (2 years)
# <handle_regions_from_file> Loaded 2 regions from file
#
# Step 3/4: Skipping temporal window generation (no year/months or start_dates/end_dates found)
#            Region-specific dates from file will be used if available.
#
# Step 4/4: Validating polygons...
#
# ================================================================================
# POLYGON VALIDATION AND FILTERING
# ================================================================================
#
# Polygon validation log saved to: E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\polygon_processing_log.csv
#
# Validation Summary:
#    Total regions: 2
#    Valid for processing: 2
#    Skipped (zero area): 0
#
# Proceeding with 2 valid region(s) out of 2 total
# ================================================================================
#
#
# ================================================================================
# PARAMETER PREPARATION COMPLETE
# ================================================================================
# Regions: 2
# Start Time windows: {'region0': ['2017-08-01', '2018-08-01'], 'region1': ['2017-08-01', '2018-08-01']}
# End Time windows: {'region0': ['2017-08-31', '2018-08-31'], 'region1': ['2017-08-31', '2018-08-31']}
# ================================================================================
#
#
# <prepare_production_params> Added properties to regions:
# {
#   "sensor": "S2_SR",
#   "unit": 2,
#   "nbYears": -1,
#   "file_variables": [
#     "TARGET_FID",
#     "AsssD_1",
#     "AsssD_2"
#   ],
#   "regions_start_index": 0,
#   "regions_end_index": 1,
#   "s2_grid_path": "sentinel-2-grid.parquet",
#   "mode": "regions",
#   "subdivide_tiles": false,
#   "temporal_buffer": [
#     [
#       "2017-08-01",
#       "2017-08-31"
#     ]
#   ],
#   "num_years": 2,
#   "resolution": 30,
#   "projection": "EPSG:3979",
#   "IncludeAngles": false,
#   "prod_names": [
#     "fCOVER"
#   ],
#   "out_folder": "E:\\TestingLEAFFinal\\hiyori_mogged regions csv_30m",
#   "out_datatype": "int16",
#   "output_type": "csv",
#   "csv_scale": 30,
#   "csv_dropNulls": true,
#   "csv_max_pixels": 100000,
#   "regions_ref": {
#     "region0": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -81.0143277776703,
#             44.792849553362
#           ],
#           [
#             -81.013046437586,
#             44.7928810241213
#           ],
#           [
#             -81.0130828894072,
#             44.7920357810087
#           ],
#           [
#             -81.0134196694422,
#             44.7918539873173
#           ],
#           [
#             -81.013283176937,
#             44.7913976888643
#           ],
#           [
#             -81.0142442205963,
#             44.7913333551658
#           ],
#           [
#             -81.0143277776703,
#             44.792849553362
#           ]
#         ]
#       ]
#     },
#     "region1": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -80.2866384110016,
#             44.3533435417762
#           ],
#           [
#             -80.2864858239462,
#             44.353000698271
#           ],
#           [
#             -80.2868313289172,
#             44.3529866183925
#           ],
#           [
#             -80.2871254773415,
#             44.3529366809224
#           ],
#           [
#             -80.2874977225433,
#             44.3529180592246
#           ],
#           [
#             -80.2876405698119,
#             44.3529059627622
#           ],
#           [
#             -80.2879206306362,
#             44.3528989373857
#           ],
#           [
#             -80.2880395541161,
#             44.3528827993289
#           ],
#           [
#             -80.2880782566738,
#             44.352880279965
#           ],
#           [
#             -80.2882027280036,
#             44.353154957613
#           ],
#           [
#             -80.288085927134,
#             44.3531261618167
#           ],
#           [
#             -80.287951530048,
#             44.3531125098555
#           ],
#           [
#             -80.2878832692439,
#             44.3531281508011
#           ],
#           [
#             -80.287738989293,
#             44.3532215337679
#           ],
#           [
#             -80.2877249039523,
#             44.3532644472593
#           ],
#           [
#             -80.287558824637,
#             44.3533088522111
#           ],
#           [
#             -80.2874518606506,
#             44.3533270111586
#           ],
#           [
#             -80.2871598357525,
#             44.3533320137857
#           ],
#           [
#             -80.2866384110016,
#             44.3533435417762
#           ]
#         ]
#       ]
#     }
#   },
#   "region_start_dates_ref": {
#     "region0": [
#       "2017-08-01",
#       "2018-08-01"
#     ],
#     "region1": [
#       "2017-08-01",
#       "2018-08-01"
#     ]
#   },
#   "region_end_dates_ref": {
#     "region0": [
#       "2017-08-31",
#       "2018-08-31"
#     ],
#     "region1": [
#       "2017-08-31",
#       "2018-08-31"
#     ]
#   }
# }
# {'region0': ['2017-08-01', '2018-08-01'], 'region1': ['2017-08-01', '2018-08-01']}
# {'region0': ['2017-08-31', '2018-08-31'], 'region1': ['2017-08-31', '2018-08-31']}
# '\nif result:\n    print("\n" + "="*80)\n    print(" SUCCESS - Parameters validated and ready!")\n    print("="*80)\n    print(f"\n Summary:")\n    print(f"  Regions: {len(result[\'ProdParams\'][\'regions\'])}")\n    print(f"  Time windows: {len(result[\'ProdParams\'][\'start_dates\'])}")\n    print(f"  Total tasks: {len(result[\'ProdParams\'][\'regions\']) * len(result[\'ProdParams\'][\'start_dates\'])}")\n    print(f"  Output folder: {result[\'ProdParams\'][\'out_folder\']}")\n    print(f"\n Processing log saved to: {result[\'ProdParams\'][\'out_folder\']}/polygon_processing_log.csv")\n    print("\n" + "="*80)\n    print("Next step: Call Production.py with the validated parameters")\n    print("="*80)\nelse:\n    print("\n" + "="*80)\n    print(" FAILED - Parameter validation failed")\n    print("="*80)\n    print("Check the error messages above for details.") '

# %%
# View processing log (if pandas is available)
try:
    import pandas as pd
    if result and result['processing_log'] is not None:
        print("\n Processing Log Preview:")
        print("=" * 80)
        display(result['processing_log'].head(10))
        print(f"\nTotal entries: {len(result['processing_log'])}")
except ImportError:
    print("pandas not available - install it to view the processing log in this cell")
    print("You can still view the CSV file directly in the output folder")
# Out:
#  Processing Log Preview:
# ================================================================================
#   region_id   area_m2  will_process status skip_reason
# 0   region0  14612.87          True  VALID         N/A
# 1   region1   4831.99          True  VALID         N/A
# Total entries: 2

# %%
import os
import sys
import geopandas as gpd

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

print(ProdParams)
# Out:
# {'sensor': 'S2_SR', 'unit': 2, 'nbYears': -1, 'regions': {'region0': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}, 'properties': {'sensor': 'S2_SR', 'unit': 2, 'nbYears': -1, 'file_variables': ['TARGET_FID', 'AsssD_1', 'AsssD_2'], 'regions_start_index': 0, 'regions_end_index': 1, 's2_grid_path': 'sentinel-2-grid.parquet', 'mode': 'regions', 'subdivide_tiles': False, 'temporal_buffer': [['2017-08-01', '2017-08-31']], 'num_years': 2, 'resolution': 30, 'projection': 'EPSG:3979', 'IncludeAngles': False, 'prod_names': ['fCOVER'], 'out_folder': 'E:\\TestingLEAFFinal\\hiyori_mogged regions csv_30m', 'out_datatype': 'int16', 'output_type': 'csv', 'csv_scale': 30, 'csv_dropNulls': True, 'csv_max_pixels': 100000, 'regions_ref': {'region0': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}}, 'region_start_dates_ref': {'region0': ['2017-08-01', '2018-08-01'], 'region1': ['2017-08-01', '2018-08-01']}, 'region_end_dates_ref': {'region0': ['2017-08-31', '2018-08-31'], 'region1': ['2017-08-31', '2018-08-31']}}}, 'file_variables': ['TARGET_FID', 'AsssD_1', 'AsssD_2'], 'regions_start_index': 0, 'regions_end_index': 1, 's2_grid_path': 'sentinel-2-grid.parquet', 'mode': 'regions', 'subdivide_tiles': False, 'temporal_buffer': [['2017-08-01', '2017-08-31']], 'num_years': 2, 'resolution': 30, 'projection': 'EPSG:3979', 'IncludeAngles': False, 'prod_names': ['fCOVER'], 'out_folder': 'E:\\TestingLEAFFinal\\hiyori_mogged regions csv_30m', 'out_datatype': 'int16', 'output_type': 'csv', 'csv_scale': 30, 'csv_dropNulls': True, 'csv_max_pixels': 100000, 'regions_ref': {'region0': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'region1': {'type': 'Po ...

# %%
main(ProdParams, CompParams)
# Out:
# <LEAF_production> Injected placeholder dates for standardization: 2017-08-01 / 2017-08-31
# <LEAF_production> All input parameters =  {'sensor': 'S2_SR', 'unit': 2, 'nbYears': -1, 'regions': {'region0': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}}, 'mode': 'regions', 'resolution': 30, 'projection': 'EPSG:3979', 'IncludeAngles': True, 'prod_names': ['fCOVER'], 'out_folder': 'E:\\TestingLEAFFinal\\hiyori_mogged regions csv_30m', 'out_datatype': 'int16', 'output_type': 'csv', 'csv_scale': 30, 'csv_dropNulls': True, 'csv_max_pixels': 100000, 'regions_ref': {'region0': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}}, 'region_start_dates_ref': {'region0': ['2017-08-01', '2018-08-01'], 'region1': ['2017-08-01', '2018-08-01']}, 'region_end_dates_ref': {'region0': ['2017-08-31', '2018-08-31'], 'region1': ['2017-08-31', '2018-08-31']}, 'region_start_dates': {'region0': ['2017-08-01', '2018-08-01'], 'region1': ['2017-08-01', '2018-08-01']}, 'region_end_dates': {'region0': ['2017-08-31', '2018-08-31'], 'region1': ['2017-08-31', '2018-08-31']}, 'start_dates': ['2017-08-01'], 'end_dates': ['2017-08-31'], 'monthly': False, 'SsrData': {'NAME': 'S2_SR', 'SSR_CODE': 21, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], '10M_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'SIX_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'NoA_BANDS': ['red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'LEAF_BANDS': ['green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'GEE_NAME': 'COPERNICUS/S2_SR_HARMONIZED', 'CLOUD': 'CLOUDY_PIXEL_PERCENTAGE', 'SZA': 'view:sun_elevation', 'SAA': 'view:sun_azimuth', 'VZA': 'view:sun_elevation', 'VAA': 'view:sun_azimuth', 'BLU': 'blue', 'GRN': 'green', 'RED': 'red', 'NIR': 'nir08', 'SW1': 'swir16', 'SW2': 'swir22'}, 'year': 2026, 'out_location': 'drive', 'months': [], 'tile_names': [], ...
#
# <LEAF_production> Using region-specific dates for region0
#   Start dates: ['2017-08-01', '2018-08-01']
#   End dates:   ['2017-08-31', '2018-08-31']
# <MosaicProduction> Processing region0 | time window: 2017-08-01 / 2017-08-31
#
# <LEAF_production> Generate and export separate vegetation biophysical maps......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': (((-81.0143277776703, 44.792849553362), (-81.0142442205963, 44.7913333551658), (-81.013283176937, 44.7913976888643), (-81.0134196694422, 44.7918539873173), (-81.0130828894072, 44.7920357810087), (-81.013046437586, 44.7928810241213), (-81.0143277776703, 44.792849553362)),)}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.01 minutes
#
# <one_mosaic> A total of 5 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/15/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/15/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/15/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/15/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/15/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/15/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/15/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/15/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/15/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/15/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/15/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/15/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/15/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/15/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/15/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/15/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TMK_20170815_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-80.96898363320281, 45.15382403743695], [-80.87584634429486, 45.15376076769412], [-80.87793799810343, 44.16531029102769], [-81.30071824497296, 44.164979714771434], [-80.96898363320281, 45.15382403743695]]]}
# Bounding Box: [-81.30071824497296, 44.164979714771434, -80.87584634429486, 45.15382403743695]
# Datetime: 2017-08-15 16:20:07.495000+00:00
# cloud cover: 33.593119
# Properties:
#   <created>: 2022-11-08T09:28:42.300Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 33.593119
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: MK
#   <grid:code>: MGRS-17TMK
#   <view:sun_azimuth>: 148.873888735149
#   <view:sun_elevation>: 55.8055567992046
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 81.244397
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.229614
#   <s2:cloud_shadow_percentage>: 4.298811
#   <s2:vegetation_percentage>: 35.412753
#   <s2:not_vegetated_percentage>: 3.740962
#   <s2:water_percentage>: 16.952682
#   <s2:unclassified_percentage>: 5.358345
#   <s2:medium_proba_clouds_percentage>: 5.422895
#   <s2:high_proba_clouds_percentage>: 27.898172
#   <s2:thin_cirrus_percentage>: 0.272052
#   <s2:snow_ice_percentage>: 0.413713
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 00.01
#   <s2:product_uri>: S2B_MSIL2A_20170815T161339_N0001_R140_T17TMK_20201014T144659.SAFE
#   <s2:generation_time>: 2020-10-14T14:46:59.453Z
#   <s2:datatake_id>: GS2B_20170815T161339_002311_N00.01
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_SHIT_20201014T144701_S20170815T162007_N00.01
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_SHIT_20201014T144701_A002311_T17TMK_N00.01
#   <s2:reflectance_conversion_factor>: 0.97406646221368
#   <datetime>: 2017-08-15T16:20:07.495000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2B_17TMK_20170815_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/d00afeea83aa23bfbfd6bca6f9a52345
#   <earthsearch:boa_offset_applied>: False
#   <processing:software>: {'sentinel2-to-stac': '0.1.0'}
#   <updated>: 2022-11-08T09:28:42.300Z
#   <proj:code>: EPSG:32617
#   <sza>: 34.1944432007954
#   <saa>: 148.873888735149
#   <vza>: 10.9308431355702
#   <vaa>: 110.327278879924
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 3kB
# Dimensions:      (y: 8, x: 5)
# Coordinates:
#   * y            (y) float64 64B -3.484e+05 -3.484e+05 ... -3.486e+05 -3.486e+05
#   * x            (x) float64 40B 1.118e+06 1.118e+06 ... 1.118e+06 1.118e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2017-08-15T16:20:07.495000
# Data variables: (12/16)
#     blue         (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     green        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     red          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge1     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge2     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge3     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     ...           ...
#     date         (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     score        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SZA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SAA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VZA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VAA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TMK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'SZA', 'SAA', 'VZA', 'VAA']
#
# <export_csv> Sampling mosaic pixels and building CSV table...
# <_clip_mosaic_to_regions> Clipped mosaic from Frozen({'y': 8, 'x': 5}) → Frozen({'y': 8, 'x': 5})  (mode=regions)
# <export_csv> Valid pixels after dropNulls filter: 29
# <export_csv> CSV written → E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\S2_SR_region0_2017-08-01_2017-08-31_30m.csv  (29 rows, 21 columns)
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.76 minutes >>>>>>
# File 'E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\log_6da358be-5762-465b-b1bf-d7a3e1bb11ea.out' does not exist.
# Directory 'E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\dask_spill_6da358be-5762-465b-b1bf-d7a3e1bb11ea' and its contents have been deleted.
#
# <create_LEAF_maps> The bands in mosaic image: Data variables:
#     blue      (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     green     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     red       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge1  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge2  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge3  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     nir08     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir16    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir22    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     scl       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     date      (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     score     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SZA       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SAA       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VZA       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VAA       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#
# <create_LEAF_maps> The bands in modified mosaic image: Data variables:
#     blue      (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     green     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     red       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge1  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge2  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge3  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     nir08     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir16    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir22    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     scl       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     date      (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     score     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     cosSZA    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     cosVZA    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     cosRAA    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#
# <get_local_CanLC> original LC map =  <xarray.DataArray (y: 160001, x: 190001)> Size: 30GB
# [30400350001 values with dtype=uint8]
# Coordinates:
#     band         int32 4B 1
#   * x            (x) float64 2MB -2.6e+06 -2.6e+06 -2.6e+06 ... 3.1e+06 3.1e+06
#   * y            (y) float64 1MB 3.915e+06 3.915e+06 ... -8.85e+05 -8.851e+05
#     spatial_ref  int32 4B 0
# Attributes:
#     TIFFTAG_SOFTWARE:  PCI Geomatica
#     TIFFTAG_DATETIME:  2020:07:01 12:00:00
#     AREA_OR_POINT:     Area
#     DESCRIPTION:       EASI Modeling Result
#     _FillValue:        0
#     scale_factor:      1.0
#     add_offset:        0.0
#
# <get_local_CanLC> clipped LC map =  <xarray.DataArray (y: 8, x: 5)> Size: 320B
# array([[15., 15., 15., 15., 15.],
#        [15., 15., 15.,  6.,  5.],
#        [15., 15., 15.,  5.,  5.],
#        [15., 15., 15., 15.,  5.],
#        [15., 15., 15., 15.,  5.],
#        [15., 15., 15., 15.,  5.],
#        [15., 15., 15., 15.,  5.],
#        [15.,  6.,  5.,  5.,  5.]])
# Coordinates:
#     band         int32 4B 1
#     spatial_ref  int32 4B 0
#   * x            (x) float64 40B 1.118e+06 1.118e+06 ... 1.118e+06 1.118e+06
#   * y            (y) float64 64B -3.484e+05 -3.484e+05 ... -3.486e+05 -3.486e+05
# Attributes:
#     TIFFTAG_SOFTWARE:  PCI Geomatica
#     TIFFTAG_DATETIME:  2020:07:01 12:00:00
#     AREA_OR_POINT:     Area
#     DESCRIPTION:       EASI Modeling Result
#     _FillValue:        0
#     scale_factor:      1.0
#     add_offset:        0.0
#
# <create_LEAF_maps> Bands in mosaic before rescaling: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'cosSZA', 'cosVZA', 'cosRAA']
# <create_LEAF_maps> Bands in ready_mosaic after rescaling: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'cosSZA', 'cosVZA', 'cosRAA']
# <estimate_VParams> the bands in DS options =  ['cosVZA', 'cosSZA', 'cosRAA', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22']
# <invalidInput> Generating sl2p input data flag
# Generating sl2p output product flag
#
#
# <<< The elapsed time for generating one monthly tile product = 0.7715662002563477 minutes>>>
#
#
# <export_VegParamMaps> data variables in given VP map: Data variables:
#     date     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     fCOVER   (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     QC       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
# <_write_VP_csv> Loaded mosaic CSV (29 rows) from E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\S2_SR_region0_2017-08-01_2017-08-31_30m.csv
# <_write_VP_csv> VP pixels after null filter: 40
# <_write_VP_csv> 29 / 29 rows matched VP values (checked via 'fCOVER').
# <_write_VP_csv> Updated CSV → E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\S2_SR_region0_2017-08-01_2017-08-31_30m.csv  (29 rows, 24 columns)
# <MosaicProduction> Processing region0 | time window: 2018-08-01 / 2018-08-31
#
# <LEAF_production> Generate and export separate vegetation biophysical maps......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': (((-81.0143277776703, 44.792849553362), (-81.0142442205963, 44.7913333551658), (-81.013283176937, 44.7913976888643), (-81.0134196694422, 44.7918539873173), (-81.0130828894072, 44.7920357810087), (-81.013046437586, 44.7928810241213), (-81.0143277776703, 44.792849553362)),)}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.02 minutes
#
# <one_mosaic> A total of 17 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/thumbnail.jp2
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/10/1/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/10/1/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/10/1/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/10/1/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/10/1/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/10/1/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/10/1/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/10/1/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/10/1/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/10/1/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/10/1/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/10/1/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/10/1/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/10/1/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/10/1/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/10/1/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TMK_20180810_1_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-80.94550349903801, 45.15381524728425], [-81.27736634163749, 44.16503879657824], [-80.87793799810343, 44.16531029102769], [-80.87584634429486, 45.15376076769412], [-80.94550349903801, 45.15381524728425]]]}
# Bounding Box: [-81.27736634163749, 44.16503879657824, -80.87584634429486, 45.15381524728425]
# Datetime: 2018-08-10 16:21:00.337000+00:00
# cloud cover: 0.213978
# Properties:
#   <created>: 2024-03-02T09:13:40.050Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 0.213978
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: MK
#   <grid:code>: MGRS-17TMK
#   <view:sun_azimuth>: 147.349897974676
#   <view:sun_elevation>: 57.1832060674556
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 82.866436
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.057551
#   <s2:cloud_shadow_percentage>: 0.506286
#   <s2:vegetation_percentage>: 73.747647
#   <s2:not_vegetated_percentage>: 4.810252
#   <s2:water_percentage>: 20.485531
#   <s2:unclassified_percentage>: 0.178754
#   <s2:medium_proba_clouds_percentage>: 0.176159
#   <s2:high_proba_clouds_percentage>: 0.033598
#   <s2:thin_cirrus_percentage>: 0.004221
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.00
#   <s2:product_uri>: S2B_MSIL2A_20180810T160819_N0500_R140_T17TMK_20230815T040600.SAFE
#   <s2:generation_time>: 2023-08-15T04:06:00.000000Z
#   <s2:datatake_id>: GS2B_20180810T160819_007459_N05.00
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_S2RP_20230815T040600_S20180810T160955_N05.00
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_S2RP_20230815T040600_A007459_T17TMK_N05.00
#   <s2:reflectance_conversion_factor>: 0.972379123238695
#   <datetime>: 2018-08-10T16:21:00.337000Z
#   <s2:sequence>: 1
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2B_17TMK_20180810_1_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/5d795428080ca0286e0de7444e96d102
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.1'}
#   <updated>: 2024-03-02T09:13:40.050Z
#   <proj:code>: EPSG:32617
#   <sza>: 32.8167939325444
#   <saa>: 147.349897974676
#   <vza>: 10.9861805040987
#   <vaa>: 110.723381235025
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 3kB
# Dimensions:      (y: 8, x: 5)
# Coordinates:
#   * y            (y) float64 64B -3.484e+05 -3.484e+05 ... -3.486e+05 -3.486e+05
#   * x            (x) float64 40B 1.118e+06 1.118e+06 ... 1.118e+06 1.118e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2018-08-10T16:21:00.337000
# Data variables: (12/16)
#     blue         (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     green        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     red          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge1     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge2     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge3     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     ...           ...
#     date         (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     score        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SZA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SAA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VZA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VAA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TMK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'SZA', 'SAA', 'VZA', 'VAA']
#
# <export_csv> Sampling mosaic pixels and building CSV table...
# <_clip_mosaic_to_regions> Clipped mosaic from Frozen({'y': 8, 'x': 5}) → Frozen({'y': 8, 'x': 5})  (mode=regions)
# <export_csv> Valid pixels after dropNulls filter: 29
# <export_csv> CSV written → E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\S2_SR_region0_2018-08-01_2018-08-31_30m.csv  (29 rows, 21 columns)
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.89 minutes >>>>>>
# File 'E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\log_89e7db6d-8c38-4f8f-9ee4-cbc53e457c6e.out' does not exist.
# Directory 'E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\dask_spill_89e7db6d-8c38-4f8f-9ee4-cbc53e457c6e' and its contents have been deleted.
#
# <create_LEAF_maps> The bands in mosaic image: Data variables:
#     blue      (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     green     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     red       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge1  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge2  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge3  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     nir08     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir16    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir22    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     scl       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     date      (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     score     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SZA       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SAA       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VZA       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VAA       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#
# <create_LEAF_maps> The bands in modified mosaic image: Data variables:
#     blue      (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     green     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     red       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge1  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge2  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge3  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     nir08     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir16    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir22    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     scl       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     date      (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     score     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     cosSZA    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     cosVZA    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     cosRAA    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#
# <get_local_CanLC> original LC map =  <xarray.DataArray (y: 160001, x: 190001)> Size: 30GB
# [30400350001 values with dtype=uint8]
# Coordinates:
#     band         int32 4B 1
#   * x            (x) float64 2MB -2.6e+06 -2.6e+06 -2.6e+06 ... 3.1e+06 3.1e+06
#   * y            (y) float64 1MB 3.915e+06 3.915e+06 ... -8.85e+05 -8.851e+05
#     spatial_ref  int32 4B 0
# Attributes:
#     TIFFTAG_SOFTWARE:  PCI Geomatica
#     TIFFTAG_DATETIME:  2020:07:01 12:00:00
#     AREA_OR_POINT:     Area
#     DESCRIPTION:       EASI Modeling Result
#     _FillValue:        0
#     scale_factor:      1.0
#     add_offset:        0.0
#
# <get_local_CanLC> clipped LC map =  <xarray.DataArray (y: 8, x: 5)> Size: 320B
# array([[15., 15., 15., 15., 15.],
#        [15., 15., 15.,  6.,  5.],
#        [15., 15., 15.,  5.,  5.],
#        [15., 15., 15., 15.,  5.],
#        [15., 15., 15., 15.,  5.],
#        [15., 15., 15., 15.,  5.],
#        [15., 15., 15., 15.,  5.],
#        [15.,  6.,  5.,  5.,  5.]])
# Coordinates:
#     band         int32 4B 1
#     spatial_ref  int32 4B 0
#   * x            (x) float64 40B 1.118e+06 1.118e+06 ... 1.118e+06 1.118e+06
#   * y            (y) float64 64B -3.484e+05 -3.484e+05 ... -3.486e+05 -3.486e+05
# Attributes:
#     TIFFTAG_SOFTWARE:  PCI Geomatica
#     TIFFTAG_DATETIME:  2020:07:01 12:00:00
#     AREA_OR_POINT:     Area
#     DESCRIPTION:       EASI Modeling Result
#     _FillValue:        0
#     scale_factor:      1.0
#     add_offset:        0.0
#
# <create_LEAF_maps> Bands in mosaic before rescaling: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'cosSZA', 'cosVZA', 'cosRAA']
# <create_LEAF_maps> Bands in ready_mosaic after rescaling: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'cosSZA', 'cosVZA', 'cosRAA']
# <estimate_VParams> the bands in DS options =  ['cosVZA', 'cosSZA', 'cosRAA', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22']
# <invalidInput> Generating sl2p input data flag
# Generating sl2p output product flag
#
#
# <<< The elapsed time for generating one monthly tile product = 0.9000549435615539 minutes>>>
#
#
# <export_VegParamMaps> data variables in given VP map: Data variables:
#     date     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     fCOVER   (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     QC       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
# <_write_VP_csv> Loaded mosaic CSV (29 rows) from E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\S2_SR_region0_2018-08-01_2018-08-31_30m.csv
# <_write_VP_csv> VP pixels after null filter: 40
# <_write_VP_csv> 29 / 29 rows matched VP values (checked via 'fCOVER').
# <_write_VP_csv> Updated CSV → E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\S2_SR_region0_2018-08-01_2018-08-31_30m.csv  (29 rows, 24 columns)
#
# <LEAF_production> Using region-specific dates for region1
#   Start dates: ['2017-08-01', '2018-08-01']
#   End dates:   ['2017-08-31', '2018-08-31']
# <MosaicProduction> Processing region1 | time window: 2017-08-01 / 2017-08-31
#
# <LEAF_production> Generate and export separate vegetation biophysical maps......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': (((-80.2866384110016, 44.3533435417762), (-80.2871598357525, 44.3533320137857), (-80.2874518606506, 44.3533270111586), (-80.287558824637, 44.3533088522111), (-80.2877249039523, 44.3532644472593), (-80.287738989293, 44.3532215337679), (-80.2878832692439, 44.3531281508011), (-80.287951530048, 44.3531125098555), (-80.288085927134, 44.3531261618167), (-80.2882027280036, 44.353154957613), (-80.2880782566738, 44.352880279965), (-80.2880395541161, 44.3528827993289), (-80.2879206306362, 44.3528989373857), (-80.2876405698119, 44.3529059627622), (-80.2874977225433, 44.3529180592246), (-80.2871254773415, 44.3529366809224), (-80.2868313289172, 44.3529866183925), (-80.2864858239462, 44.353000698271), (-80.2866384110016, 44.3533435417762)),)}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.01 minutes
#
# <one_mosaic> A total of 5 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/3/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/3/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/3/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/3/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/3/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/3/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/3/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/3/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/3/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/3/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/3/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/3/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/3/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/3/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/3/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2017/8/3/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2A_17TNK_20170803_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-79.60548769854074, 45.145313876654235], [-80.00463876405956, 44.161039200892276], [-81.00023764531663, 44.16537549832127], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.00024171761814, 44.161039200892276, -79.60548769854074, 45.153828248771845]
# Datetime: 2017-08-03 16:26:11.785000+00:00
# cloud cover: 48.137439
# Properties:
#   <created>: 2022-11-08T13:27:17.659Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 48.137439
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:sun_azimuth>: 152.100196116746
#   <view:sun_elevation>: 60.2129809047126
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 13.714427
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.144098
#   <s2:cloud_shadow_percentage>: 0.6102
#   <s2:vegetation_percentage>: 12.144495
#   <s2:not_vegetated_percentage>: 0.941063
#   <s2:water_percentage>: 35.340199
#   <s2:unclassified_percentage>: 2.679689
#   <s2:medium_proba_clouds_percentage>: 5.905157
#   <s2:high_proba_clouds_percentage>: 30.188632
#   <s2:thin_cirrus_percentage>: 12.04365
#   <s2:snow_ice_percentage>: 0.002819
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 00.01
#   <s2:product_uri>: S2A_MSIL2A_20170803T161901_N0001_R040_T17TNK_20201019T223725.SAFE
#   <s2:generation_time>: 2020-10-19T22:37:25.322Z
#   <s2:datatake_id>: GS2A_20170803T161901_011048_N00.01
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_SHIT_20201019T223727_S20170803T162611_N00.01
#   <s2:granule_id>: S2A_OPER_MSI_L2A_TL_SHIT_20201019T223727_A011048_T17TNK_N00.01
#   <s2:reflectance_conversion_factor>: 0.97057870924473
#   <datetime>: 2017-08-03T16:26:11.785000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2017/8/S2A_17TNK_20170803_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/2ad6dd050fa6d2a8b59264586dc3eede
#   <earthsearch:boa_offset_applied>: False
#   <processing:software>: {'sentinel2-to-stac': '0.1.0'}
#   <updated>: 2022-11-08T13:27:17.659Z
#   <proj:code>: EPSG:32617
#   <sza>: 29.7870190952874
#   <saa>: 152.100196116746
#   <vza>: 8.19630025329192
#   <vaa>: 286.10703332069
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 1kB
# Dimensions:      (y: 4, x: 5)
# Coordinates:
#   * y            (y) float64 32B -3.838e+05 -3.838e+05 -3.838e+05 -3.839e+05
#   * x            (x) float64 40B 1.187e+06 1.187e+06 ... 1.187e+06 1.187e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2017-08-03T16:26:11.785000
# Data variables: (12/16)
#     blue         (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     green        (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     red          (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     rededge1     (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     rededge2     (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     rededge3     (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     ...           ...
#     date         (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     score        (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     SZA          (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     SAA          (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     VZA          (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     VAA          (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'SZA', 'SAA', 'VZA', 'VAA']
#
# <export_csv> Sampling mosaic pixels and building CSV table...
# <_clip_mosaic_to_regions> Clipped mosaic from Frozen({'y': 4, 'x': 5}) → Frozen({'y': 4, 'x': 5})  (mode=regions)
# <export_csv> Valid pixels after dropNulls filter: 13
# <export_csv> CSV written → E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\S2_SR_region1_2017-08-01_2017-08-31_30m.csv  (13 rows, 21 columns)
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.57 minutes >>>>>>
# ...
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.01 minutes
#
# <one_mosaic> A total of 19 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/thumbnail.jp2
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/1/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/1/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/1/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/1/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/1/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/1/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/1/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/1/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/1/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/1/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/1/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/1/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/1/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/1/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/1/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2018/8/23/1/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TNK_20180823_1_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-81.00023764893122, 44.16627582418431], [-79.99112303289569, 44.16191081403583], [-79.6088439512832, 45.10473718716024], [-79.60487578550494, 45.14530640203707], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.00024171761814, 44.16191081403583, -79.60487578550494, 45.153828248771845]
# Datetime: 2018-08-23 16:30:49.237000+00:00
# cloud cover: 16.631016
# Properties:
#   <created>: 2024-02-27T14:44:24.498Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 16.631016
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:sun_azimuth>: 157.09609963341
#   <view:sun_elevation>: 54.7490634124459
#   <s2:degraded_msi_data_percentage>: 0.0127
#   <s2:nodata_pixel_percentage>: 12.769404
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.099728
#   <s2:cloud_shadow_percentage>: 1.229269
#   <s2:vegetation_percentage>: 44.433576
#   <s2:not_vegetated_percentage>: 2.504691
#   <s2:water_percentage>: 33.935258
#   <s2:unclassified_percentage>: 1.166466
#   <s2:medium_proba_clouds_percentage>: 6.784305
#   <s2:high_proba_clouds_percentage>: 5.151074
#   <s2:thin_cirrus_percentage>: 4.695636
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.00
#   <s2:product_uri>: S2B_MSIL2A_20180823T161819_N0500_R040_T17TNK_20230816T204733.SAFE
#   <s2:generation_time>: 2023-08-16T20:47:33.000000Z
#   <s2:datatake_id>: GS2B_20180823T161819_007645_N05.00
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_S2RP_20230816T204733_S20180823T162356_N05.00
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_S2RP_20230816T204733_A007645_T17TNK_N05.00
#   <s2:reflectance_conversion_factor>: 0.976897734843365
#   <datetime>: 2018-08-23T16:30:49.237000Z
#   <s2:sequence>: 1
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2018/8/S2B_17TNK_20180823_1_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/026126f9da6578a2eb8fd13ed7b2528b
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.1'}
#   <updated>: 2024-02-27T14:44:24.498Z
#   <proj:code>: EPSG:32617
#   <sza>: 35.2509365875541
#   <saa>: 157.09609963341
#   <vza>: 8.14995231895604
#   <vaa>: 285.188627077647
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 1kB
# Dimensions:      (y: 4, x: 5)
# Coordinates:
#   * y            (y) float64 32B -3.838e+05 -3.838e+05 -3.838e+05 -3.839e+05
#   * x            (x) float64 40B 1.187e+06 1.187e+06 ... 1.187e+06 1.187e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2018-08-23T16:30:49.237000
# Data variables: (12/16)
#     blue         (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     green        (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     red          (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     rededge1     (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     rededge2     (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     rededge3     (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     ...           ...
#     date         (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     score        (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     SZA          (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     SAA          (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     VZA          (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     VAA          (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'SZA', 'SAA', 'VZA', 'VAA']
#
# <export_csv> Sampling mosaic pixels and building CSV table...
# <_clip_mosaic_to_regions> Clipped mosaic from Frozen({'y': 4, 'x': 5}) → Frozen({'y': 4, 'x': 5})  (mode=regions)
# <export_csv> Valid pixels after dropNulls filter: 13
# <export_csv> CSV written → E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\S2_SR_region1_2018-08-01_2018-08-31_30m.csv  (13 rows, 21 columns)
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.76 minutes >>>>>>
# File 'E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\log_fbdd8e0c-7573-40f8-8a25-0ca656e75675.out' does not exist.
# Directory 'E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\dask_spill_fbdd8e0c-7573-40f8-8a25-0ca656e75675' and its contents have been deleted.
#
# <create_LEAF_maps> The bands in mosaic image: Data variables:
#     blue      (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     green     (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     red       (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     rededge1  (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     rededge2  (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     rededge3  (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     nir08     (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     swir16    (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     swir22    (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     scl       (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     date      (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     score     (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     SZA       (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     SAA       (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     VZA       (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     VAA       (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#
# <create_LEAF_maps> The bands in modified mosaic image: Data variables:
#     blue      (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     green     (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     red       (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     rededge1  (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     rededge2  (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     rededge3  (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     nir08     (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     swir16    (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     swir22    (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     scl       (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     date      (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     score     (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     cosSZA    (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     cosVZA    (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     cosRAA    (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#
# <get_local_CanLC> original LC map =  <xarray.DataArray (y: 160001, x: 190001)> Size: 30GB
# [30400350001 values with dtype=uint8]
# Coordinates:
#     band         int32 4B 1
#   * x            (x) float64 2MB -2.6e+06 -2.6e+06 -2.6e+06 ... 3.1e+06 3.1e+06
#   * y            (y) float64 1MB 3.915e+06 3.915e+06 ... -8.85e+05 -8.851e+05
#     spatial_ref  int32 4B 0
# Attributes:
#     TIFFTAG_SOFTWARE:  PCI Geomatica
#     TIFFTAG_DATETIME:  2020:07:01 12:00:00
#     AREA_OR_POINT:     Area
#     DESCRIPTION:       EASI Modeling Result
#     _FillValue:        0
#     scale_factor:      1.0
#     add_offset:        0.0
#
# <get_local_CanLC> clipped LC map =  <xarray.DataArray (y: 4, x: 5)> Size: 160B
# array([[14.,  6., 15., 15., 15.],
#        [ 6., 15., 15., 15., 15.],
#        [15., 15., 15., 15., 15.],
#        [15., 15., 15., 15., 15.]])
# Coordinates:
#     band         int32 4B 1
#     spatial_ref  int32 4B 0
#   * x            (x) float64 40B 1.187e+06 1.187e+06 ... 1.187e+06 1.187e+06
#   * y            (y) float64 32B -3.838e+05 -3.838e+05 -3.838e+05 -3.839e+05
# Attributes:
#     TIFFTAG_SOFTWARE:  PCI Geomatica
#     TIFFTAG_DATETIME:  2020:07:01 12:00:00
#     AREA_OR_POINT:     Area
#     DESCRIPTION:       EASI Modeling Result
#     _FillValue:        0
#     scale_factor:      1.0
#     add_offset:        0.0
#
# <create_LEAF_maps> Bands in mosaic before rescaling: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'cosSZA', 'cosVZA', 'cosRAA']
# <create_LEAF_maps> Bands in ready_mosaic after rescaling: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'cosSZA', 'cosVZA', 'cosRAA']
# <estimate_VParams> the bands in DS options =  ['cosVZA', 'cosSZA', 'cosRAA', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22']
# <invalidInput> Generating sl2p input data flag
# Generating sl2p output product flag
#
#
# <<< The elapsed time for generating one monthly tile product = 0.7695287466049194 minutes>>>
#
#
# <export_VegParamMaps> data variables in given VP map: Data variables:
#     date     (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     fCOVER   (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
#     QC       (y, x) float32 80B dask.array<chunksize=(4, 5), meta=np.ndarray>
# <_write_VP_csv> Loaded mosaic CSV (13 rows) from E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\S2_SR_region1_2018-08-01_2018-08-31_30m.csv
# <_write_VP_csv> VP pixels after null filter: 20
# <_write_VP_csv> 13 / 13 rows matched VP values (checked via 'fCOVER').
# <_write_VP_csv> Updated CSV → E:\TestingLEAFFinal\hiyori_mogged regions csv_30m\S2_SR_region1_2018-08-01_2018-08-31_30m.csv  (13 rows, 24 columns)
