# %% [markdown]
# # Parameter Preparation - Interactive Notebook
#
# This notebook provides **4 pre-configured parameter templates** for different use cases.
#
# ## Quick Guide
#
# 1. **Choose your template** (Template 1-4 below)
# 2. **Customize the parameters** directly in the dictionary
# 3. **Run the cell** to see your configuration
# 4. **Execute the preparation** using the last cell
#
# ---

# %%
import os
import sys
from pathlib import Path

project_root = Path.cwd()
sys.path.insert(0, str(project_root))

from prepare_params import prepare_production_params

print("Modules imported successfully")
print(f"Current working directory: {os.getcwd()}")


kml = "Sample Points\AfforestationSItesFixed.kml"
shp = "Sample Points\FieldPoints32_2018.shp"

print(kml)
print(shp)
# Out:
# Modules imported successfully
# Current working directory: C:\Users\aradar\LEAF Files\LEAF_runner
# Sample Points\AfforestationSItesFixed.kml
# Sample Points\FieldPoints32_2018.shp

# %%
# TEMPLATE 1: Single Year Monthly Mosaics
# Use Case: Generate monthly mosaics for specific months in one year
# Example: Summer months (June, July, August) of 2023
# Customize these parameters as needed:

Template1_ProdParams = {
    # ============ REQUIRED PARAMETERS ============
    'sensor': 'S2_SR',                    # Sensor type
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'nbYears': -1,            # positive int for annual product, or negative int for monthly product
    'year': 2023,                          # CHANGE THIS: Year to process
    'months': [6, 7, 8],                   # CHANGE THIS: Months to process (1-12)
    
    # ============ REGION PARAMETERS ============
    'regions': kml,  # CHANGE THIS: Path to your KML/SHP file
    'regions_start_index': 21,              # CHANGE THIS: Start at this region index
    'regions_end_index': 30,             # CHANGE THIS: End at this index (None = all)
    
    # ============ BUFFER PARAMETERS ============
    'spatial_buffer_m': -20,             # UNCOMMENT & CHANGE: Buffer in meters around regions
    # 'temporal_buffer': [-5, 5],          # UNCOMMENT & CHANGE: [days_before, days_after]
    
    # ============ OUTPUT PARAMETERS ============
    'resolution': 30,                      # Resolution in meters
    'projection': 'EPSG:3979',             # Coordinate projection
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'out_folder': 'E:/S2_mosaics_runner_2026/S2_temp1_3_30m',
    'out_datatype': 'int16'
}

Template1_CompParams = {
  "number_workers":32,     
  "debug"       : True,
  "entire_tile" : False, 
  "nodes"       : 1,
  "node_memory" : "16G",
  'chunk_size': {'x': 512, 'y': 512}
}

# Display configuration
print("="*80)
print("TEMPLATE 1: Single Year Monthly Mosaics")
print("="*80)
print(f"Year: {Template1_ProdParams['year']}")
print(f"Months: {Template1_ProdParams['months']}")
print(f"Region file: {Template1_ProdParams['regions']}")
print(f"Indices: {Template1_ProdParams['regions_start_index']} to {Template1_ProdParams['regions_end_index'] or 'end'}")
print(f"Output: {Template1_ProdParams['out_folder']}")
if 'spatial_buffer_m' in Template1_ProdParams:
    print(f"Spatial buffer: {Template1_ProdParams['spatial_buffer_m']}m")
if 'temporal_buffer' in Template1_ProdParams:
    print(f"Temporal buffer: {Template1_ProdParams['temporal_buffer']} days")
print("="*80)
print("\n✓ Template 1 configured")
# Out:
# ================================================================================
# TEMPLATE 1: Single Year Monthly Mosaics
# ================================================================================
# Year: 2023
# Months: [6, 7, 8]
# Region file: Sample Points\AfforestationSItesFixed.kml
# Indices: 0 to 20
# Output: E:/S2_mosaics_runner_2026/S2_temp1_2_30m
# Spatial buffer: -20m
# ================================================================================
#
# ✓ Template 1 configured

# %%
# TEMPLATE 2: Custom Date Ranges
#Use Case: Specify exact start and end dates for each time window
#Example: Pre/post event comparison or specific growing periods
#What this creates:
#Custom windows based on your exact dates
# Customize these parameters as needed:

Template2_ProdParams = {
    # ============ REQUIRED PARAMETERS ============
    'sensor': 'S2_SR',
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'nbYears': -1,            # positive int for annual product, or negative int for monthly product
    
    # CHANGE THESE: Specify exact date ranges (must have same number of start and end dates)
    'start_dates': ['2023-06-01', '2023-08-15', '2023-10-01'],  # Start dates for each window
    'end_dates':   ['2023-06-30', '2023-09-15', '2023-10-31'],  # End dates for each window
    
    # ============ REGION PARAMETERS ============
    'regions': kml,  # 🔧 CHANGE THIS
    'regions_start_index': 1,              # CHANGE THIS
    'regions_end_index': 5,               # CHANGE THIS: Process first 10 regions only
    
    # ============ BUFFER PARAMETERS ============
    'spatial_buffer_m': 100,               # CHANGE THIS: 100m buffer
    # 'temporal_buffer': [-3, 3],          # UNCOMMENT & CHANGE if needed
    
    # ============ OUTPUT PARAMETERS ============
    'resolution': 30,
    'projection': 'EPSG:3979',
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'out_folder': 'E:/S2_mosaics_runner_2026/S2_temp2_30m',
    'out_datatype': 'int16'
}

Template2_CompParams = {
  "number_workers":32,     
  "debug"       : True,
  "entire_tile" : False, 
  "nodes"       : 1,
  "node_memory" : "16G",
  'chunk_size': {'x': 512, 'y': 512}
}

# Display configuration
print("="*80)
print("TEMPLATE 2: Custom Date Ranges")
print("="*80)
print(f"Number of windows: {len(Template2_ProdParams['start_dates'])}")
for i, (start, end) in enumerate(zip(Template2_ProdParams['start_dates'], Template2_ProdParams['end_dates']), 1):
    print(f"  Window {i}: {start} to {end}")
print(f"Region file: {Template2_ProdParams['regions']}")
print(f"Indices: {Template2_ProdParams['regions_start_index']} to {Template2_ProdParams['regions_end_index'] or 'end'}")
print(f"Spatial buffer: {Template2_ProdParams.get('spatial_buffer_m', 'None')}m")
print(f"Output: {Template2_ProdParams['out_folder']}")
print("="*80)
print("\n Template 2 configured")
# Out:
# ================================================================================
# TEMPLATE 2: Custom Date Ranges
# ================================================================================
# Number of windows: 3
#   Window 1: 2023-06-01 to 2023-06-30
#   Window 2: 2023-08-15 to 2023-09-15
#   Window 3: 2023-10-01 to 2023-10-31
# Region file: Sample Points\AfforestationSItesFixed.kml
# Indices: 1 to 5
# Spatial buffer: 100m
# Output: E:/S2_mosaics_runner_2026/S2_temp2_30m
# ================================================================================
#
#  Template 2 configured

# %%
# TEMPLATE 3: Single Date Processing
# Use Case: Process imagery for one specific date
# Example: Capture a snapshot on a specific event date
# Customize these parameters as needed:

Template3_ProdParams = {
    # ============ REQUIRED PARAMETERS ============
    'sensor': 'S2_SR',
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'nbYears': -1,            # positive int for annual product, or negative int for monthly product
    'start_dates': ['2023-07-15'],            # CHANGE THIS: Single date to process (YYYY-MM-DD)
    
    # ============ REGION PARAMETERS ============
    'regions': kml,  # 🔧 CHANGE THIS
    'regions_start_index': 0,
    'regions_end_index': 5,                # CHANGE THIS: First 5 regions only
    
    # ============ BUFFER PARAMETERS ============
    'spatial_buffer_m': 50,                # CHANGE THIS: 50m buffer
    'temporal_buffer': [-20, 10],            # CHANGE THIS: bufferdays around the date
    
    # ============ OUTPUT PARAMETERS ============
    'resolution': 30,
    'projection': 'EPSG:3979',
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'out_folder': 'E:/S2_mosaics_runner_2026/S2_temp3_30m',
    'out_datatype': 'int16'
}

Template3_CompParams = {
  "number_workers":32,     
  "debug"       : True,
  "entire_tile" : False, 
  "nodes"       : 1,
  "node_memory" : "16G",
  'chunk_size': {'x': 512, 'y': 512}
}

# Display configuration
print("="*80)
print("TEMPLATE 3: Single Date Processing")
print("="*80)
print(f"Date: {Template3_ProdParams['start_dates']}")
print(f"Region file: {Template3_ProdParams['regions']}")
print(f"Indices: {Template3_ProdParams['regions_start_index']} to {Template3_ProdParams['regions_end_index'] or 'end'}")
print(f"Spatial buffer: {Template3_ProdParams.get('spatial_buffer_m', 'None')}m")
print(f"Temporal buffer: {Template3_ProdParams.get('temporal_buffer', 'None')} days")
print(f"Output: {Template3_ProdParams['out_folder']}")
print("="*80)
print("\n Template 3 configured")
# Out:
# ================================================================================
# TEMPLATE 3: Single Date Processing
# ================================================================================
# Date: ['2023-07-15']
# Region file: Sample Points\AfforestationSItesFixed.kml
# Indices: 0 to 5
# Spatial buffer: 50m
# Temporal buffer: [-20, 10] days
# Output: E:/S2_mosaics_runner_2026/S2_temp3_30m
# ================================================================================
#
#  Template 3 configured

# %%
# TEMPLATE 4: Multi-Year Monthly Mosaics
# Use Case: Repeat the same months across multiple years for trend analysis
# Example: Summer months for 5 years (2019-2023)
# Customize these parameters as needed:

Template4_ProdParams = {
    # ============ REQUIRED PARAMETERS ============
    'sensor': 'S2_SR',
    'year': 2019,                          # CHANGE THIS: Starting year
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'nbYears': -1,            # positive int for annual product, or negative int for monthly product
    'num_years': 5,                        # CHANGE THIS: Number of years to process
    'months': [7, 8],                   # CHANGE THIS: Months to repeat each year
    
    # ============ REGION PARAMETERS ============
    'regions': kml,  # 🔧 CHANGE THIS
    'regions_start_index': 1,
    'regions_end_index': 3,             # Process all regions
    
    # ============ BUFFER PARAMETERS ============
    'spatial_buffer_m': 100,               # CHANGE THIS
    'temporal_buffer': [-5, 5],            # CHANGE THIS: ±5 days
    
    # ============ OUTPUT PARAMETERS ============
    'resolution': 30,
    'projection': 'EPSG:3979',
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'out_folder': 'E:/S2_mosaics_runner_2026/S2_temp4_30m',
    'out_datatype': 'int16'
}

Template4_CompParams = {
  "number_workers":32,     
  "debug"       : True,
  "entire_tile" : False, 
  "nodes"       : 1,
  "node_memory" : "16G",
  'chunk_size': {'x': 512, 'y': 512}
}

# Display configuration
print("="*80)
print("TEMPLATE 4: Multi-Year Monthly Mosaics")
print("="*80)
print(f"Years: {Template4_ProdParams['year']} to {Template4_ProdParams['year'] + Template4_ProdParams['num_years'] - 1}")
print(f"Months per year: {Template4_ProdParams['months']}")
print(f"Total windows: {len(Template4_ProdParams['months']) * Template4_ProdParams['num_years']}")
print(f"Region file: {Template4_ProdParams['regions']}")
print(f"Indices: {Template4_ProdParams['regions_start_index']} to {Template4_ProdParams['regions_end_index'] or 'end'}")
print(f"Spatial buffer: {Template4_ProdParams.get('spatial_buffer_m', 'None')}m")
print(f"Temporal buffer: {Template4_ProdParams.get('temporal_buffer', 'None')} days")
print(f"Output: {Template4_ProdParams['out_folder']}")
print("="*80)
print("\n Template 4 configured")
# Out:
# ================================================================================
# TEMPLATE 4: Multi-Year Monthly Mosaics
# ================================================================================
# Years: 2019 to 2023
# Months per year: [7, 8]
# Total windows: 10
# Region file: Sample Points\AfforestationSItesFixed.kml
# Indices: 1 to 3
# Spatial buffer: 100m
# Temporal buffer: [-5, 5] days
# Output: E:/S2_mosaics_runner_2026/S2_temp4_30m
# ================================================================================
#
#  Template 4 configured

# %% [markdown]
# ---
#
# # Run Parameter Preparation
#
# Choose which template to run by uncommenting the appropriate line below:

# %%
# ============================================
# SELECT YOUR TEMPLATE HERE
# ============================================
# Uncomment ONE of these lines:

ProdParams, CompParams = Template1_ProdParams, Template1_CompParams  # Monthly mosaics
# ProdParams, CompParams = Template2_ProdParams, Template2_CompParams  # Custom date ranges
# ProdParams, CompParams = Template3_ProdParams, Template3_CompParams  # Single date
# ProdParams, CompParams = Template4_ProdParams, Template4_CompParams  # Multi-year monthly

print("Template selected")
print(f"  Output folder: {ProdParams['out_folder']}")
# Out:
# Template selected
#   Output folder: E:/S2_mosaics_runner_2026/S2_temp1_2_30m

# %% [markdown]
# ## Execute Parameter Preparation
#
# This cell will:
# 1. Load regions from your KML/SHP file
# 2. Generate time windows
# 3. Validate all polygons
# 4. Create a processing log
# 5. Return validated parameters ready for Production.py

# %%
# Run the parameter preparation
result = prepare_production_params(ProdParams, CompParams)

if result:
    print("\n" + "="*80)
    print(" SUCCESS - Parameters validated and ready!")
    print("="*80)
    print(f"\n Summary:")
    print(f"  Regions: {len(result['ProdParams']['regions'])}")
    print(f"  Time windows: {len(result['ProdParams']['start_dates'])}")
    print(f"  Total tasks: {len(result['ProdParams']['regions']) * len(result['ProdParams']['start_dates'])}")
    print(f"  Output folder: {result['ProdParams']['out_folder']}")
    print(f"\n Processing log saved to: {result['ProdParams']['out_folder']}/polygon_processing_log.csv")
    print("\n" + "="*80)
    print("Next step: Call Production.py with the validated parameters")
    print("="*80)
else:
    print("\n" + "="*80)
    print(" FAILED - Parameter validation failed")
    print("="*80)
    print("Check the error messages above for details.")
# Out:
# ================================================================================
# PARAMETER PREPARATION PIPELINE
# ================================================================================
#
# Step 1/4: Loading regions from files...
# <handle_regions_from_file> Detected file-based regions input: Sample Points\AfforestationSItesFixed.kml
# <handle_regions_from_file> Loading regions...
# Applied -20m buffer to geometries
# <handle_regions_from_file> Loaded 21 regions from file
#
# Step 2/4: Generating temporal windows...
# <form_time_windows> Generating temporal windows...
# <form_time_windows> Mode 1: Single year months (2023)
# <form_time_windows> Generated 3 time windows
#
# Step 3/4: Ensuring date symmetry...
#
# Step 4/4: Validating polygons...
#
# ================================================================================
# POLYGON VALIDATION AND FILTERING
# ================================================================================
#
# Processing log saved to: E:/S2_mosaics_runner_2026/S2_temp1_2_30m\polygon_processing_log.csv
#
# Summary:
#    Total region-date combinations: 63
#    Valid for processing: 63
#    Skipped (zero area): 0
# {'region0': {'type': 'Polygon', 'coordinates': [[[-81.01407002242462, 44.79267906707021], [-81.01330262006587, 44.79269791515045], [-81.01332729853362, 44.792125598129914], [-81.01356958725377, 44.79199481022313], [-81.01358754905286, 44.79198412839945], [-81.01360401796325, 44.79197228928953], [-81.01361884753459, 44.79195939817421], [-81.01363190589481, 44.79194556968921], [-81.01364307692285, 44.79193092680585], [-81.01365226128124, 44.79191559973739], [-81.0136593772994, 44.791899724781175], [-81.01366436169985, 44.79188344310641], [-81.01366717016083, 44.79186689949894], [-81.01366777771032, 44.79185024107373], [-81.01366617894813, 44.79183361596648], [-81.01366238809366, 44.79181717201645], [-81.01358397645194, 44.79155504536759], [-81.01400652550205, 44.79152675923877], [-81.01407002242462, 44.79267906707021]]]}, 'region1': {'type': 'Polygon', 'coordinates': [[[-80.28757693170076, 44.353088925477714], [-80.28757436343093, 44.35309058774067], [-80.28755681331879, 44.35310315525703], [-80.28754111727173, 44.35311692755925], [-80.28753075888093, 44.353128160128016], [-80.28748734176706, 44.35313976860315], [-80.28742029000678, 44.35315115176717], [-80.28715396984438, 44.35315571400851], [-80.28715226504858, 44.35315574745682], [-80.2868482330018, 44.35316246955875], [-80.2868667295257, 44.35316112943509], [-80.28688791987476, 44.35315823001266], [-80.28716256523732, 44.35311160355574], [-80.2875148177553, 44.353093981943964], [-80.28752652950898, 44.35309319356706], [-80.28757693170076, 44.353088925477714]]]}, 'region2': {'type': 'Polygon', 'coordinates': [[[-80.52935543585073, 44.524090455747064], [-80.52366623593824, 44.52511605928874], [-80.52357050273189, 44.52510019710509], [-80.52342300648527, 44.52489802696817], [-80.5292776053621, 44.52377986647738], [-80.52935543585073, 44.524090455747064]]]}, 'region3': {'type': 'Polygon', 'coordinates': [[[-80.3771610093081, 44.32412761042391], [-80.37718479512608, 44.324130729107026], [-80.37720889284101, 44.32413215384387], [-80.37723306893287, 44.32413187082791], [-80.37761443008196, 44.32411389999962], [-80.37808623179264, 44.325563972091935], [-80.3764340949819, 44.32574395821214], [-80.37638788588333, 44.32573619452611], [-80.37638658368334, 44.3257346884808], [-80.37637288192575, 44.32572045186878], [-80.37635730224719, 44.32570724787696], [-80.37633999468783, 44.32569520366488], [-80.37632112592753, 44.32568443522284], [-80.37630087768085, 44.3256750462549], [-80.37627944494687, 44.32566712718023], [-80.37625703413148, 44.3256607542623], [-80.37623386105946, 44.325655988874566], [-80.37582727369465, 44.32558767568043], [-80.37580246293425, 44.3255844609074], [-80.37577732381465, 44.3255830887045], [-80.37575212117189, 44.32558357352767], [-80.37541292039556, 44.32560263689509], [-80.37507466834043, 44.32407466641943], [-80.37637487169384, 44.32380911878289], [-80.37638603406049, 44.32382455894062], [-80.37647126546935, 44.32394656754978], [-80.3764830055654, 44.323961511448296], [-80.3764967132093, 44.32397556554219], [-80.37651225862605, 44.323988596774484], [-80.37652949464108, 44.32400048177194], [-80.37654825807373, 44.32401110801322], [-80.3765683712822, 44.324020374894104], [-80.37658964384528, 44.32402819468021], [-80.37661187436524, 44.32403449333738], [-80.37663485237456, 44.32403921123288], [-80.37685009728554, 44.32407537542745], [-80.3771610093081, 44.32412761042391]]]}, 'region4': {'type': 'Polygon', 'coordinates': [[[-80.44120286751011, 44.44671753250675], [-80.4401808073085, 44.44695329112621], [-80.43983407691753, 44.44490172259086], [-80.44079568691667, 44.444660689701145], [-80.44120286751011, 44.44671753250675]]]}, 'region5': {'type': 'Polygon', 'coordinates': [[[-80.44190487545005, 44.44652465862805], [-80.44187648925327, 44.446536470156694], [-80.44180237681462, 44.44616610923648], [-80.44190487545005, 44.44652465862805]]]}, 'region6': {'type': 'Polygon', 'coordinates': [[[-80.93183825777987, 44.54975002114337], [-80.93001168186503, 44.54997727056954 ...
#
# Proceeding with 21 valid region(s) out of 21 total
# ================================================================================
#
#
# ================================================================================
# PARAMETER PREPARATION COMPLETE
# ================================================================================
# Regions: 21
# Time windows: 3
# Total tasks: 63
# ================================================================================
#
#
# ================================================================================
#  SUCCESS - Parameters validated and ready!
# ================================================================================
#
#  Summary:
#   Regions: 21
#   Time windows: 3
#   Total tasks: 63
#   Output folder: E:/S2_mosaics_runner_2026/S2_temp1_2_30m
#
#  Processing log saved to: E:/S2_mosaics_runner_2026/S2_temp1_2_30m/polygon_processing_log.csv
#
# ================================================================================
# Next step: Call Production.py with the validated parameters
# ================================================================================

# %% [markdown]
# ---
#
# # View Results (Optional)
#
# Examine the validated parameters and processing log:

# %%
# View validated parameters
if result:
    print("\n Time Windows:")
    print("=" * 80)
    for i, (start, end) in enumerate(zip(result['ProdParams']['start_dates'], 
                                          result['ProdParams']['end_dates']), 1):
        print(f"  {i:2d}. {start} to {end}")
    
    print("\n Regions:")
    print("=" * 80)
    region_names = list(result['ProdParams']['regions'].keys())
    for i, name in enumerate(region_names[:10], 1):  # Show first 10
        print(f"  {i:2d}. {name}")
    if len(region_names) > 10:
        print(f"  ... and {len(region_names) - 10} more")
# Out:
#  Time Windows:
# ================================================================================
#    1. 2023-06-01 to 2023-06-30
#    2. 2023-07-01 to 2023-07-31
#    3. 2023-08-01 to 2023-08-31
#
#  Regions:
# ================================================================================
#    1. region0
#    2. region1
#    3. region2
#    4. region3
#    5. region4
#    6. region5
#    7. region6
#    8. region7
#    9. region8
#   10. region9
#   ... and 11 more

# %%
# View processing log (if pandas is available)
try:
    import pandas as pd
    if result and result['processing_log'] is not None:
        print("\n Processing Log Preview:")
        print("=" * 80)
        display(result['processing_log'].head(10))
        print(f"\nTotal entries: {len(result['processing_log'])}")
except ImportError:
    print("pandas not available - install it to view the processing log in this cell")
    print("You can still view the CSV file directly in the output folder")
# Out:
#  Processing Log Preview:
# ================================================================================
#   region_id        date   area_m2  will_process  status skip_reason  \
# 0   region0  2023-06-30   4109.91          True  QUEUED         N/A
# 1   region0  2023-07-31   4109.91          True  QUEUED         N/A
# 2   region0  2023-08-31   4109.91          True  QUEUED         N/A
# 3   region1  2023-06-30    149.82          True  QUEUED         N/A
# 4   region1  2023-07-31    149.82          True  QUEUED         N/A
# 5   region1  2023-08-31    149.82          True  QUEUED         N/A
# 6   region2  2023-06-30  10399.67          True  QUEUED         N/A
# 7   region2  2023-07-31  10399.67          True  QUEUED         N/A
# 8   region2  2023-08-31  10399.67          True  QUEUED         N/A
# 9   region3  2023-06-30  25881.84          True  QUEUED         N/A
#
#                     timestamp
# 0  2026-02-09T10:24:45.937795
# 1  2026-02-09T10:24:45.937795
# 2  2026-02-09T10:24:45.937795
# 3  2026-02-09T10:24:45.937795
# 4  2026-02-09T10:24:45.937795
# 5  2026-02-09T10:24:45.937795
# 6  2026-02-09T10:24:45.937795
# 7  2026-02-09T10:24:45.937795
# 8  2026-02-09T10:24:45.937795
# 9  2026-02-09T10:24:45.937795
# Total entries: 63

# %% [markdown]
# ---
#
# # Next Steps
#
# Now that your parameters are validated, you can:
#
# 1. **Review the processing log** in your output folder
# 2. **Call Production.py** with the validated parameters:
#
# ```python
# from Production import main
# main(result['ProdParams'], result['CompParams'])
# ```
#
# ---
#
# # Parameter Reference
#
# ### Common Parameters (All Templates)
#
# | Parameter | Type | Description | Example |
# |-----------|------|-------------|----------|
# | `sensor` | str | Sensor type | `'HLS_SR'` |
# | `regions` | str | Path to KML/SHP file | `'./data/regions.kml'` |
# | `regions_start_index` | int | First region to process | `0` |
# | `regions_end_index` | int/None | Last region to process | `10` or `None` |
# | `spatial_buffer_m` | float | Buffer in meters | `100` |
# | `temporal_buffer` | list | Days before/after | `[-5, 5]` |
# | `resolution` | int | Meters per pixel | `30` |
# | `projection` | str | Coordinate system | `'EPSG:3979'` |
# | `out_folder` | str | Output directory | `'./output'` |
#
# ### Template-Specific Parameters
#
# **Template 1 & 4:**
# - `year`: Starting year (int)
# - `months`: List of months (list of int, 1-12)
# - `num_years`: Number of years (Template 4 only)
#
# **Template 2:**
# - `start_dates`: List of start dates (list of str, 'YYYY-MM-DD')
# - `end_dates`: List of end dates (list of str, 'YYYY-MM-DD')
#
# **Template 3:**
# - `start_date`: Single date (str, 'YYYY-MM-DD')
#
# ---
#
# ## Tips
#
# 1. **Test with small subsets first**: Use `regions_end_index` to process just a few regions
# 2. **Use buffers wisely**: Temporal buffers increase image availability
# 3. **Check the log**: Always review `polygon_processing_log.csv` before full runs
# 4. **Save working configs**: Keep successful parameter sets for future use
#
# ---

# %%
import os
import sys
import geopandas as gpd

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
INVALID_KEYS = {
    "regions_start_index",
    "regions_end_index",
    "spatial_buffer_m",
    "temporal_buffer",
    "num_years"
}

for key in list(ProdParams.keys()):
    if key in INVALID_KEYS:
        ProdParams.pop(key)

# %%
print(ProdParams)
# Out:
# {'sensor': 'S2_SR', 'unit': 2, 'nbYears': -1, 'year': 2023, 'months': [6, 7, 8], 'regions': {'region0': {'type': 'Polygon', 'coordinates': [[[-81.01407002242462, 44.79267906707021], [-81.01330262006587, 44.79269791515045], [-81.01332729853362, 44.792125598129914], [-81.01356958725377, 44.79199481022313], [-81.01358754905286, 44.79198412839945], [-81.01360401796325, 44.79197228928953], [-81.01361884753459, 44.79195939817421], [-81.01363190589481, 44.79194556968921], [-81.01364307692285, 44.79193092680585], [-81.01365226128124, 44.79191559973739], [-81.0136593772994, 44.791899724781175], [-81.01366436169985, 44.79188344310641], [-81.01366717016083, 44.79186689949894], [-81.01366777771032, 44.79185024107373], [-81.01366617894813, 44.79183361596648], [-81.01366238809366, 44.79181717201645], [-81.01358397645194, 44.79155504536759], [-81.01400652550205, 44.79152675923877], [-81.01407002242462, 44.79267906707021]]]}, 'region1': {'type': 'Polygon', 'coordinates': [[[-80.28757693170076, 44.353088925477714], [-80.28757436343093, 44.35309058774067], [-80.28755681331879, 44.35310315525703], [-80.28754111727173, 44.35311692755925], [-80.28753075888093, 44.353128160128016], [-80.28748734176706, 44.35313976860315], [-80.28742029000678, 44.35315115176717], [-80.28715396984438, 44.35315571400851], [-80.28715226504858, 44.35315574745682], [-80.2868482330018, 44.35316246955875], [-80.2868667295257, 44.35316112943509], [-80.28688791987476, 44.35315823001266], [-80.28716256523732, 44.35311160355574], [-80.2875148177553, 44.353093981943964], [-80.28752652950898, 44.35309319356706], [-80.28757693170076, 44.353088925477714]]]}, 'region2': {'type': 'Polygon', 'coordinates': [[[-80.52935543585073, 44.524090455747064], [-80.52366623593824, 44.52511605928874], [-80.52357050273189, 44.52510019710509], [-80.52342300648527, 44.52489802696817], [-80.5292776053621, 44.52377986647738], [-80.52935543585073, 44.524090455747064]]]}, 'region3': {'type': 'Polygon', 'coordinates': [[[-80.3771610093081, 44.32412761042391], [-80.37718479512608, 44.324130729107026], [-80.37720889284101, 44.32413215384387], [-80.37723306893287, 44.32413187082791], [-80.37761443008196, 44.32411389999962], [-80.37808623179264, 44.325563972091935], [-80.3764340949819, 44.32574395821214], [-80.37638788588333, 44.32573619452611], [-80.37638658368334, 44.3257346884808], [-80.37637288192575, 44.32572045186878], [-80.37635730224719, 44.32570724787696], [-80.37633999468783, 44.32569520366488], [-80.37632112592753, 44.32568443522284], [-80.37630087768085, 44.3256750462549], [-80.37627944494687, 44.32566712718023], [-80.37625703413148, 44.3256607542623], [-80.37623386105946, 44.325655988874566], [-80.37582727369465, 44.32558767568043], [-80.37580246293425, 44.3255844609074], [-80.37577732381465, 44.3255830887045], [-80.37575212117189, 44.32558357352767], [-80.37541292039556, 44.32560263689509], [-80.37507466834043, 44.32407466641943], [-80.37637487169384, 44.32380911878289], [-80.37638603406049, 44.32382455894062], [-80.37647126546935, 44.32394656754978], [-80.3764830055654, 44.323961511448296], [-80.3764967132093, 44.32397556554219], [-80.37651225862605, 44.323988596774484], [-80.37652949464108, 44.32400048177194], [-80.37654825807373, 44.32401110801322], [-80.3765683712822, 44.324020374894104], [-80.37658964384528, 44.32402819468021], [-80.37661187436524, 44.32403449333738], [-80.37663485237456, 44.32403921123288], [-80.37685009728554, 44.32407537542745], [-80.3771610093081, 44.32412761042391]]]}, 'region4': {'type': 'Polygon', 'coordinates': [[[-80.44120286751011, 44.44671753250675], [-80.4401808073085, 44.44695329112621], [-80.43983407691753, 44.44490172259086], [-80.44079568691667, 44.444660689701145], [-80.44120286751011, 44.44671753250675]]]}, 'region5': {'type': 'Polygon', 'coordinates': [[[-80.44190487545005, 44.44652465862805], [-80.44187648925327, 44.446536470156694], [-80.44180237681462, 44.44616610923648], [-80.44190487545005, 44.44652465862805]]]}, 'region6': {'type': 'Polygon', 'coo ...

# %%
main(ProdParams, CompParams)
# Out:
# <MosaicProduction> User defined input parameters:
# sensor: S2_SR
# unit: 2
# nbYears: -1
# year: 2023
# months: [6, 7, 8]
# regions: {'region0': {'type': 'Polygon', 'coordinates': [[[-81.01407002242462, 44.79267906707021], [-81.01330262006587, 44.79269791515045], [-81.01332729853362, 44.792125598129914], [-81.01356958725377, 44.79199481022313], [-81.01358754905286, 44.79198412839945], [-81.01360401796325, 44.79197228928953], [-81.01361884753459, 44.79195939817421], [-81.01363190589481, 44.79194556968921], [-81.01364307692285, 44.79193092680585], [-81.01365226128124, 44.79191559973739], [-81.0136593772994, 44.791899724781175], [-81.01366436169985, 44.79188344310641], [-81.01366717016083, 44.79186689949894], [-81.01366777771032, 44.79185024107373], [-81.01366617894813, 44.79183361596648], [-81.01366238809366, 44.79181717201645], [-81.01358397645194, 44.79155504536759], [-81.01400652550205, 44.79152675923877], [-81.01407002242462, 44.79267906707021]]]}, 'region1': {'type': 'Polygon', 'coordinates': [[[-80.28757693170076, 44.353088925477714], [-80.28757436343093, 44.35309058774067], [-80.28755681331879, 44.35310315525703], [-80.28754111727173, 44.35311692755925], [-80.28753075888093, 44.353128160128016], [-80.28748734176706, 44.35313976860315], [-80.28742029000678, 44.35315115176717], [-80.28715396984438, 44.35315571400851], [-80.28715226504858, 44.35315574745682], [-80.2868482330018, 44.35316246955875], [-80.2868667295257, 44.35316112943509], [-80.28688791987476, 44.35315823001266], [-80.28716256523732, 44.35311160355574], [-80.2875148177553, 44.353093981943964], [-80.28752652950898, 44.35309319356706], [-80.28757693170076, 44.353088925477714]]]}, 'region2': {'type': 'Polygon', 'coordinates': [[[-80.52935543585073, 44.524090455747064], [-80.52366623593824, 44.52511605928874], [-80.52357050273189, 44.52510019710509], [-80.52342300648527, 44.52489802696817], [-80.5292776053621, 44.52377986647738], [-80.52935543585073, 44.524090455747064]]]}, 'region3': {'type': 'Polygon', 'coordinates': [[[-80.3771610093081, 44.32412761042391], [-80.37718479512608, 44.324130729107026], [-80.37720889284101, 44.32413215384387], [-80.37723306893287, 44.32413187082791], [-80.37761443008196, 44.32411389999962], [-80.37808623179264, 44.325563972091935], [-80.3764340949819, 44.32574395821214], [-80.37638788588333, 44.32573619452611], [-80.37638658368334, 44.3257346884808], [-80.37637288192575, 44.32572045186878], [-80.37635730224719, 44.32570724787696], [-80.37633999468783, 44.32569520366488], [-80.37632112592753, 44.32568443522284], [-80.37630087768085, 44.3256750462549], [-80.37627944494687, 44.32566712718023], [-80.37625703413148, 44.3256607542623], [-80.37623386105946, 44.325655988874566], [-80.37582727369465, 44.32558767568043], [-80.37580246293425, 44.3255844609074], [-80.37577732381465, 44.3255830887045], [-80.37575212117189, 44.32558357352767], [-80.37541292039556, 44.32560263689509], [-80.37507466834043, 44.32407466641943], [-80.37637487169384, 44.32380911878289], [-80.37638603406049, 44.32382455894062], [-80.37647126546935, 44.32394656754978], [-80.3764830055654, 44.323961511448296], [-80.3764967132093, 44.32397556554219], [-80.37651225862605, 44.323988596774484], [-80.37652949464108, 44.32400048177194], [-80.37654825807373, 44.32401110801322], [-80.3765683712822, 44.324020374894104], [-80.37658964384528, 44.32402819468021], [-80.37661187436524, 44.32403449333738], [-80.37663485237456, 44.32403921123288], [-80.37685009728554, 44.32407537542745], [-80.3771610093081, 44.32412761042391]]]}, 'region4': {'type': 'Polygon', 'coordinates': [[[-80.44120286751011, 44.44671753250675], [-80.4401808073085, 44.44695329112621], [-80.43983407691753, 44.44490172259086], [-80.44079568691667, 44.444660689701145], [-80.44120286751011, 44.44671753250675]]]}, 'region5': {'type': 'Polygon', 'coordinates': [[[-80.44190487545005, 44.44652465862805], [-80.44187648925327, 44.446536470156694], [-80.44180237681462, 44.44616610923648], [-80.44190487545005, 44.44652465862805]]]}, 'region6': {'type': 'Polygon', 'coordinates': [[[-80.93183825777987, 44.54975002114337], [-80.93001168186503, 44.54997 ...
# resolution: 30
# projection: EPSG:3979
# prod_names: ['mosaic']
# out_folder: E:/S2_mosaics_runner_2026/S2_temp1_2_30m
# out_datatype: int16
# region_start_dates: {'region0': ['2020-07-01'], 'region2': ['2020-07-01'], 'region3': ['2020-07-01'], 'region4': ['2021-07-01'], 'region5': ['2009-07-01'], 'region6': ['2009-07-01'], 'region7': ['2009-07-01'], 'region8': ['2009-07-01'], 'region9': ['2009-07-01'], 'region10': ['2009-07-01'], 'region11': ['2009-07-01'], 'region12': ['2009-07-01'], 'region13': ['2009-07-01'], 'region15': ['2009-07-01'], 'region16': ['2009-07-01'], 'region17': ['2009-07-01'], 'region18': ['2009-07-01']}
# region_end_dates: {'region0': ['2020-08-01'], 'region2': ['2020-08-01'], 'region3': ['2020-08-01'], 'region4': ['2021-08-01'], 'region5': ['2010-07-01'], 'region6': ['2010-07-01'], 'region7': ['2010-07-01'], 'region8': ['2010-07-01'], 'region9': ['2010-07-01'], 'region10': ['2010-07-01'], 'region11': ['2010-07-01'], 'region12': ['2010-07-01'], 'region13': ['2010-07-01'], 'region14': ['2010-07-01'], 'region16': ['2010-07-01'], 'region17': ['2010-07-01'], 'region18': ['2010-07-01']}
# monthly: False
# start_dates: ['2023-06-01', '2023-07-01', '2023-08-01']
# end_dates: ['2023-06-30', '2023-07-31', '2023-08-31']
# current_time: 0
# SsrData: {'NAME': 'S2_SR', 'SSR_CODE': 21, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], '10M_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'SIX_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'NoA_BANDS': ['red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'LEAF_BANDS': ['green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'GEE_NAME': 'COPERNICUS/S2_SR_HARMONIZED', 'CLOUD': 'CLOUDY_PIXEL_PERCENTAGE', 'SZA': 'view:sun_elevation', 'SAA': 'view:sun_azimuth', 'VZA': 'view:sun_elevation', 'VAA': 'view:sun_azimuth', 'BLU': 'blue', 'GRN': 'green', 'RED': 'red', 'NIR': 'nir08', 'SW1': 'swir16', 'SW2': 'swir22'}
# out_location: drive
# tile_names: []
# cloud_cover: 80
# export_style: separate
# IncludeAngles: False
# scene_ID:
# current_region: region0
# Criteria: {'timeframe': '2023-06-01/2023-06-30', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-81.01407002242462, 44.79267906707021], [-81.01330262006587, 44.79269791515045], [-81.01332729853362, 44.792125598129914], [-81.01356958725377, 44.79199481022313], [-81.01358754905286, 44.79198412839945], [-81.01360401796325, 44.79197228928953], [-81.01361884753459, 44.79195939817421], [-81.01363190589481, 44.79194556968921], [-81.01364307692285, 44.79193092680585], [-81.01365226128124, 44.79191559973739], [-81.0136593772994, 44.791899724781175], [-81.01366436169985, 44.79188344310641], [-81.01366717016083, 44.79186689949894], [-81.01366777771032, 44.79185024107373], [-81.01366617894813, 44.79183361596648], [-81.01366238809366, 44.79181717201645], [-81.01358397645194, 44.79155504536759], [-81.01400652550205, 44.79152675923877], [-81.01407002242462, 44.79267906707021]]]}, 'catalog': 'https://earth-search.aws.element84.com/v1', 'collection': ['sentinel-2-l2a'], 'bands': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl']}
# standardized: True
# number_workers: 32
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 16G
# chunk_size: {'x': 512, 'y': 512}
#
# <MosaicProduction> Using region-specific dates for region0
#   Start dates: ['2020-07-01']
#   End dates: ['2020-08-01']
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-81.01407002242462, 44.79267906707021], [-81.01330262006587, 44.79269791515045], [-81.01332729853362, 44.792125598129914], [-81.01356958725377, 44.79199481022313], [-81.01358754905286, 44.79198412839945], [-81.01360401796325, 44.79197228928953], [-81.01361884753459, 44.79195939817421], [-81.01363190589481, 44.79194556968921], [-81.01364307692285, 44.79193092680585], [-81.01365226128124, 44.79191559973739], [-81.0136593772994, 44.791899724781175], [-81.01366436169985, 44.79188344310641], [-81.01366717016083, 44.79186689949894], [-81.01366777771032, 44.79185024107373], [-81.01366617894813, 44.79183361596648], [-81.01366238809366, 44.79181717201645], [-81.01358397645194, 44.79155504536759], [-81.01400652550205, 44.79152675923877], [-81.01407002242462, 44.79267906707021]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.02 minutes
#
# <one_mosaic> A total of 16 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/30/1/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/30/1/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/30/1/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/30/1/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/30/1/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/30/1/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/30/1/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/30/1/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/30/1/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/30/1/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/30/1/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/30/1/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/30/1/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/30/1/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/30/1/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/30/1/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TMK_20200730_1_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-80.94321354428031, 45.15381413165476], [-81.27511500386915, 44.16504424032678], [-80.87793799810343, 44.16531029102769], [-80.87584634429486, 45.15376076769412], [-80.94321354428031, 45.15381413165476]]]}
# Bounding Box: [-81.27511500386915, 44.16504424032678, -80.87584634429486, 45.15381413165476]
# Datetime: 2020-07-30 16:21:08.186000+00:00
# cloud cover: 37.743798
# Properties:
#   <created>: 2023-09-09T08:54:00.575Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 37.743798
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: MK
#   <grid:code>: MGRS-17TMK
#   <view:sun_azimuth>: 144.695394631029
#   <view:sun_elevation>: 59.6727141730558
#   <s2:degraded_msi_data_percentage>: 0.0654
#   <s2:nodata_pixel_percentage>: 83.021647
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.02982
#   <s2:cloud_shadow_percentage>: 11.680907
#   <s2:vegetation_percentage>: 28.336713
#   <s2:not_vegetated_percentage>: 3.425582
#   <s2:water_percentage>: 18.476963
#   <s2:unclassified_percentage>: 0.306217
#   <s2:medium_proba_clouds_percentage>: 12.759329
#   <s2:high_proba_clouds_percentage>: 24.943627
#   <s2:thin_cirrus_percentage>: 0.040842
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.00
#   <s2:product_uri>: S2B_MSIL2A_20200730T160829_N0500_R140_T17TMK_20230513T154037.SAFE
#   <s2:generation_time>: 2023-05-13T15:40:37.000000Z
#   <s2:datatake_id>: GS2B_20200730T160829_017755_N05.00
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_S2RP_20230513T154037_S20200730T161139_N05.00
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_S2RP_20230513T154037_A017755_T17TMK_N05.00
#   <s2:reflectance_conversion_factor>: 0.969703194936717
#   <datetime>: 2020-07-30T16:21:08.186000Z
#   <s2:sequence>: 1
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200730_1_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/ce7b67ebd060de16206727b06aac629c
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.1'}
#   <updated>: 2023-09-09T08:54:00.575Z
#   <proj:code>: EPSG:32617
#   <sza>: 30.3272858269442
#   <saa>: 144.695394631029
#   <vza>: 11.0011424294811
#   <vaa>: 110.72332749256
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 948B
# Dimensions:      (y: 6, x: 3)
# Coordinates:
#   * y            (y) float64 48B -3.484e+05 -3.485e+05 ... -3.486e+05 -3.486e+05
#   * x            (x) float64 24B 1.118e+06 1.118e+06 1.118e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2020-07-30T16:21:08.186000
# Data variables:
#     blue         (y, x) float32 72B dask.array<chunksize=(6, 3), meta=np.ndarray>
#     green        (y, x) float32 72B dask.array<chunksize=(6, 3), meta=np.ndarray>
#     red          (y, x) float32 72B dask.array<chunksize=(6, 3), meta=np.ndarray>
#     rededge1     (y, x) float32 72B dask.array<chunksize=(6, 3), meta=np.ndarray>
#     rededge2     (y, x) float32 72B dask.array<chunksize=(6, 3), meta=np.ndarray>
#     rededge3     (y, x) float32 72B dask.array<chunksize=(6, 3), meta=np.ndarray>
#     nir08        (y, x) float32 72B dask.array<chunksize=(6, 3), meta=np.ndarray>
#     swir16       (y, x) float32 72B dask.array<chunksize=(6, 3), meta=np.ndarray>
#     swir22       (y, x) float32 72B dask.array<chunksize=(6, 3), meta=np.ndarray>
#     scl          (y, x) float32 72B dask.array<chunksize=(6, 3), meta=np.ndarray>
#     date         (y, x) float32 72B dask.array<chunksize=(6, 3), meta=np.ndarray>
#     score        (y, x) float32 72B dask.array<chunksize=(6, 3), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TMK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.92 minutes >>>>>>
# File 'E:\S2_mosaics_runner_2026\S2_temp1_2_30m\log_51c3c1e5-16f8-4fb8-bd89-3d05a2811d60.out' does not exist.
# Directory 'E:\S2_mosaics_runner_2026\S2_temp1_2_30m\dask_spill_51c3c1e5-16f8-4fb8-bd89-3d05a2811d60' and its contents have been deleted.
#
# <MosaicProduction> Using default dates for region1
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-80.28757693170076, 44.353088925477714], [-80.28757436343093, 44.35309058774067], [-80.28755681331879, 44.35310315525703], [-80.28754111727173, 44.35311692755925], [-80.28753075888093, 44.353128160128016], [-80.28748734176706, 44.35313976860315], [-80.28742029000678, 44.35315115176717], [-80.28715396984438, 44.35315571400851], [-80.28715226504858, 44.35315574745682], [-80.2868482330018, 44.35316246955875], [-80.2868667295257, 44.35316112943509], [-80.28688791987476, 44.35315823001266], [-80.28716256523732, 44.35311160355574], [-80.2875148177553, 44.353093981943964], [-80.28752652950898, 44.35309319356706], [-80.28757693170076, 44.353088925477714]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.02 minutes
#
# <one_mosaic> A total of 8 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/6/18/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/6/18/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/6/18/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/6/18/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/6/18/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/6/18/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/6/18/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/6/18/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/6/18/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/6/18/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/6/18/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/6/18/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/6/18/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/6/18/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/6/18/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/6/18/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TNK_20230618_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-79.60797608483071, 45.145344238902524], [-80.00682600479827, 44.16249664781883], [-81.00023764893123, 44.166275830095536], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.00024171761814, 44.16249664781883, -79.60797608483071, 45.153828248771845]
# Datetime: 2023-06-18 16:31:01.712000+00:00
# cloud cover: 3.869149
# Properties:
#   <created>: 2023-06-19T01:46:17.541Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 3.869149
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:sun_azimuth>: 149.521458003602
#   <view:sun_elevation>: 66.30554011373201
#   <s2:degraded_msi_data_percentage>: 0.0233
#   <s2:nodata_pixel_percentage>: 13.890862
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.046942
#   <s2:cloud_shadow_percentage>: 0.26793
#   <s2:vegetation_percentage>: 44.499016
#   <s2:not_vegetated_percentage>: 6.938102
#   <s2:water_percentage>: 43.9989
#   <s2:unclassified_percentage>: 0.379958
#   <s2:medium_proba_clouds_percentage>: 0.20165
#   <s2:high_proba_clouds_percentage>: 0.15173
#   <s2:thin_cirrus_percentage>: 3.51577
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.09
#   <s2:product_uri>: S2B_MSIL2A_20230618T161829_N0509_R040_T17TNK_20230618T191812.SAFE
#   <s2:generation_time>: 2023-06-18T19:18:12.000000Z
#   <s2:datatake_id>: GS2B_20230618T161829_032813_N05.09
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_2BPS_20230618T191812_S20230618T162118_N05.09
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_2BPS_20230618T191812_A032813_T17TNK_N05.09
#   <s2:reflectance_conversion_factor>: 0.969318832791174
#   <datetime>: 2023-06-18T16:31:01.712000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2023/6/S2B_17TNK_20230618_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/dd6b4f24d30a4d7ba4a209081f2202f2
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.0'}
#   <updated>: 2023-06-19T01:46:17.541Z
#   <proj:code>: EPSG:32617
#   <sza>: 23.694459886267992
#   <saa>: 149.521458003602
#   <vza>: 8.20015286689124
#   <vaa>: 285.322636268374
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 340B
# Dimensions:      (y: 2, x: 3)
# Coordinates:
#   * y            (y) float64 16B -3.838e+05 -3.838e+05
#   * x            (x) float64 24B 1.187e+06 1.187e+06 1.187e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2023-06-18T16:31:01.712000
# Data variables:
#     blue         (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     green        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     red          (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge1     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge2     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge3     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     nir08        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     swir16       (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     swir22       (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     scl          (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     date         (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     score        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.76 minutes >>>>>>
# File 'E:\S2_mosaics_runner_2026\S2_temp1_2_30m\log_1a782b47-9ad0-447a-822e-d05216ab5795.out' does not exist.
# Directory 'E:\S2_mosaics_runner_2026\S2_temp1_2_30m\dask_spill_1a782b47-9ad0-447a-822e-d05216ab5795' and its contents have been deleted.
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-80.28757693170076, 44.353088925477714], [-80.28757436343093, 44.35309058774067], [-80.28755681331879, 44.35310315525703], [-80.28754111727173, 44.35311692755925], [-80.28753075888093, 44.353128160128016], [-80.28748734176706, 44.35313976860315], [-80.28742029000678, 44.35315115176717], [-80.28715396984438, 44.35315571400851], [-80.28715226504858, 44.35315574745682], [-80.2868482330018, 44.35316246955875], [-80.2868667295257, 44.35316112943509], [-80.28688791987476, 44.35315823001266], [-80.28716256523732, 44.35311160355574], [-80.2875148177553, 44.353093981943964], [-80.28752652950898, 44.35309319356706], [-80.28757693170076, 44.353088925477714]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.01 minutes
#
# <one_mosaic> A total of 8 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/7/3/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/7/3/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/7/3/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/7/3/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/7/3/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/7/3/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/7/3/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/7/3/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/7/3/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/7/3/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/7/3/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/7/3/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/7/3/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/7/3/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/7/3/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/7/3/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2A_17TNK_20230703_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-79.60873890481405, 45.145353535648724], [-80.00695120252882, 44.162499292632155], [-81.00023764893123, 44.16627583011753], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.00024171761814, 44.162499292632155, -79.60873890481405, 45.153828248771845]
# Datetime: 2023-07-03 16:31:02.054000+00:00
# cloud cover: 4.72169
# Properties:
#   <created>: 2023-07-04T07:12:36.573Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 4.72169
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:sun_azimuth>: 148.374172223758
#   <view:sun_elevation>: 65.5901500846481
#   <s2:degraded_msi_data_percentage>: 0.0257
#   <s2:nodata_pixel_percentage>: 13.925242
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.047207
#   <s2:cloud_shadow_percentage>: 3.006254
#   <s2:vegetation_percentage>: 42.74407
#   <s2:not_vegetated_percentage>: 1.926025
#   <s2:water_percentage>: 47.174034
#   <s2:unclassified_percentage>: 0.380719
#   <s2:medium_proba_clouds_percentage>: 2.323824
#   <s2:high_proba_clouds_percentage>: 1.872057
#   <s2:thin_cirrus_percentage>: 0.52581
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.09
#   <s2:product_uri>: S2A_MSIL2A_20230703T161831_N0509_R040_T17TNK_20230704T002803.SAFE
#   <s2:generation_time>: 2023-07-04T00:28:03.000000Z
#   <s2:datatake_id>: GS2A_20230703T161831_041936_N05.09
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_2APS_20230704T002803_S20230703T162407_N05.09
#   <s2:granule_id>: S2A_OPER_MSI_L2A_TL_2APS_20230704T002803_A041936_T17TNK_N05.09
#   <s2:reflectance_conversion_factor>: 0.967502587367245
#   <datetime>: 2023-07-03T16:31:02.054000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2023/7/S2A_17TNK_20230703_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/efe2553ebb027724b39efbc1399df4f5
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.0'}
#   <updated>: 2023-07-04T07:12:36.573Z
#   <proj:code>: EPSG:32617
#   <sza>: 24.4098499153519
#   <saa>: 148.374172223758
#   <vza>: 8.19499775417296
#   <vaa>: 286.071579824523
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 340B
# Dimensions:      (y: 2, x: 3)
# Coordinates:
#   * y            (y) float64 16B -3.838e+05 -3.838e+05
#   * x            (x) float64 24B 1.187e+06 1.187e+06 1.187e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2023-07-03T16:31:02.054000
# Data variables:
#     blue         (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     green        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     red          (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge1     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge2     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     rededge3     (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     nir08        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     swir16       (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     swir22       (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     scl          (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     date         (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     score        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.86 minutes >>>>>>
# File 'E:\S2_mosaics_runner_2026\S2_temp1_2_30m\log_a5729263-61c5-44a9-808e-c9d13409b325.out' does not exist.
# Directory 'E:\S2_mosaics_runner_2026\S2_temp1_2_30m\dask_spill_a5729263-61c5-44a9-808e-c9d13409b325' and its contents have been deleted.
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-80.28757693170076, 44.353088925477714], [-80.28757436343093, 44.35309058774067], [-80.28755681331879, 44.35310315525703], [-80.28754111727173, 44.35311692755925], [-80.28753075888093, 44.353128160128016], [-80.28748734176706, 44.35313976860315], [-80.28742029000678, 44.35315115176717], [-80.28715396984438, 44.35315571400851], [-80.28715226504858, 44.35315574745682], [-80.2868482330018, 44.35316246955875], [-80.2868667295257, 44.35316112943509], [-80.28688791987476, 44.35315823001266], [-80.28716256523732, 44.35311160355574], [-80.2875148177553, 44.353093981943964], [-80.28752652950898, 44.35309319356706], [-80.28757693170076, 44.353088925477714]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.01 minutes
#
# <one_mosaic> A total of 9 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/8/27/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/8/27/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/8/27/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/8/27/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/8/27/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/8/27/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/8/27/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/8/27/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/8/27/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/8/27/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/8/27/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/8/27/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/8/27/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/8/27/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/8/27/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2023/8/27/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TNK_20230827_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-81.00023764893123, 44.16627583011753], [-80.01045384630054, 44.16252778490946], [-79.6125537471008, 45.145399951930116], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.00024171761814, 44.16252778490946, -79.6125537471008, 45.153828248771845]
# Datetime: 2023-08-27 16:31:01.574000+00:00
# cloud cover: 8.133141
# Properties:
#   <created>: 2023-08-28T00:38:54.538Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 8.133141
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:sun_azimuth>: 158.210866932129
#   <view:sun_elevation>: 53.5721567943155
#   <s2:degraded_msi_data_percentage>: 0.0231
#   <s2:nodata_pixel_percentage>: 14.163981
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.042159
#   <s2:cloud_shadow_percentage>: 4.591829
#   <s2:vegetation_percentage>: 38.113785
#   <s2:not_vegetated_percentage>: 1.860125
#   <s2:water_percentage>: 46.965355
#   <s2:unclassified_percentage>: 0.293606
#   <s2:medium_proba_clouds_percentage>: 3.743364
#   <s2:high_proba_clouds_percentage>: 2.936246
#   <s2:thin_cirrus_percentage>: 1.453531
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.09
#   <s2:product_uri>: S2B_MSIL2A_20230827T161829_N0509_R040_T17TNK_20230827T203255.SAFE
#   <s2:generation_time>: 2023-08-27T20:32:55.000000Z
#   <s2:datatake_id>: GS2B_20230827T161829_033814_N05.09
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_2BPS_20230827T203255_S20230827T162957_N05.09
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_2BPS_20230827T203255_A033814_T17TNK_N05.09
#   <s2:reflectance_conversion_factor>: 0.978320420950092
#   <datetime>: 2023-08-27T16:31:01.574000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2023/8/S2B_17TNK_20230827_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/9eefc705c40894277c482d8977f94c3a
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.1'}
#   <updated>: 2023-08-28T00:38:54.538Z
#   <proj:code>: EPSG:32617
#   <sza>: 36.4278432056845
#   <saa>: 158.210866932129
#   <vza>: 8.20585569273146
#   <vaa>: 285.251238662429
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 340B
# Dimensions:      (y: 2, x: 3)
# Coordinates:
#   * y            (y) float64 16B -3.838e+05 -3.838e+05
#   * x            (x) float64 24B 1.187e+06 1.187e+06 1.187e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2023-08-27T16:31:01.574000
# Data variables:
#     blue         (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
#     green        (y, x) float32 24B dask.array<chunksize=(2, 3), meta=np.ndarray>
# ...
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/QK/2023/7/7/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/QK/2023/7/7/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/QK/2023/7/7/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/QK/2023/7/7/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/QK/2023/7/7/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/QK/2023/7/7/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2A_17TQK_20230707_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-78.45735633937558, 45.12551560665338], [-77.06391573845917, 45.08594841709943], [-77.13002511200345, 44.09978032341], [-78.50013834131882, 44.13801640880522], [-78.45735633937558, 45.12551560665338]]]}
# Bounding Box: [-78.50013834131882, 44.09978032341, -77.06391573845917, 45.12551560665338]
# Datetime: 2023-07-07 16:11:02.735000+00:00
# cloud cover: 56.175661
# Properties:
#   <created>: 2023-07-08T03:12:01.699Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 56.175661
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: QK
#   <grid:code>: MGRS-17TQK
#   <view:sun_azimuth>: 143.502228635934
#   <view:sun_elevation>: 64.2249244369758
#   <s2:degraded_msi_data_percentage>: 0.0336
#   <s2:nodata_pixel_percentage>: 0
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.00793
#   <s2:cloud_shadow_percentage>: 11.90719
#   <s2:vegetation_percentage>: 28.034154
#   <s2:not_vegetated_percentage>: 0.972386
#   <s2:water_percentage>: 2.436249
#   <s2:unclassified_percentage>: 0.466428
#   <s2:medium_proba_clouds_percentage>: 17.399597
#   <s2:high_proba_clouds_percentage>: 32.89724
#   <s2:thin_cirrus_percentage>: 5.878826
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.09
#   <s2:product_uri>: S2A_MSIL2A_20230707T155821_N0509_R097_T17TQK_20230707T235453.SAFE
#   <s2:generation_time>: 2023-07-07T23:54:53.000000Z
#   <s2:datatake_id>: GS2A_20230707T155821_041993_N05.09
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_2APS_20230707T235453_S20230707T160645_N05.09
#   <s2:granule_id>: S2A_OPER_MSI_L2A_TL_2APS_20230707T235453_A041993_T17TQK_N05.09
#   <s2:reflectance_conversion_factor>: 0.967371823228441
#   <datetime>: 2023-07-07T16:11:02.735000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/QK/2023/7/S2A_17TQK_20230707_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/24d9500ac31904871b7aeaf19fae71b9
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.0'}
#   <updated>: 2023-07-08T03:12:01.699Z
#   <proj:code>: EPSG:32617
#   <sza>: 25.775075563024203
#   <saa>: 143.502228635934
#   <vza>: 6.91244626677311
#   <vaa>: 106.500936776597
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 2kB
# Dimensions:      (y: 7, x: 7)
# Coordinates:
#   * y            (y) float64 56B -3.364e+05 -3.364e+05 ... -3.366e+05 -3.366e+05
#   * x            (x) float64 56B 1.414e+06 1.414e+06 ... 1.414e+06 1.414e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2023-07-07T16:11:02.735000
# Data variables:
#     blue         (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     green        (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     red          (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     rededge1     (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     rededge2     (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     rededge3     (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     nir08        (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     swir16       (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     swir22       (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     scl          (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     date         (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     score        (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 2
#
# <<<<<< The unique granule tiles =  ['17TQK', '18TUQ']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.76 minutes >>>>>>
# File 'E:\S2_mosaics_runner_2026\S2_temp1_2_30m\log_af3e4659-0af8-40be-a16e-7b800aa818b8.out' does not exist.
# Directory 'E:\S2_mosaics_runner_2026\S2_temp1_2_30m\dask_spill_af3e4659-0af8-40be-a16e-7b800aa818b8' and its contents have been deleted.
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-77.43332458451215, 44.25213684454684], [-77.4344053892866, 44.25192328156998], [-77.43474799351438, 44.2526478892495], [-77.43474843715062, 44.25264881900849], [-77.43513964418156, 44.25346129527729], [-77.43442889575745, 44.25365219938359], [-77.43417635283319, 44.25302154314254], [-77.4340910492759, 44.252760784642035], [-77.43408453611481, 44.25274445232611], [-77.43407586549357, 44.252728646578156], [-77.43406511797014, 44.252713514243766], [-77.43405239339792, 44.25269919591194], [-77.43403780999813, 44.252685824608946], [-77.43402150326129, 44.25267352456239], [-77.43400362468843, 44.252662410047186], [-77.43398434038356, 44.252652584323755], [-77.43396382951043, 44.2526441386789], [-77.43394228262804, 44.252637151577545], [-77.4339198999202, 44.25263168793388], [-77.43389688933586, 44.25262779850835], [-77.43387346465704, 44.25262551943584], [-77.43384984351287, 44.25262487189025], [-77.43382624535765, 44.25262586188768], [-77.43380288943216, 44.25262848023045], [-77.43377999272676, 44.25263270259271], [-77.43375776796555, 44.25263848974628], [-77.43342214814248, 44.25273928272413], [-77.43332458451215, 44.25213684454684]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.03 minutes
#
# <one_mosaic> A total of 13 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/31/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/31/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/31/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/31/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/31/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/31/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/31/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/31/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/31/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/31/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/31/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/31/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/31/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/31/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/31/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/31/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_18TUQ_20230831_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-77.54312638001969, 45.12550485176269], [-77.50033627674769, 44.138006015963036], [-76.12809397147082, 44.15980551127438], [-76.14741991916983, 45.14806405473198], [-77.54312638001969, 45.12550485176269]]]}
# Bounding Box: [-77.54312638001969, 44.138006015963036, -76.12809397147082, 45.14806405473198]
# Datetime: 2023-08-31 16:10:58.984000+00:00
# cloud cover: 4.207753
# Properties:
#   <created>: 2023-09-01T01:16:34.845Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 4.207753
#   <mgrs:utm_zone>: 18
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: UQ
#   <grid:code>: MGRS-18TUQ
#   <view:sun_azimuth>: 156.913014166459
#   <view:sun_elevation>: 51.8848599565221
#   <s2:degraded_msi_data_percentage>: 0.0105
#   <s2:nodata_pixel_percentage>: 7e-06
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.106841
#   <s2:cloud_shadow_percentage>: 0.259525
#   <s2:vegetation_percentage>: 85.092199
#   <s2:not_vegetated_percentage>: 1.406014
#   <s2:water_percentage>: 8.367205
#   <s2:unclassified_percentage>: 0.560466
#   <s2:medium_proba_clouds_percentage>: 0.542742
#   <s2:high_proba_clouds_percentage>: 0.144727
#   <s2:thin_cirrus_percentage>: 3.520284
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.09
#   <s2:product_uri>: S2B_MSIL2A_20230831T155829_N0509_R097_T18TUQ_20230831T203613.SAFE
#   <s2:generation_time>: 2023-08-31T20:36:13.000000Z
#   <s2:datatake_id>: GS2B_20230831T155829_033871_N05.09
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_2BPS_20230831T203613_S20230831T160717_N05.09
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_2BPS_20230831T203613_A033871_T18TUQ_N05.09
#   <s2:reflectance_conversion_factor>: 0.980041807173516
#   <datetime>: 2023-08-31T16:10:58.984000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2B_18TUQ_20230831_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/aed928c2913d398accae89877588b14d
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.1'}
#   <updated>: 2023-09-01T01:16:34.845Z
#   <proj:code>: EPSG:32618
#   <sza>: 38.1151400434779
#   <saa>: 156.913014166459
#   <vza>: 3.03488118684987
#   <vaa>: 162.421631094811
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 2kB
# Dimensions:      (y: 7, x: 7)
# Coordinates:
#   * y            (y) float64 56B -3.364e+05 -3.364e+05 ... -3.366e+05 -3.366e+05
#   * x            (x) float64 56B 1.414e+06 1.414e+06 ... 1.414e+06 1.414e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2023-08-31T16:10:58.984000
# Data variables:
#     blue         (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     green        (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     red          (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     rededge1     (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     rededge2     (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     rededge3     (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     nir08        (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     swir16       (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     swir22       (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     scl          (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     date         (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#     score        (y, x) float32 196B dask.array<chunksize=(7, 7), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 2
#
# <<<<<< The unique granule tiles =  ['18TUQ', '17TQK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.91 minutes >>>>>>
# File 'E:\S2_mosaics_runner_2026\S2_temp1_2_30m\log_76d99e68-e59d-4738-8958-27716e73f86b.out' does not exist.
# Directory 'E:\S2_mosaics_runner_2026\S2_temp1_2_30m\dask_spill_76d99e68-e59d-4738-8958-27716e73f86b' and its contents have been deleted.
