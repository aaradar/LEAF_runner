# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
from pathlib import Path

project_root = Path.cwd()
sys.path.insert(0, str(project_root))

from prepare_params import prepare_production_params

print("Modules imported successfully")
print(f"Current working directory: {os.getcwd()}")


kml = "Sample Points\AfforestationSItesFixed.kml"
shp = "Sample Points\FieldPoints32_2018.shp"
tmx = "Sample Points\TMX\TML_pipeline_100mbuffer.kml"
cbc = "Sample Points\ColdwaterBCregion.kml"
ls_mgrs = "S2A_OPER_GIP_TILPAR_MPC.kml"
s2_mgrs = "sentinel-2-grid.parquet"
print(kml)
print(shp)
print(tmx)
print(cbc)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Modules imported successfully
# Current working directory: C:\Users\aradar\LEAF Files\LEAF_runner
# Sample Points\AfforestationSItesFixed.kml
# Sample Points\FieldPoints32_2018.shp
# Sample Points\TMX\TML_pipeline_100mbuffer.kml
# Sample Points\ColdwaterBCregion.kml

# %%
# Use Case: Generate monthly mosaics
# Customize these parameters as needed:

ProdParams = {
    # ============ REQUIRED PARAMETERS ============
    'sensor': 'S2_SR',                    # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR', 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'nbYears': -1,            # positive int for annual product, or negative int for monthly product
    #'year': 2023,                          # CHANGE THIS: Year to process
    #'months': [8,9,10],                   # CHANGE THIS: Months to process (1-12)
    
    
    # ============ REGION PARAMETERS ============
    'regions': kml,  # CHANGE THIS: Path to your KML/SHP file
    'file_variables': ['TARGET_FID', 'AsssD_1', 'AsssD_2'], # CHANGE THIS: id, start_date, end_date (None for dates if they don't exist)
    #'file_variables': ['id', 'begin', 'end'], # for pipelines file
    #'file_variables': ['system:index', None, None], # for cold water file
    'regions_start_index': 0,              # CHANGE THIS: Start at this region index
    'regions_end_index': 5,             # CHANGE THIS: End at this index (None = all)

    # ============ TILES PARAMETERS ============
    's2_grid_path': s2_mgrs,
    'mode': 'tiles', #regions or tiles
    'subdivide_tiles': False, # Whether to subdivide tiles into smaller regions (only applicable if mode is 'tiles')
    
    # ============ BUFFER PARAMETERS ============
    #'spatial_buffer_m': -10,             # UNCOMMENT & CHANGE: Buffer in meters around regions
    #'temporal_buffer': [[50, 90], [-10, 10]],          # UNCOMMENT & CHANGE: [days_before, days_after]
    'temporal_buffer': [["2017-08-01", "2017-08-31"]],
    'num_years': 3,
    
    
    # ============ OUTPUT PARAMETERS ============
    'resolution': 30,                      # Resolution in meters
    'projection': 'EPSG:3979',             # Coordinate projection
    'IncludeAngles': False,
    'prod_names': ['fCOVER'],    #['mosaic', 'LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'out_folder': 'E:\\TestingLEAFFinal\\hiyori_mogged geotiff_30m',
    'out_datatype': 'int16',

    # ============ CSV OUTPUT (NEW) ============
    'output_type': 'geotiff',        # <-- switch from GeoTIFF to CSV
    'csv_scale': 30,             # optional: same as resolution, explicit here for clarity
    'csv_dropNulls': True,       # optional: skip masked/nodata pixels (mirrors GEE dropNulls)
    'csv_max_pixels': 100_000,   # optional: lower this first for a quick test
}

CompParams = {
  "number_workers":10,    
  "debug"       : True,
  "entire_tile" : False,
  "nodes"       : 1,
  "node_memory" : "50G",
  'chunk_size': {'x': 512, 'y': 512}
}


print("\nconfigured")
# Out:
# configured

# %%
# Run the parameter preparation
result = prepare_production_params(ProdParams, CompParams)
'''
if result:
    print("\n" + "="*80)
    print(" SUCCESS - Parameters validated and ready!")
    print("="*80)
    print(f"\n Summary:")
    print(f"  Regions: {len(result['ProdParams']['regions'])}")
    print(f"  Time windows: {len(result['ProdParams']['start_dates'])}")
    print(f"  Total tasks: {len(result['ProdParams']['regions']) * len(result['ProdParams']['start_dates'])}")
    print(f"  Output folder: {result['ProdParams']['out_folder']}")
    print(f"\n Processing log saved to: {result['ProdParams']['out_folder']}/polygon_processing_log.csv")
    print("\n" + "="*80)
    print("Next step: Call Production.py with the validated parameters")
    print("="*80)
else:
    print("\n" + "="*80)
    print(" FAILED - Parameter validation failed")
    print("="*80)
    print("Check the error messages above for details.") '''
# Out:
# ================================================================================
# PARAMETER PREPARATION
# ================================================================================
#
# Step 1/4: Validating input parameters...
# ✓ All parameters valid
#
# Step 2/4: Loading regions from files...
# <handle_regions_from_file> Detected file-based regions input: Sample Points\AfforestationSItesFixed.kml
# <handle_regions_from_file> Loading regions...
# <handle_regions_from_file> Resolving Sentinel-2 tiles...
#   Loading S2 tile grid from: C:\Users\aradar\LEAF Files\LEAF_runner\source\sentinel-2-grid.parquet
#     Loaded parquet (56686 tiles)
#   Pre-filtered to 6 candidate S2 tiles in bounding box
#   Filtering to first match only (one tile per source region)...
#   Tile name column: 'tile'
#   Resolved 2 Sentinel-2 tile(s) covering 6 selected region(s)
# <handle_regions_from_file> Override mode: Setting all regions to 1 date window(s)
# <handle_regions_from_file> Region tile_17TMK: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Region tile_17TNK: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Region region0: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Region region1: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Region region2: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Region region3: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Region region4: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Region region5: 1 windows [['2017-08-01', '2017-08-31']]
# <handle_regions_from_file> Expanding region dates across 3 years...
# <handle_regions_from_file> Region tile_17TMK: Expanded from 1 to 3 date windows (3 years)
# <handle_regions_from_file> Region tile_17TNK: Expanded from 1 to 3 date windows (3 years)
# <handle_regions_from_file> Region region0: Expanded from 1 to 3 date windows (3 years)
# <handle_regions_from_file> Region region1: Expanded from 1 to 3 date windows (3 years)
# <handle_regions_from_file> Region region2: Expanded from 1 to 3 date windows (3 years)
# <handle_regions_from_file> Region region3: Expanded from 1 to 3 date windows (3 years)
# <handle_regions_from_file> Region region4: Expanded from 1 to 3 date windows (3 years)
# <handle_regions_from_file> Region region5: Expanded from 1 to 3 date windows (3 years)
# <handle_regions_from_file> Loaded 2 regions from file
#
# Step 3/4: Skipping temporal window generation (no year/months or start_dates/end_dates found)
#            Region-specific dates from file will be used if available.
#
# Step 4/4: Validating polygons...
#
# ================================================================================
# POLYGON VALIDATION AND FILTERING
# ================================================================================
#
# Polygon validation log saved to: E:\TestingLEAFFinal\hiyori_mogged csv_30m\polygon_processing_log.csv
#
# Validation Summary:
#    Total regions: 2
#    Valid for processing: 2
#    Skipped (zero area): 0
#
# Proceeding with 2 valid region(s) out of 2 total
# ================================================================================
#
#
# ================================================================================
# PARAMETER PREPARATION COMPLETE
# ================================================================================
# Regions: 2
# Start Time windows: {'tile_17TMK': ['2017-08-01', '2018-08-01', '2019-08-01'], 'tile_17TNK': ['2017-08-01', '2018-08-01', '2019-08-01']}
# End Time windows: {'tile_17TMK': ['2017-08-31', '2018-08-31', '2019-08-31'], 'tile_17TNK': ['2017-08-31', '2018-08-31', '2019-08-31']}
# ================================================================================
#
#
# <prepare_production_params> Added properties to regions:
# {
#   "sensor": "S2_SR",
#   "unit": 2,
#   "nbYears": -1,
#   "file_variables": [
#     "TARGET_FID",
#     "AsssD_1",
#     "AsssD_2"
#   ],
#   "regions_start_index": 0,
#   "regions_end_index": 5,
#   "s2_grid_path": "sentinel-2-grid.parquet",
#   "mode": "tiles",
#   "subdivide_tiles": false,
#   "temporal_buffer": [
#     [
#       "2017-08-01",
#       "2017-08-31"
#     ]
#   ],
#   "num_years": 3,
#   "resolution": 30,
#   "projection": "EPSG:3979",
#   "IncludeAngles": false,
#   "prod_names": [
#     "fCOVER"
#   ],
#   "out_folder": "E:\\TestingLEAFFinal\\hiyori_mogged csv_30m",
#   "out_datatype": "int16",
#   "output_type": "csv",
#   "csv_scale": 30,
#   "csv_dropNulls": true,
#   "csv_max_pixels": 100000,
#   "regions_ref": {
#     "region0": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -81.0143277776703,
#             44.792849553362
#           ],
#           [
#             -81.013046437586,
#             44.7928810241213
#           ],
#           [
#             -81.0130828894072,
#             44.7920357810087
#           ],
#           [
#             -81.0134196694422,
#             44.7918539873173
#           ],
#           [
#             -81.013283176937,
#             44.7913976888643
#           ],
#           [
#             -81.0142442205963,
#             44.7913333551658
#           ],
#           [
#             -81.0143277776703,
#             44.792849553362
#           ]
#         ]
#       ]
#     },
#     "region1": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -80.2866384110016,
#             44.3533435417762
#           ],
#           [
#             -80.2864858239462,
#             44.353000698271
#           ],
#           [
#             -80.2868313289172,
#             44.3529866183925
#           ],
#           [
#             -80.2871254773415,
#             44.3529366809224
#           ],
#           [
#             -80.2874977225433,
#             44.3529180592246
#           ],
#           [
#             -80.2876405698119,
#             44.3529059627622
#           ],
#           [
#             -80.2879206306362,
#             44.3528989373857
#           ],
#           [
#             -80.2880395541161,
#             44.3528827993289
#           ],
#           [
#             -80.2880782566738,
#             44.352880279965
#           ],
#           [
#             -80.2882027280036,
#             44.353154957613
#           ],
#           [
#             -80.288085927134,
#             44.3531261618167
#           ],
#           [
#             -80.287951530048,
#             44.3531125098555
#           ],
#           [
#             -80.2878832692439,
#             44.3531281508011
#           ],
#           [
#             -80.287738989293,
#             44.3532215337679
#           ],
#           [
#             -80.2877249039523,
#             44.3532644472593
#           ],
#           [
#             -80.287558824637,
#             44.3533088522111
#           ],
#           [
#             -80.2874518606506,
#             44.3533270111586
#           ],
#           [
#             -80.2871598357525,
#             44.3533320137857
#           ],
#           [
#             -80.2866384110016,
#             44.3533435417762
#           ]
#         ]
#       ]
#     },
#     "region2": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -80.529638877948,
#             44.5242213601121
#           ],
#           [
#             -80.5236686736853,
#             44.5252976281762
#           ],
#           [
#             -80.5234042910143,
#             44.5252538220711
#           ],
#           [
#             -80.5231938083608,
#             44.5249653160984
#           ],
#           [
#             -80.5230220292666,
#             44.5247919216231
#           ],
#           [
#             -80.5294731056627,
#             44.5235598453566
#           ],
#           [
#             -80.529638877948,
#             44.5242213601121
#           ]
#         ]
#       ]
#     },
#     "region3": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -80.3772169808165,
#             44.3239559238229
#           ],
#           [
#             -80.3778062318809,
#             44.3239281559541
#           ],
#           [
#             -80.3783858830901,
#             44.3257096706257
#           ],
#           [
#             -80.3764241776696,
#             44.3259233842728
#           ],
#           [
#             -80.376232840644,
#             44.3258912372486
#           ],
#           [
#             -80.3761778827904,
#             44.3258276760676
#           ],
#           [
#             -80.3757712939805,
#             44.325759362561
#           ],
#           [
#             -80.3752059343744,
#             44.3257911355417
#           ],
#           [
#             -80.3747978938721,
#             44.3239478686715
#           ],
#           [
#             -80.3765005174368,
#             44.3236001331235
#           ],
#           [
#             -80.3766048311268,
#             44.3237444227003
#           ],
#           [
#             -80.3766908273936,
#             44.3238675253118
#           ],
#           [
#             -80.3769060715396,
#             44.323903689341
#           ],
#           [
#             -80.3772169808165,
#             44.3239559238229
#           ]
#         ]
#       ]
#     },
#     "region4": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -80.4414758461818,
#             44.4468399119331
#           ],
#           [
#             -80.4399721805282,
#             44.4471867620164
#           ],
#           [
#             -80.4395657798354,
#             44.4447820571645
#           ],
#           [
#             -80.44099741403,
#             44.4444232095963
#           ],
#           [
#             -80.4414758461818,
#             44.4468399119331
#           ]
#         ]
#       ]
#     },
#     "region5": {
#       "type": "Polygon",
#       "coordinates": [
#         [
#           [
#             -80.4421816733383,
#             44.4466135137253
#           ],
#           [
#             -80.4416845003799,
#             44.4468203876096
#           ],
#           [
#             -80.4411932481774,
#             44.444365318568
#           ],
#           [
#             -80.4415073722911,
#             44.4442547096037
#           ],
#           [
#             -80.4421816733383,
#             44.4466135137253
#           ]
#         ]
#       ]
#     }
#   },
#   "region_start_dates_ref": {
#     "region0": [
#       "2017-08-01",
#       "2018-08-01",
#       "2019-08-01"
#     ],
#     "region1": [
#       "2017-08-01",
#       "2018-08-01",
#       "2019-08-01"
#     ],
#     "region2": [
#       "2017-08-01",
#       "2018-08-01",
#       "2019-08-01"
#     ],
#     "region3": [
#       "2017-08-01",
#       "2018-08-01",
#       "2019-08-01"
#     ],
#     "region4": [
#       "2017-08-01",
#       "2018-08-01",
#       "2019-08-01"
#     ],
#     "region5": [
#       "2017-08-01",
#       "2018-08-01",
#       "2019-08-01"
#     ]
#   },
#   "region_end_dates_ref": {
#     "region0": [
#       "2017-08-31",
#       "2018-08-31",
#       "2019-08-31"
#     ],
#     "region1": [
#       "2017-08-31",
#       "2018-08-31",
#       "2019-08-31"
#     ],
#     "region2": [
#       "2017-08-31",
#       "2018-08-31",
#       "2019-08-31"
#     ],
#     "region3": [
#       "2017-08-31",
#       "2018-08-31",
#       "2019-08-31"
#     ],
#     "region4": [
#       "2017-08-31",
#       "2018-08-31",
#       "2019-08-31"
#     ],
#     "region5": [
#       "2017-08-31",
#       "2018-08-31",
#       "2019-08-31"
#     ]
#   }
# }
# {'tile_17TMK': ['2017-08-01', '2018-08-01', '2019-08-01'], 'tile_17TNK': ['2017-08-01', '2018-08-01', '2019-08-01']}
# {'tile_17TMK': ['2017-08-31', '2018-08-31', '2019-08-31'], 'tile_17TNK': ['2017-08-31', '2018-08-31', '2019-08-31']}
# '\nif result:\n    print("\n" + "="*80)\n    print(" SUCCESS - Parameters validated and ready!")\n    print("="*80)\n    print(f"\n Summary:")\n    print(f"  Regions: {len(result[\'ProdParams\'][\'regions\'])}")\n    print(f"  Time windows: {len(result[\'ProdParams\'][\'start_dates\'])}")\n    print(f"  Total tasks: {len(result[\'ProdParams\'][\'regions\']) * len(result[\'ProdParams\'][\'start_dates\'])}")\n    print(f"  Output folder: {result[\'ProdParams\'][\'out_folder\']}")\n    print(f"\n Processing log saved to: {result[\'ProdParams\'][\'out_folder\']}/polygon_processing_log.csv")\n    print("\n" + "="*80)\n    print("Next step: Call Production.py with the validated parameters")\n    print("="*80)\nelse:\n    print("\n" + "="*80)\n    print(" FAILED - Parameter validation failed")\n    print("="*80)\n    print("Check the error messages above for details.") '

# %%
# View processing log (if pandas is available)
try:
    import pandas as pd
    if result and result['processing_log'] is not None:
        print("\n Processing Log Preview:")
        print("=" * 80)
        display(result['processing_log'].head(10))
        print(f"\nTotal entries: {len(result['processing_log'])}")
except ImportError:
    print("pandas not available - install it to view the processing log in this cell")
    print("You can still view the CSV file directly in the output folder")
# Out:
#  Processing Log Preview:
# ================================================================================
#     region_id      area_m2  will_process status skip_reason
# 0  tile_17TMK      15397.7          True  VALID         N/A
# 1  tile_17TNK  107270129.9          True  VALID         N/A
# Total entries: 2

# %%
import os
import sys
import geopandas as gpd

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

print(ProdParams)
# Out:
# {'sensor': 'S2_SR', 'unit': 2, 'nbYears': -1, 'regions': {'tile_17TMK': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'tile_17TNK': {'type': 'Polygon', 'coordinates': [[[-80.3778062318809, 44.3239281559541], [-80.5294731056627, 44.5235598453566], [-80.529638877948, 44.5242213601121], [-80.5236686736853, 44.5252976281762], [-80.5234042910143, 44.5252538220711], [-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.3747978938721, 44.3239478686715], [-80.3765005174368, 44.3236001331235], [-80.3778062318809, 44.3239281559541]]]}, 'properties': {'sensor': 'S2_SR', 'unit': 2, 'nbYears': -1, 'file_variables': ['TARGET_FID', 'AsssD_1', 'AsssD_2'], 'regions_start_index': 0, 'regions_end_index': 5, 's2_grid_path': 'sentinel-2-grid.parquet', 'mode': 'tiles', 'subdivide_tiles': False, 'temporal_buffer': [['2017-08-01', '2017-08-31']], 'num_years': 3, 'resolution': 30, 'projection': 'EPSG:3979', 'IncludeAngles': False, 'prod_names': ['fCOVER'], 'out_folder': 'E:\\TestingLEAFFinal\\hiyori_mogged csv_30m', 'out_datatype': 'int16', 'output_type': 'csv', 'csv_scale': 30, 'csv_dropNulls': True, 'csv_max_pixels': 100000, 'regions_ref': {'region0': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}, 'region2': {'type': 'Polygon', 'coordinates': [[[-80.529638877948, 44.5242213601121], [-80.5236686736853, 44.5252976281762], [-80.5234042910143, 44.5252538220711], [-80.5231938083608, 44.5249653160984], [-80.5230220292666, 44.5247919216231], [-80.5294731056627, 44.5235598453566], [-80.529638877948, 44.5242213601121]]]}, 'region3': {'type': 'Polygon', 'coordinates': [[[-80.3772169808165, 44.3239559238229], [-80.3778062318809, 44.3239281559541], [-80.3783858830901, 44.3257096706257], [-80.3764241776696, 44.3259233842728], [-80.376232840644, 44.3258912372486], [-80.3761778827904, 44.3258276760676], [-80.3757712939805, 44.325759362561], [-80.3752059343744, 44.3257911355417], [-80.3747978938721, 44.3239478686715], [-80.3765005174368, 44.3236001331235], [-80.3766048311268, 44.3237444227003], [-80.3766908273936, 44.3238675253118], [-80.3769060715396, 44.323903689341], [-80.3772169808165, 44.3239559238229]]]}, 'region4': {'type': 'Polygon', 'coordinates': [[[-80.4414758461818, 44.4468399119331], [-80.4399721805282, 44.4471867620164], [-80.4395657798354, 44.4447820571645], [-80.44099741403, 44.4444232095963], [-80.4414758461818, 44.4468399119331]]]}, 'region5': {'type': 'Polygon', 'coordinates': [[[-80.4421816733383, 44.4466135137253], [-80.4416845003799, 44.4468203876096], [-80.4411932481774, 44.444365318568], [-80.4415073722911, 44.4442547096037], [-80.4421816733383, 44.4466135137253]]]}}, 'region_start_dates_ref': {'region0': ['2017-08-01', '2018-08-01', '2019-08-01'], 'region1': ['2017-0 ...

# %%
main(ProdParams, CompParams)
# Out:
# <LEAF_production> Injected placeholder dates for standardization: 2017-08-01 / 2017-08-31
# <LEAF_production> All input parameters =  {'sensor': 'S2_SR', 'unit': 2, 'nbYears': -1, 'regions': {'tile_17TMK': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'tile_17TNK': {'type': 'Polygon', 'coordinates': [[[-80.3778062318809, 44.3239281559541], [-80.5294731056627, 44.5235598453566], [-80.529638877948, 44.5242213601121], [-80.5236686736853, 44.5252976281762], [-80.5234042910143, 44.5252538220711], [-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.3747978938721, 44.3239478686715], [-80.3765005174368, 44.3236001331235], [-80.3778062318809, 44.3239281559541]]]}}, 'mode': 'tiles', 'resolution': 30, 'projection': 'EPSG:3979', 'IncludeAngles': True, 'prod_names': ['fCOVER'], 'out_folder': 'E:\\TestingLEAFFinal\\hiyori_mogged csv_30m', 'out_datatype': 'int16', 'output_type': 'csv', 'csv_scale': 30, 'csv_dropNulls': True, 'csv_max_pixels': 100000, 'regions_ref': {'region0': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}, 'region2': {'type': 'Polygon', 'coordinates': [[[-80.529638877948, 44.5242213601121], [-80.5236686736853, 44.5252976281762], [-80.5234042910143, 44.5252538220711], [-80.5231938083608, 44.5249653160984], [-80.5230220292666, 44.5247919216231], [-80.5294731056627, 44.5235598453566], [-80.529638877948, 44.5242213601121]]]}, 'region3': {'type': 'Polygon', 'coordinates': [[[-80.3772169808165, 44.3239559238229], [-80.3778062318809, 44.3239281559541], [-80.3783858830901, 44.3257096706257], [-80.3764241776696, 44.3259233842728], [-80.376232840644, 44.3258912372486], [-80.3761778827904, 44.3258276760676], [-80.3757712939805, 44.325759362561], [-80.3752059343744, 44.3257911355417], [-80.3747978938721, 44.3239478686715], [-80.3765005174368, 44.3236001331235], [-80.3766048311268, 44.3237444227003], [-80.3766908273936, 44.3238675253118], [-80.3769060715396, 44.323903689341], [-80.3772169808165, 44.3239559238229]]]}, 'region4': {'type': 'Polygon', 'coordinates': [[[-80.4414758461818, 44.4468399119331], [-80.4399721805282, 44.4471867620164], [-80.4395657798354, 44.4447820571645], [-80.44099741403, 44.4444232095963], [-80.4414758461818, 44.4468399119331]]]}, 'region5': {'type': 'Polygon', 'coordinates': [[[-80.4421816733383, 44.4466135137253], [-80.4416845003799, 44.4468203876096], [-80.4411932481774, 44.444365318568], [-80.4415073722911, 44.4442547096037], [-80.4421816733383, 44.4466135137253]]]}}, 'region_start_dates': {'tile_17TMK': ['2017-08-01', '2018-08-01', '2019-08-01'], 'tile_17TNK': ['2017-08-01', '2018-08-01', '2019-08-01']}, 'region_end_dates': {'tile_17TMK': ['2017-08-31', '2018-08-31', '2019-08-31'], 'tile_17TNK': ['2017-08-31', '2018-08-31', '2019-08-31']}, 'region_start_dates_ref': {'region0': ['2017-08-01', '2018-08-01', '2019-08-01'], ' ...
#
# <LEAF_production> Using region-specific dates for tile_17TMK
#   Start dates: ['2017-08-01', '2018-08-01', '2019-08-01']
#   End dates:   ['2017-08-31', '2018-08-31', '2019-08-31']
# <MosaicProduction> Processing tile_17TMK | time window: 2017-08-01 / 2017-08-31
#
# <LEAF_production> Generate and export separate vegetation biophysical maps......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': (((-81.0143277776703, 44.792849553362), (-81.0142442205963, 44.7913333551658), (-81.013283176937, 44.7913976888643), (-81.0130828894072, 44.7920357810087), (-81.013046437586, 44.7928810241213), (-81.0143277776703, 44.792849553362)),)}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.01 minutes
#
# <one_mosaic> A total of 5 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/10/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/10/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/10/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/10/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/10/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/10/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/10/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/10/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/10/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/10/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/10/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/10/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/10/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/10/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/10/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2017/8/10/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2A_17TMK_20170810_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-80.96438346426764, 45.15382269551626], [-80.87584634429486, 45.15376076769412], [-80.87793799810343, 44.16531029102769], [-81.29688180936175, 44.16498974888183], [-80.96438346426764, 45.15382269551626]]]}
# Bounding Box: [-81.29688180936175, 44.16498974888183, -80.87584634429486, 45.15382269551626]
# Datetime: 2017-08-10 16:17:47.178000+00:00
# cloud cover: 56.565757
# Properties:
#   <created>: 2022-11-03T09:15:29.870Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 56.565757
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: MK
#   <grid:code>: MGRS-17TMK
#   <view:sun_azimuth>: 147.467346917529
#   <view:sun_elevation>: 57.1327884187958
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 81.580591
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.056956
#   <s2:cloud_shadow_percentage>: 0.011852
#   <s2:vegetation_percentage>: 29.078653
#   <s2:not_vegetated_percentage>: 2.035222
#   <s2:water_percentage>: 5.65153
#   <s2:unclassified_percentage>: 6.600027
#   <s2:medium_proba_clouds_percentage>: 18.509738
#   <s2:high_proba_clouds_percentage>: 11.12695
#   <s2:thin_cirrus_percentage>: 26.929069
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 00.01
#   <s2:product_uri>: S2A_MSIL2A_20170810T161351_N0001_R140_T17TMK_20201031T050106.SAFE
#   <s2:generation_time>: 2020-10-31T05:01:06.522Z
#   <s2:datatake_id>: GS2A_20170810T161351_011148_N00.01
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_SHIT_20201031T050108_S20170810T161747_N00.01
#   <s2:granule_id>: S2A_OPER_MSI_L2A_TL_SHIT_20201031T050108_A011148_T17TMK_N00.01
#   <s2:reflectance_conversion_factor>: 0.972470132845409
#   <datetime>: 2017-08-10T16:17:47.178000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/MK/2017/8/S2A_17TMK_20170810_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/31e018df5ff4494e594db1312a784736
#   <earthsearch:boa_offset_applied>: False
#   <processing:software>: {'sentinel2-to-stac': '0.1.0'}
#   <updated>: 2022-11-08T09:21:37.515Z
#   <proj:code>: EPSG:32617
#   <sza>: 32.8672115812042
#   <saa>: 147.467346917529
#   <vza>: 10.9359709762304
#   <vaa>: 109.910838733136
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 3kB
# Dimensions:      (y: 8, x: 5)
# Coordinates:
#   * y            (y) float64 64B -3.484e+05 -3.484e+05 ... -3.486e+05 -3.486e+05
#   * x            (x) float64 40B 1.118e+06 1.118e+06 ... 1.118e+06 1.118e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2017-08-10T16:17:47.178000
# Data variables: (12/16)
#     blue         (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     green        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     red          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge1     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge2     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge3     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     ...           ...
#     date         (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     score        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SZA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SAA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VZA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VAA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TMK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'SZA', 'SAA', 'VZA', 'VAA']
# <_get_tile_regions> 1 region(s) matched for tile tile_17TMK (2017-08-01 – 2017-08-31)  [skipped: 0 date-mismatch, 5 out-of-bounds]
#
# <export_mosaic> tiles mode — exporting region: region0 (tile: tile_17TMK)
#
# <export_csv> Sampling mosaic pixels and building CSV table...
# <_clip_mosaic_to_regions> Clipped mosaic → Frozen({'y': 8, 'x': 5})
# <export_csv> Valid pixels after dropNulls filter: 29
# <export_csv> CSV written → E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region0_tile_17TMK_2017-08-01_2017-08-31_30m.csv  (29 rows, 21 columns)
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.76 minutes >>>>>>
# File 'E:\TestingLEAFFinal\hiyori_mogged csv_30m\log_79ca1998-f81e-4cb1-8d8b-75cd7a810fce.out' does not exist.
# Directory 'E:\TestingLEAFFinal\hiyori_mogged csv_30m\dask_spill_79ca1998-f81e-4cb1-8d8b-75cd7a810fce' and its contents have been deleted.
#
# <create_LEAF_maps> The bands in mosaic image: Data variables:
#     blue      (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     green     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     red       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge1  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge2  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge3  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     nir08     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir16    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir22    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     scl       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     date      (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     score     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SZA       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SAA       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VZA       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VAA       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#
# <create_LEAF_maps> The bands in modified mosaic image: Data variables:
#     blue      (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     green     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     red       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge1  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge2  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge3  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     nir08     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir16    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir22    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     scl       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     date      (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     score     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     cosSZA    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     cosVZA    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     cosRAA    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#
# <get_local_CanLC> original LC map =  <xarray.DataArray (y: 160001, x: 190001)> Size: 30GB
# [30400350001 values with dtype=uint8]
# Coordinates:
#     band         int32 4B 1
#   * x            (x) float64 2MB -2.6e+06 -2.6e+06 -2.6e+06 ... 3.1e+06 3.1e+06
#   * y            (y) float64 1MB 3.915e+06 3.915e+06 ... -8.85e+05 -8.851e+05
#     spatial_ref  int32 4B 0
# Attributes:
#     TIFFTAG_SOFTWARE:  PCI Geomatica
#     TIFFTAG_DATETIME:  2020:07:01 12:00:00
#     AREA_OR_POINT:     Area
#     DESCRIPTION:       EASI Modeling Result
#     _FillValue:        0
#     scale_factor:      1.0
#     add_offset:        0.0
#
# <get_local_CanLC> clipped LC map =  <xarray.DataArray (y: 8, x: 5)> Size: 320B
# array([[15., 15., 15., 15., 15.],
#        [15., 15., 15.,  6.,  5.],
#        [15., 15., 15.,  5.,  5.],
#        [15., 15., 15., 15.,  5.],
#        [15., 15., 15., 15.,  5.],
#        [15., 15., 15., 15.,  5.],
#        [15., 15., 15., 15.,  5.],
#        [15.,  6.,  5.,  5.,  5.]])
# Coordinates:
#     band         int32 4B 1
#     spatial_ref  int32 4B 0
#   * x            (x) float64 40B 1.118e+06 1.118e+06 ... 1.118e+06 1.118e+06
#   * y            (y) float64 64B -3.484e+05 -3.484e+05 ... -3.486e+05 -3.486e+05
# Attributes:
#     TIFFTAG_SOFTWARE:  PCI Geomatica
#     TIFFTAG_DATETIME:  2020:07:01 12:00:00
#     AREA_OR_POINT:     Area
#     DESCRIPTION:       EASI Modeling Result
#     _FillValue:        0
#     scale_factor:      1.0
#     add_offset:        0.0
#
# <create_LEAF_maps> Bands in mosaic before rescaling: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'cosSZA', 'cosVZA', 'cosRAA']
# <create_LEAF_maps> Bands in ready_mosaic after rescaling: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'cosSZA', 'cosVZA', 'cosRAA']
# <estimate_VParams> the bands in DS options =  ['cosVZA', 'cosSZA', 'cosRAA', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22']
# <invalidInput> Generating sl2p input data flag
# Generating sl2p output product flag
#
#
# <<< The elapsed time for generating one monthly tile product = 0.8005208055178324 minutes>>>
#
#
# <export_VegParamMaps> data variables in given VP map: Data variables:
#     date     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     fCOVER   (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     QC       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
# <_get_tile_regions> 1 region(s) matched for tile tile_17TMK (2017-08-01 – 2017-08-31)  [skipped: 0 date-mismatch, 5 out-of-bounds]
#
# <export_VegParamMaps> tiles mode — exporting region: region0 (tile: tile_17TMK)
# <_write_VP_csv> Loaded mosaic CSV (29 rows) from E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region0_tile_17TMK_2017-08-01_2017-08-31_30m.csv
# <_clip_mosaic_to_regions> Clipped mosaic → Frozen({'y': 8, 'x': 5})
# <_write_VP_csv> VP pixels after null filter: 29
# <_write_VP_csv> 29 / 29 rows matched VP values (checked via 'fCOVER').
# <_write_VP_csv> Updated CSV → E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region0_tile_17TMK_2017-08-01_2017-08-31_30m.csv  (29 rows, 24 columns)
# <MosaicProduction> Processing tile_17TMK | time window: 2018-08-01 / 2018-08-31
#
# <LEAF_production> Generate and export separate vegetation biophysical maps......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': (((-81.0143277776703, 44.792849553362), (-81.0142442205963, 44.7913333551658), (-81.013283176937, 44.7913976888643), (-81.0130828894072, 44.7920357810087), (-81.013046437586, 44.7928810241213), (-81.0143277776703, 44.792849553362)),)}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.02 minutes
#
# <one_mosaic> A total of 17 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/5/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/5/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/5/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/5/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/5/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/5/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/5/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/5/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/5/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/5/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/5/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/5/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/5/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/5/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/5/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2018/8/5/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2A_17TMK_20180805_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-80.96088166921773, 45.15382154979668], [-80.87584634429486, 45.15376076769412], [-80.87793799810343, 44.16531029102769], [-81.29254030926583, 44.16500094858399], [-80.96088166921773, 45.15382154979668]]]}
# Bounding Box: [-81.29254030926583, 44.16500094858399, -80.87584634429486, 45.15382154979668]
# Datetime: 2018-08-05 16:17:51.805000+00:00
# cloud cover: 17.25978
# Properties:
#   <created>: 2022-11-08T13:30:18.358Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 17.25978
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: MK
#   <grid:code>: MGRS-17TMK
#   <view:sun_azimuth>: 146.038222971679
#   <view:sun_elevation>: 58.423642696078204
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 81.856799
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.212549
#   <s2:cloud_shadow_percentage>: 0.057366
#   <s2:vegetation_percentage>: 67.635995
#   <s2:not_vegetated_percentage>: 4.532075
#   <s2:water_percentage>: 10.093285
#   <s2:unclassified_percentage>: 0.208947
#   <s2:medium_proba_clouds_percentage>: 2.603258
#   <s2:high_proba_clouds_percentage>: 2.315092
#   <s2:thin_cirrus_percentage>: 12.341429
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 00.01
#   <s2:product_uri>: S2A_MSIL2A_20180805T160901_N0001_R140_T17TMK_20200920T163726.SAFE
#   <s2:generation_time>: 2020-09-20T16:37:26.978Z
#   <s2:datatake_id>: GS2A_20180805T160901_016296_N00.01
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_SHIT_20200920T163729_S20180805T161751_N00.01
#   <s2:granule_id>: S2A_OPER_MSI_L2A_TL_SHIT_20200920T163729_A016296_T17TMK_N00.01
#   <s2:reflectance_conversion_factor>: 0.970998281964625
#   <datetime>: 2018-08-05T16:17:51.805000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/MK/2018/8/S2A_17TMK_20180805_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/3bfed37124871eb0124c6eea3ecc9554
#   <earthsearch:boa_offset_applied>: False
#   <processing:software>: {'sentinel2-to-stac': '0.1.0'}
#   <updated>: 2022-11-08T13:30:18.358Z
#   <proj:code>: EPSG:32617
#   <sza>: 31.576357303921796
#   <saa>: 146.038222971679
#   <vza>: 10.9484890658753
#   <vaa>: 109.92463454421
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 3kB
# Dimensions:      (y: 8, x: 5)
# Coordinates:
#   * y            (y) float64 64B -3.484e+05 -3.484e+05 ... -3.486e+05 -3.486e+05
#   * x            (x) float64 40B 1.118e+06 1.118e+06 ... 1.118e+06 1.118e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2018-08-05T16:17:51.805000
# Data variables: (12/16)
#     blue         (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     green        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     red          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge1     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge2     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge3     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     ...           ...
#     date         (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     score        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SZA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SAA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VZA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VAA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TMK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'SZA', 'SAA', 'VZA', 'VAA']
# <_get_tile_regions> 1 region(s) matched for tile tile_17TMK (2018-08-01 – 2018-08-31)  [skipped: 0 date-mismatch, 5 out-of-bounds]
#
# <export_mosaic> tiles mode — exporting region: region0 (tile: tile_17TMK)
#
# <export_csv> Sampling mosaic pixels and building CSV table...
# <_clip_mosaic_to_regions> Clipped mosaic → Frozen({'y': 8, 'x': 5})
# <export_csv> Valid pixels after dropNulls filter: 29
# <export_csv> CSV written → E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region0_tile_17TMK_2018-08-01_2018-08-31_30m.csv  (29 rows, 21 columns)
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.69 minutes >>>>>>
# File 'E:\TestingLEAFFinal\hiyori_mogged csv_30m\log_218c8326-f365-492e-b562-46f9b033206d.out' does not exist.
# Directory 'E:\TestingLEAFFinal\hiyori_mogged csv_30m\dask_spill_218c8326-f365-492e-b562-46f9b033206d' and its contents have been deleted.
#
# <create_LEAF_maps> The bands in mosaic image: Data variables:
#     blue      (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     green     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     red       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge1  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge2  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge3  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     nir08     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir16    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir22    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     scl       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     date      (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     score     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SZA       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SAA       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VZA       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VAA       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#
# <create_LEAF_maps> The bands in modified mosaic image: Data variables:
#     blue      (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     green     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     red       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge1  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge2  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge3  (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     nir08     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir16    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir22    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     scl       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     date      (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     score     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     cosSZA    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     cosVZA    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     cosRAA    (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#
# <get_local_CanLC> original LC map =  <xarray.DataArray (y: 160001, x: 190001)> Size: 30GB
# [30400350001 values with dtype=uint8]
# Coordinates:
#     band         int32 4B 1
#   * x            (x) float64 2MB -2.6e+06 -2.6e+06 -2.6e+06 ... 3.1e+06 3.1e+06
#   * y            (y) float64 1MB 3.915e+06 3.915e+06 ... -8.85e+05 -8.851e+05
#     spatial_ref  int32 4B 0
# Attributes:
#     TIFFTAG_SOFTWARE:  PCI Geomatica
#     TIFFTAG_DATETIME:  2020:07:01 12:00:00
#     AREA_OR_POINT:     Area
#     DESCRIPTION:       EASI Modeling Result
#     _FillValue:        0
#     scale_factor:      1.0
#     add_offset:        0.0
#
# <get_local_CanLC> clipped LC map =  <xarray.DataArray (y: 8, x: 5)> Size: 320B
# array([[15., 15., 15., 15., 15.],
#        [15., 15., 15.,  6.,  5.],
#        [15., 15., 15.,  5.,  5.],
#        [15., 15., 15., 15.,  5.],
#        [15., 15., 15., 15.,  5.],
#        [15., 15., 15., 15.,  5.],
#        [15., 15., 15., 15.,  5.],
#        [15.,  6.,  5.,  5.,  5.]])
# Coordinates:
#     band         int32 4B 1
#     spatial_ref  int32 4B 0
#   * x            (x) float64 40B 1.118e+06 1.118e+06 ... 1.118e+06 1.118e+06
#   * y            (y) float64 64B -3.484e+05 -3.484e+05 ... -3.486e+05 -3.486e+05
# Attributes:
#     TIFFTAG_SOFTWARE:  PCI Geomatica
#     TIFFTAG_DATETIME:  2020:07:01 12:00:00
#     AREA_OR_POINT:     Area
#     DESCRIPTION:       EASI Modeling Result
#     _FillValue:        0
#     scale_factor:      1.0
#     add_offset:        0.0
#
# <create_LEAF_maps> Bands in mosaic before rescaling: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'cosSZA', 'cosVZA', 'cosRAA']
# <create_LEAF_maps> Bands in ready_mosaic after rescaling: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'cosSZA', 'cosVZA', 'cosRAA']
# <estimate_VParams> the bands in DS options =  ['cosVZA', 'cosSZA', 'cosRAA', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22']
# <invalidInput> Generating sl2p input data flag
# Generating sl2p output product flag
#
#
# <<< The elapsed time for generating one monthly tile product = 0.6983269135157267 minutes>>>
#
#
# <export_VegParamMaps> data variables in given VP map: Data variables:
#     date     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     fCOVER   (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     QC       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
# <_get_tile_regions> 1 region(s) matched for tile tile_17TMK (2018-08-01 – 2018-08-31)  [skipped: 0 date-mismatch, 5 out-of-bounds]
#
# <export_VegParamMaps> tiles mode — exporting region: region0 (tile: tile_17TMK)
# <_write_VP_csv> Loaded mosaic CSV (29 rows) from E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region0_tile_17TMK_2018-08-01_2018-08-31_30m.csv
# <_clip_mosaic_to_regions> Clipped mosaic → Frozen({'y': 8, 'x': 5})
# <_write_VP_csv> VP pixels after null filter: 29
# <_write_VP_csv> 29 / 29 rows matched VP values (checked via 'fCOVER').
# <_write_VP_csv> Updated CSV → E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region0_tile_17TMK_2018-08-01_2018-08-31_30m.csv  (29 rows, 24 columns)
# <MosaicProduction> Processing tile_17TMK | time window: 2019-08-01 / 2019-08-31
#
# <LEAF_production> Generate and export separate vegetation biophysical maps......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': (((-81.0143277776703, 44.792849553362), (-81.0142442205963, 44.7913333551658), (-81.013283176937, 44.7913976888643), (-81.0130828894072, 44.7920357810087), (-81.013046437586, 44.7928810241213), (-81.0143277776703, 44.792849553362)),)}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.02 minutes
#
# <one_mosaic> A total of 20 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/thumbnail.jp2
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2019/8/30/1/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2019/8/30/1/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2019/8/30/1/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2019/8/30/1/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2019/8/30/1/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2019/8/30/1/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2019/8/30/1/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2019/8/30/1/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2019/8/30/1/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2019/8/30/1/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2019/8/30/1/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2019/8/30/1/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2019/8/30/1/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2019/8/30/1/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2019/8/30/1/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2019/8/30/1/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2A_17TMK_20190830_1_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-80.96000623285862, 45.15382124659483], [-81.2931253500889, 44.16499944898164], [-80.87793799810343, 44.16531029102769], [-80.87584634429486, 45.15376076769412], [-80.96000623285862, 45.15382124659483]]]}
# Bounding Box: [-81.2931253500889, 44.16499944898164, -80.87584634429486, 45.15382124659483]
# Datetime: 2019-08-30 16:21:06.152000+00:00
# cloud cover: 24.399786
# Properties:
#   <created>: 2024-08-25T13:31:51.487Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 24.399786
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: MK
#   <grid:code>: MGRS-17TMK
#   <view:sun_azimuth>: 153.253455202978
#   <view:sun_elevation>: 51.5380903257499
#   <s2:degraded_msi_data_percentage>: 0.0554
#   <s2:nodata_pixel_percentage>: 81.768638
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.039727
#   <s2:cloud_shadow_percentage>: 12.81513
#   <s2:vegetation_percentage>: 43.564144
#   <s2:not_vegetated_percentage>: 3.556975
#   <s2:water_percentage>: 15.064596
#   <s2:unclassified_percentage>: 0.559641
#   <s2:medium_proba_clouds_percentage>: 12.634692
#   <s2:high_proba_clouds_percentage>: 11.516283
#   <s2:thin_cirrus_percentage>: 0.24881
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.00
#   <s2:product_uri>: S2A_MSIL2A_20190830T160901_N0500_R140_T17TMK_20230720T143337.SAFE
#   <s2:generation_time>: 2023-07-20T14:33:37.000000Z
#   <s2:datatake_id>: GS2A_20190830T160901_021873_N05.00
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_S2RP_20230720T143337_S20190830T161839_N05.00
#   <s2:granule_id>: S2A_OPER_MSI_L2A_TL_S2RP_20230720T143337_A021873_T17TMK_N05.00
#   <s2:reflectance_conversion_factor>: 0.979694095729625
#   <datetime>: 2019-08-30T16:21:06.152000Z
#   <s2:sequence>: 1
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/MK/2019/8/S2A_17TMK_20190830_1_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/3aea07a73ee517182f3a9cae04a88baf
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.1'}
#   <updated>: 2024-08-25T13:31:51.487Z
#   <proj:code>: EPSG:32617
#   <sza>: 38.4619096742501
#   <saa>: 153.253455202978
#   <vza>: 10.9529532841862
#   <vaa>: 109.88941776338
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 3kB
# Dimensions:      (y: 8, x: 5)
# Coordinates:
#   * y            (y) float64 64B -3.484e+05 -3.484e+05 ... -3.486e+05 -3.486e+05
#   * x            (x) float64 40B 1.118e+06 1.118e+06 ... 1.118e+06 1.118e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2019-08-30T16:21:06.152000
# Data variables: (12/16)
#     blue         (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     green        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     red          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge1     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge2     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge3     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     ...           ...
#     date         (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     score        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SZA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     SAA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VZA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     VAA          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TMK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'SZA', 'SAA', 'VZA', 'VAA']
# <_get_tile_regions> 1 region(s) matched for tile tile_17TMK (2019-08-01 – 2019-08-31)  [skipped: 0 date-mismatch, 5 out-of-bounds]
#
# <export_mosaic> tiles mode — exporting region: region0 (tile: tile_17TMK)
#
# <export_csv> Sampling mosaic pixels and building CSV table...
# <_clip_mosaic_to_regions> Clipped mosaic → Frozen({'y': 8, 'x': 5})
# ...
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2019/8/28/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TNK_20190828_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-79.60360176290054, 45.14529082911873], [-79.60371000582505, 45.14085752005338], [-80.00064467706537, 44.16100432882957], [-81.00023764531663, 44.16537549832127], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.00024171761814, 44.16100432882957, -79.60360176290054, 45.153828248771845]
# Datetime: 2019-08-28 16:31:01.203000+00:00
# cloud cover: 6.675575
# Properties:
#   <created>: 2022-11-08T09:29:14.088Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 6.675575
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:sun_azimuth>: 158.482408891423
#   <view:sun_elevation>: 53.2652522728364
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 13.434617
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.532699
#   <s2:cloud_shadow_percentage>: 2.289669
#   <s2:vegetation_percentage>: 40.924525
#   <s2:not_vegetated_percentage>: 3.569326
#   <s2:water_percentage>: 44.862777
#   <s2:unclassified_percentage>: 1.144028
#   <s2:medium_proba_clouds_percentage>: 1.354316
#   <s2:high_proba_clouds_percentage>: 4.608214
#   <s2:thin_cirrus_percentage>: 0.713046
#   <s2:snow_ice_percentage>: 0.001403
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 02.13
#   <s2:product_uri>: S2B_MSIL2A_20190828T161839_N0213_R040_T17TNK_20190828T203313.SAFE
#   <s2:generation_time>: 2019-08-28T20:33:13.000000Z
#   <s2:datatake_id>: GS2B_20190828T161839_012936_N02.13
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_MTI__20190828T203313_S20190828T162908_N02.13
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_MTI__20190828T203313_A012936_T17TNK_N02.13
#   <s2:reflectance_conversion_factor>: 0.97883052972375
#   <datetime>: 2019-08-28T16:31:01.203000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2019/8/S2B_17TNK_20190828_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/931bb302cb21f45806a48d2d38ca2fcd
#   <earthsearch:boa_offset_applied>: False
#   <processing:software>: {'sentinel2-to-stac': '0.1.0'}
#   <updated>: 2022-11-08T09:29:14.088Z
#   <proj:code>: EPSG:32617
#   <sza>: 36.7347477271636
#   <saa>: 158.482408891423
#   <vza>: 8.19455924185174
#   <vaa>: 285.188822453566
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 33MB
# Dimensions:      (y: 652, x: 789)
# Coordinates:
#   * y            (y) float64 5kB -3.692e+05 -3.692e+05 ... -3.887e+05 -3.887e+05
#   * x            (x) float64 6kB 1.163e+06 1.163e+06 ... 1.187e+06 1.187e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2019-08-28T16:31:01.203000
# Data variables: (12/16)
#     blue         (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     green        (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     red          (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     rededge1     (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     rededge2     (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     rededge3     (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     ...           ...
#     date         (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     score        (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     SZA          (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     SAA          (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     VZA          (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     VAA          (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <one_mosaic> Final mosaic bands: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'SZA', 'SAA', 'VZA', 'VAA']
# <_get_tile_regions> 5 region(s) matched for tile tile_17TNK (2019-08-01 – 2019-08-31)  [skipped: 0 date-mismatch, 1 out-of-bounds]
#
# <export_mosaic> tiles mode — exporting region: region1 (tile: tile_17TNK)
#
# <export_csv> Sampling mosaic pixels and building CSV table...
# <_clip_mosaic_to_regions> Clipped mosaic → Frozen({'y': 4, 'x': 5})
# <export_csv> Valid pixels after dropNulls filter: 13
# <export_csv> CSV written → E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region1_tile_17TNK_2019-08-01_2019-08-31_30m.csv  (13 rows, 21 columns)
#
# <export_mosaic> tiles mode — exporting region: region2 (tile: tile_17TNK)
#
# <export_csv> Sampling mosaic pixels and building CSV table...
# <_clip_mosaic_to_regions> Clipped mosaic → Frozen({'y': 10, 'x': 18})
# <export_csv> Valid pixels after dropNulls filter: 68
# <export_csv> CSV written → E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region2_tile_17TNK_2019-08-01_2019-08-31_30m.csv  (68 rows, 21 columns)
#
# <export_mosaic> tiles mode — exporting region: region3 (tile: tile_17TNK)
#
# <export_csv> Sampling mosaic pixels and building CSV table...
# <_clip_mosaic_to_regions> Clipped mosaic → Frozen({'y': 9, 'x': 12})
# <export_csv> Valid pixels after dropNulls filter: 84
# <export_csv> CSV written → E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region3_tile_17TNK_2019-08-01_2019-08-31_30m.csv  (84 rows, 21 columns)
#
# <export_mosaic> tiles mode — exporting region: region4 (tile: tile_17TNK)
#
# <export_csv> Sampling mosaic pixels and building CSV table...
# <_clip_mosaic_to_regions> Clipped mosaic → Frozen({'y': 12, 'x': 8})
# <export_csv> Valid pixels after dropNulls filter: 56
# <export_csv> CSV written → E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region4_tile_17TNK_2019-08-01_2019-08-31_30m.csv  (56 rows, 21 columns)
#
# <export_mosaic> tiles mode — exporting region: region5 (tile: tile_17TNK)
#
# <export_csv> Sampling mosaic pixels and building CSV table...
# <_clip_mosaic_to_regions> Clipped mosaic → Frozen({'y': 10, 'x': 5})
# <export_csv> Valid pixels after dropNulls filter: 24
# <export_csv> CSV written → E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region5_tile_17TNK_2019-08-01_2019-08-31_30m.csv  (24 rows, 21 columns)
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   1.70 minutes >>>>>>
# File 'E:\TestingLEAFFinal\hiyori_mogged csv_30m\log_34979c9c-9fb1-450d-ba38-8a9817a1f1f9.out' does not exist.
# Directory 'E:\TestingLEAFFinal\hiyori_mogged csv_30m\dask_spill_34979c9c-9fb1-450d-ba38-8a9817a1f1f9' and its contents have been deleted.
#
# <create_LEAF_maps> The bands in mosaic image: Data variables:
#     blue      (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     green     (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     red       (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     rededge1  (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     rededge2  (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     rededge3  (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     nir08     (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     swir16    (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     swir22    (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     scl       (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     date      (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     score     (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     SZA       (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     SAA       (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     VZA       (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     VAA       (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#
# <create_LEAF_maps> The bands in modified mosaic image: Data variables:
#     blue      (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     green     (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     red       (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     rededge1  (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     rededge2  (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     rededge3  (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     nir08     (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     swir16    (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     swir22    (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     scl       (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     date      (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     score     (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     cosSZA    (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     cosVZA    (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     cosRAA    (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#
# <get_local_CanLC> original LC map =  <xarray.DataArray (y: 160001, x: 190001)> Size: 30GB
# [30400350001 values with dtype=uint8]
# Coordinates:
#     band         int32 4B 1
#   * x            (x) float64 2MB -2.6e+06 -2.6e+06 -2.6e+06 ... 3.1e+06 3.1e+06
#   * y            (y) float64 1MB 3.915e+06 3.915e+06 ... -8.85e+05 -8.851e+05
#     spatial_ref  int32 4B 0
# Attributes:
#     TIFFTAG_SOFTWARE:  PCI Geomatica
#     TIFFTAG_DATETIME:  2020:07:01 12:00:00
#     AREA_OR_POINT:     Area
#     DESCRIPTION:       EASI Modeling Result
#     _FillValue:        0
#     scale_factor:      1.0
#     add_offset:        0.0
#
# <get_local_CanLC> clipped LC map =  <xarray.DataArray (y: 652, x: 789)> Size: 4MB
# array([[15., 15., 15., ..., 15., 15., 15.],
#        [15., 15., 15., ..., 17., 15., 15.],
#        [15., 15., 15., ..., 17., 17., 15.],
#        ...,
#        [15.,  6.,  6., ..., 15., 15., 15.],
#        [15., 15.,  6., ..., 15., 15., 15.],
#        [ 6.,  6.,  5., ..., 15., 15., 15.]])
# Coordinates:
#     band         int32 4B 1
#     spatial_ref  int32 4B 0
#   * x            (x) float64 6kB 1.163e+06 1.163e+06 ... 1.187e+06 1.187e+06
#   * y            (y) float64 5kB -3.692e+05 -3.692e+05 ... -3.887e+05 -3.887e+05
# Attributes:
#     TIFFTAG_SOFTWARE:  PCI Geomatica
#     TIFFTAG_DATETIME:  2020:07:01 12:00:00
#     AREA_OR_POINT:     Area
#     DESCRIPTION:       EASI Modeling Result
#     _FillValue:        0
#     scale_factor:      1.0
#     add_offset:        0.0
#
# <create_LEAF_maps> Bands in mosaic before rescaling: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'cosSZA', 'cosVZA', 'cosRAA']
# <create_LEAF_maps> Bands in ready_mosaic after rescaling: ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl', 'date', 'score', 'cosSZA', 'cosVZA', 'cosRAA']
# <estimate_VParams> the bands in DS options =  ['cosVZA', 'cosSZA', 'cosRAA', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22']
# <invalidInput> Generating sl2p input data flag
# C:\Users\aradar\LEAF Files\LEAF_runner\source\SL2P_NetsTools.py:311: RuntimeWarning: invalid value encountered in cast
#   image_format=np.sum((np.uint8(np.ceil(data_array*10)%10))* np.array([10**value for value in range(len(bandList))])[:,None],axis=0)
# Generating sl2p output product flag
#
#
# <<< The elapsed time for generating one monthly tile product = 1.7783153533935547 minutes>>>
#
#
# <export_VegParamMaps> data variables in given VP map: Data variables:
#     date     (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     fCOVER   (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
#     QC       (y, x) float32 2MB dask.array<chunksize=(512, 512), meta=np.ndarray>
# <_get_tile_regions> 5 region(s) matched for tile tile_17TNK (2019-08-01 – 2019-08-31)  [skipped: 0 date-mismatch, 1 out-of-bounds]
#
# <export_VegParamMaps> tiles mode — exporting region: region1 (tile: tile_17TNK)
# <_write_VP_csv> Loaded mosaic CSV (13 rows) from E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region1_tile_17TNK_2019-08-01_2019-08-31_30m.csv
# <_clip_mosaic_to_regions> Clipped mosaic → Frozen({'y': 4, 'x': 5})
# <_write_VP_csv> VP pixels after null filter: 13
# <_write_VP_csv> 13 / 13 rows matched VP values (checked via 'fCOVER').
# <_write_VP_csv> Updated CSV → E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region1_tile_17TNK_2019-08-01_2019-08-31_30m.csv  (13 rows, 24 columns)
#
# <export_VegParamMaps> tiles mode — exporting region: region2 (tile: tile_17TNK)
# <_write_VP_csv> Loaded mosaic CSV (68 rows) from E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region2_tile_17TNK_2019-08-01_2019-08-31_30m.csv
# <_clip_mosaic_to_regions> Clipped mosaic → Frozen({'y': 10, 'x': 18})
# <_write_VP_csv> VP pixels after null filter: 68
# <_write_VP_csv> 68 / 68 rows matched VP values (checked via 'fCOVER').
# <_write_VP_csv> Updated CSV → E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region2_tile_17TNK_2019-08-01_2019-08-31_30m.csv  (68 rows, 24 columns)
#
# <export_VegParamMaps> tiles mode — exporting region: region3 (tile: tile_17TNK)
# <_write_VP_csv> Loaded mosaic CSV (84 rows) from E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region3_tile_17TNK_2019-08-01_2019-08-31_30m.csv
# <_clip_mosaic_to_regions> Clipped mosaic → Frozen({'y': 9, 'x': 12})
# <_write_VP_csv> VP pixels after null filter: 84
# <_write_VP_csv> 84 / 84 rows matched VP values (checked via 'fCOVER').
# <_write_VP_csv> Updated CSV → E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region3_tile_17TNK_2019-08-01_2019-08-31_30m.csv  (84 rows, 24 columns)
#
# <export_VegParamMaps> tiles mode — exporting region: region4 (tile: tile_17TNK)
# <_write_VP_csv> Loaded mosaic CSV (56 rows) from E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region4_tile_17TNK_2019-08-01_2019-08-31_30m.csv
# <_clip_mosaic_to_regions> Clipped mosaic → Frozen({'y': 12, 'x': 8})
# <_write_VP_csv> VP pixels after null filter: 56
# <_write_VP_csv> 56 / 56 rows matched VP values (checked via 'fCOVER').
# <_write_VP_csv> Updated CSV → E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region4_tile_17TNK_2019-08-01_2019-08-31_30m.csv  (56 rows, 24 columns)
#
# <export_VegParamMaps> tiles mode — exporting region: region5 (tile: tile_17TNK)
# <_write_VP_csv> Loaded mosaic CSV (24 rows) from E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region5_tile_17TNK_2019-08-01_2019-08-31_30m.csv
# <_clip_mosaic_to_regions> Clipped mosaic → Frozen({'y': 10, 'x': 5})
# <_write_VP_csv> VP pixels after null filter: 24
# <_write_VP_csv> 24 / 24 rows matched VP values (checked via 'fCOVER').
# <_write_VP_csv> Updated CSV → E:\TestingLEAFFinal\hiyori_mogged csv_30m\S2_SR_region5_tile_17TNK_2019-08-01_2019-08-31_30m.csv  (24 rows, 24 columns)
