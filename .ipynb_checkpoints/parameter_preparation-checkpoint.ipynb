# %%
import os
import sys
from pathlib import Path

project_root = Path.cwd()
sys.path.insert(0, str(project_root))

from prepare_params import prepare_production_params

print("Modules imported successfully")
print(f"Current working directory: {os.getcwd()}")


kml = "Sample Points\AfforestationSItesFixed.kml"
shp = "Sample Points\FieldPoints32_2018.shp"
tmx = "TMX\TML_pipeline_100mbuffer.kml"
print(kml)
print(shp)
print(tmx)

# %%
# TEMPLATE 1: Single Year Monthly Mosaics
# Use Case: Generate monthly mosaics for specific months in one year
# Example: Summer months (June, July, August) of 2023
# Customize these parameters as needed:

ProdParams = {
    # ============ REQUIRED PARAMETERS ============
    'sensor': 'S2_SR',                    # Sensor type
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'nbYears': -1,            # positive int for annual product, or negative int for monthly product
    #'year': 2023,                          # CHANGE THIS: Year to process
    #'months': [8,9,10],                   # CHANGE THIS: Months to process (1-12)
    
    
    # ============ REGION PARAMETERS ============
    'regions': tmx,  # CHANGE THIS: Path to your KML/SHP file
    #'file_variables': ['TARGET_FID', 'AsssD_1', 'AsssD_2'], # CHANGE THIS: id, start_date, end_date
    'file_variables': ['id', 'begin', 'end'],
    'regions_start_index': 0,              # CHANGE THIS: Start at this region index
    'regions_end_index': None,             # CHANGE THIS: End at this index (None = all)
    
    # ============ BUFFER PARAMETERS ============
    #'spatial_buffer_m': -10,             # UNCOMMENT & CHANGE: Buffer in meters around regions
    #'temporal_buffer': [[50, 90], [-10, 10], [100, 130]],          # UNCOMMENT & CHANGE: [days_before, days_after]
    #'temporal_buffer': [["2024-04-15", "2024-05-15"], ["2024-08-01", "2024-09-01"]],
    #'num_years': 3,
    
    
    # ============ OUTPUT PARAMETERS ============
    'resolution': 10,                      # Resolution in meters
    'projection': 'EPSG:3979',             # Coordinate projection
    'prod_names': ['LAI'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'out_folder': 'E:/S2_mosaics_runner_2026/S2_tmx_LAI_10m',
    'out_datatype': 'int16'
}

CompParams = {
  "number_workers":32,     
  "debug"       : True,
  "entire_tile" : False, 
  "nodes"       : 1,
  "node_memory" : "16G",
  'chunk_size': {'x': 512, 'y': 512}
}


print("\nconfigured")
# Out:
# configured

# %%
# Run the parameter preparation
result = prepare_production_params(ProdParams, CompParams)
'''
if result:
    print("\n" + "="*80)
    print(" SUCCESS - Parameters validated and ready!")
    print("="*80)
    print(f"\n Summary:")
    print(f"  Regions: {len(result['ProdParams']['regions'])}")
    print(f"  Time windows: {len(result['ProdParams']['start_dates'])}")
    print(f"  Total tasks: {len(result['ProdParams']['regions']) * len(result['ProdParams']['start_dates'])}")
    print(f"  Output folder: {result['ProdParams']['out_folder']}")
    print(f"\n Processing log saved to: {result['ProdParams']['out_folder']}/polygon_processing_log.csv")
    print("\n" + "="*80)
    print("Next step: Call Production.py with the validated parameters")
    print("="*80)
else:
    print("\n" + "="*80)
    print(" FAILED - Parameter validation failed")
    print("="*80)
    print("Check the error messages above for details.") '''
# Out:
# ================================================================================
# PARAMETER PREPARATION
# ================================================================================
#
# Step 1/4: Validating input parameters...
# ✓ All parameters valid
#
# Step 2/4: Loading regions from files...
# <handle_regions_from_file> Detected file-based regions input: Sample Points\AfforestationSItesFixed.kml
# <handle_regions_from_file> Loading regions...
# <handle_regions_from_file> Offset mode: Applying 3 buffer(s) to multiply date windows
# <handle_regions_from_file> Region region3: Expanded from 1 to 3 windows
# <handle_regions_from_file> Region region4: Expanded from 1 to 3 windows
# <handle_regions_from_file> Region region5: Expanded from 1 to 3 windows
# <handle_regions_from_file> Expanding region dates across 3 years...
# <handle_regions_from_file> Region region5: Expanded from 3 to 9 date windows (3 years)
# <handle_regions_from_file> Region region4: Expanded from 3 to 9 date windows (3 years)
# <handle_regions_from_file> Region region3: Expanded from 3 to 9 date windows (3 years)
# <handle_regions_from_file> Loaded 6 regions from file
#
# Step 3/4: Generating temporal windows...
# <form_time_windows> Generating temporal windows...
# <form_time_windows> Mode 4: Multi-year months (3 years)
# <form_time_windows> Warning: Multiple buffers ignored for global time windows (use region dates instead)
# <apply_global_dates_to_regions> Region 'region0': Applied 9 global time windows
# <apply_global_dates_to_regions> Region 'region1': Applied 9 global time windows
# <apply_global_dates_to_regions> Region 'region2': Applied 9 global time windows
# <apply_global_dates_to_regions> Updated 3 region(s) with global time windows
#
# Step 4/4: Validating polygons...
#
# ================================================================================
# POLYGON VALIDATION AND FILTERING
# ================================================================================
#
# Processing log saved to: E:/S2_mosaics_runner_2026/S2_kml_test_2_30m\polygon_processing_log.csv
#
# Summary:
#    Total region-date combinations: 54
#    Valid for processing: 54
#    Skipped (zero area): 0
# {'region0': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}, 'region2': {'type': 'Polygon', 'coordinates': [[[-80.529638877948, 44.5242213601121], [-80.5236686736853, 44.5252976281762], [-80.5234042910143, 44.5252538220711], [-80.5231938083608, 44.5249653160984], [-80.5230220292666, 44.5247919216231], [-80.5294731056627, 44.5235598453566], [-80.529638877948, 44.5242213601121]]]}, 'region3': {'type': 'Polygon', 'coordinates': [[[-80.3772169808165, 44.3239559238229], [-80.3778062318809, 44.3239281559541], [-80.3783858830901, 44.3257096706257], [-80.3764241776696, 44.3259233842728], [-80.376232840644, 44.3258912372486], [-80.3761778827904, 44.3258276760676], [-80.3757712939805, 44.325759362561], [-80.3752059343744, 44.3257911355417], [-80.3747978938721, 44.3239478686715], [-80.3765005174368, 44.3236001331235], [-80.3766048311268, 44.3237444227003], [-80.3766908273936, 44.3238675253118], [-80.3769060715396, 44.323903689341], [-80.3772169808165, 44.3239559238229]]]}, 'region4': {'type': 'Polygon', 'coordinates': [[[-80.4414758461818, 44.4468399119331], [-80.4399721805282, 44.4471867620164], [-80.4395657798354, 44.4447820571645], [-80.44099741403, 44.4444232095963], [-80.4414758461818, 44.4468399119331]]]}, 'region5': {'type': 'Polygon', 'coordinates': [[[-80.4421816733383, 44.4466135137253], [-80.4416845003799, 44.4468203876096], [-80.4411932481774, 44.444365318568], [-80.4415073722911, 44.4442547096037], [-80.4421816733383, 44.4466135137253]]]}}
#
# Proceeding with 6 valid region(s) out of 6 total
# ================================================================================
#
#
# ================================================================================
# PARAMETER PREPARATION COMPLETE
# ================================================================================
# Regions: 6
# Start Time windows: {'region5': ['2009-08-20', '2010-08-20', '2011-08-20', '2009-06-21', '2010-06-21', '2011-06-21', '2009-10-09', '2010-10-09', '2011-10-09'], 'region4': ['2021-08-20', '2022-08-20', '2023-08-20', '2021-06-21', '2022-06-21', '2023-06-21', '2021-10-09', '2022-10-09', '2023-10-09'], 'region3': ['2020-08-20', '2021-08-20', '2022-08-20', '2020-06-21', '2021-06-21', '2022-06-21', '2020-10-09', '2021-10-09', '2022-10-09'], 'region0': ['2023-08-01', '2023-09-01', '2023-10-01', '2024-08-01', '2024-09-01', '2024-10-01', '2025-08-01', '2025-09-01', '2025-10-01'], 'region1': ['2023-08-01', '2023-09-01', '2023-10-01', '2024-08-01', '2024-09-01', '2024-10-01', '2025-08-01', '2025-09-01', '2025-10-01'], 'region2': ['2023-08-01', '2023-09-01', '2023-10-01', '2024-08-01', '2024-09-01', '2024-10-01', '2025-08-01', '2025-09-01', '2025-10-01']}
# End Time windows: {'region5': ['2010-09-29', '2011-09-29', '2012-09-29', '2010-07-11', '2011-07-11', '2012-07-11', '2010-11-08', '2011-11-08', '2012-11-08'], 'region4': ['2021-10-30', '2022-10-30', '2023-10-30', '2021-08-11', '2022-08-11', '2023-08-11', '2021-12-09', '2022-12-09', '2023-12-09'], 'region3': ['2020-10-30', '2021-10-30', '2022-10-30', '2020-08-11', '2021-08-11', '2022-08-11', '2020-12-09', '2021-12-09', '2022-12-09'], 'region0': ['2023-08-31', '2023-09-30', '2023-10-31', '2024-08-31', '2024-09-30', '2024-10-31', '2025-08-31', '2025-09-30', '2025-10-31'], 'region1': ['2023-08-31', '2023-09-30', '2023-10-31', '2024-08-31', '2024-09-30', '2024-10-31', '2025-08-31', '2025-09-30', '2025-10-31'], 'region2': ['2023-08-31', '2023-09-30', '2023-10-31', '2024-08-31', '2024-09-30', '2024-10-31', '2025-08-31', '2025-09-30', '2025-10-31']}
# ================================================================================
# '\nif result:\n    print("\n" + "="*80)\n    print(" SUCCESS - Parameters validated and ready!")\n    print("="*80)\n    print(f"\n Summary:")\n    print(f"  Regions: {len(result[\'ProdParams\'][\'regions\'])}")\n    print(f"  Time windows: {len(result[\'ProdParams\'][\'start_dates\'])}")\n    print(f"  Total tasks: {len(result[\'ProdParams\'][\'regions\']) * len(result[\'ProdParams\'][\'start_dates\'])}")\n    print(f"  Output folder: {result[\'ProdParams\'][\'out_folder\']}")\n    print(f"\n Processing log saved to: {result[\'ProdParams\'][\'out_folder\']}/polygon_processing_log.csv")\n    print("\n" + "="*80)\n    print("Next step: Call Production.py with the validated parameters")\n    print("="*80)\nelse:\n    print("\n" + "="*80)\n    print(" FAILED - Parameter validation failed")\n    print("="*80)\n    print("Check the error messages above for details.") '

# %%
# View processing log (if pandas is available)
try:
    import pandas as pd
    if result and result['processing_log'] is not None:
        print("\n Processing Log Preview:")
        print("=" * 80)
        display(result['processing_log'].head(10))
        print(f"\nTotal entries: {len(result['processing_log'])}")
except ImportError:
    print("pandas not available - install it to view the processing log in this cell")
    print("You can still view the CSV file directly in the output folder")
# Out:
#  Processing Log Preview:
# ================================================================================
#   region_id   area_m2  will_process  status skip_reason  \
# 0   region0  10189.20          True  QUEUED         N/A
# 1   region1   3311.11          True  QUEUED         N/A
# 2   region2  25232.42          True  QUEUED         N/A
# 3   region3  37378.53          True  QUEUED         N/A
# 4   region4  22477.70          True  QUEUED         N/A
# 5   region5   6503.72          True  QUEUED         N/A
# 6   region6  19116.32          True  QUEUED         N/A
# 7   region7  29843.50          True  QUEUED         N/A
# 8   region8  30458.06          True  QUEUED         N/A
# 9   region9  10847.28          True  QUEUED         N/A
#
#                     timestamp
# 0  2026-02-12T13:29:11.601980
# 1  2026-02-12T13:29:11.601980
# 2  2026-02-12T13:29:11.601980
# 3  2026-02-12T13:29:11.603168
# 4  2026-02-12T13:29:11.603168
# 5  2026-02-12T13:29:11.603168
# 6  2026-02-12T13:29:11.603168
# 7  2026-02-12T13:29:11.603168
# 8  2026-02-12T13:29:11.604328
# 9  2026-02-12T13:29:11.604328
# Total entries: 51

# %%
import os
import sys
import geopandas as gpd

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
INVALID_KEYS = {
    "regions_start_index",
    "regions_end_index",
    "spatial_buffer_m",
    "temporal_buffer",
    "num_years",
    "file_variables"
}

for key in list(ProdParams.keys()):
    if key in INVALID_KEYS:
        ProdParams.pop(key)

# %%
print(ProdParams)
# Out:
# {'sensor': 'S2_SR', 'unit': 2, 'nbYears': -1, 'regions': {'region0': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}, 'region2': {'type': 'Polygon', 'coordinates': [[[-80.529638877948, 44.5242213601121], [-80.5236686736853, 44.5252976281762], [-80.5234042910143, 44.5252538220711], [-80.5231938083608, 44.5249653160984], [-80.5230220292666, 44.5247919216231], [-80.5294731056627, 44.5235598453566], [-80.529638877948, 44.5242213601121]]]}, 'region3': {'type': 'Polygon', 'coordinates': [[[-80.3772169808165, 44.3239559238229], [-80.3778062318809, 44.3239281559541], [-80.3783858830901, 44.3257096706257], [-80.3764241776696, 44.3259233842728], [-80.376232840644, 44.3258912372486], [-80.3761778827904, 44.3258276760676], [-80.3757712939805, 44.325759362561], [-80.3752059343744, 44.3257911355417], [-80.3747978938721, 44.3239478686715], [-80.3765005174368, 44.3236001331235], [-80.3766048311268, 44.3237444227003], [-80.3766908273936, 44.3238675253118], [-80.3769060715396, 44.323903689341], [-80.3772169808165, 44.3239559238229]]]}, 'region4': {'type': 'Polygon', 'coordinates': [[[-80.4414758461818, 44.4468399119331], [-80.4399721805282, 44.4471867620164], [-80.4395657798354, 44.4447820571645], [-80.44099741403, 44.4444232095963], [-80.4414758461818, 44.4468399119331]]]}, 'region5': {'type': 'Polygon', 'coordinates': [[[-80.4421816733383, 44.4466135137253], [-80.4416845003799, 44.4468203876096], [-80.4411932481774, 44.444365318568], [-80.4415073722911, 44.4442547096037], [-80.4421816733383, 44.4466135137253]]]}, 'region6': {'type': 'Polygon', 'coordinates': [[[-80.9325933080696, 44.5498352374311], [-80.9298022130011, 44.5501824933335], [-80.9297443710376, 44.5498837167649], [-80.9298093629941, 44.5496770614209], [-80.9298833439626, 44.5492004715374], [-80.9299477575271, 44.5491565535586], [-80.9308393905871, 44.5491371064736], [-80.9310061212362, 44.5489287206699], [-80.9309266115154, 44.5486988301339], [-80.9310866510696, 44.5481094372133], [-80.9311437966441, 44.5478472486186], [-80.9313340317683, 44.5478054707114], [-80.9317085151748, 44.5479018706664], [-80.9320318423446, 44.5480805024271], [-80.9319608781638, 44.5484671148719], [-80.9319091501391, 44.5487120843411], [-80.9318441686648, 44.5489187398937], [-80.9317575276717, 44.5491942798101], [-80.931740711354, 44.5494086808599], [-80.9318178040998, 44.5495658121554], [-80.9319623025166, 44.5495890456082], [-80.932360882683, 44.5496893161368], [-80.9325933080696, 44.5498352374311]]]}, 'region7': {'type': 'Polygon', 'coordinates': [[[-80.7678626419066, 44.5800194690721], [-80.7674320641043, 44.5780302954957], [-80.7697213494948, 44.5778413709173], [-80.7699107066962, 44.5779626891718], [-80.7700256476137, 44.5779994856129], [-80.7703154079468, 44.5790785849546], [-80.7699234222215, 44.579195890536], [-80.769997704847, 44.5796787000452], [-80.7698169991731, 44.5798484687958], [-80.7678626419066, 44.5800194690721]]]}, 'region8': {'type': 'Polygon', 'coordinates': [ ...

# %%
main(ProdParams, CompParams)
# Out:
# <get_time_window> one of required keys is not exist!!
# <MosaicProduction> User defined input parameters:
# sensor: S2_SR
# unit: 2
# nbYears: -1
# regions: {'region0': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'region1': {'type': 'Polygon', 'coordinates': [[[-80.2866384110016, 44.3533435417762], [-80.2864858239462, 44.353000698271], [-80.2868313289172, 44.3529866183925], [-80.2871254773415, 44.3529366809224], [-80.2874977225433, 44.3529180592246], [-80.2876405698119, 44.3529059627622], [-80.2879206306362, 44.3528989373857], [-80.2880395541161, 44.3528827993289], [-80.2880782566738, 44.352880279965], [-80.2882027280036, 44.353154957613], [-80.288085927134, 44.3531261618167], [-80.287951530048, 44.3531125098555], [-80.2878832692439, 44.3531281508011], [-80.287738989293, 44.3532215337679], [-80.2877249039523, 44.3532644472593], [-80.287558824637, 44.3533088522111], [-80.2874518606506, 44.3533270111586], [-80.2871598357525, 44.3533320137857], [-80.2866384110016, 44.3533435417762]]]}, 'region2': {'type': 'Polygon', 'coordinates': [[[-80.529638877948, 44.5242213601121], [-80.5236686736853, 44.5252976281762], [-80.5234042910143, 44.5252538220711], [-80.5231938083608, 44.5249653160984], [-80.5230220292666, 44.5247919216231], [-80.5294731056627, 44.5235598453566], [-80.529638877948, 44.5242213601121]]]}, 'region3': {'type': 'Polygon', 'coordinates': [[[-80.3772169808165, 44.3239559238229], [-80.3778062318809, 44.3239281559541], [-80.3783858830901, 44.3257096706257], [-80.3764241776696, 44.3259233842728], [-80.376232840644, 44.3258912372486], [-80.3761778827904, 44.3258276760676], [-80.3757712939805, 44.325759362561], [-80.3752059343744, 44.3257911355417], [-80.3747978938721, 44.3239478686715], [-80.3765005174368, 44.3236001331235], [-80.3766048311268, 44.3237444227003], [-80.3766908273936, 44.3238675253118], [-80.3769060715396, 44.323903689341], [-80.3772169808165, 44.3239559238229]]]}, 'region4': {'type': 'Polygon', 'coordinates': [[[-80.4414758461818, 44.4468399119331], [-80.4399721805282, 44.4471867620164], [-80.4395657798354, 44.4447820571645], [-80.44099741403, 44.4444232095963], [-80.4414758461818, 44.4468399119331]]]}, 'region5': {'type': 'Polygon', 'coordinates': [[[-80.4421816733383, 44.4466135137253], [-80.4416845003799, 44.4468203876096], [-80.4411932481774, 44.444365318568], [-80.4415073722911, 44.4442547096037], [-80.4421816733383, 44.4466135137253]]]}, 'region6': {'type': 'Polygon', 'coordinates': [[[-80.9325933080696, 44.5498352374311], [-80.9298022130011, 44.5501824933335], [-80.9297443710376, 44.5498837167649], [-80.9298093629941, 44.5496770614209], [-80.9298833439626, 44.5492004715374], [-80.9299477575271, 44.5491565535586], [-80.9308393905871, 44.5491371064736], [-80.9310061212362, 44.5489287206699], [-80.9309266115154, 44.5486988301339], [-80.9310866510696, 44.5481094372133], [-80.9311437966441, 44.5478472486186], [-80.9313340317683, 44.5478054707114], [-80.9317085151748, 44.5479018706664], [-80.9320318423446, 44.5480805024271], [-80.9319608781638, 44.5484671148719], [-80.9319091501391, 44.5487120843411], [-80.9318441686648, 44.5489187398937], [-80.9317575276717, 44.5491942798101], [-80.931740711354, 44.5494086808599], [-80.9318178040998, 44.5495658121554], [-80.9319623025166, 44.5495890456082], [-80.932360882683, 44.5496893161368], [-80.9325933080696, 44.5498352374311]]]}, 'region7': {'type': 'Polygon', 'coordinates': [[[-80.7678626419066, 44.5800194690721], [-80.7674320641043, 44.5780302954957], [-80.7697213494948, 44.5778413709173], [-80.7699107066962, 44.5779626891718], [-80.7700256476137, 44.5779994856129], [-80.7703154079468, 44.5790785849546], [-80.7699234222215, 44.579195890536], [-80.769997704847, 44.5796787000452], [-80.7698169991731, 44.5798484687958], [-80.7678626419066, 44.5800194690721]]]}, 'region8': {'type': 'Polygon', 'coordinates': [[[-80.7184487795423, 44.5695391742947], [-80.718 ...
# resolution: 30
# projection: EPSG:3979
# prod_names: ['mosaic']
# out_folder: E:/S2_mosaics_runner_2026/S2_kml_test_2_30m
# out_datatype: int16
# region_start_dates: {'region0': ['2020-08-20', '2020-06-21', '2020-10-09'], 'region2': ['2020-08-20', '2020-06-21', '2020-10-09'], 'region3': ['2020-08-20', '2020-06-21', '2020-10-09'], 'region4': ['2021-08-20', '2021-06-21', '2021-10-09'], 'region5': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region6': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region7': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region8': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region9': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region10': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region11': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region12': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region13': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region14': ['2010-08-20', '2010-06-21', '2010-10-09'], 'region15': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region16': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region17': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region18': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region22': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region23': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region24': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region25': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region26': ['2010-08-20', '2010-06-21', '2010-10-09'], 'region27': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region28': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region30': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region31': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region32': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region33': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region34': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region35': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region36': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region37': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region38': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region39': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region40': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region42': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region44': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region46': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region47': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region48': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region49': ['2009-08-20', '2009-06-21', '2009-10-09'], 'region50': ['2009-08-20', '2009-06-21', '2009-10-09']}
# region_end_dates: {'region0': ['2020-10-30', '2020-08-11', '2020-12-09'], 'region2': ['2020-10-30', '2020-08-11', '2020-12-09'], 'region3': ['2020-10-30', '2020-08-11', '2020-12-09'], 'region4': ['2021-10-30', '2021-08-11', '2021-12-09'], 'region5': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region6': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region7': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region8': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region9': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region10': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region11': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region12': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region13': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region14': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region15': ['2009-09-29', '2009-07-11', '2009-11-08'], 'region16': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region17': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region18': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region22': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region23': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region24': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region25': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region26': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region27': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region28': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region30': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region31': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region32': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region33': ['2009-09-29', '2009-07-11', '2009-11-08'], 'region34': ['2009-09-29', '2009-07-11', '2009-11-08'], 'region35': ['2009-09-29', '2009-07-11', '2009-11-08'], 'region36': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region37': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region38': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region39': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region40': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region42': ['2009-09-29', '2009-07-11', '2009-11-08'], 'region44': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region46': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region47': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region48': ['2010-09-29', '2010-07-11', '2010-11-08'], 'region49': ['2009-09-29', '2009-07-11', '2009-11-08'], 'region50': ['2009-09-29', '2009-07-11', '2009-11-08']}
# SsrData: {'NAME': 'S2_SR', 'SSR_CODE': 21, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], '10M_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'SIX_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'NoA_BANDS': ['red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'LEAF_BANDS': ['green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'GEE_NAME': 'COPERNICUS/S2_SR_HARMONIZED', 'CLOUD': 'CLOUDY_PIXEL_PERCENTAGE', 'SZA': 'view:sun_elevation', 'SAA': 'view:sun_azimuth', 'VZA': 'view:sun_elevation', 'VAA': 'view:sun_azimuth', 'BLU': 'blue', 'GRN': 'green', 'RED': 'red', 'NIR': 'nir08', 'SW1': 'swir16', 'SW2': 'swir22'}
# year: 2026
# out_location: drive
# months: []
# tile_names: []
# cloud_cover: 80
# export_style: separate
# IncludeAngles: False
# monthly: True
# current_time: 0
# scene_ID:
# current_region: region0
# Criteria: {'timeframe': 'None/None', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}, 'catalog': 'https://earth-search.aws.element84.com/v1', 'collection': ['sentinel-2-l2a'], 'bands': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl']}
# standardized: True
# number_workers: 23
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 8G
# chunk_size: {'x': 512, 'y': 512}
#
# <MosaicProduction> Using region-specific dates for region0
#   Start dates: ['2020-08-20', '2020-06-21', '2020-10-09']
#   End dates: ['2020-10-30', '2020-08-11', '2020-12-09']
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.03 minutes
#
# <one_mosaic> A total of 29 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/9/18/1/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/9/18/1/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/9/18/1/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/9/18/1/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/9/18/1/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/9/18/1/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/9/18/1/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/9/18/1/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/9/18/1/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/9/18/1/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/9/18/1/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/9/18/1/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/9/18/1/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/9/18/1/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/9/18/1/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/9/18/1/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TMK_20200918_1_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-80.94550334131806, 45.15381524720899], [-81.2781166186895, 44.16503697254722], [-80.87793799810343, 44.16531029102769], [-80.87584634429486, 45.15376076769412], [-80.94550334131806, 45.15381524720899]]]}
# Bounding Box: [-81.2781166186895, 44.16503697254722, -80.87584634429486, 45.15381524720899]
# Datetime: 2020-09-18 16:21:07.181000+00:00
# cloud cover: 40.21917
# Properties:
#   <created>: 2023-10-04T07:03:40.683Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 40.21917
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: MK
#   <grid:code>: MGRS-17TMK
#   <view:sun_azimuth>: 158.910330842204
#   <view:sun_elevation>: 44.9132907902579
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 82.824886
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0
#   <s2:cloud_shadow_percentage>: 14.120612
#   <s2:vegetation_percentage>: 26.842889
#   <s2:not_vegetated_percentage>: 3.046346
#   <s2:water_percentage>: 15.720214
#   <s2:unclassified_percentage>: 0.050767
#   <s2:medium_proba_clouds_percentage>: 11.319233
#   <s2:high_proba_clouds_percentage>: 22.010313
#   <s2:thin_cirrus_percentage>: 6.889624
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.00
#   <s2:product_uri>: S2B_MSIL2A_20200918T160839_N0500_R140_T17TMK_20230417T044949.SAFE
#   <s2:generation_time>: 2023-04-17T04:49:49.000000Z
#   <s2:datatake_id>: GS2B_20200918T160839_018470_N05.00
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_S2RP_20230417T044949_S20200918T161640_N05.00
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_S2RP_20230417T044949_A018470_T17TMK_N05.00
#   <s2:reflectance_conversion_factor>: 0.989394990122509
#   <datetime>: 2020-09-18T16:21:07.181000Z
#   <s2:sequence>: 1
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/MK/2020/9/S2B_17TMK_20200918_1_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/56a41ea249e7fa5ae56c6d340f9c96c3
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.1'}
#   <updated>: 2023-10-04T07:03:40.683Z
#   <proj:code>: EPSG:32617
#   <sza>: 45.0867092097421
#   <saa>: 158.910330842204
#   <vza>: 10.9861187930409
#   <vaa>: 110.738989934011
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 2kB
# Dimensions:      (y: 8, x: 5)
# Coordinates:
#   * y            (y) float64 64B -3.484e+05 -3.484e+05 ... -3.486e+05 -3.486e+05
#   * x            (x) float64 40B 1.118e+06 1.118e+06 ... 1.118e+06 1.118e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2020-09-18T16:21:07.181000
# Data variables:
#     blue         (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     green        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     red          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge1     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge2     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge3     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     nir08        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir16       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir22       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     scl          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     date         (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     score        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TMK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.87 minutes >>>>>>
# File 'E:\S2_mosaics_runner_2026\S2_kml_test_2_30m\log_726a5aed-20a3-4d2d-a3ad-d04df5d506c4.out' does not exist.
# Directory 'E:\S2_mosaics_runner_2026\S2_kml_test_2_30m\dask_spill_726a5aed-20a3-4d2d-a3ad-d04df5d506c4' and its contents have been deleted.
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.06 minutes
#
# <one_mosaic> A total of 25 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/10/1/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/10/1/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/10/1/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/10/1/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/10/1/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/10/1/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/10/1/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/10/1/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/10/1/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/10/1/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/10/1/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/10/1/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/10/1/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/10/1/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/10/1/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/7/10/1/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TMK_20200710_1_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-80.94092343193901, 45.153812970029406], [-81.27361394294262, 44.16504784524923], [-80.87793799810343, 44.16531029102769], [-80.87584634429486, 45.15376076769412], [-80.94092343193901, 45.153812970029406]]]}
# Bounding Box: [-81.27361394294262, 44.16504784524923, -80.87584634429486, 45.153812970029406]
# Datetime: 2020-07-10 16:21:07.220000+00:00
# cloud cover: 18.805654
# Properties:
#   <created>: 2023-09-12T07:53:18.757Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 18.805654
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: MK
#   <grid:code>: MGRS-17TMK
#   <view:sun_azimuth>: 141.448146913135
#   <view:sun_elevation>: 63.185005990219196
#   <s2:degraded_msi_data_percentage>: 0.0852
#   <s2:nodata_pixel_percentage>: 83.164138
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.019963
#   <s2:cloud_shadow_percentage>: 6.012676
#   <s2:vegetation_percentage>: 51.642478
#   <s2:not_vegetated_percentage>: 6.345291
#   <s2:water_percentage>: 15.489464
#   <s2:unclassified_percentage>: 1.684473
#   <s2:medium_proba_clouds_percentage>: 7.964633
#   <s2:high_proba_clouds_percentage>: 10.805707
#   <s2:thin_cirrus_percentage>: 0.035315
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.00
#   <s2:product_uri>: S2B_MSIL2A_20200710T160829_N0500_R140_T17TMK_20230603T070409.SAFE
#   <s2:generation_time>: 2023-06-03T07:04:09.000000Z
#   <s2:datatake_id>: GS2B_20200710T160829_017469_N05.00
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_S2RP_20230603T070409_S20200710T161117_N05.00
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_S2RP_20230603T070409_A017469_T17TMK_N05.00
#   <s2:reflectance_conversion_factor>: 0.967388880412871
#   <datetime>: 2020-07-10T16:21:07.220000Z
#   <s2:sequence>: 1
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/MK/2020/7/S2B_17TMK_20200710_1_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/61a741d643ca2335722fe8f43cab19c2
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.1'}
#   <updated>: 2023-09-12T07:53:18.757Z
#   <proj:code>: EPSG:32617
#   <sza>: 26.814994009780804
#   <saa>: 141.448146913135
#   <vza>: 11.0006293063011
#   <vaa>: 110.731195630233
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 2kB
# Dimensions:      (y: 8, x: 5)
# Coordinates:
#   * y            (y) float64 64B -3.484e+05 -3.484e+05 ... -3.486e+05 -3.486e+05
#   * x            (x) float64 40B 1.118e+06 1.118e+06 ... 1.118e+06 1.118e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2020-07-10T16:21:07.220000
# Data variables:
#     blue         (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     green        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     red          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge1     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge2     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge3     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     nir08        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir16       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir22       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     scl          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     date         (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     score        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TMK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.76 minutes >>>>>>
# File 'E:\S2_mosaics_runner_2026\S2_kml_test_2_30m\log_8e1b798a-31b2-4f26-9129-c3cb6b067a0f.out' does not exist.
# Directory 'E:\S2_mosaics_runner_2026\S2_kml_test_2_30m\dask_spill_8e1b798a-31b2-4f26-9129-c3cb6b067a0f' and its contents have been deleted.
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-81.0143277776703, 44.792849553362], [-81.013046437586, 44.7928810241213], [-81.0130828894072, 44.7920357810087], [-81.0134196694422, 44.7918539873173], [-81.013283176937, 44.7913976888643], [-81.0142442205963, 44.7913333551658], [-81.0143277776703, 44.792849553362]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.02 minutes
#
# <one_mosaic> A total of 20 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/11/17/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/11/17/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/11/17/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/11/17/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/11/17/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/11/17/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/11/17/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/11/17/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/11/17/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/11/17/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/11/17/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/11/17/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/11/17/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/11/17/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/11/17/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/MK/2020/11/17/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TMK_20201117_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-80.95771709564097, 45.15382042205261], [-80.87584634429486, 45.15376076769412], [-80.87793799810343, 44.16531029102769], [-81.28937274413298, 44.16500901580191], [-80.95771709564097, 45.15382042205261]]]}
# Bounding Box: [-81.28937274413298, 44.16500901580191, -80.87584634429486, 45.15382042205261]
# Datetime: 2020-11-17 16:21:06.142000+00:00
# cloud cover: 53.724204
# Properties:
#   <created>: 2022-11-06T12:08:41.103Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 53.724204
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: MK
#   <grid:code>: MGRS-17TMK
#   <view:sun_azimuth>: 166.880680837538
#   <view:sun_elevation>: 25.114306815728995
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 82.048088
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.908196
#   <s2:cloud_shadow_percentage>: 0.250798
#   <s2:vegetation_percentage>: 0.820241
#   <s2:not_vegetated_percentage>: 0.01449
#   <s2:water_percentage>: 12.346146
#   <s2:unclassified_percentage>: 4.425525
#   <s2:medium_proba_clouds_percentage>: 7.89275
#   <s2:high_proba_clouds_percentage>: 41.632682
#   <s2:thin_cirrus_percentage>: 4.198772
#   <s2:snow_ice_percentage>: 27.510399
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 02.14
#   <s2:product_uri>: S2B_MSIL2A_20201117T161549_N0214_R140_T17TMK_20201117T185622.SAFE
#   <s2:generation_time>: 2020-11-17T18:56:22.000000Z
#   <s2:datatake_id>: GS2B_20201117T161549_019328_N02.14
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_VGS1_20201117T185622_S20201117T161544_N02.14
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_VGS1_20201117T185622_A019328_T17TMK_N02.14
#   <s2:reflectance_conversion_factor>: 1.02209086156937
#   <datetime>: 2020-11-17T16:21:06.142000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/MK/2020/11/S2B_17TMK_20201117_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/14b6f65991057183b707bdd0a5f1f434
#   <earthsearch:boa_offset_applied>: False
#   <processing:software>: {'sentinel2-to-stac': '0.1.0'}
#   <updated>: 2022-11-06T12:08:41.103Z
#   <proj:code>: EPSG:32617
#   <sza>: 64.885693184271
#   <saa>: 166.880680837538
#   <vza>: 10.9561240670533
#   <vaa>: 110.462189949873
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 2kB
# Dimensions:      (y: 8, x: 5)
# Coordinates:
#   * y            (y) float64 64B -3.484e+05 -3.484e+05 ... -3.486e+05 -3.486e+05
#   * x            (x) float64 40B 1.118e+06 1.118e+06 ... 1.118e+06 1.118e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2020-11-17T16:21:06.142000
# Data variables:
#     blue         (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     green        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     red          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge1     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge2     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     rededge3     (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     nir08        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir16       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     swir22       (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     scl          (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     date         (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#     score        (y, x) float32 160B dask.array<chunksize=(8, 5), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TMK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.74 minutes >>>>>>
# File 'E:\S2_mosaics_runner_2026\S2_kml_test_2_30m\log_d6bbc2d1-bf12-41a9-8a6e-cf1a4ffb7a15.out' does not exist.
# Directory 'E:\S2_mosaics_runner_2026\S2_kml_test_2_30m\dask_spill_d6bbc2d1-bf12-41a9-8a6e-cf1a4ffb7a15' and its contents have been deleted.
#
# <MosaicProduction> WARNING: Region region1 has no region-specific dates
#   SKIPPING this region
#
# <MosaicProduction> Using region-specific dates for region2
#   Start dates: ['2020-08-20', '2020-06-21', '2020-10-09']
#   End dates: ['2020-10-30', '2020-08-11', '2020-12-09']
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-80.529638877948, 44.5242213601121], [-80.5236686736853, 44.5252976281762], [-80.5234042910143, 44.5252538220711], [-80.5231938083608, 44.5249653160984], [-80.5230220292666, 44.5247919216231], [-80.5294731056627, 44.5235598453566], [-80.529638877948, 44.5242213601121]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.04 minutes
#
# <one_mosaic> A total of 35 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2020/10/S2A_17TNK_20201006_1_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2020/10/6/1/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2020/10/6/1/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2020/10/6/1/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2020/10/6/1/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2020/10/6/1/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2020/10/6/1/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2020/10/6/1/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2020/10/6/1/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2020/10/6/1/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2020/10/6/1/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2020/10/6/1/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2020/10/6/1/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2020/10/6/1/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2020/10/6/1/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2020/10/6/1/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2020/10/6/1/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2A_17TNK_20201006_1_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-81.00024171761814, 45.153828248771845], [-81.00023764893123, 44.16627583011202], [-80.00669981442483, 44.162496836511416], [-79.60721326549243, 45.1453349370662], [-81.00024171761814, 45.153828248771845]]]}
# Bounding Box: [-81.00024171761814, 44.162496836511416, -79.60721326549243, 45.153828248771845]
# Datetime: 2020-10-06 16:31:02.954000+00:00
# cloud cover: 58.471382
# Properties:
#   <created>: 2023-10-13T13:05:14.571Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 58.471382
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:sun_azimuth>: 167.752801371293
# ...
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2021/11/S2B_17TNK_20211122_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2021/11/S2B_17TNK_20211122_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/17/T/NK/2021/11/S2B_17TNK_20211122_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2021/11/22/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2021/11/22/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2021/11/22/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2021/11/22/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2021/11/22/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2021/11/22/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2021/11/22/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2021/11/22/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2021/11/22/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2021/11/22/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2021/11/22/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2021/11/22/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2021/11/22/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2021/11/22/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/17/T/NK/2021/11/22/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/17/T/NK/2021/11/22/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2B_17TNK_20211122_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-80.96000666893529, 45.15382124674754], [-79.60360176290054, 45.14529082911873], [-79.62711829312833, 44.15712570786563], [-81.00023764531663, 44.16537549832127], [-81.00024121889423, 45.03548490751938], [-80.96000666893529, 45.15382124674754]]]}
# Bounding Box: [-81.00024121889423, 44.15712570786563, -79.60360176290054, 45.15382124674754]
# Datetime: 2021-11-22 16:20:57.600000+00:00
# cloud cover: 61.381081
# Properties:
#   <created>: 2022-11-06T08:36:01.335Z
#   <platform>: sentinel-2b
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 61.381081
#   <mgrs:utm_zone>: 17
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: NK
#   <grid:code>: MGRS-17TNK
#   <view:sun_azimuth>: 168.045232877339
#   <view:sun_elevation>: 24.206918263595895
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 0.162584
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 1.784505
#   <s2:cloud_shadow_percentage>: 1.491514
#   <s2:vegetation_percentage>: 0.978359
#   <s2:not_vegetated_percentage>: 0.368877
#   <s2:water_percentage>: 9.29229
#   <s2:unclassified_percentage>: 3.546458
#   <s2:medium_proba_clouds_percentage>: 31.743231
#   <s2:high_proba_clouds_percentage>: 23.778901
#   <s2:thin_cirrus_percentage>: 5.858949
#   <s2:snow_ice_percentage>: 21.156919
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 03.01
#   <s2:product_uri>: S2B_MSIL2A_20211122T161559_N0301_R140_T17TNK_20211122T184634.SAFE
#   <s2:generation_time>: 2021-11-22T18:46:34.000000Z
#   <s2:datatake_id>: GS2B_20211122T161559_024619_N03.01
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2B_OPER_MSI_L2A_DS_VGS1_20211122T184634_S20211122T161558_N03.01
#   <s2:granule_id>: S2B_OPER_MSI_L2A_TL_VGS1_20211122T184634_A024619_T17TNK_N03.01
#   <s2:reflectance_conversion_factor>: 1.0241430200643
#   <datetime>: 2021-11-22T16:20:57.600000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/17/T/NK/2021/11/S2B_17TNK_20211122_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/7a11f6a00040ec8ac5fbb55afb8fcc42
#   <earthsearch:boa_offset_applied>: False
#   <processing:software>: {'sentinel2-to-stac': '0.1.0'}
#   <updated>: 2022-11-06T08:36:01.335Z
#   <proj:code>: EPSG:32617
#   <sza>: 65.7930817364041
#   <saa>: 168.045232877339
#   <vza>: 6.9941496337314
#   <vaa>: 107.24065898332
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 5kB
# Dimensions:      (y: 12, x: 8)
# Coordinates:
#   * y            (y) float64 96B -3.763e+05 -3.763e+05 ... -3.766e+05 -3.766e+05
#   * x            (x) float64 64B 1.172e+06 1.172e+06 ... 1.172e+06 1.172e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2021-11-22T16:20:57.600000
# Data variables:
#     blue         (y, x) float32 384B dask.array<chunksize=(12, 8), meta=np.ndarray>
#     green        (y, x) float32 384B dask.array<chunksize=(12, 8), meta=np.ndarray>
#     red          (y, x) float32 384B dask.array<chunksize=(12, 8), meta=np.ndarray>
#     rededge1     (y, x) float32 384B dask.array<chunksize=(12, 8), meta=np.ndarray>
#     rededge2     (y, x) float32 384B dask.array<chunksize=(12, 8), meta=np.ndarray>
#     rededge3     (y, x) float32 384B dask.array<chunksize=(12, 8), meta=np.ndarray>
#     nir08        (y, x) float32 384B dask.array<chunksize=(12, 8), meta=np.ndarray>
#     swir16       (y, x) float32 384B dask.array<chunksize=(12, 8), meta=np.ndarray>
#     swir22       (y, x) float32 384B dask.array<chunksize=(12, 8), meta=np.ndarray>
#     scl          (y, x) float32 384B dask.array<chunksize=(12, 8), meta=np.ndarray>
#     date         (y, x) float32 384B dask.array<chunksize=(12, 8), meta=np.ndarray>
#     score        (y, x) float32 384B dask.array<chunksize=(12, 8), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['17TNK']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
#
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =   0.73 minutes >>>>>>
# File 'E:\S2_mosaics_runner_2026\S2_kml_test_2_30m\log_d8aaa82f-84c0-4077-8ece-80f317bb5f5a.out' does not exist.
# Directory 'E:\S2_mosaics_runner_2026\S2_kml_test_2_30m\dask_spill_d8aaa82f-84c0-4077-8ece-80f317bb5f5a' and its contents have been deleted.
#
# <MosaicProduction> WARNING: Region region5 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region6 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region7 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region8 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region9 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region10 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region11 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region12 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region13 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region14 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2010-08-20', '2010-06-21', '2010-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region15 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2009-09-29', '2009-07-11', '2009-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region16 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region17 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region18 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region19 has no region-specific dates
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region20 has no region-specific dates
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region21 has no region-specific dates
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region22 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region23 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region24 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region25 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region26 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2010-08-20', '2010-06-21', '2010-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region27 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region28 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region29 has no region-specific dates
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region30 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region31 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region32 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region33 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2009-09-29', '2009-07-11', '2009-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region34 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2009-09-29', '2009-07-11', '2009-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region35 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2009-09-29', '2009-07-11', '2009-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region36 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region37 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region38 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region39 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region40 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region41 has no region-specific dates
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region42 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2009-09-29', '2009-07-11', '2009-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region43 has no region-specific dates
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region44 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region45 has no region-specific dates
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region46 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region47 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region48 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2010-09-29', '2010-07-11', '2010-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region49 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2009-09-29', '2009-07-11', '2009-11-08']
#   SKIPPING this region
#
# <MosaicProduction> WARNING: Region region50 has dates before 2016 (Sentinel-2 launch)
#   Region dates: ['2009-08-20', '2009-06-21', '2009-10-09'] to ['2009-09-29', '2009-07-11', '2009-11-08']
#   SKIPPING this region
