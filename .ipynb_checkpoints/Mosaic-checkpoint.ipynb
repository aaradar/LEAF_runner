# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

import eoMosaic as eoMz
import eoImage as eoIM
import eoParams as eoPM
import LEAFProduction as LP

# %%
from dask.distributed import LocalCluster
 
cluster = LocalCluster(n_workers = 2, threads_per_worker = 10) # Refined through testing
client = cluster.get_client()
client # Can open in other window by clicking 'Dashboard' link below
# Out:
# <Client: 'tcp://127.0.0.1:52789' processes=2 threads=20, memory=15.72 GiB>

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}


sub_region = {
    'type': 'Polygon',
    'coordinates': [
       [[-78.6303, 44.2113], [-77.04546666666667, 44.2113], [-77.04546666666667, 45.318], [-78.6303, 45.318], [-78.6303, 44.2113]]
    ]
}

params = {
    'sensor': 'S2_SR',           # A sensor type string (e.g., 'S2_SR' or 'L8_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2023,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [8],               # A list of integers represening one or multiple monthes     
    'tile_names': ['tile55_922'], # A list of (sub-)tile names (defined using CCRS' tile griding system) 
    'prod_names': ['LAI', 'fCOVER', 'fAPAR', 'Albedo'],    #['mosaic', 'LAI', 'fCOVER', ]    
    'resolution': 100,            # Exporting spatial resolution    
    'out_folder': 'C:/Work_documents/LEAF_tile55_922_2023_Aug_100m',  # the folder name for exporting
    'projection': 'EPSG:3979',    
    #'start_date': '2022-06-15',
    #'end_date': '2022-09-15'
}

# %%
LP.LEAF_production(params)
# Out:
# <LEAF_production> All input parameters =  {'sensor': 'S2_SR', 'unit': 2, 'year': 2023, 'nbYears': -1, 'months': [8], 'tile_names': ['tile55_922'], 'prod_names': ['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 'resolution': 60, 'out_folder': 'C:/Work_documents/LEAF_tile55_922_2023_Aug_60m', 'projection': 'EPSG:3979', 'out_location': 'drive', 'export_style': 'separate', 'monthly': True, 'start_dates': ['2023-08-01'], 'end_dates': ['2023-08-31'], 'current_time': 0, 'time_str': 'Aug', 'scene_ID': '', 'regions': {'tile55_922': {'type': 'Polygon', 'coordinates': [[[-77.6221, 47.5314], [-78.6303, 44.9569], [-75.0742, 44.2113], [-73.8758, 46.7329], [-77.6221, 47.5314]]]}}, 'current_region': 'tile55_922'}
#
# <tile_LEAF_production> Generate and export separate vegetation biophysical maps......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-77.6221, 47.5314], [-78.6303, 44.9569], [-75.0742, 44.2113], [-73.8758, 46.7329], [-77.6221, 47.5314]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.00 minutes
#
# <period_mosaic> A total of 147 items were found.
#
# <<<<<<< The assets associated with an item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/29/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/29/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/29/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/29/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/29/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/29/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/29/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/29/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/29/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/29/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/29/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/29/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/29/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/29/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/29/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/18/T/UQ/2023/8/29/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: S2A_18TUQ_20230829_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-77.54312638001969, 45.12550485176269], [-77.50073646246912, 44.14748094733423], [-77.10078929882897, 45.134502855511855], [-77.54312638001969, 45.12550485176269]]]}
# Bounding Box: [-77.54312638001969, 44.14748094733423, -77.10078929882897, 45.134502855511855]
# Datetime: 2023-08-29 16:20:53.910000+00:00
# Properties:
#   <created>: 2023-08-30T04:54:55.472Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 1.135092
#   <proj:epsg>: 32618
#   <mgrs:utm_zone>: 18
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: UQ
#   <grid:code>: MGRS-18TUQ
#   <view:sun_azimuth>: 160.269417182797
#   <view:sun_elevation>: 53.1812163555001
#   <s2:degraded_msi_data_percentage>: 0
#   <s2:nodata_pixel_percentage>: 84.158963
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.106985
#   <s2:cloud_shadow_percentage>: 2.210533
#   <s2:vegetation_percentage>: 91.043323
#   <s2:not_vegetated_percentage>: 0.721227
#   <s2:water_percentage>: 4.186068
#   <s2:unclassified_percentage>: 0.596774
#   <s2:medium_proba_clouds_percentage>: 0.831709
#   <s2:high_proba_clouds_percentage>: 0.295926
#   <s2:thin_cirrus_percentage>: 0.007456
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.09
#   <s2:product_uri>: S2A_MSIL2A_20230829T160831_N0509_R140_T18TUQ_20230829T234253.SAFE
#   <s2:generation_time>: 2023-08-29T23:42:53.000000Z
#   <s2:datatake_id>: GS2A_20230829T160831_042751_N05.09
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_2APS_20230829T234253_S20230829T161818_N05.09
#   <s2:granule_id>: S2A_OPER_MSI_L2A_TL_2APS_20230829T234253_A042751_T18TUQ_N05.09
#   <s2:reflectance_conversion_factor>: 0.97916850948939
#   <datetime>: 2023-08-29T16:20:53.910000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/18/T/UQ/2023/8/S2A_18TUQ_20230829_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/7f2a29dc7d7e1778ce9a43d072367166
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.1'}
#   <updated>: 2023-08-30T04:54:55.472Z
#   <sza>: 36.8187836444999
#   <saa>: 160.269417182797
#   <vza>: 0.0
#   <vaa>: 0.0
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 1GB
# Dimensions:      (y: 5001, x: 5001)
# Coordinates:
#   * y            (y) float64 40kB 1.491e+04 1.485e+04 ... -2.85e+05 -2.851e+05
#   * x            (x) float64 40kB 1.3e+06 1.3e+06 1.3e+06 ... 1.6e+06 1.6e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2023-08-29T16:20:53.910000
# Data variables:
#     blue         (y, x) float32 100MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     green        (y, x) float32 100MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     red          (y, x) float32 100MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     rededge1     (y, x) float32 100MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     rededge2     (y, x) float32 100MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     rededge3     (y, x) float32 100MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     nir08        (y, x) float32 100MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     swir16       (y, x) float32 100MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     swir22       (y, x) float32 100MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     scl          (y, x) float32 100MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     date         (y, x) float32 100MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     score        (y, x) float32 100MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#
# <<<<<<<<<< Complete generating base image, elapsed time =   0.20 minutes>>>>>>>>>
#
# <<<<<< The number of unique granule tiles = 19
#
# <<<<<< The unique granule tiles =  ['MGRS-18TUQ', 'MGRS-18TWQ', 'MGRS-18TVS', 'MGRS-17TPK', 'MGRS-18TUR', 'MGRS-17TQM', 'MGRS-17TQK', 'MGRS-18TUS', 'MGRS-17TPL', 'MGRS-18TVQ', 'MGRS-18TWT', 'MGRS-17TQL', 'MGRS-18TWR', 'MGRS-18TVR', 'MGRS-18TVP', 'MGRS-18TVT', 'MGRS-18TUT', 'MGRS-18TWS', 'MGRS-17TQN']
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\client.py:3361: UserWarning: Sending large graph of size 1.12 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(

# %%
#base_img = stacMoz.get_base_Image(ssr_data, sub_region, 'EPSG:3979', 100, start_str, end_str)
#base_img = eoIM.attach_AngleBands(base_img, ssr_data)

params = eoPM.get_mosaic_params(params)
mosaic = eoMz.period_mosaic(params, eoIM.EXTRA_ANGLE)
#sub_mosaic = stacMoz.get_sub_mosaic(ssr_data, sub_region, 'EPSG:3979', 200, start_str, end_str)

#base_img = eoIM.apply_gain_offset(base_img, ssr_data, 100, False)
#base_img.odc.geobox
#display(mosaic)

eoMz.export_mosaic(params, mosaic)
# Out:
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-77.6221, 47.5314], [-78.6303, 44.9569], [-75.0742, 44.2113], [-73.8758, 46.7329], [-77.6221, 47.5314]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.20 minutes
#
# <period_mosaic> A total of 160 items were found.
#
# <<<<<<< The assets associated with an item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/AOT.tif
# Asset key: blue, title: Blue (band 2) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/B02.tif
# Asset key: coastal, title: Coastal aerosol (band 1) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/granule_metadata.xml
# Asset key: green, title: Green (band 3) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 (band 8) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 (band 8A) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 (band 9) - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/B09.tif
# Asset key: red, title: Red (band 4) - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/B04.tif
# Asset key: rededge1, title: Red edge 1 (band 5) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/B05.tif
# Asset key: rededge2, title: Red edge 2 (band 6) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/B06.tif
# Asset key: rededge3, title: Red edge 3 (band 7) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/SCL.tif
# Asset key: swir16, title: SWIR 1 (band 11) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2 (band 12) - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/B12.tif
# Asset key: thumbnail, title: Thumbnail image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/thumbnail.jpg
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/TCI.tif
# Asset key: wvp, title: Water vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A/WVP.tif
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/18/T/VT/2023/7/30/0/AOT.jp2
# Asset key: blue-jp2, title: Blue (band 2) - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/VT/2023/7/30/0/B02.jp2
# Asset key: coastal-jp2, title: Coastal aerosol (band 1) - 60m, href: s3://sentinel-s2-l2a/tiles/18/T/VT/2023/7/30/0/B01.jp2
# Asset key: green-jp2, title: Green (band 3) - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/VT/2023/7/30/0/B03.jp2
# Asset key: nir-jp2, title: NIR 1 (band 8) - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/VT/2023/7/30/0/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 (band 8A) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VT/2023/7/30/0/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 (band 9) - 60m, href: s3://sentinel-s2-l2a/tiles/18/T/VT/2023/7/30/0/B09.jp2
# Asset key: red-jp2, title: Red (band 4) - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/VT/2023/7/30/0/B04.jp2
# Asset key: rededge1-jp2, title: Red edge 1 (band 5) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VT/2023/7/30/0/B05.jp2
# Asset key: rededge2-jp2, title: Red edge 2 (band 6) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VT/2023/7/30/0/B06.jp2
# Asset key: rededge3-jp2, title: Red edge 3 (band 7) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VT/2023/7/30/0/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/18/T/VT/2023/7/30/0/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1 (band 11) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VT/2023/7/30/0/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2 (band 12) - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VT/2023/7/30/0/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/18/T/VT/2023/7/30/0/TCI.jp2
# Asset key: wvp-jp2, title: Water vapour (WVP), href: s3://sentinel-s2-l2a/tiles/18/T/VT/2023/7/30/0/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: S2A_18TVT_20230730_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-76.33712111608995, 47.8459059875105], [-76.31508487493689, 46.968092104527926], [-75.92400950500144, 47.84997449942044], [-76.33712111608995, 47.8459059875105]]]}
# Bounding Box: [-76.33712111608995, 46.968092104527926, -75.92400950500144, 47.84997449942044]
# Datetime: 2023-07-30 16:20:06.113000+00:00
# Properties:
#   <created>: 2023-07-31T05:32:19.360Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 66.10148
#   <proj:epsg>: 32618
#   <mgrs:utm_zone>: 18
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: VT
#   <grid:code>: MGRS-18TVT
#   <view:sun_azimuth>: 156.84413695325
#   <view:sun_elevation>: 59.425093351647504
#   <s2:degraded_msi_data_percentage>: 0.0626
#   <s2:nodata_pixel_percentage>: 87.355357
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:dark_features_percentage>: 0.13849
#   <s2:cloud_shadow_percentage>: 6.318007
#   <s2:vegetation_percentage>: 19.409715
#   <s2:not_vegetated_percentage>: 0.373304
#   <s2:water_percentage>: 2.531443
#   <s2:unclassified_percentage>: 5.127565
#   <s2:medium_proba_clouds_percentage>: 17.290094
#   <s2:high_proba_clouds_percentage>: 47.586462
#   <s2:thin_cirrus_percentage>: 1.22492
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.09
#   <s2:product_uri>: S2A_MSIL2A_20230730T160831_N0509_R140_T18TVT_20230730T235202.SAFE
#   <s2:generation_time>: 2023-07-30T23:52:02.000000Z
#   <s2:datatake_id>: GS2A_20230730T160831_042322_N05.09
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_2APS_20230730T235202_S20230730T161947_N05.09
#   <s2:granule_id>: S2A_OPER_MSI_L2A_TL_2APS_20230730T235202_A042322_T18TVT_N05.09
#   <s2:reflectance_conversion_factor>: 0.969519873865523
#   <datetime>: 2023-07-30T16:20:06.113000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/18/T/VT/2023/7/S2A_18TVT_20230730_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/a19a9b30edddc7f17375088f2cc6b41a
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '0.1.1'}
#   <updated>: 2023-07-31T05:32:19.360Z
#   <sza>: 30.574906648352496
#   <saa>: 156.84413695325
#   <vza>: 11.0691692089807
#   <vaa>: 295.393488820103
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 541MB
# Dimensions:      (y: 3001, x: 3002)
# Coordinates:
#   * y            (y) float64 24kB 1.495e+04 1.485e+04 ... -2.85e+05 -2.85e+05
#   * x            (x) float64 24kB 1.3e+06 1.3e+06 1.3e+06 ... 1.6e+06 1.6e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2023-07-30T16:20:06.113000
# Data variables: (12/15)
#     blue         (y, x) float32 36MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     green        (y, x) float32 36MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     red          (y, x) float32 36MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     rededge1     (y, x) float32 36MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     rededge2     (y, x) float32 36MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     rededge3     (y, x) float32 36MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     ...           ...
#     scl          (y, x) float32 36MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     date         (y, x) float32 36MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     score        (y, x) float32 36MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     cosSZA       (y, x) float32 36MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     cosVZA       (y, x) float32 36MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#     cosRAA       (y, x) float32 36MB -1e+04 -1e+04 -1e+04 ... -1e+04 -1e+04
#
# <<<<<<<<<< Complete generating base image, elapsed time =   0.08 minutes>>>>>>>>>
#
# <<<<<< The number of unique granule tiles = 19
#
# <<<<<< The unique granule tiles =  ['MGRS-18TVT', 'MGRS-18TUQ', 'MGRS-17TPK', 'MGRS-18TUR', 'MGRS-17TQK', 'MGRS-17TQL', 'MGRS-17TQN', 'MGRS-18TUS', 'MGRS-18TUT', 'MGRS-17TQM', 'MGRS-17TPL', 'MGRS-18TVR', 'MGRS-18TWS', 'MGRS-18TVS', 'MGRS-18TWT', 'MGRS-18TVP', 'MGRS-18TWQ', 'MGRS-18TVQ', 'MGRS-18TWR']
#
#
#  The numb of CPU cores =  4.0
#
# <get_granule_mosaic> Time Dimension Values:
# 2023-07-30T16:20
#
# <get_granule_mosaic> Time Dimension Values:
# 2023-07-22T16:11:09.971000000
# 2023-07-24T16:01:12.622000000
# 2023-07-19T16:01:13.664000000
# 2023-07-17T16:11:08.505000000
# 2023-07-14T16:01:12.881000000
# 2023-07-04T16:01:12.929000000
# <get_granule_mosaic> Complete pixel scoring, elapsed time =   1.65 minutes
# <get_granule_mosaic> Data variables of granule mosaic =  Data variables:
#     blue      (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     green     (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     red       (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     rededge1  (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     rededge2  (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     rededge3  (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     nir08     (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     swir16    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     swir22    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     scl       (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     score     (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     date      (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     cosSZA    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     cosVZA    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     cosRAA    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#
# <<<<<<<<<< Complete 14th sub mosaic >>>>>>>>>
#
# <<<<<<<<<< Complete 15th sub mosaic >>>>>>>>>
#
# <get_granule_mosaic> Time Dimension Values:
# 2023-07-22T16:10:55.858000000
# 2023-07-19T16:00:59.288000000
# 2023-07-17T16:10:54.398000000
# 2023-07-14T16:00:58.504000000
# 2023-07-04T16:00:58.563000000
#
# <get_granule_mosaic> Time Dimension Values:
# 2023-07-19T16:00:41.205000000
# 2023-07-17T16:10:36.047000000
# 2023-07-14T16:00:40.421000000
# 2023-07-12T16:10:36.293000000
# 2023-07-04T16:00:40.471000000
#
# <get_score_refers> median image =  <xarray.Dataset> Size: 104MB
# Dimensions:      (y: 1413, x: 1413)
# Coordinates:
#   * y            (y) float64 11kB -1.47e+05 -1.47e+05 ... -2.88e+05 -2.882e+05
#   * x            (x) float64 11kB 1.573e+06 1.573e+06 ... 1.714e+06 1.714e+06
#     spatial_ref  int32 4B 3979
# Data variables: (12/13)
#     blue         (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     green        (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     red          (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     rededge1     (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     rededge2     (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     rededge3     (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     ...           ...
#     swir16       (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     swir22       (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     scl          (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     score        (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     date         (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     time_index   (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#
# <get_score_refers> median image =  <xarray.Dataset> Size: 104MB
# Dimensions:      (y: 1417, x: 1416)
# Coordinates:
#   * y            (y) float64 11kB -2.756e+05 -2.756e+05 ... -4.17e+05 -4.172e+05
#   * x            (x) float64 11kB 1.507e+06 1.507e+06 ... 1.648e+06 1.649e+06
#     spatial_ref  int32 4B 3979
# Data variables: (12/13)
#     blue         (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     green        (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     red          (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     rededge1     (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     rededge2     (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     rededge3     (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     ...           ...
#     swir16       (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     swir22       (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     scl          (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     score        (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     date         (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     time_index   (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
# <get_granule_mosaic> Complete pixel scoring, elapsed time =   1.70 minutes
# <get_granule_mosaic> Complete pixel scoring, elapsed time =   1.68 minutes
# <get_granule_mosaic> Data variables of granule mosaic =  Data variables:
#     blue      (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     green     (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     red       (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     rededge1  (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     rededge2  (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     rededge3  (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     nir08     (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     swir16    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     swir22    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     scl       (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     score     (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     date      (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     cosSZA    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     cosVZA    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     cosRAA    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
# <get_granule_mosaic> Data variables of granule mosaic =  Data variables:
#     blue      (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     green     (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     red       (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     rededge1  (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     rededge2  (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     rededge3  (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     nir08     (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     swir16    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     swir22    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     scl       (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     score     (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     date      (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     cosSZA    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     cosVZA    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     cosRAA    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#
# <<<<<<<<<< Complete 16th sub mosaic >>>>>>>>>
#
# <get_score_refers> median image =  <xarray.Dataset> Size: 103MB
# Dimensions:      (y: 1410, x: 1410)
# Coordinates:
#   * y            (y) float64 11kB -1.786e+05 -1.788e+05 ... -3.196e+05
#   * x            (x) float64 11kB 1.476e+06 1.476e+06 ... 1.617e+06 1.617e+06
#     spatial_ref  int32 4B 3979
# Data variables: (12/13)
#     blue         (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     green        (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     red          (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     rededge1     (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     rededge2     (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     rededge3     (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     ...           ...
#     swir16       (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     swir22       (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     scl          (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     score        (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     date         (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     time_index   (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
# <get_granule_mosaic> Complete pixel scoring, elapsed time =   1.46 minutes
#
# <<<<<<<<<< Complete 17th sub mosaic >>>>>>>>>
# <get_granule_mosaic> Data variables of granule mosaic =  Data variables:
#     blue      (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     green     (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     red       (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     rededge1  (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     rededge2  (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     rededge3  (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     nir08     (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     swir16    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     swir22    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     scl       (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     score     (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     date      (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     cosSZA    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     cosVZA    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     cosRAA    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#
# <<<<<<<<<< Complete 18th sub mosaic >>>>>>>>>
#
# <get_score_refers> median image =  <xarray.Dataset> Size: 103MB
# Dimensions:      (y: 1407, x: 1407)
# Coordinates:
#   * y            (y) float64 11kB -5.065e+04 -5.075e+04 ... -1.912e+05
#   * x            (x) float64 11kB 1.541e+06 1.541e+06 ... 1.682e+06 1.682e+06
#     spatial_ref  int32 4B 3979
# Data variables: (12/13)
#     blue         (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     green        (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     red          (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     rededge1     (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     rededge2     (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     rededge3     (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     ...           ...
#     swir16       (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     swir22       (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     scl          (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     score        (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     date         (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
#     time_index   (y, x) float32 8MB nan nan nan nan nan ... nan nan nan nan nan
# <get_granule_mosaic> Complete pixel scoring, elapsed time =   1.14 minutes
# <get_granule_mosaic> Data variables of granule mosaic =  Data variables:
#     blue      (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     green     (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     red       (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     rededge1  (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     rededge2  (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     rededge3  (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     nir08     (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     swir16    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     swir22    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     scl       (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     score     (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     date      (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     cosSZA    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     cosVZA    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#     cosRAA    (y, x) float32 8MB nan nan nan nan nan nan ... nan nan nan nan nan
#
# <<<<<<<<<< Complete 19th sub mosaic >>>>>>>>>
#
#
# <<<<<<<<<< The total elapsed time for generating the mosaic =  14.73 minutes>>>>>>>>>
# C:\Users\lsun\Anaconda3\envs\stac312\Lib\site-packages\xarray\core\duck_array_ops.py:213: RuntimeWarning: invalid value encountered in cast
#   return data.astype(dtype, **kwargs)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 12
#       5 mosaic = eoMz.period_mosaic(params, eoIM.EXTRA_ANGLE)
#       6 #sub_mosaic = stacMoz.get_sub_mosaic(ssr_data, sub_region, 'EPSG:3979', 200, start_str, end_str)
#       7
#       8 #base_img = eoIM.apply_gain_offset(base_img, ssr_data, 100, False)
#       9 #base_img.odc.geobox
#      10 #display(mosaic)
# ---> 12 eoMz.export_mosaic(params, mosaic)
#
# File ~\STAC_python\source\eoMosaic.py:968, in export_mosaic(inParams, inMosaic)
#     964 #==========================================================================================================
#     965 # Create prefix filename
#     966 #==========================================================================================================
#     967 SsrData    = eoIM.SSR_META_DICT[str(params['sensor'])]
# --> 968 region_str = str(params['region_str'])
#     969 period_str = str(params['time_str'])
#     971 filePrefix = f"{SsrData['NAME']}_{region_str}_{period_str}"
#
# KeyError: 'region_str'

# %%
scored_img_coll = stacM.attach_score(stac_IC)
display(scored_img_coll)

# %%
mosaic = mosaic/100.0
#mosaic.plot.imshow(vmin=500, vmax=4000)
mosaic

# %%
stac_IC.sizes['time']
# Out:
# 7

# %%
import xarray as xr
import numpy as np

# Step 1: Import the required modules (done)

# Step 2: Create a simple xarray dataset
data1 = np.random.rand(4, 3)
data2 = np.random.randint(0, 100, size=(4, 3))

ds = xr.Dataset(
    {
        "temperature": (("x", "y"), data1),
        "precipitation": (("x", "y"), data2)
    },
    coords={
        "x": [0, 1, 2, 3],
        "y": [0, 1, 2]
    }
)

print("Original Data Types:")
print(ds) 

# Step 3: Change the data type of the 'temperature' and 'precipitation' variables
ds = ds.astype(np.float32)


print("\n\nNew Data Types:")
print(ds)  # Output: float32
# Out:
# Original Data Types:
# <xarray.Dataset> Size: 172B
# Dimensions:        (x: 4, y: 3)
# Coordinates:
#   * x              (x) int32 16B 0 1 2 3
#   * y              (y) int32 12B 0 1 2
# Data variables:
#     temperature    (x, y) float64 96B 0.5453 0.5308 0.7008 ... 0.4494 0.9391
#     precipitation  (x, y) int32 48B 70 82 10 29 18 89 30 11 7 77 11 57
#
#
# New Data Types:
# <xarray.Dataset> Size: 124B
# Dimensions:        (x: 4, y: 3)
# Coordinates:
#   * x              (x) int32 16B 0 1 2 3
#   * y              (y) int32 12B 0 1 2
# Data variables:
#     temperature    (x, y) float32 48B 0.5453 0.5308 0.7008 ... 0.4494 0.9391
#     precipitation  (x, y) float32 48B 70.0 82.0 10.0 29.0 ... 7.0 77.0 11.0 57.0

# %%
import certifi
certifi.where()
# Out:
# 'C:\\Users\\lsun\\Anaconda3\\envs\\stac\\Lib\\site-packages\\certifi\\cacert.pem'

# %%
import xarray as xr
from pystac_client import Client
import odc.stac

# Define the STAC API endpoint
STAC_API_URL = "https://planetarycomputer.microsoft.com/api/stac/v1"

# Initialize the STAC client
stac_client = Client.open(STAC_API_URL)

# Define a function to load STAC items into an xarray object with error handling
def load_stac_data(collection, bbox, datetime, limit, bands):
    # Search parameters
    # Perform the search
    search = stac_client.search(collections = [collection],
        bbox = bbox,       
        datetime = datetime,
        limit = limit)
    
    # Get the items
    items = list(search.items())
    
    # Load the items into an xarray object
    try:
        ds = odc.stac.load(items, bands=bands, groupby='solar_day', crs = 'EPSG:3979',                        
                        fail_on_error = False,
                        resolution = 10)
        return ds
    except Exception as e:
        print(f"Failed to load data: {e}")
        return None

# Define search parameters for Landsat Surface Reflectance data
collection_landsat = "landsat-8-c2-l2"
bbox = [-125.0, 35.0, -122.0, 37.0]  # Example bounding box
datetime = "2022-06-01/2022-06-05"
limit = 1
bands = ['red', 'green', 'blue']  # Example bands

# Load Landsat data into an xarray object
landsat_ds = load_stac_data(collection_landsat, bbox, datetime, limit, bands)
if landsat_ds is not None:
    print(landsat_ds)
else:
    print("No data loaded")

# Example analysis or usage of the xarray object
# Out:
# Failed to load data: Union of empty stream is undefined
# No data loaded

# %%
import odc.stac
import pystac_client
import requests
import matplotlib.pyplot as plt

# Define the STAC API endpoint
#stac_api_url = "https://earth-search.aws.element84.com/v0"
stac_api_url = "https://earth-search.aws.element84.com/v1"

# Create a STAC client
client = pystac_client.Client.open(stac_api_url)

# Define search parameters (e.g., collection, time range, and bounding box)
search = client.search(
    collections="landsat-8-l1",       #"sentinel-2-l2a", 
    datetime="2020-08-14/2020-08-15",
    bbox=[-110.0, 40.0, -109.0, 41.0]  # Example bounding box
)

# Get the first item from the search results
items = search.items()
#item = items[0]

# Check the available assets
#print(item.assets)

# Specify the bands you want to load (e.g., band 4 and band 5)
bands = ["red", "blue"]

# Load the data using odc.stac.load
crs = "EPSG:32613"  # Example CRS, replace with the correct CRS for your data
resolution = (-30.0, 30.0)  # Example resolution in meters, adjust as needed

# Load the data using odc.stac.load
ds = odc.stac.load(items, bands=bands, crs=crs, resolution=resolution)

# Inspect the dataset
print(ds)

# Access the data array for the band
band4_data = ds.sel(band="red")
band5_data = ds.sel(band="blue")

# Plot the data (optional, requires matplotlib)
plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.imshow(band4_data, cmap='gray')
plt.title('red')

plt.subplot(1, 2, 2)
plt.imshow(band5_data, cmap='gray')
plt.title('blue')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 35
#      32 resolution = (-30.0, 30.0)  # Example resolution in meters, adjust as needed
#      34 # Load the data using odc.stac.load
# ---> 35 ds = odc.stac.load(items, bands=bands, crs=crs, resolution=resolution)
#      37 # Inspect the dataset
#      38 print(ds)
#
# File ~\Anaconda3\envs\stac\Lib\site-packages\odc\stac\_load.py:489, in load(items, bands, groupby, resampling, dtype, chunks, pool, crs, resolution, anchor, geobox, bbox, lon, lat, x, y, like, geopolygon, progress, fail_on_error, stac_cfg, patch_url, preserve_original_order, **kw)
#     486 items = list(items)
#     487 _parsed = list(parse_items(items, cfg=stac_cfg))
# --> 489 gbox = output_geobox(
#     490     _parsed,
#     491     bands=bands,
#     492     crs=crs,
#     493     resolution=resolution,
#     494     anchor=anchor,
#     495     align=kw.get("align", None),
#     496     geobox=geobox,
#     497     like=like,
#     498     geopolygon=geopolygon,
#     499     bbox=bbox,
#     500     lon=lon,
#     501     lat=lat,
#     502     x=x,
#     503     y=y,
#     504 )
#     506 if gbox is None:
#     507     raise ValueError("Failed to auto-guess CRS/resolution.")
#
# File ~\Anaconda3\envs\stac\Lib\site-packages\odc\stac\_mdtools.py:995, in output_geobox(items, bands, crs, resolution, anchor, align, geobox, like, geopolygon, bbox, lon, lat, x, y)
#     987     return GeoBox.from_geopolygon(
#     988         geopolygon,
#     989         resolution=resolution,
#     990         crs=crs,
#     991         anchor=anchor,
#     992     )
#     994 # compute from parsed items
# --> 995 _bbox = _compute_bbox(items, crs)
#     996 return GeoBox.from_bbox(_bbox, resolution=resolution, anchor=anchor)
#
# File ~\Anaconda3\envs\stac\Lib\site-packages\odc\stac\_mdtools.py:818, in _compute_bbox(items, crs, bands)
#     815             crs0 = g.crs
#     816         yield g.boundingbox
# --> 818 return geom.bbox_union(bboxes(items))
#
# File ~\Anaconda3\envs\stac\Lib\site-packages\odc\geo\geom.py:1340, in bbox_union(bbs)
#    1338     bb, *bbs = bbs
#    1339 except ValueError:
# -> 1340     raise ValueError("Union of empty stream is undefined") from None
#    1342 L, B, R, T = bb
#    1343 crs = bb.crs
#
# ValueError: Union of empty stream is undefined

# %%
import certifi
certifi.where()
# Out:
# 'C:\\Users\\lsun\\Anaconda3\\envs\\stac\\Lib\\site-packages\\certifi\\cacert.pem'

# %%
import odc.stac
import xarray as xr
import numpy as np
from pystac_client import Client
from shapely.geometry import box
from datetime import datetime

import dask
from concurrent.futures import ThreadPoolExecutor


# Define the spatial region (bounding box)
bbox = box(minx=12.492, miny=41.890, maxx=14.503, maxy=43.899)  # Example: Rome, Italy

# Define the time window
start_date = "2023-07-01"
end_date = "2023-07-31"

# Define cloud coverage filter
max_cloud_coverage = 20  # maximum cloud coverage in percent

# Connect to the STAC catalog
catalog = Client.open("https://earth-search.aws.element84.com/v1")

# Search for Sentinel-2 surface reflectance data
search = catalog.search(
    collections=["sentinel-2-l2a"],
    bbox=bbox.bounds,
    datetime=f"{start_date}/{end_date}",
    query={"eo:cloud_cover": {"lt": max_cloud_coverage}}
)

# Get the items from the search results
items = list(search.items())
print('the number of items = ', len(items))
print('items properties = ', items[0].properties)





# Load the data using odc.stac.load
ds = odc.stac.load(
    items,
    bands=["red", "green", "blue", "scl"],  # Load some bands as an example
    bbox=bbox.bounds,
    crs='EPSG:3979',
    chunks={'x': 1000, 'y': 1000},  # Use Dask for chunking along the time dimension
    resolution = 10
)


'''
# Load data as xarray.Dataset
ds = odc.stac.load(
    items,
    bands=["B04", "B03", "B02", "SCL"],
    groupby="solar_day",
    resolution=(-10, 10),
    crs="EPSG:4326"
)
'''

print('xrDS = ', ds)

# Extract the sun elevation angle and compute the sun zenith angle
#sun_elevation_angle = ds.attrs.get("view:sun_elevation", None)
#if sun_elevation_angle is None:
#    raise ValueError("Sun elevation angle metadata is not available in the dataset attributes.")

# Compute sun zenith angle for the entire dataset
sun_zenith = 55.5
ds = ds.assign(sun_zenith=([], sun_zenith))

print('xrDS after adding SZA = ', ds)
# Define a Dask configuration for threading
with dask.config.set(pool=ThreadPoolExecutor(64), scheduler="threads"):
    # Access the data to trigger the computation
    raw_data = ds.compute()

# Now ds contains the sun zenith angle for each item in the dataset
print(ds)






# Extract the view:sun_elevation values from the metadata
sun_elevations = []
for item in items:
    if "view:sun_elevation" in item.properties:
        sun_elevations.append(item.properties["view:sun_elevation"])

# Print the extracted sun elevation values
print(sun_elevations)

# Merge the sun elevation data array into the dataset
#ds = ds.assign(sun_elevation=sun_elevation_da)

# Print the final dataset
#print(ds)
# Out:
# the number of items =  70
# items properties =  {'created': '2023-07-29T18:32:16.899Z', 'platform': 'sentinel-2a', 'constellation': 'sentinel-2', 'instruments': ['msi'], 'eo:cloud_cover': 0.236217, 'proj:epsg': 32632, 'mgrs:utm_zone': 32, 'mgrs:latitude_band': 'T', 'mgrs:grid_square': 'QM', 'grid:code': 'MGRS-32TQM', 'view:sun_azimuth': 142.447252649291, 'view:sun_elevation': 62.5912315500185, 's2:degraded_msi_data_percentage': 0.0003, 's2:nodata_pixel_percentage': 3.365616, 's2:saturated_defective_pixel_percentage': 0, 's2:dark_features_percentage': 0.009964, 's2:cloud_shadow_percentage': 0.14447, 's2:vegetation_percentage': 28.829089, 's2:not_vegetated_percentage': 21.764129, 's2:water_percentage': 48.96532, 's2:unclassified_percentage': 0.050303, 's2:medium_proba_clouds_percentage': 0.183079, 's2:high_proba_clouds_percentage': 0.052754, 's2:thin_cirrus_percentage': 0.000385, 's2:snow_ice_percentage': 0.000508, 's2:product_type': 'S2MSI2A', 's2:processing_baseline': '05.09', 's2:product_uri': 'S2A_MSIL2A_20230729T100031_N0509_R122_T32TQM_20230729T134559.SAFE', 's2:generation_time': '2023-07-29T13:45:59.000000Z', 's2:datatake_id': 'GS2A_20230729T100031_042304_N05.09', 's2:datatake_type': 'INS-NOBS', 's2:datastrip_id': 'S2A_OPER_MSI_L2A_DS_2APS_20230729T134559_S20230729T100031_N05.09', 's2:granule_id': 'S2A_OPER_MSI_L2A_TL_2APS_20230729T134559_A042304_T32TQM_N05.09', 's2:reflectance_conversion_factor': 0.969277407974526, 'datetime': '2023-07-29T10:09:16.980000Z', 's2:sequence': '1', 'earthsearch:s3_path': 's3://sentinel-cogs/sentinel-s2-l2a-cogs/32/T/QM/2023/7/S2A_32TQM_20230729_1_L2A', 'earthsearch:payload_id': 'roda-sentinel2/workflow-sentinel2-to-stac/b4fc0dd29e4b5c9d702053364b3ce99e', 'earthsearch:boa_offset_applied': True, 'processing:software': {'sentinel2-to-stac': '0.1.1'}, 'updated': '2023-07-29T18:32:16.899Z'}
# xrDS =  <xarray.Dataset> Size: 239GB
# Dimensions:      (y: 19824, x: 25010, time: 69)
# Coordinates:
#   * y            (y) float64 159kB 5.474e+06 5.474e+06 ... 5.276e+06 5.276e+06
#   * x            (x) float64 200kB 5.168e+06 5.168e+06 ... 5.418e+06 5.418e+06
#     spatial_ref  int32 4B 3979
#   * time         (time) datetime64[ns] 552B 2023-07-02T10:18:39.963000 ... 20...
# Data variables:
#     red          (time, y, x) uint16 68GB dask.array<chunksize=(1, 1000, 1000), meta=np.ndarray>
#     green        (time, y, x) uint16 68GB dask.array<chunksize=(1, 1000, 1000), meta=np.ndarray>
#     blue         (time, y, x) uint16 68GB dask.array<chunksize=(1, 1000, 1000), meta=np.ndarray>
#     scl          (time, y, x) uint8 34GB dask.array<chunksize=(1, 1000, 1000), meta=np.ndarray>
# xrDS after adding SZA =  <xarray.Dataset> Size: 239GB
# Dimensions:      (y: 19824, x: 25010, time: 69)
# Coordinates:
#   * y            (y) float64 159kB 5.474e+06 5.474e+06 ... 5.276e+06 5.276e+06
#   * x            (x) float64 200kB 5.168e+06 5.168e+06 ... 5.418e+06 5.418e+06
#     spatial_ref  int32 4B 3979
#   * time         (time) datetime64[ns] 552B 2023-07-02T10:18:39.963000 ... 20...
# Data variables:
#     red          (time, y, x) uint16 68GB dask.array<chunksize=(1, 1000, 1000), meta=np.ndarray>
#     green        (time, y, x) uint16 68GB dask.array<chunksize=(1, 1000, 1000), meta=np.ndarray>
#     blue         (time, y, x) uint16 68GB dask.array<chunksize=(1, 1000, 1000), meta=np.ndarray>
#     scl          (time, y, x) uint8 34GB dask.array<chunksize=(1, 1000, 1000), meta=np.ndarray>
#     sun_zenith   float64 8B 55.5
# C:\Users\lsun\Anaconda3\envs\stac\Lib\site-packages\rasterio\warp.py:344: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   _reproject(
# C:\Users\lsun\Anaconda3\envs\stac\Lib\site-packages\rasterio\warp.py:344: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   _reproject(
# Aborting load due to failure while reading: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/32/T/QN/2023/7/S2B_32TQN_20230727_0_L2A/B04.tif:1
# Aborting load due to failure while reading: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/32/T/QN/2023/7/S2B_32TQN_20230727_0_L2A/B04.tif:1
# Aborting load due to failure while reading: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/32/T/QN/2023/7/S2B_32TQN_20230727_0_L2A/B04.tif:1
# Aborting load due to failure while reading: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/32/T/QN/2023/7/S2B_32TQN_20230727_0_L2A/B04.tif:1
# Aborting load due to failure while reading: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/32/T/QN/2023/7/S2B_32TQN_20230727_0_L2A/B04.tif:1
# ---------------------------------------------------------------------------
# CPLE_AppDefinedError                      Traceback (most recent call last)
# File rasterio\\_warp.pyx:590, in rasterio._warp._reproject()
#
# File rasterio\\_err.pyx:195, in rasterio._err.exc_wrap_int()
#
# CPLE_AppDefinedError: GetBlockRef failed at X block offset 9, Y block offset 10: D:\bld\gdal-split_1717860834713\work\gcore\gdalrasterblock.cpp, 1111: cannot allocate 2097152 bytes
#
# The above exception was the direct cause of the following exception:
#
# WarpOperationError                        Traceback (most recent call last)
# Cell In[3], line 79
#      76 # Define a Dask configuration for threading
#      77 with dask.config.set(pool=ThreadPoolExecutor(64), scheduler="threads"):
#      78     # Access the data to trigger the computation
# ---> 79     raw_data = ds.compute()
#      81 # Now ds contains the sun zenith angle for each item in the dataset
#      82 print(ds)
#
# File ~\Anaconda3\envs\stac\Lib\site-packages\xarray\core\dataset.py:1036, in Dataset.compute(self, **kwargs)
#    1012 """Manually trigger loading and/or computation of this dataset's data
#    1013 from disk or a remote source into memory and return a new dataset.
#    1014 Unlike load, the original dataset is left unaltered.
#    (...)
#    1033 dask.compute
#    1034 """
#    1035 new = self.copy(deep=False)
# -> 1036 return new.load(**kwargs)
#
# File ~\Anaconda3\envs\stac\Lib\site-packages\xarray\core\dataset.py:863, in Dataset.load(self, **kwargs)
#     860 chunkmanager = get_chunked_array_type(*lazy_data.values())
#     862 # evaluate all the chunked arrays simultaneously
# --> 863 evaluated_data: tuple[np.ndarray[Any, Any], ...] = chunkmanager.compute(
#     864     *lazy_data.values(), **kwargs
#     865 )
#     867 for k, data in zip(lazy_data, evaluated_data):
#     868     self.variables[k].data = data
#
# File ~\Anaconda3\envs\stac\Lib\site-packages\xarray\namedarray\daskmanager.py:86, in DaskManager.compute(self, *data, **kwargs)
#      81 def compute(
#      82     self, *data: Any, **kwargs: Any
#      83 ) -> tuple[np.ndarray[Any, _DType_co], ...]:
#      84     from dask.array import compute
# ---> 86     return compute(*data, **kwargs)
#
# File ~\Anaconda3\envs\stac\Lib\site-packages\dask\base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~\Anaconda3\envs\stac\Lib\site-packages\odc\stac\_load.py:696, in _dask_loader_tyx(srcs, gbt, iyx, cfg, env)
#     694 with rio_env(**env):
#     695     for i, plane in enumerate(srcs):
# --> 696         _fill_2d_slice(plane, gbox, cfg, chunk[i, :, :])
#     697     return chunk
#
# File ~\Anaconda3\envs\stac\Lib\site-packages\odc\stac\_load.py:724, in _fill_2d_slice(srcs, dst_gbox, cfg, dst)
#     721     return dst
#     723 src, *rest = srcs
# --> 724 _roi, pix = rio_read(src, cfg, dst_gbox, dst=dst)
#     726 for src in rest:
#     727     # first valid pixel takes precedence over others
#     728     _roi, pix = rio_read(src, cfg, dst_gbox)
#
# File ~\Anaconda3\envs\stac\Lib\site-packages\odc\stac\_reader.py:199, in rio_read(src, cfg, dst_geobox, dst)
#     193     if cfg.fail_on_error:
#     194         log.error(
#     195             "Aborting load due to failure while reading: %s:%d",
#     196             src.uri,
#     197             src.band,
#     198         )
# --> 199         raise e
#     200 except rasterio.errors.RasterioError as e:
#     201     if cfg.fail_on_error:
#
# File ~\Anaconda3\envs\stac\Lib\site-packages\odc\stac\_reader.py:186, in rio_read(src, cfg, dst_geobox, dst)
#     163 """
#     164 Internal read method.
#     165
#    (...)
#     182
#     183 """
#     185 try:
# --> 186     return _rio_read(src, cfg, dst_geobox, dst)
#     187 except (
#     188     rasterio.errors.RasterioIOError,
#     189     rasterio.errors.RasterBlockError,
#     190     rasterio.errors.WarpOperationError,
#     191     rasterio.errors.WindowEvaluationError,
#     192 ) as e:
#     193     if cfg.fail_on_error:
#
# File ~\Anaconda3\envs\stac\Lib\site-packages\odc\stac\_reader.py:246, in _rio_read(src, cfg, dst_geobox, dst)
#     244 if ovr_idx is None:
#     245     with rio_env(VSI_CACHE=False):
# --> 246         return _do_read(
#     247             rasterio.band(rdr, src.band), cfg, dst_geobox, rr, dst=dst
#     248         )
#     250 # read from overview
#     251 with rasterio.open(
#     252     src.uri, "r", sharing=False, overview_level=ovr_idx
#     253 ) as rdr_ovr:
#
# File ~\Anaconda3\envs\stac\Lib\site-packages\odc\stac\_reader.py:144, in _do_read(src, cfg, dst_geobox, rr, dst)
#     138         np.copyto(_dst, dst_nodata, where=_nodata_mask(_dst, src_nodata))
#     139 else:
#     140     # some form of reproject
#     141     # TODO: support read with integer shrink then reproject more
#     142     # TODO: deal with int8 inputs
# --> 144     rasterio.warp.reproject(
#     145         src,
#     146         _dst,
#     147         src_nodata=src_nodata,
#     148         dst_crs=str(dst_geobox.crs),
#     149         dst_transform=dst_geobox[rr.roi_dst].transform,
#     150         dst_nodata=dst_nodata,
#     151         resampling=resampling,
#     152     )
#     154 return (rr.roi_dst, _dst)
#
# File ~\Anaconda3\envs\stac\Lib\site-packages\rasterio\env.py:398, in ensure_env.<locals>.wrapper(*args, **kwds)
#     395 @wraps(f)
#     396 def wrapper(*args, **kwds):
#     397     if local._env:
# --> 398         return f(*args, **kwds)
#     399     else:
#     400         with Env.from_defaults():
#
# File ~\Anaconda3\envs\stac\Lib\site-packages\rasterio\warp.py:344, in reproject(source, destination, src_transform, gcps, rpcs, src_crs, src_nodata, dst_transform, dst_crs, dst_nodata, dst_resolution, src_alpha, dst_alpha, resampling, num_threads, init_dest_nodata, warp_mem_limit, **kwargs)
#     340         destination = np.empty((int(dst_count), int(dst_height), int(dst_width)),
#     341                                dtype=source.dtype)
#     343 # Call the function in our extension module.
# --> 344 _reproject(
#     345     source, destination, src_transform=src_transform, gcps=gcps, rpcs=rpcs,
#     346     src_crs=src_crs, src_nodata=src_nodata, dst_transform=dst_transform,
#     347     dst_crs=dst_crs, dst_nodata=dst_nodata, dst_alpha=dst_alpha,
#     348     src_alpha=src_alpha, resampling=resampling,
#     349     init_dest_nodata=init_dest_nodata, num_threads=num_threads,
#     350     warp_mem_limit=warp_mem_limit, **kwargs)
#     352 return destination, dst_transform
#
# File rasterio\\_warp.pyx:592, in rasterio._warp._reproject()
#
# WarpOperationError: Chunk and warp failed

# %%
from sgp4.api import Satrec
from sgp4.api import jday
import datetime

# Example TLE for Sentinel-2A
tle_line1 = '1 40697U 15028A   20223.50986343  .00000039  00000-0  27263-4 0  9993'
tle_line2 = '2 40697  98.5637 295.7634 0001038  87.8427 272.2872 14.30860136266384'

# Create a satellite object
satellite = Satrec.twoline2rv(tle_line1, tle_line2)

# Get the current date and time in UTC
now = datetime.datetime.utcnow()
jd, fr = jday(now.year, now.month, now.day, now.hour, now.minute, now.second)

# Compute the position and velocity in ECI coordinates (km and km/s)
e, r, v = satellite.sgp4(jd, fr)

if e == 0:
    print(f"Position (km): {r}")
    print(f"Velocity (km/s): {v}")
else:
    print("Error in computation")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from sgp4.api import Satrec
#       2 from sgp4.api import jday
#       3 import datetime
#
# ModuleNotFoundError: No module named 'sgp4'

# %%
import numpy as np 

S_pinv = np.random.rand(3, 4)
images = np.random.rand(4, 5, 6)

# error: 
# (S_pinv @ images).shape 
res_shape = S_pinv.shape[:1] + images.shape[1:]  # (3, 5, 6) 


res = (S_pinv @ images.reshape(images.shape[0], -1)).reshape(res_shape)
print(res.shape)  # (3, 5, 6)
# Out:
# (5, 6)
# (3, 5, 6)
