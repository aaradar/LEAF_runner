# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "number_workers":20,     
  "debug"       : True,
  "entire_tile" : False, 
  "nodes"       : 1,
  "node_memory" : "25G",
  'chunk_size': {'x': 4096, 'y': 4096}
}

  
ProdParams = {
    'sensor': 'S2_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR' or 'HLSS30_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2025,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [8],    # A list of integers represening one or multiple monthes     
    #'tile_names': ['tile46_411','tile46_412','tile46_421','tile46_422'],  # A list of (sub-)tile names
    #'tile_names': ['tile46_412'],
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution': 100,            # Exporting spatial resolution    
    'out_folder': 'E:/S2_mosaics_2025/S2_mosaic_tile46_412_2025_100m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    'start_dates': ['2025-06-15'],
    'end_dates': ['2025-09-15'],
    'regions': {'ottawa': ottawa_region} #, {'vancouver': vancouver_region}    
}

print(ProdParams)
# Out:
# {'sensor': 'S2_SR', 'unit': 2, 'year': 2025, 'nbYears': -1, 'prod_names': ['mosaic'], 'resolution': 100, 'out_folder': 'E:/S2_mosaics_2025/S2_mosaic_tile46_412_2025_100m', 'out_datatype': 'int16', 'projection': 'EPSG:3979', 'IncludeAngles': False, 'start_dates': ['2025-06-15'], 'end_dates': ['2025-09-15'], 'regions': {'ottawa': {'type': 'Polygon', 'coordinates': [[[-76.12, 45.184], [-75.383, 45.171], [-75.39, 45.564], [-76.105, 45.568], [-76.12, 45.184]]]}}}

# %%
main(ProdParams, CompParams)
# Out:
# <MosaicProduction> User defined input parameters:
# sensor: S2_SR
# unit: 2
# year: 2025
# nbYears: -1
# prod_names: ['mosaic']
# resolution: 100
# out_folder: E:/S2_mosaics_2025/S2_mosaic_tile46_412_2025_100m
# out_datatype: int16
# projection: EPSG:3979
# IncludeAngles: False
# start_dates: ['2025-06-15']
# end_dates: ['2025-09-15']
# regions: {'ottawa': {'type': 'Polygon', 'coordinates': [[[-76.12, 45.184], [-75.383, 45.171], [-75.39, 45.564], [-76.105, 45.568], [-76.12, 45.184]]]}}
# SsrData: {'NAME': 'S2_SR', 'SSR_CODE': 21, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], '10M_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'SIX_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'NoA_BANDS': ['red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'LEAF_BANDS': ['green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'GEE_NAME': 'COPERNICUS/S2_SR_HARMONIZED', 'CLOUD': 'CLOUDY_PIXEL_PERCENTAGE', 'SZA': 'view:sun_elevation', 'SAA': 'view:sun_azimuth', 'VZA': 'view:sun_elevation', 'VAA': 'view:sun_azimuth', 'BLU': 'blue', 'GRN': 'green', 'RED': 'red', 'NIR': 'nir08', 'SW1': 'swir16', 'SW2': 'swir22'}
# out_location: drive
# months: []
# tile_names: []
# cloud_cover: 80
# export_style: separate
# monthly: False
# current_time: 0
# scene_ID:
# current_region: ottawa
# Criteria: {'timeframe': '2025-06-15/2025-09-15', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-76.12, 45.184], [-75.383, 45.171], [-75.39, 45.564], [-76.105, 45.568], [-76.12, 45.184]]]}, 'catalog': 'https://earth-search.aws.element84.com/v1', 'collection': ['sentinel-2-l2a'], 'bands': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl']}
# standardized: True
# number_workers: 20
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 25G
# chunk_size: {'x': 4096, 'y': 4096}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-76.12, 45.184], [-75.383, 45.171], [-75.39, 45.564], [-76.105, 45.568], [-76.12, 45.184]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.02 minutes
#
# <one_mosaic> A total of 28 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/AOT.tif
# Asset key: blue, title: Blue - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/B02.tif
# Asset key: cloud, title: Cloud Probabilities, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/qi/CLD_20m.jp2
# Asset key: coastal, title: Coastal - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/granule_metadata.xml
# Asset key: green, title: Green - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/B09.tif
# Asset key: product_metadata, title: None, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/product_metadata.xml
# Asset key: red, title: Red - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/B04.tif
# Asset key: rededge1, title: Red Edge 1 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/B05.tif
# Asset key: rededge2, title: Red Edge 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/B06.tif
# Asset key: rededge3, title: Red Edge 3 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/SCL.tif
# Asset key: snow, title: Snow Probabilities, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/qi/SNW_20m.jp2
# Asset key: swir16, title: SWIR 1.6μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2.2μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/B12.tif
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/TCI.tif
# Asset key: wvp, title: Water Vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/WVP.tif
# Asset key: thumbnail, title: Thumbnail of preview image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A/preview.jpg
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/R20m/AOT.jp2
# Asset key: blue-jp2, title: Blue - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/R10m/B02.jp2
# Asset key: coastal-jp2, title: Coastal - 60m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/R60m/B01.jp2
# Asset key: green-jp2, title: Green - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/R10m/B03.jp2
# Asset key: nir-jp2, title: NIR 1 - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/R10m/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/R20m/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 - 60m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/R60m/B09.jp2
# Asset key: red-jp2, title: Red - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/R10m/B04.jp2
# Asset key: rededge1-jp2, title: Red Edge 1 - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/R20m/B05.jp2
# Asset key: rededge2-jp2, title: Red Edge 2 - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/R20m/B06.jp2
# Asset key: rededge3-jp2, title: Red Edge 3 - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/R20m/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/R20m/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1.6μm - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/R20m/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2.2μm - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/R20m/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/R10m/TCI.jp2
# Asset key: wvp-jp2, title: Water Vapour (WVP), href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/7/25/0/R20m/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2A_18TVR_20250725_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-75.62326995078233, 46.05186598173959], [-75.9642357828627, 45.06119837019081], [-74.87603818430986, 45.065201721669794], [-74.87384571020863, 46.053495749294726], [-75.62326995078233, 46.05186598173959]]]}
# Bounding Box: [-75.964236, 45.061198, -74.873846, 46.053496]
# Datetime: 2025-07-25 16:00:57.709000+00:00
# cloud cover: 29.563504
# Properties:
#   <created>: 2025-07-25T22:18:19.357Z
#   <platform>: sentinel-2a
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 29.563504
#   <proj:centroid>: {'lat': 45.52756, 'lon': -75.33972}
#   <mgrs:utm_zone>: 18
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: VR
#   <grid:code>: MGRS-18TVR
#   <view:azimuth>: 105.571548048536
#   <view:incidence_angle>: 9.03833417021635
#   <view:sun_azimuth>: 146.12616606532
#   <view:sun_elevation>: 60.4025872967293
#   <s2:tile_id>: S2A_OPER_MSI_L2A_TL_2APS_20250725T205016_A052704_T18TVR_N05.11
#   <s2:degraded_msi_data_percentage>: 0.0188
#   <s2:nodata_pixel_percentage>: 34.515059
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 7.954455
#   <s2:vegetation_percentage>: 54.762828
#   <s2:not_vegetated_percentage>: 4.194682
#   <s2:water_percentage>: 2.756993
#   <s2:unclassified_percentage>: 0.657296
#   <s2:medium_proba_clouds_percentage>: 11.435197
#   <s2:high_proba_clouds_percentage>: 9.667806
#   <s2:thin_cirrus_percentage>: 8.460499
#   <s2:snow_ice_percentage>: 0
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2A_MSIL2A_20250725T155711_N0511_R054_T18TVR_20250725T205016.SAFE
#   <s2:generation_time>: 2025-07-25T20:50:16.000000Z
#   <s2:datatake_id>: GS2A_20250725T155711_052704_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2A_OPER_MSI_L2A_DS_2APS_20250725T205016_S20250725T155709_N05.11
#   <s2:reflectance_conversion_factor>: 0.968698802692454
#   <datetime>: 2025-07-25T16:00:57.709000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/18/T/VR/2025/7/S2A_18TVR_20250725_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/4a952eedc539e27f0f2b3e55dad148f1
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '2025.03.06'}
#   <updated>: 2025-07-25T22:18:19.357Z
#   <proj:code>: EPSG:32618
#   <sza>: 29.5974127032707
#   <saa>: 146.12616606532
#   <vza>: 9.09084798215032
#   <vaa>: 106.061930101874
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 19MB
# Dimensions:      (y: 583, x: 683)
# Coordinates:
#   * y            (y) float64 5kB -1.472e+05 -1.472e+05 ... -2.052e+05 -2.054e+05
#   * x            (x) float64 5kB 1.475e+06 1.475e+06 ... 1.543e+06 1.543e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-07-25T16:00:57.709000
# Data variables:
#     blue         (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     green        (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     red          (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     rededge1     (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     rededge2     (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     rededge3     (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     nir08        (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     swir16       (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     swir22       (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     scl          (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     date         (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     score        (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['18TVR']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:58338/status >>>>>>>>>
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 main(ProdParams, CompParams)
#
# File ~\LEAF Files\LEAF_stac\Production.py:202, in main(inProdParams, inCompParams)
#     199   leaf.LEAF_production(prod_params, comp_params)
#     201 else:
# --> 202   MosaicProduction(prod_params, comp_params)
#
# File ~\LEAF Files\LEAF_stac\Production.py:169, in MosaicProduction(ProdParams, CompParams)
#     167 print('\n<MosaicProduction> Generate and export separate mosaic images......')
#     168 #AIMz.one_mosaicC(usedParams, CompParams)
# --> 169 eoMz.one_mosaic(usedParams, CompParams)
#
# File ~\LEAF Files\LEAF_stac\source\eoMosaic.py:1619, in one_mosaic(AllParams, Output)
#    1616   client.cancel(future)
#    1618 # We do the compute to get a dask array instead of a future
# -> 1619 base_img = base_img.chunk(ChunkDict).compute()
#    1621 #==========================================================================================================
#    1622 # Mask out the pixels with negative date value
#    1623 #==========================================================================================================
#    1624 mosaic = base_img.where(base_img[eoIM.pix_date] > 0)
#
# File ~\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\dask\base.py:375, in DaskMethodsMixin.compute(self, **kwargs)
#     351 def compute(self, **kwargs):
#     352     """Compute this dask collection
#     353
#     354     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)    373     dask.compute
#     374     """
# --> 375     (result,) = compute(self, traverse=False, **kwargs)
#     376     return result
#
# File ~\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\dask\base.py:661, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     658     postcomputes.append(x.__dask_postcompute__())
#     660 with shorten_traceback():
# --> 661     results = schedule(dsk, keys, **kwargs)
#     663 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\odc\loader\_builder.py:434, in _dask_loader_tyx()
#     432 with rdr.restore_env(env, load_state):
#     433     for ti, ti_srcs in enumerate(srcs):
# --> 434         _fill_nd_slice(
#     435             ti_srcs, gbox, cfg, chunk[ti], ydim=ydim, selection=selection
#     436         )
#     437     return chunk
#
# File ~\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\odc\loader\_builder.py:511, in _fill_nd_slice()
#     508     return dst
#     510 src, *rest = srcs
# --> 511 yx_roi, pix = src.read(cfg, dst_gbox, dst=dst, selection=selection)
#     512 assert len(yx_roi) == 2
#     513 assert pix.ndim == dst.ndim
#
# File ~\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\odc\loader\_rio.py:115, in read()
#     107 def read(
#     108     self,
#     109     cfg: RasterLoadParams,
#    (...)    113     selection: Optional[ReaderSubsetSelection] = None,
#     114 ) -> tuple[tuple[slice, slice], np.ndarray]:
# --> 115     return rio_read(self._src, cfg, dst_geobox, dst=dst, selection=selection)
#
# File ~\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\odc\loader\_rio.py:512, in rio_read()
#     508     return roi, out.transpose([1, 2, 0])
#     510 try:
#     511     return fixup_out(
# --> 512         _rio_read(src, cfg, dst_geobox, prep_dst(dst), selection=selection)
#     513     )
#     514 except (
#     515     rasterio.errors.RasterioIOError,
#     516     rasterio.errors.RasterBlockError,
#     517     rasterio.errors.WarpOperationError,
#     518     rasterio.errors.WindowEvaluationError,
#     519 ) as e:
#     520     if cfg.fail_on_error:
#
# File ~\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\odc\loader\_rio.py:581, in _rio_read()
#     579 rr = _reproject_info_from_rio(rdr, dst_geobox, ttol=ttol)
#     580 with rio_env(VSI_CACHE=False):
# --> 581     return _do_read(
#     582         rasterio.band(rdr_ovr, bidx), cfg, dst_geobox, rr, dst=dst
#     583     )
#
# File ~\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\odc\loader\_rio.py:440, in _do_read()
#     434         np.copyto(_dst, dst_nodata, where=nodata_mask(_dst, src_nodata))
#     435 else:
#     436     # some form of reproject
#     437     # TODO: support read with integer shrink then reproject more
#     438     # TODO: deal with int8 inputs
# --> 440     rasterio.warp.reproject(
#     441         src,
#     442         _dst,
#     443         src_nodata=src_nodata,
#     444         dst_crs=str(dst_geobox.crs),
#     445         dst_transform=dst_geobox[rr.roi_dst].transform,
#     446         dst_nodata=dst_nodata,
#     447         resampling=resampling,
#     448     )
#     450 return (roi_dst, _dst)
#
# File ~\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\rasterio\env.py:398, in wrapper()
#     395 @wraps(f)
#     396 def wrapper(*args, **kwds):
#     397     if local._env:
# --> 398         return f(*args, **kwds)
#     399     else:
#     400         with Env.from_defaults():
#
# File ~\AppData\Local\anaconda3\envs\leaftoolbox2\Lib\site-packages\rasterio\warp.py:344, in reproject()
#     340         destination = np.empty((int(dst_count), int(dst_height), int(dst_width)),
#     341                                dtype=source.dtype)
#     343 # Call the function in our extension module.
# --> 344 _reproject(
#     345     source, destination, src_transform=src_transform, gcps=gcps, rpcs=rpcs,
#     346     src_crs=src_crs, src_nodata=src_nodata, dst_transform=dst_transform,
#     347     dst_crs=dst_crs, dst_nodata=dst_nodata, dst_alpha=dst_alpha,
#     348     src_alpha=src_alpha, resampling=resampling,
#     349     init_dest_nodata=init_dest_nodata, num_threads=num_threads,
#     350     warp_mem_limit=warp_mem_limit, **kwargs)
#     352 return destination, dst_transform
#
# File rasterio\\_warp.pyx:464, in rasterio._warp._reproject()
#
# File rasterio\\_warp.pyx:426, in rasterio._warp._reproject()
#
# File rasterio\\_io.pyx:2152, in rasterio._io.MemoryDataset.__init__()
#
# File rasterio\\_io.pyx:2154, in rasterio._io.MemoryDataset.__init__()
#
# File rasterio\\_io.pyx:1529, in rasterio._io.DatasetWriterBase.__init__()
#
# File rasterio\\_base.pyx:221, in rasterio._base.open_dataset()
#
# File rasterio\\_err.pyx:221, in rasterio._err.exc_wrap_pointer()
#
# Exception: CPLE_AppDefinedError(3, 1, 'Opening a MEM dataset with the MEM:::DATAPOINTER= syntax is no longer supported by default for security reasons. If you want to allow it, define the GDAL_MEM_ENABLE_OPEN configuration option to YES, or build GDAL with the GDAL_MEM_ENABLE_OPEN compilation definition')
