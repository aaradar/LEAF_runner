# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "number_workers":10,   #For S2 data, only use 10 rather than 20  
  "debug"       : True,
  "entire_tile" : False,     #
  "nodes"       : 1,
  "node_memory" : "50G",
  'chunk_size': {'x': 4096, 'y': 4096}
}

  
ProdParams = {
    'sensor': 'HLS_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR', 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2024,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [5,6,7,8,9,10],            # A list of integers represening one or multiple monthes     
    'tile_names': ['tile23_421'], # A list of (sub-)tile names (defined using CCRS' tile griding system) 
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution': 30,            # Exporting spatial resolution    
    'out_folder': 'E:/HLS_mosaics_2024/HLS_mosaic_tile23_421_2024_30m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2025-06-15'],
    #'end_dates': ['2025-09-15'],
    #'regions': {'ottawa': ottawa_region}  #, {'vancouver': vancouver_region}    
}

# %%
main(ProdParams, CompParams)
# Out:
# <form_spatial_regions> Raw polygon = {'type': 'Polygon', 'coordinates': [[[-121.2106, 52.7067], [-118.7501, 48.9443], [-112.8399, 50.2479], [-114.7797, 54.1602], [-121.2106, 52.7067]]]}
# <MosaicProduction> User defined input parameters:
# sensor: HLS_SR
# unit: 2
# year: 2024
# nbYears: -1
# months: [5, 6, 7, 8, 9, 10]
# tile_names: ['tile42_421']
# prod_names: ['mosaic']
# resolution: 30
# out_folder: E:/HLS_mosaics_2024/HLS_mosaic_tile42_421_2024_30m
# out_datatype: int16
# projection: EPSG:3979
# IncludeAngles: False
# SsrData: {'NAME': 'HLS_SR', 'SSR_CODE': 102, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'SIX_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'NoA_BANDS': ['B04', 'B05', 'B06', 'B07'], 'LEAF_BANDS': ['B03', 'B04', 'B05', 'B06', 'B07'], 'ANGLE_BANDS': ['VZA', 'VAA', 'SZA', 'SAA'], 'CLOUD': 'CLOUD_COVERAGE', 'BLU': 'B02', 'GRN': 'B03', 'RED': 'B04', 'NIR': 'B05', 'SW1': 'B06', 'SW2': 'B07'}
# out_location: drive
# cloud_cover: 80
# export_style: separate
# CloudScore: False
# monthly: True
# start_dates: ['2024-05-01', '2024-06-01', '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01']
# end_dates: ['2024-05-31', '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30', '2024-10-31']
# current_time: 0
# scene_ID:
# regions: {'tile42_421': {'type': 'Polygon', 'coordinates': [[[-121.4106, 52.9067], [-118.9501, 48.744299999999996], [-112.6399, 50.0479], [-114.5797, 54.360200000000006], [-121.4106, 52.9067]]]}}
# current_region: tile42_421
# Criteria: {'timeframe': '2024-05-01/2024-05-31', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-121.4106, 52.9067], [-118.9501, 48.744299999999996], [-112.6399, 50.0479], [-114.5797, 54.360200000000006], [-121.4106, 52.9067]]]}, 'collection': ['HLSS30_2.0', 'HLSL30_2.0'], 'bands': {'S2': ['B02', 'B03', 'B04', 'B08', 'B11', 'B12', 'Fmask'], 'LS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'Fmask'], 'angle': ['SZA', 'SAA', 'VZA', 'VAA']}, 'catalog': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD'}
# standardized: True
# number_workers: 10
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 50G
# chunk_size: {'x': 4096, 'y': 4096}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-121.4106, 52.9067], [-118.9501, 48.744299999999996], [-112.6399, 50.0479], [-114.5797, 54.360200000000006], [-121.4106, 52.9067]]]}
#
# <one_mosaic> A total of 363 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T10UFD.2024122T185919.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.jpg
# Asset key: B11, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B11.tif
# Asset key: B8A, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B8A.tif
# Asset key: B05, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B05.tif
# Asset key: B02, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B02.tif
# Asset key: B01, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B01.tif
# Asset key: B10, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B10.tif
# Asset key: B06, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B06.tif
# Asset key: B03, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B03.tif
# Asset key: B12, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B12.tif
# Asset key: VZA, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.VZA.tif
# Asset key: Fmask, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.Fmask.tif
# Asset key: B07, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B07.tif
# Asset key: B04, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B04.tif
# Asset key: VAA, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.VAA.tif
# Asset key: SAA, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.SAA.tif
# Asset key: B08, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B08.tif
# Asset key: SZA, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.SZA.tif
# Asset key: B09, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B09.tif
# Asset key: s3_B11, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B11.tif
# Asset key: s3_B8A, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B8A.tif
# Asset key: s3_B05, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B05.tif
# Asset key: s3_B02, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B02.tif
# Asset key: s3_B01, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B01.tif
# Asset key: s3_B10, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B10.tif
# Asset key: s3_B06, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B06.tif
# Asset key: s3_B03, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B03.tif
# Asset key: s3_B12, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B12.tif
# Asset key: s3_VZA, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.VZA.tif
# Asset key: s3_Fmask, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.Fmask.tif
# Asset key: s3_B07, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B07.tif
# Asset key: s3_B04, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B04.tif
# Asset key: s3_VAA, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.VAA.tif
# Asset key: s3_SAA, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.SAA.tif
# Asset key: s3_B08, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B08.tif
# Asset key: s3_SZA, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.SZA.tif
# Asset key: s3_B09, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T10UFD.2024122T185919.v2.0/HLS.S30.T10UFD.2024122T185919.v2.0.B09.tif
# Asset key: metadata, title: CMR XML metadata for G2979385874-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G2979385874-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T10UFD.2024122T185919.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-119.9283215, 52.222566], [-119.8582301, 53.2082014], [-120.6372862, 53.2262057], [-121.064138, 52.2466729], [-119.9283215, 52.222566]]]}
# Bounding Box: [-121.064138, 52.222566, -119.8582301, 53.2262057]
# Datetime: 2024-05-01 19:09:55.886000+00:00
# cloud cover: 74
# Properties:
#   <datetime>: 2024-05-01T19:09:55.886Z
#   <eo:cloud_cover>: 74
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2024-05-01T19:09:55.886Z
#   <end_datetime>: 2024-05-01T19:09:55.886Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16691, x: 16357)
# Coordinates:
#   * y            (y) float64 134kB 7.904e+05 7.904e+05 ... 2.897e+05 2.897e+05
#   * x            (x) float64 131kB -1.722e+06 -1.722e+06 ... -1.231e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2024-05-01T19:09:55.886000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 47
#
# <<<<<< The unique granule tiles =  ['T11UPU', 'T11UPS', 'T12UUA', 'T11UPV', 'T11UQU', 'T11UQR', 'T11ULQ', 'T10UGV', 'T12UUB', 'T11UQS', 'T11UNA', 'T12UUE', 'T11UQV', 'T11UNV', 'T12UUD', 'T11UNU', 'T11ULS', 'T11UPR', 'T12UUC', 'T11UQT', 'T11UMV', 'T11UNT', 'T11ULT', 'T10UGC', 'T11UMQ', 'T10UGB', 'T10UFD', 'T10UFB', 'T11UPT', 'T11UMR', 'T11UPQ', 'T11ULV', 'T10UGE', 'T10UED', 'T11ULU', 'T11UMT', 'T11UMS', 'T10UFE', 'T11UNQ', 'T11UPA', 'T10UFC', 'T10UGA', 'T11UMU', 'T10UGD', 'T11UNS', 'T11UNR', 'T11ULR']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 230.88 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.02 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation =  85.94 minutes >>>>>>
# File 'E:\HLS_mosaics_2024\HLS_mosaic_tile42_421_2024_30m\log_ab6dd29c-0dc2-4109-a3ba-d4286054bfe3.out' does not exist.
# Directory 'E:\HLS_mosaics_2024\HLS_mosaic_tile42_421_2024_30m\dask_spill_ab6dd29c-0dc2-4109-a3ba-d4286054bfe3' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-121.4106, 52.9067], [-118.9501, 48.744299999999996], [-112.6399, 50.0479], [-114.5797, 54.360200000000006], [-121.4106, 52.9067]]]}
#
# <one_mosaic> A total of 492 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T12UUC.2024153T182919.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.jpg
# Asset key: VAA, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.VAA.tif
# Asset key: B09, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B09.tif
# Asset key: B08, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B08.tif
# Asset key: B02, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B02.tif
# Asset key: SAA, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.SAA.tif
# Asset key: B05, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B05.tif
# Asset key: B03, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B03.tif
# Asset key: B06, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B06.tif
# Asset key: B12, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B12.tif
# Asset key: B04, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B04.tif
# Asset key: VZA, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.VZA.tif
# Asset key: Fmask, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.Fmask.tif
# Asset key: B01, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B01.tif
# Asset key: B07, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B07.tif
# Asset key: B11, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B11.tif
# Asset key: SZA, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.SZA.tif
# Asset key: B10, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B10.tif
# Asset key: B8A, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B8A.tif
# Asset key: s3_VAA, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.VAA.tif
# Asset key: s3_B09, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B09.tif
# Asset key: s3_B08, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B08.tif
# Asset key: s3_B02, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B02.tif
# Asset key: s3_SAA, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.SAA.tif
# Asset key: s3_B05, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B05.tif
# Asset key: s3_B03, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B03.tif
# Asset key: s3_B06, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B06.tif
# Asset key: s3_B12, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B12.tif
# Asset key: s3_B04, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B04.tif
# Asset key: s3_VZA, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.VZA.tif
# Asset key: s3_Fmask, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.Fmask.tif
# Asset key: s3_B01, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B01.tif
# Asset key: s3_B07, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B07.tif
# Asset key: s3_B11, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B11.tif
# Asset key: s3_SZA, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.SZA.tif
# Asset key: s3_B10, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B10.tif
# Asset key: s3_B8A, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024153T182919.v2.0/HLS.S30.T12UUC.2024153T182919.v2.0.B8A.tif
# Asset key: metadata, title: CMR XML metadata for G3058406949-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3058406949-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T12UUC.2024153T182919.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-113.8707891, 51.3280533], [-112.2954215, 51.3560798], [-112.3240754, 52.3430544], [-113.4747742, 52.3245486], [-113.8721695, 51.3776687], [-113.8707891, 51.3280533]]]}
# Bounding Box: [-113.8721695, 51.3280533, -112.2954215, 52.3430544]
# Datetime: 2024-06-01 18:39:58.856000+00:00
# cloud cover: 11
# Properties:
#   <datetime>: 2024-06-01T18:39:58.856Z
#   <eo:cloud_cover>: 11
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2024-06-01T18:39:58.856Z
#   <end_datetime>: 2024-06-01T18:39:58.856Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16691, x: 16357)
# Coordinates:
#   * y            (y) float64 134kB 7.904e+05 7.904e+05 ... 2.897e+05 2.897e+05
#   * x            (x) float64 131kB -1.722e+06 -1.722e+06 ... -1.231e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2024-06-01T18:39:58.856000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 47
#
# <<<<<< The unique granule tiles =  ['T11UQT', 'T11UPS', 'T12UUC', 'T12UUA', 'T11UQR', 'T11UMQ', 'T11UQS', 'T11UNV', 'T11UQU', 'T11UPU', 'T12UUB', 'T11UPR', 'T12UUD', 'T11UPT', 'T11UNQ', 'T11UPV', 'T11UMR', 'T10UFB', 'T11UQV', 'T11ULR', 'T10UGA', 'T11ULS', 'T10UGB', 'T11UMT', 'T12UUE', 'T11UNU', 'T11UNT', 'T11ULQ', 'T10UGV', 'T11ULT', 'T11UNR', 'T10UFC', 'T10UED', 'T11ULU', 'T11UPQ', 'T10UFD', 'T11UNA', 'T11UMU', 'T11UMV', 'T11UPA', 'T10UGC', 'T11UMS', 'T10UGD', 'T11ULV', 'T10UGE', 'T11UNS', 'T10UFE']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 247.64 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.02 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
# ERROR:asyncio:Exception in callback BaseIOStream.write.<locals>.<lambda>() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\iostream.py:536
# handle: <Handle BaseIOStream.write.<locals>.<lambda>() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\iostream.py:536>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\iostream.py", line 536, in <lambda>
#     future.add_done_callback(lambda f: f.exception())
#                                        ~~~~~~~~~~~^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 88, in _needs_document_lock_wrapper
#     with await self._lock.acquire():
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^
# asyncio.exceptions.CancelledError
# ERROR:asyncio:Exception in callback multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540
# handle: <Handle multi_future.<locals>.callback() at C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py:540>
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\asyncio\events.py", line 89, in _run
#     self._context.run(self._callback, *self._args)
#     ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\gen.py", line 546, in callback
#     result_list.append(f.result())
#                        ~~~~~~~~^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\session.py", line 106, in _needs_document_lock_wrapper
#     await p
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\views\ws.py", line 284, in send_message
#     await message.send(self)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\protocol\message.py", line 325, in send
#     sent += await self.write_buffers(conn, locked=False)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\protocol\message.py", line 269, in write_buffers
#     await conn.write_message(header, locked=locked)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\bokeh\server\views\ws.py", line 300, in write_message
#     await super().write_message(message, binary)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\tornado\websocket.py", line 1113, in wrapper
#     await fut
# asyncio.exceptions.CancelledError
# <<<<<< The total elapsed time for mosaic generation = 109.87 minutes >>>>>>
# File 'E:\HLS_mosaics_2024\HLS_mosaic_tile42_421_2024_30m\log_1a56bfb2-a23e-415f-9f14-bbaca8e3f923.out' does not exist.
# Directory 'E:\HLS_mosaics_2024\HLS_mosaic_tile42_421_2024_30m\dask_spill_1a56bfb2-a23e-415f-9f14-bbaca8e3f923' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-121.4106, 52.9067], [-118.9501, 48.744299999999996], [-112.6399, 50.0479], [-114.5797, 54.360200000000006], [-121.4106, 52.9067]]]}
#
# <one_mosaic> A total of 850 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T12UUC.2024183T182919.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.jpg
# Asset key: B01, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B01.tif
# Asset key: VAA, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.VAA.tif
# Asset key: SZA, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.SZA.tif
# Asset key: B11, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B11.tif
# Asset key: B05, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B05.tif
# Asset key: B07, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B07.tif
# Asset key: B04, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B04.tif
# Asset key: B06, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B06.tif
# Asset key: B03, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B03.tif
# Asset key: B09, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B09.tif
# Asset key: B12, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B12.tif
# Asset key: B10, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B10.tif
# Asset key: B8A, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B8A.tif
# Asset key: SAA, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.SAA.tif
# Asset key: B08, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B08.tif
# Asset key: VZA, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.VZA.tif
# Asset key: Fmask, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.Fmask.tif
# Asset key: B02, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B02.tif
# Asset key: s3_B01, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B01.tif
# Asset key: s3_VAA, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.VAA.tif
# Asset key: s3_SZA, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.SZA.tif
# Asset key: s3_B11, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B11.tif
# Asset key: s3_B05, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B05.tif
# Asset key: s3_B07, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B07.tif
# Asset key: s3_B04, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B04.tif
# Asset key: s3_B06, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B06.tif
# Asset key: s3_B03, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T12UUC.2024183T182919.v2.0/HLS.S30.T12UUC.2024183T182919.v2.0.B03.tif
# ...
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation = 143.57 minutes >>>>>>
# File 'E:\HLS_mosaics_2024\HLS_mosaic_tile42_421_2024_30m\log_e5aacee1-dc75-4efb-9346-ccfcbf3d161a.out' does not exist.
# Directory 'E:\HLS_mosaics_2024\HLS_mosaic_tile42_421_2024_30m\dask_spill_e5aacee1-dc75-4efb-9346-ccfcbf3d161a' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-121.4106, 52.9067], [-118.9501, 48.744299999999996], [-112.6399, 50.0479], [-114.5797, 54.360200000000006], [-121.4106, 52.9067]]]}
#
# <one_mosaic> A total of 494 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T11UMV.2024275T191119.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.jpg
# Asset key: B12, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B12.tif
# Asset key: B11, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B11.tif
# Asset key: B08, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B08.tif
# Asset key: B02, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B02.tif
# Asset key: B04, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B04.tif
# Asset key: B10, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B10.tif
# Asset key: Fmask, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.Fmask.tif
# Asset key: SAA, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.SAA.tif
# Asset key: B05, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B05.tif
# Asset key: B01, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B01.tif
# Asset key: B8A, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B8A.tif
# Asset key: B07, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B07.tif
# Asset key: SZA, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.SZA.tif
# Asset key: VAA, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.VAA.tif
# Asset key: B09, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B09.tif
# Asset key: VZA, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.VZA.tif
# Asset key: B06, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B06.tif
# Asset key: B03, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B03.tif
# Asset key: s3_B12, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B12.tif
# Asset key: s3_B11, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B11.tif
# Asset key: s3_B08, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B08.tif
# Asset key: s3_B02, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B02.tif
# Asset key: s3_B04, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B04.tif
# Asset key: s3_B10, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B10.tif
# Asset key: s3_Fmask, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.Fmask.tif
# Asset key: s3_SAA, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.SAA.tif
# Asset key: s3_B05, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B05.tif
# Asset key: s3_B01, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B01.tif
# Asset key: s3_B8A, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B8A.tif
# Asset key: s3_B07, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B07.tif
# Asset key: s3_SZA, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.SZA.tif
# Asset key: s3_VAA, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.VAA.tif
# Asset key: s3_B09, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B09.tif
# Asset key: s3_VZA, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.VZA.tif
# Asset key: s3_B06, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B06.tif
# Asset key: s3_B03, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T11UMV.2024275T191119.v2.0/HLS.S30.T11UMV.2024275T191119.v2.0.B03.tif
# Asset key: metadata, title: CMR XML metadata for G3255347458-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3255347458-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T11UMV.2024275T191119.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-118.501836, 53.3194566], [-118.0378816, 54.1296093], [-118.0308853, 54.143691], [-118.5313133, 54.1383655], [-118.501836, 53.3194566]]]}
# Bounding Box: [-118.5313133, 53.3194566, -118.0308853, 54.143691]
# Datetime: 2024-10-01 19:19:28.027000+00:00
# cloud cover: 71
# Properties:
#   <datetime>: 2024-10-01T19:19:28.027Z
#   <eo:cloud_cover>: 71
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2024-10-01T19:19:28.027Z
#   <end_datetime>: 2024-10-01T19:19:28.027Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 11GB
# Dimensions:      (y: 16691, x: 16357)
# Coordinates:
#   * y            (y) float64 134kB 7.904e+05 7.904e+05 ... 2.897e+05 2.897e+05
#   * x            (x) float64 131kB -1.722e+06 -1.722e+06 ... -1.231e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2024-10-01T19:19:28.027000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 47
#
# <<<<<< The unique granule tiles =  ['T11UQT', 'T11UPS', 'T12UUA', 'T11UPT', 'T11UPR', 'T11UQR', 'T11UNV', 'T11UNU', 'T11UNT', 'T11UPU', 'T11UMV', 'T10UFB', 'T11UMQ', 'T12UUB', 'T12UUC', 'T11UPQ', 'T10UGV', 'T11UNA', 'T11UQS', 'T10UGB', 'T10UGA', 'T11UPV', 'T11UNQ', 'T12UUD', 'T11UQU', 'T11UMR', 'T11ULR', 'T11ULQ', 'T12UUE', 'T11UQV', 'T11UNR', 'T11ULS', 'T11UPA', 'T11ULV', 'T10UGE', 'T11UMU', 'T11ULT', 'T10UGC', 'T11UNS', 'T10UED', 'T10UFC', 'T11ULU', 'T10UFD', 'T11UMS', 'T10UFE', 'T10UGD', 'T11UMT']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 246.44 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 1.02 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 2.03 GiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< Complete saving composite images >>>>>>>>>
#
#
# <<<<<< The total elapsed time for mosaic generation = 111.49 minutes >>>>>>
# File 'E:\HLS_mosaics_2024\HLS_mosaic_tile42_421_2024_30m\log_2423ad6f-420e-49b8-af92-e6d16a273cce.out' does not exist.
# Directory 'E:\HLS_mosaics_2024\HLS_mosaic_tile42_421_2024_30m\dask_spill_2423ad6f-420e-49b8-af92-e6d16a273cce' and its contents have been deleted.
