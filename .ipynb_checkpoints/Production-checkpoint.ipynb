# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "number_workers" : 8,   #For S2 data, only use 10 rather than 20
  "worker_threads": 1,
  "debug"       : True,
  "entire_tile" : False,     #
  "nodes"       : 1,
  "node_memory" : "64G",
  'chunk_size': {'x': 2048, 'y': 2048}
}

  
ProdParams = {
    'sensor': 'HLS_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR', 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2025,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [8],            # A list of integers represening one or multiple monthes     
    'tile_names': ['tile55_422'], # A list of (sub-)tile names (defined using CCRS' tile griding system) 
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution':30,            # Exporting spatial resolution    
    'out_folder': 'C:/Work_Data/HLS_mosaic_tile55_422_2025_30m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2025-06-15'],
    #'end_dates': ['2025-09-15'],
    #'regions': {'ottawa': ottawa_region}  #, {'vancouver': vancouver_region}    
}

# %%
main(ProdParams, CompParams)
# Out:
#  <get_query_conditions> inParams = {'sensor': 'HLS_SR', 'unit': 2, 'year': 2025, 'nbYears': -1, 'months': [8], 'tile_names': ['tile55'], 'prod_names': ['mosaic'], 'resolution': 30, 'out_folder': 'C:/Work_Data/HLS_mosaic_tile55_2025_30m', 'out_datatype': 'int16', 'projection': 'EPSG:3979', 'IncludeAngles': False, 'SsrData': {'NAME': 'HLS_SR', 'SSR_CODE': 102, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'SIX_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'NoA_BANDS': ['B04', 'B05', 'B06', 'B07'], 'LEAF_BANDS': ['B03', 'B04', 'B05', 'B06', 'B07'], 'ANGLE_BANDS': ['VZA', 'VAA', 'SZA', 'SAA'], 'CLOUD': 'CLOUD_COVERAGE', 'BLU': 'B02', 'GRN': 'B03', 'RED': 'B04', 'NIR': 'B05', 'SW1': 'B06', 'SW2': 'B07'}, 'out_location': 'drive', 'cloud_cover': 80, 'export_style': 'separate', 'CloudScore': False, 'monthly': True, 'start_dates': ['2025-08-01'], 'end_dates': ['2025-08-31'], 'current_time': 0, 'scene_ID': '', 'regions': {'tile55': {'type': 'Polygon', 'coordinates': [[[-80.5932, 50.8149], [-83.004, 42.9647], [-72.8716, 40.8803], [-68.7488, 48.2563], [-80.5932, 50.8149]]]}}, 'current_region': 'tile55'}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-80.5932, 50.8149], [-83.004, 42.9647], [-72.8716, 40.8803], [-68.7488, 48.2563], [-80.5932, 50.8149]]]}
#
# <period_mosaic> A total of 1946 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T19UEP.2025213T153559.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.jpg
# Asset key: B8A, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B8A.tif
# Asset key: B05, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B05.tif
# Asset key: B03, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B03.tif
# Asset key: B04, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B04.tif
# Asset key: B06, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B06.tif
# Asset key: B07, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B07.tif
# Asset key: B10, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B10.tif
# Asset key: B01, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B01.tif
# Asset key: B08, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B08.tif
# Asset key: VAA, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.VAA.tif
# Asset key: SZA, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.SZA.tif
# Asset key: B11, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B11.tif
# Asset key: VZA, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.VZA.tif
# Asset key: B09, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B09.tif
# Asset key: B12, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B12.tif
# Asset key: Fmask, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.Fmask.tif
# Asset key: SAA, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.SAA.tif
# Asset key: B02, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B02.tif
# Asset key: s3_B8A, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B8A.tif
# Asset key: s3_B05, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B05.tif
# Asset key: s3_B03, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B03.tif
# Asset key: s3_B04, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B04.tif
# Asset key: s3_B06, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B06.tif
# Asset key: s3_B07, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B07.tif
# Asset key: s3_B10, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B10.tif
# Asset key: s3_B01, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B01.tif
# Asset key: s3_B08, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B08.tif
# Asset key: s3_VAA, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.VAA.tif
# Asset key: s3_SZA, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.SZA.tif
# Asset key: s3_B11, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B11.tif
# Asset key: s3_VZA, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.VZA.tif
# Asset key: s3_B09, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B09.tif
# Asset key: s3_B12, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B12.tif
# Asset key: s3_Fmask, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.Fmask.tif
# Asset key: s3_SAA, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.SAA.tif
# Asset key: s3_B02, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19UEP.2025213T153559.v2.0/HLS.S30.T19UEP.2025213T153559.v2.0.B02.tif
# Asset key: metadata, title: CMR XML metadata for G3652748152-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G