# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "number_workers" : 8,   #For S2 data, only use 10 rather than 20
  "worker_threads": 1,
  "debug"       : True,
  "entire_tile" : False,     #
  "nodes"       : 1,
  "node_memory" : "64G",
  'chunk_size': {'x': 2048, 'y': 2048}
}

  
ProdParams = {
    'sensor': 'HLS_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR', 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2025,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [8],            # A list of integers represening one or multiple monthes     
    'tile_names': ['tile55_422'], # A list of (sub-)tile names (defined using CCRS' tile griding system) 
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution':30,            # Exporting spatial resolution    
    'out_folder': 'C:/Work_Data/HLS_mosaic_tile55_422_2025_30m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2025-06-15'],
    #'end_dates': ['2025-09-15'],
    #'regions': {'ottawa': ottawa_region}  #, {'vancouver': vancouver_region}    
}

# %%
main(ProdParams, CompParams)
# Out:
# <MosaicProduction> User defined input parameters:
# sensor: HLS_SR
# unit: 2
# year: 2025
# nbYears: -1
# months: [8]
# tile_names: ['tile55_422']
# prod_names: ['mosaic']
# resolution: 30
# out_folder: C:/Work_Data/HLS_mosaic_tile55_422_2025_30m
# out_datatype: int16
# projection: EPSG:3979
# IncludeAngles: False
# SsrData: {'NAME': 'HLS_SR', 'SSR_CODE': 102, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'SIX_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'NoA_BANDS': ['B04', 'B05', 'B06', 'B07'], 'LEAF_BANDS': ['B03', 'B04', 'B05', 'B06', 'B07'], 'ANGLE_BANDS': ['VZA', 'VAA', 'SZA', 'SAA'], 'CLOUD': 'CLOUD_COVERAGE', 'BLU': 'B02', 'GRN': 'B03', 'RED': 'B04', 'NIR': 'B05', 'SW1': 'B06', 'SW2': 'B07'}
# out_location: drive
# cloud_cover: 80
# export_style: separate
# CloudScore: False
# monthly: True
# start_dates: ['2025-08-01']
# end_dates: ['2025-08-31']
# current_time: 0
# scene_ID:
# regions: {'tile55_422': {'type': 'Polygon', 'coordinates': [[[-76.3005, 45.8742], [-77.8264, 42.0702], [-72.8716, 40.8803], [-70.9774, 44.5602], [-76.3005, 45.8742]]]}}
# current_region: tile55_422
# Criteria: {'timeframe': '2025-08-01/2025-08-31', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-76.3005, 45.8742], [-77.8264, 42.0702], [-72.8716, 40.8803], [-70.9774, 44.5602], [-76.3005, 45.8742]]]}, 'collection': ['HLSS30_2.0', 'HLSL30_2.0'], 'bands': {'S2': ['B02', 'B03', 'B04', 'B08', 'B11', 'B12', 'Fmask'], 'LS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'Fmask'], 'angle': ['SZA', 'SAA', 'VZA', 'VAA']}, 'catalog': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD'}
# standardized: True
# number_workers: 8
# worker_threads: 1
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 64G
# chunk_size: {'x': 2048, 'y': 2048}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-76.3005, 45.8742], [-77.8264, 42.0702], [-72.8716, 40.8803], [-70.9774, 44.5602], [-76.3005, 45.8742]]]}
#
# <period_mosaic> A total of 549 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T19TCK.2025213T153559.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.jpg
# Asset key: B10, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B10.tif
# Asset key: Fmask, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.Fmask.tif
# Asset key: B09, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B09.tif
# Asset key: B07, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B07.tif
# Asset key: SAA, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.SAA.tif
# Asset key: B06, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B06.tif
# Asset key: B05, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B05.tif
# Asset key: B08, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B08.tif
# Asset key: B01, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B01.tif
# Asset key: B02, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B02.tif
# Asset key: B8A, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B8A.tif
# Asset key: B11, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B11.tif
# Asset key: SZA, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.SZA.tif
# Asset key: B03, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B03.tif
# Asset key: VZA, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.VZA.tif
# Asset key: B04, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B04.tif
# Asset key: B12, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B12.tif
# Asset key: VAA, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.VAA.tif
# Asset key: s3_B10, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B10.tif
# Asset key: s3_Fmask, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.Fmask.tif
# Asset key: s3_B09, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B09.tif
# Asset key: s3_B07, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B07.tif
# Asset key: s3_SAA, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.SAA.tif
# Asset key: s3_B06, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B06.tif
# Asset key: s3_B05, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B05.tif
# Asset key: s3_B08, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B08.tif
# Asset key: s3_B01, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B01.tif
# Asset key: s3_B02, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B02.tif
# Asset key: s3_B8A, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B8A.tif
# Asset key: s3_B11, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B11.tif
# Asset key: s3_SZA, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.SZA.tif
# Asset key: s3_B03, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B03.tif
# Asset key: s3_VZA, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.VZA.tif
# Asset key: s3_B04, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B04.tif
# Asset key: s3_B12, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.B12.tif
# Asset key: s3_VAA, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T19TCK.2025213T153559.v2.0/HLS.S30.T19TCK.2025213T153559.v2.0.VAA.tif
# Asset key: metadata, title: CMR XML metadata for G3647308283-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G3647308283-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: HLS.S30.T19TCK.2025213T153559.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-71.212535, 44.1439366], [-70.1280813, 44.1597966], [-70.1474074, 45.1480732], [-70.878276, 45.1383896], [-71.212535, 44.1439366]]]}
# Bounding Box: [-71.212535, 44.1439366, -70.1280813, 45.1480732]
# Datetime: 2025-08-01 15:40:46.060000+00:00
# cloud cover: 60
# Properties:
#   <datetime>: 2025-08-01T15:40:46.060Z
#   <eo:cloud_cover>: 60
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2025-08-01T15:40:46.060Z
#   <end_datetime>: 2025-08-01T15:40:46.060Z
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 8GB
# Dimensions:      (y: 15001, x: 15001)
# Coordinates:
#   * y            (y) float64 120kB -1.351e+05 -1.351e+05 ... -5.851e+05
#   * x            (x) float64 120kB 1.45e+06 1.45e+06 ... 1.9e+06 1.9e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-08-01T15:40:46.060000
# Data variables:
#     blue         (y, x) float32 900MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     green        (y, x) float32 900MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     red          (y, x) float32 900MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     nir08        (y, x) float32 900MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     swir16       (y, x) float32 900MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     swir22       (y, x) float32 900MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     Fmask        (y, x) float32 900MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     date         (y, x) float32 900MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#     score        (y, x) float32 900MB dask.array<chunksize=(2048, 2048), meta=np.ndarray>
#
# <period_mosaic> The number of unique granule tiles = 36
#
# <<<<<< The unique granule tiles =  ['T18TYP', 'T18TWN', 'T18TUP', 'T19TCJ', 'T18TXM', 'T19TCK', 'T18TXL', 'T18TWM', 'T18TYQ', 'T18TXQ', 'T18TXP', 'T18TUN', 'T18TWL', 'T18TWP', 'T18TVP', 'T18TVM', 'T18TXN', 'T18TXR', 'T18TUM', 'T18TVN', 'T18TWQ', 'T18TWR', 'T18TYN', 'T18TVR', 'T18TVQ', 'T18TVL', 'T17TQJ', 'T17TQH', 'T17TQG', 'T18TYM', 'T19TBG', 'T18TTM', 'T18TYL', 'T18TUQ', 'T19TBF', 'T18TUR']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# 2025-12-15 11:44:23,826 - distributed.protocol.core - CRITICAL - Failed to Serialize
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2025-12-15 11:44:24,276 - distributed.comm.utils - ERROR - 0-dim memory has no length
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\utils.py", line 34, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2025-12-15 11:44:24,540 - distributed.batched - ERROR - Error in batched write
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\batched.py", line 115, in _background_send
#     nbytes = yield coro
#              ^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\tornado\gen.py", line 766, in run
#     value = future.result()
#             ^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\tcp.py", line 265, in write
#     frames = await to_frames(
#              ^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\utils.py", line 50, in to_frames
#     return _to_frames()
#            ^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\utils.py", line 34, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2025-12-15 11:44:36,729 - distributed.protocol.core - CRITICAL - Failed to Serialize
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2025-12-15 11:44:36,918 - distributed.comm.utils - ERROR - 0-dim memory has no length
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\utils.py", line 34, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2025-12-15 11:44:37,181 - distributed.batched - ERROR - Error in batched write
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\batched.py", line 115, in _background_send
#     nbytes = yield coro
#              ^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\tornado\gen.py", line 766, in run
#     value = future.result()
#             ^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\tcp.py", line 265, in write
#     frames = await to_frames(
#              ^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\utils.py", line 48, in to_frames
#     return await offload(_to_frames)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\utils.py", line 1507, in run_in_executor_with_context
#     return await loop.run_in_executor(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\concurrent\futures\thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\utils.py", line 1508, in <lambda>
#     executor, lambda: context.run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\utils.py", line 34, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2025-12-15 11:44:39,544 - distributed.protocol.core - CRITICAL - Failed to Serialize
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2025-12-15 11:44:39,637 - distributed.comm.utils - ERROR - 0-dim memory has no length
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\utils.py", line 34, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2025-12-15 11:44:40,292 - distributed.batched - ERROR - Error in batched write
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\batched.py", line 115, in _background_send
#     nbytes = yield coro
#              ^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\tornado\gen.py", line 766, in run
#     value = future.result()
#             ^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\tcp.py", line 265, in write
#     frames = await to_frames(
#              ^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\utils.py", line 50, in to_frames
#     return _to_frames()
#            ^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\utils.py", line 34, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2025-12-15 11:44:44,207 - distributed.protocol.core - CRITICAL - Failed to Serialize
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2025-12-15 11:44:44,228 - distributed.comm.utils - ERROR - 0-dim memory has no length
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# ...
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\batched.py", line 115, in _background_send
#     nbytes = yield coro
#              ^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\tornado\gen.py", line 766, in run
#     value = future.result()
#             ^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\tcp.py", line 265, in write
#     frames = await to_frames(
#              ^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\utils.py", line 48, in to_frames
#     return await offload(_to_frames)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\utils.py", line 1507, in run_in_executor_with_context
#     return await loop.run_in_executor(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\concurrent\futures\thread.py", line 58, in run
#     result = self.fn(*self.args, **self.kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\utils.py", line 1508, in <lambda>
#     executor, lambda: context.run(func, *args, **kwargs)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\utils.py", line 34, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2025-12-15 11:45:09,047 - distributed.protocol.core - CRITICAL - Failed to Serialize
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2025-12-15 11:45:09,058 - distributed.comm.utils - ERROR - 0-dim memory has no length
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\utils.py", line 34, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# 2025-12-15 11:45:09,066 - distributed.batched - ERROR - Error in batched write
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 109, in dumps
#     frames[0] = msgpack.dumps(msg, default=_encode_default, use_bin_type=True)
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\batched.py", line 115, in _background_send
#     nbytes = yield coro
#              ^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\tornado\gen.py", line 766, in run
#     value = future.result()
#             ^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\tcp.py", line 265, in write
#     frames = await to_frames(
#              ^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\utils.py", line 50, in to_frames
#     return _to_frames()
#            ^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\comm\utils.py", line 34, in _to_frames
#     return list(protocol.dumps(msg, **kwargs))
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\protocol\core.py", line 130, in dumps
#     frames[0] = msgpack.dumps(
#                 ^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\__init__.py", line 35, in packb
#     return Packer(**kwargs).pack(o)
#            ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 885, in pack
#     self._pack(obj)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 864, in _pack
#     return self._pack_map_pairs(
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 970, in _pack_map_pairs
#     self._pack(v, nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 861, in _pack
#     self._pack(obj[i], nest_limit - 1)
#   File "C:\Users\lsun\AppData\Local\anaconda3\envs\stac\Lib\site-packages\msgpack\fallback.py", line 819, in _pack
#     n = len(obj) * obj.itemsize
#         ^^^^^^^^
# TypeError: 0-dim memory has no length
# ---------------------------------------------------------------------------
# FutureCancelledError                      Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 main(ProdParams, CompParams)
#
# File ~\STAC_python\Production.py:203, in main(inProdParams, inCompParams)
#     200   leaf.LEAF_production(prod_params, comp_params)
#     202 else:
# --> 203   MosaicProduction(prod_params, comp_params)
#
# File ~\STAC_python\Production.py:170, in MosaicProduction(ProdParams, CompParams)
#     168 print('\n<MosaicProduction> Generate and export separate mosaic images......')
#     169 #AIMz.one_mosaicC(usedParams, CompParams)
# --> 170 eoMz.one_mosaic(usedParams, CompParams)
#
# File ~\STAC_python\source\eoMosaic.py:1621, in one_mosaic(AllParams, Output)
#    1618   client.cancel(future)
#    1620 # We do the compute to get a dask array instead of a future
# -> 1621 base_img = base_img.chunk(ChunkDict).compute()
#    1623 #==========================================================================================================
#    1624 # Mask out the pixels with negative date value
#    1625 #==========================================================================================================
#    1626 mosaic = base_img.where(base_img[eoIM.pix_date] > 0)
#
# File ~\AppData\Local\anaconda3\envs\stac\Lib\site-packages\dask\base.py:374, in DaskMethodsMixin.compute(self, **kwargs)
#     350 def compute(self, **kwargs):
#     351     """Compute this dask collection
#     352
#     353     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)    372     dask.compute
#     373     """
# --> 374     (result,) = compute(self, traverse=False, **kwargs)
#     375     return result
#
# File ~\AppData\Local\anaconda3\envs\stac\Lib\site-packages\dask\base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File ~\AppData\Local\anaconda3\envs\stac\Lib\site-packages\distributed\client.py:2426, in Client._gather(self, futures, errors, direct, local_worker)
#    2424     exception = st.exception
#    2425     traceback = st.traceback
# -> 2426     raise exception.with_traceback(traceback)
#    2427 if errors == "skip":
#    2428     bad_keys.add(key)
#
# FutureCancelledError: chunk-60b4cc18-88ff-4f97-98e7-f6308c935974 cancelled for reason: scheduler-connection-lost.
# Client lost the connection to the scheduler. Please check your connection and re-run your work.
