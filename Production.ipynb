# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "debug"       : True,
  "entire_tile" : False,     #
  "nodes"       : 1,
  "node_memory" : "120G",
  "number_workers" : 20
}

  
ProdParams = {
    'sensor': 'HLS_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR', 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2020,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [8,9,10],            # A list of integers represening one or multiple monthes     
    'tile_names': ['tile23_922'], # A list of (sub-)tile names (defined using CCRS' tile griding system) 
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution':20,            # Exporting spatial resolution    
    'out_folder': 'C:/Work_Data/HLS_mosaic_vancouver2020_20m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2025-06-15'],
    #'end_dates': ['2025-09-15'],
    'regions': {'ottawa': ottawa_region}  #, {'vancouver': vancouver_region}    
}

# %%
main(ProdParams, CompParams)
# Out:
#  <get_query_conditions> inParams = {'sensor': 'HLS_SR', 'unit': 2, 'year': 2020, 'nbYears': -1, 'months': [8, 9, 10], 'tile_names': ['tile23_922'], 'prod_names': ['mosaic'], 'resolution': 20, 'out_folder': 'C:/Work_Data/HLS_mosaic_vancouver2020_20m', 'out_datatype': 'int16', 'projection': 'EPSG:3979', 'IncludeAngles': False, 'regions': {'ottawa': {'type': 'Polygon', 'coordinates': [[[-76.12, 45.184], [-75.383, 45.171], [-75.39, 45.564], [-76.105, 45.568], [-76.12, 45.184]]]}}, 'SsrData': {'NAME': 'HLS_SR', 'SSR_CODE': 102, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'SIX_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'NoA_BANDS': ['B04', 'B05', 'B06', 'B07'], 'LEAF_BANDS': ['B03', 'B04', 'B05', 'B06', 'B07'], 'ANGLE_BANDS': ['VZA', 'VAA', 'SZA', 'SAA'], 'CLOUD': 'CLOUD_COVERAGE', 'BLU': 'B02', 'GRN': 'B03', 'RED': 'B04', 'NIR': 'B05', 'SW1': 'B06', 'SW2': 'B07'}, 'out_location': 'drive', 'cloud_cover': 80, 'export_style': 'separate', 'CloudScore': False, 'monthly': True, 'start_dates': ['2020-08-01', '2020-09-01', '2020-10-01'], 'end_dates': ['2020-08-31', '2020-09-30', '2020-10-31'], 'current_time': 0, 'scene_ID': '', 'current_region': 'ottawa'}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-76.12, 45.184], [-75.383, 45.171], [-75.39, 45.564], [-76.105, 45.568], [-76.12, 45.184]]]}
#
# <period_mosaic> A total of 13 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T18TVR.2020214T155911.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.jpg
# Asset key: B8A, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B8A.tif
# Asset key: SZA, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.SZA.tif
# Asset key: Fmask, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.Fmask.tif
# Asset key: B10, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B10.tif
# Asset key: B04, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B04.tif
# Asset key: B02, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B02.tif
# Asset key: B01, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B01.tif
# Asset key: B06, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B06.tif
# Asset key: SAA, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.SAA.tif
# Asset key: B12, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B12.tif
# Asset key: VZA, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.VZA.tif
# Asset key: B07, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B07.tif
# Asset key: B03, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B03.tif
# Asset key: VAA, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.VAA.tif
# Asset key: B05, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B05.tif
# Asset key: B08, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B08.tif
# Asset key: B11, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B11.tif
# Asset key: B09, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B09.tif
# Asset key: s3_B8A, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B8A.tif
# Asset key: s3_SZA, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.SZA.tif
# Asset key: s3_Fmask, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.Fmask.tif
# Asset key: s3_B10, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B10.tif
# Asset key: s3_B04, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B04.tif
# Asset key: s3_B02, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B02.tif
# Asset key: s3_B01, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B01.tif
# Asset key: s3_B06, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B06.tif
# Asset key: s3_SAA, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.SAA.tif
# Asset key: s3_B12, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B12.tif
# Asset key: s3_VZA, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.VZA.tif
# Asset key: s3_B07, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B07.tif
# Asset key: s3_B03, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B03.tif
# Asset key: s3_VAA, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.VAA.tif
# Asset key: s3_B05, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B05.tif
# Asset key: s3_B08, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B08.tif
# Asset key: s3_B11, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B11.tif
# Asset key: s3_B09, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020214T155911.v2.0/HLS.S30.T18TVR.2020214T155911.v2.0.B09.tif
# Asset key: metadata, title: CMR XML metadata for G2633781027-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G2633781027-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: HLS.S30.T18TVR.2020214T155911.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-76.2705836, 45.0581917], [-74.8760255, 45.0651927], [-74.8738328, 46.0535047], [-76.2930489, 46.0462596], [-76.2705836, 45.0581917]]]}
# Bounding Box: [-76.2930489, 45.0581917, -74.8738328, 46.0535047]
# Datetime: 2020-08-01 16:10:41.631000+00:00
# cloud cover: 25
# Properties:
#   <datetime>: 2020-08-01T16:10:41.631Z
#   <eo:cloud_cover>: 25
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2020-08-01T16:10:41.631Z
#   <end_datetime>: 2020-08-01T16:10:41.631Z
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 358MB
# Dimensions:      (y: 2913, x: 3411)
# Coordinates:
#   * y            (y) float64 23kB -1.472e+05 -1.472e+05 ... -2.054e+05
#   * x            (x) float64 27kB 1.475e+06 1.475e+06 ... 1.543e+06 1.543e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2020-08-01T16:10:41.631000
# Data variables:
#     blue         (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     green        (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     red          (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     nir08        (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     swir16       (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     swir22       (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     Fmask        (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     date         (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     score        (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#
# <period_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['T18TVR']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:49329/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 11.21 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# <<<<<<<<<< The total elapsed time for generating the mosaic =   7.80 minutes>>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 341.15 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# File 'C:\Work_Data\HLS_mosaic_vancouver2020_20m\log_06a96f0b-d37c-4cda-a513-2fac1bb834d3.out' does not exist.
# Directory 'C:\Work_Data\HLS_mosaic_vancouver2020_20m\dask_spill_06a96f0b-d37c-4cda-a513-2fac1bb834d3' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-76.12, 45.184], [-75.383, 45.171], [-75.39, 45.564], [-76.105, 45.568], [-76.12, 45.184]]]}
#
# <period_mosaic> A total of 10 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T18TVR.2020249T155829.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.jpg
# Asset key: B01, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B01.tif
# Asset key: B10, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B10.tif
# Asset key: B05, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B05.tif
# Asset key: B12, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B12.tif
# Asset key: B02, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B02.tif
# Asset key: SAA, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.SAA.tif
# Asset key: B8A, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B8A.tif
# Asset key: B04, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B04.tif
# Asset key: Fmask, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.Fmask.tif
# Asset key: VAA, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.VAA.tif
# Asset key: B07, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B07.tif
# Asset key: B08, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B08.tif
# Asset key: B03, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B03.tif
# Asset key: B09, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B09.tif
# Asset key: B06, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B06.tif
# Asset key: VZA, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.VZA.tif
# Asset key: SZA, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.SZA.tif
# Asset key: B11, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B11.tif
# Asset key: s3_B01, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B01.tif
# Asset key: s3_B10, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B10.tif
# Asset key: s3_B05, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B05.tif
# Asset key: s3_B12, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B12.tif
# Asset key: s3_B02, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B02.tif
# Asset key: s3_SAA, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.SAA.tif
# Asset key: s3_B8A, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B8A.tif
# Asset key: s3_B04, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B04.tif
# Asset key: s3_Fmask, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.Fmask.tif
# Asset key: s3_VAA, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.VAA.tif
# Asset key: s3_B07, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B07.tif
# Asset key: s3_B08, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B08.tif
# Asset key: s3_B03, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B03.tif
# Asset key: s3_B09, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B09.tif
# Asset key: s3_B06, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B06.tif
# Asset key: s3_VZA, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.VZA.tif
# Asset key: s3_SZA, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.SZA.tif
# Asset key: s3_B11, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020249T155829.v2.0/HLS.S30.T18TVR.2020249T155829.v2.0.B11.tif
# Asset key: metadata, title: CMR XML metadata for G2630898546-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G2630898546-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: HLS.S30.T18TVR.2020249T155829.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-76.2705836, 45.0581917], [-74.8760255, 45.0651927], [-74.8738328, 46.0535047], [-76.2930489, 46.0462596], [-76.2705836, 45.0581917]]]}
# Bounding Box: [-76.2930489, 45.0581917, -74.8738328, 46.0535047]
# Datetime: 2020-09-05 16:10:38.627000+00:00
# cloud cover: 42
# Properties:
#   <datetime>: 2020-09-05T16:10:38.627Z
#   <eo:cloud_cover>: 42
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2020-09-05T16:10:38.627Z
#   <end_datetime>: 2020-09-05T16:10:38.627Z
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 358MB
# Dimensions:      (y: 2913, x: 3411)
# Coordinates:
#   * y            (y) float64 23kB -1.472e+05 -1.472e+05 ... -2.054e+05
#   * x            (x) float64 27kB 1.475e+06 1.475e+06 ... 1.543e+06 1.543e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2020-09-05T16:10:38.627000
# Data variables:
#     blue         (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     green        (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     red          (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     nir08        (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     swir16       (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     swir22       (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     Fmask        (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     date         (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     score        (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#
# <period_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['T18TVR']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:63491/status >>>>>>>>>
#
#
# <<<<<<<<<< The total elapsed time for generating the mosaic =   2.60 minutes>>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 341.15 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# File 'C:\Work_Data\HLS_mosaic_vancouver2020_20m\log_690801ad-6706-4cc2-bc99-07b1fcc855a9.out' does not exist.
# Directory 'C:\Work_Data\HLS_mosaic_vancouver2020_20m\dask_spill_690801ad-6706-4cc2-bc99-07b1fcc855a9' and its contents have been deleted.
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-76.12, 45.184], [-75.383, 45.171], [-75.39, 45.564], [-76.105, 45.568], [-76.12, 45.184]]]}
#
# <period_mosaic> A total of 8 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T18TVR.2020284T160211.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.jpg
# Asset key: B09, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B09.tif
# Asset key: B06, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B06.tif
# Asset key: B08, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B08.tif
# Asset key: B02, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B02.tif
# Asset key: VZA, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.VZA.tif
# Asset key: Fmask, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.Fmask.tif
# Asset key: B04, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B04.tif
# Asset key: VAA, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.VAA.tif
# Asset key: B11, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B11.tif
# Asset key: B01, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B01.tif
# Asset key: B12, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B12.tif
# Asset key: B10, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B10.tif
# Asset key: SAA, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.SAA.tif
# Asset key: B03, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B03.tif
# Asset key: B07, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B07.tif
# Asset key: SZA, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.SZA.tif
# Asset key: B05, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B05.tif
# Asset key: B8A, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B8A.tif
# Asset key: s3_B09, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B09.tif
# Asset key: s3_B06, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B06.tif
# Asset key: s3_B08, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B08.tif
# Asset key: s3_B02, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B02.tif
# Asset key: s3_VZA, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.VZA.tif
# Asset key: s3_Fmask, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.Fmask.tif
# Asset key: s3_B04, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B04.tif
# Asset key: s3_VAA, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.VAA.tif
# Asset key: s3_B11, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B11.tif
# Asset key: s3_B01, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B01.tif
# Asset key: s3_B12, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B12.tif
# Asset key: s3_B10, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B10.tif
# Asset key: s3_SAA, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.SAA.tif
# Asset key: s3_B03, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B03.tif
# Asset key: s3_B07, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B07.tif
# Asset key: s3_SZA, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.SZA.tif
# Asset key: s3_B05, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B05.tif
# Asset key: s3_B8A, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T18TVR.2020284T160211.v2.0/HLS.S30.T18TVR.2020284T160211.v2.0.B8A.tif
# Asset key: metadata, title: CMR XML metadata for G2168126361-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G2168126361-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# ID: HLS.S30.T18TVR.2020284T160211.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-76.2705836, 45.0581917], [-74.8760255, 45.0651927], [-74.8738328, 46.0535047], [-76.2930489, 46.0462596], [-76.2705836, 45.0581917]]]}
# Bounding Box: [-76.2930489, 45.0581917, -74.8738328, 46.0535047]
# Datetime: 2020-10-10 16:10:41.598000+00:00
# cloud cover: 76
# Properties:
#   <datetime>: 2020-10-10T16:10:41.598Z
#   <eo:cloud_cover>: 76
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2020-10-10T16:10:41.598Z
#   <end_datetime>: 2020-10-10T16:10:41.598Z
#
# <period_mosaic> based mosaic image =  <xarray.Dataset> Size: 358MB
# Dimensions:      (y: 2913, x: 3411)
# Coordinates:
#   * y            (y) float64 23kB -1.472e+05 -1.472e+05 ... -2.054e+05
#   * x            (x) float64 27kB 1.475e+06 1.475e+06 ... 1.543e+06 1.543e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2020-10-10T16:10:41.598000
# Data variables:
#     blue         (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     green        (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     red          (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     nir08        (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     swir16       (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     swir22       (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     Fmask        (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     date         (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#     score        (y, x) float32 40MB dask.array<chunksize=(2000, 2000), meta=np.ndarray>
#
# <period_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['T18TVR']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:61745/status >>>>>>>>>
#
#
# <<<<<<<<<< The total elapsed time for generating the mosaic =   4.86 minutes>>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 341.15 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
# File 'C:\Work_Data\HLS_mosaic_vancouver2020_20m\log_086ce179-f22b-4ed5-87e4-d2e9166f4715.out' does not exist.
# Directory 'C:\Work_Data\HLS_mosaic_vancouver2020_20m\dask_spill_086ce179-f22b-4ed5-87e4-d2e9166f4715' and its contents have been deleted.
