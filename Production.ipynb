# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "number_workers":10,   #For S2 data, only use 10 rather than 20  
  "debug"       : True,
  "entire_tile" : False,     #
  "nodes"       : 1,
  "node_memory" : "50G",
  'chunk_size': {'x': 4096, 'y': 4096}
}

  
ProdParams = {
    'sensor': 'HLS_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR', 'HLSS30_SR' or 'MOD_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2024,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [5,6,7,8,9,10],            # A list of integers represening one or multiple monthes     
    'tile_names': ['tile23_421'], # A list of (sub-)tile names (defined using CCRS' tile griding system) 
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution': 30,            # Exporting spatial resolution    
    'out_folder': 'E:/HLS_mosaics_2024/HLS_mosaic_tile23_421_2024_30m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    #'start_dates': ['2025-06-15'],
    #'end_dates': ['2025-09-15'],
    #'regions': {'ottawa': ottawa_region}  #, {'vancouver': vancouver_region}    
}

# %%
main(ProdParams, CompParams)
# Out:
# <form_spatial_regions> Raw polygon = {'type': 'Polygon', 'coordinates': [[[-118.2601, 71.197], [-114.4132, 67.2829], [-103.7123, 68.197], [-105.5575, 72.285], [-118.2601, 71.197]]]}
# <MosaicProduction> User defined input parameters:
# sensor: HLS_SR
# unit: 2
# year: 2024
# nbYears: -1
# months: [5, 6, 7, 8, 9, 10]
# tile_names: ['tile23_421']
# prod_names: ['mosaic']
# resolution: 30
# out_folder: E:/HLS_mosaics_2024/HLS_mosaic_tile23_421_2024_30m
# out_datatype: int16
# projection: EPSG:3979
# IncludeAngles: False
# SsrData: {'NAME': 'HLS_SR', 'SSR_CODE': 102, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'SIX_BANDS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07'], 'NoA_BANDS': ['B04', 'B05', 'B06', 'B07'], 'LEAF_BANDS': ['B03', 'B04', 'B05', 'B06', 'B07'], 'ANGLE_BANDS': ['VZA', 'VAA', 'SZA', 'SAA'], 'CLOUD': 'CLOUD_COVERAGE', 'BLU': 'B02', 'GRN': 'B03', 'RED': 'B04', 'NIR': 'B05', 'SW1': 'B06', 'SW2': 'B07'}
# out_location: drive
# cloud_cover: 80
# export_style: separate
# CloudScore: False
# monthly: True
# start_dates: ['2024-05-01', '2024-06-01', '2024-07-01', '2024-08-01', '2024-09-01', '2024-10-01']
# end_dates: ['2024-05-31', '2024-06-30', '2024-07-31', '2024-08-31', '2024-09-30', '2024-10-31']
# current_time: 0
# scene_ID:
# regions: {'tile23_421': {'type': 'Polygon', 'coordinates': [[[-118.4601, 71.397], [-114.6132, 67.0829], [-103.5123, 67.997], [-105.3575, 72.485], [-118.4601, 71.397]]]}}
# current_region: tile23_421
# Criteria: {'timeframe': '2024-05-01/2024-05-31', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-118.4601, 71.397], [-114.6132, 67.0829], [-103.5123, 67.997], [-105.3575, 72.485], [-118.4601, 71.397]]]}, 'collection': ['HLSS30_2.0', 'HLSL30_2.0'], 'bands': {'S2': ['B02', 'B03', 'B04', 'B08', 'B11', 'B12', 'Fmask'], 'LS': ['B02', 'B03', 'B04', 'B05', 'B06', 'B07', 'Fmask'], 'angle': ['SZA', 'SAA', 'VZA', 'VAA']}, 'catalog': 'https://cmr.earthdata.nasa.gov/stac/LPCLOUD'}
# standardized: True
# number_workers: 10
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 50G
# chunk_size: {'x': 4096, 'y': 4096}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-118.4601, 71.397], [-114.6132, 67.0829], [-103.5123, 67.997], [-105.3575, 72.485], [-118.4601, 71.397]]]}
#
# <one_mosaic> A total of 1466 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: browse, title: Download HLS.S30.T13WEU.2024122T185919.v2.0.jpg, href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.jpg
# Asset key: thumbnail_0, title: Thumbnail [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-public/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.jpg
# Asset key: thumbnail_1, title: Thumbnail [1], href: s3://lp-prod-public/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.jpg
# Asset key: B06, title: Direct Download [0], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B06.tif
# Asset key: B01, title: Direct Download [1], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B01.tif
# Asset key: B07, title: Direct Download [2], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B07.tif
# Asset key: B12, title: Direct Download [3], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B12.tif
# Asset key: SAA, title: Direct Download [4], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.SAA.tif
# Asset key: VAA, title: Direct Download [5], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.VAA.tif
# Asset key: B03, title: Direct Download [6], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B03.tif
# Asset key: SZA, title: Direct Download [7], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.SZA.tif
# Asset key: B11, title: Direct Download [8], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B11.tif
# Asset key: B10, title: Direct Download [9], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B10.tif
# Asset key: B04, title: Direct Download [10], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B04.tif
# Asset key: Fmask, title: Direct Download [11], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.Fmask.tif
# Asset key: VZA, title: Direct Download [12], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.VZA.tif
# Asset key: B02, title: Direct Download [13], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B02.tif
# Asset key: B09, title: Direct Download [14], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B09.tif
# Asset key: B8A, title: Direct Download [15], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B8A.tif
# Asset key: B05, title: Direct Download [16], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B05.tif
# Asset key: B08, title: Direct Download [17], href: https://data.lpdaac.earthdatacloud.nasa.gov/lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B08.tif
# Asset key: s3_B06, title: S3 Direct Download [0], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B06.tif
# Asset key: s3_B01, title: S3 Direct Download [1], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B01.tif
# Asset key: s3_B07, title: S3 Direct Download [2], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B07.tif
# Asset key: s3_B12, title: S3 Direct Download [3], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B12.tif
# Asset key: s3_SAA, title: S3 Direct Download [4], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.SAA.tif
# Asset key: s3_VAA, title: S3 Direct Download [5], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.VAA.tif
# Asset key: s3_B03, title: S3 Direct Download [6], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B03.tif
# Asset key: s3_SZA, title: S3 Direct Download [7], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.SZA.tif
# Asset key: s3_B11, title: S3 Direct Download [8], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B11.tif
# Asset key: s3_B10, title: S3 Direct Download [9], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B10.tif
# Asset key: s3_B04, title: S3 Direct Download [10], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B04.tif
# Asset key: s3_Fmask, title: S3 Direct Download [11], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.Fmask.tif
# Asset key: s3_VZA, title: S3 Direct Download [12], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.VZA.tif
# Asset key: s3_B02, title: S3 Direct Download [13], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B02.tif
# Asset key: s3_B09, title: S3 Direct Download [14], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B09.tif
# Asset key: s3_B8A, title: S3 Direct Download [15], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B8A.tif
# Asset key: s3_B05, title: S3 Direct Download [16], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B05.tif
# Asset key: s3_B08, title: S3 Direct Download [17], href: s3://lp-prod-protected/HLSS30.020/HLS.S30.T13WEU.2024122T185919.v2.0/HLS.S30.T13WEU.2024122T185919.v2.0.B08.tif
# Asset key: metadata, title: CMR XML metadata for G2980006753-LPCLOUD, href: https://cmr.earthdata.nasa.gov/search/concepts/G2980006753-LPCLOUD.xml
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: HLS.S30.T13WEU.2024122T185919.v2.0
# Geometry: {'type': 'Polygon', 'coordinates': [[[-102.0959368, 70.1948429], [-101.950145, 71.1780394], [-105.0005561, 71.2028426], [-105.0005295, 70.2183208], [-102.0959368, 70.1948429]]]}
# Bounding Box: [-105.0005561, 70.1948429, -101.950145, 71.2028426]
# Datetime: 2024-05-01 19:04:30.898000+00:00
# cloud cover: 44
# Properties:
#   <datetime>: 2024-05-01T19:04:30.898Z
#   <eo:cloud_cover>: 44
#   <storage:schemes>: {'aws': {'type': 'aws-s3', 'platform': 'https://{bucket}.s3.{region}.amazonaws.com', 'bucket': 'lp-prod-protected', 'region': 'us-west-2'}}
#   <start_datetime>: 2024-05-01T19:04:30.898Z
#   <end_datetime>: 2024-05-01T19:04:30.898Z
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 10GB
# Dimensions:      (y: 16515, x: 15823)
# Coordinates:
#   * y            (y) float64 132kB 2.588e+06 2.588e+06 ... 2.092e+06 2.092e+06
#   * x            (x) float64 127kB -8.145e+05 -8.145e+05 ... -3.399e+05
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2024-05-01T19:04:30.898000
# Data variables:
#     blue         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     green        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     red          (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     nir08        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir16       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     swir22       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     Fmask        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     sensor       (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     date         (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#     score        (y, x) float32 1GB dask.array<chunksize=(4096, 4096), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 49
#
# <<<<<< The unique granule tiles =  ['T12WVA', 'T12WWC', 'T13WDT', 'T12WWD', 'T12WXD', 'T12WWB', 'T12WWA', 'T12WVV', 'T12WWE', 'T11WNU', 'T11WPT', 'T11WPV', 'T13WDR', 'T12WVC', 'T13WDU', 'T13WDS', 'T12WXB', 'T11WMU', 'T12WXC', 'T12WVE', 'T12WXA', 'T11WPS', 'T13WET', 'T13XDA', 'T12XXF', 'T11WNT', 'T11WMV', 'T13WDV', 'T11WPU', 'T12WVB', 'T12WXE', 'T13WEU', 'T11WPR', 'T12XWF', 'T11WPQ', 'T11WNS', 'T12WWV', 'T11WMT', 'T10WFD', 'T11WNR', 'T13WES', 'T12XVF', 'T12WVD', 'T11WNV', 'T10WFE', 'T11WNQ', 'T13WER', 'T11XPA', 'T13WEV']
#
#
# <<<<<<<<<< Dask dashboard is available http://127.0.0.1:8787/status >>>>>>>>>
# C:\Users\lsun\AppData\Local\anaconda3\envs\stac313\Lib\site-packages\distributed\client.py:3370: UserWarning: Sending large graph of size 303.09 MiB.
# This may cause some slowdown.
# Consider loading the data with Dask directly
#  or using futures or delayed objects to embed the data into the graph without repetition.
# See also https://docs.dask.org/en/stable/best-practices.html#load-data-with-dask for more information.
#   warnings.warn(
