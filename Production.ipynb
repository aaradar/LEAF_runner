# %%
import os
import sys

#Get the absolute path to the parent of current working directory 
cwd    = os.getcwd()
source_path = os.path.join(cwd, 'source')
sys.path.append(source_path)
sys.path

from Production import main

# %%
ottawa_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-76.120,45.184], 
         [-75.383,45.171],
         [-75.390,45.564], 
         [-76.105,45.568], 
         [-76.120,45.184]
       ]
    ]
}

vancouver_region = {
    'type': 'Polygon',
    'coordinates': [
       [
         [-123.32, 49.37], 
         [-122.44, 49.35],
         [-122.96, 48.75], 
         [-123.27, 48.96], 
         [-123.32, 49.37]
       ]
    ]
}

CompParams = {
  "number_workers":20,     
  "debug"       : True,
  "entire_tile" : False, 
  "nodes"       : 1,
  "node_memory" : "25G",
  'chunk_size': {'x': 4096, 'y': 4096}
}

  
ProdParams = {
    'sensor': 'S2_SR',       # A sensor type string (e.g., 'S2_SR', 'HLS_SR', 'HLSL30_SR' or 'HLSS30_SR')
    'unit': 2,                   # A data unit code (1 or 2 for TOA or surface reflectance)    
    'year': 2025,                # An integer representing image acquisition year
    'nbYears': -1,               # positive int for annual product, or negative int for monthly product
    'months': [8],    # A list of integers represening one or multiple monthes     
    #'tile_names': ['tile46_411','tile46_412','tile46_421','tile46_422'],  # A list of (sub-)tile names
    #'tile_names': ['tile46_412'],
    'prod_names': ['mosaic'],    #['LAI', 'fCOVER', 'fAPAR', 'Albedo'], 
    'resolution': 100,            # Exporting spatial resolution    
    'out_folder': 'E:/S2_mosaics_2025/S2_mosaic_tile46_412_2025_100m',  # the folder name for exporting
    'out_datatype': 'int16',     # 'int8' or 'int16'
    'projection': 'EPSG:3979',
    'IncludeAngles': False,
    'start_dates': ['2025-06-15'],
    'end_dates': ['2025-09-15'],
    'regions': {'ottawa': ottawa_region, 'vancouver': vancouver_region}    
}

print(ProdParams)
# Out:
# {'sensor': 'S2_SR', 'unit': 2, 'year': 2025, 'nbYears': -1, 'months': [8], 'prod_names': ['mosaic'], 'resolution': 100, 'out_folder': 'E:/S2_mosaics_2025/S2_mosaic_tile46_412_2025_100m', 'out_datatype': 'int16', 'projection': 'EPSG:3979', 'IncludeAngles': False, 'start_dates': ['2025-06-15'], 'end_dates': ['2025-09-15'], 'regions': {'ottawa': {'type': 'Polygon', 'coordinates': [[[-76.12, 45.184], [-75.383, 45.171], [-75.39, 45.564], [-76.105, 45.568], [-76.12, 45.184]]]}, 'vancouver': {'type': 'Polygon', 'coordinates': [[[-123.32, 49.37], [-122.44, 49.35], [-122.96, 48.75], [-123.27, 48.96], [-123.32, 49.37]]]}}}

# %%
main(ProdParams, CompParams)
# Out:
# <MosaicProduction> User defined input parameters:
# sensor: S2_SR
# unit: 2
# year: 2025
# nbYears: -1
# months: [8]
# prod_names: ['mosaic']
# resolution: 100
# out_folder: E:/S2_mosaics_2025/S2_mosaic_tile46_412_2025_100m
# out_datatype: int16
# projection: EPSG:3979
# IncludeAngles: False
# start_dates: ['2025-06-15']
# end_dates: ['2025-09-15']
# regions: {'ottawa': {'type': 'Polygon', 'coordinates': [[[-76.12, 45.184], [-75.383, 45.171], [-75.39, 45.564], [-76.105, 45.568], [-76.12, 45.184]]]}, 'vancouver': {'type': 'Polygon', 'coordinates': [[[-123.32, 49.37], [-122.44, 49.35], [-122.96, 48.75], [-123.27, 48.96], [-123.32, 49.37]]]}}
# SsrData: {'NAME': 'S2_SR', 'SSR_CODE': 21, 'DATA_UNIT': 2, 'GAIN': 0.0001, 'OFFSET': 0, 'ALL_BANDS': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], '10M_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'SIX_BANDS': ['blue', 'green', 'red', 'nir08', 'swir16', 'swir22'], 'NoA_BANDS': ['red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'LEAF_BANDS': ['green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22'], 'GEE_NAME': 'COPERNICUS/S2_SR_HARMONIZED', 'CLOUD': 'CLOUDY_PIXEL_PERCENTAGE', 'SZA': 'view:sun_elevation', 'SAA': 'view:sun_azimuth', 'VZA': 'view:sun_elevation', 'VAA': 'view:sun_azimuth', 'BLU': 'blue', 'GRN': 'green', 'RED': 'red', 'NIR': 'nir08', 'SW1': 'swir16', 'SW2': 'swir22'}
# out_location: drive
# tile_names: []
# cloud_cover: 80
# export_style: separate
# monthly: False
# current_time: 0
# scene_ID:
# current_region: ottawa
# Criteria: {'timeframe': '2025-06-15/2025-09-15', 'filters': {'eo:cloud_cover': {'lt': 80}}, 'region': {'type': 'Polygon', 'coordinates': [[[-76.12, 45.184], [-75.383, 45.171], [-75.39, 45.564], [-76.105, 45.568], [-76.12, 45.184]]]}, 'catalog': 'https://earth-search.aws.element84.com/v1', 'collection': ['sentinel-2-l2a'], 'bands': ['blue', 'green', 'red', 'rededge1', 'rededge2', 'rededge3', 'nir08', 'swir16', 'swir22', 'scl']}
# standardized: True
# number_workers: 20
# debug: True
# entire_tile: False
# nodes: 1
# node_memory: 25G
# chunk_size: {'x': 4096, 'y': 4096}
#
# <MosaicProduction> Generate and export separate mosaic images......
# <search_STAC_Images> The given region =  {'type': 'Polygon', 'coordinates': [[[-76.12, 45.184], [-75.383, 45.171], [-75.39, 45.564], [-76.105, 45.568], [-76.12, 45.184]]]}
#
# <search_STAC_Catalog> The total elapsed time for ingesting angles =   0.02 minutes
#
# <one_mosaic> A total of 28 items were found.
#
# <<<<<<< The assets associated with the first item >>>>>>>
#
# Asset key: aot, title: Aerosol optical thickness (AOT), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/AOT.tif
# Asset key: blue, title: Blue - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/B02.tif
# Asset key: cloud, title: Cloud Probabilities, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/qi/CLD_20m.jp2
# Asset key: coastal, title: Coastal - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/B01.tif
# Asset key: granule_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/granule_metadata.xml
# Asset key: green, title: Green - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/B03.tif
# Asset key: nir, title: NIR 1 - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/B08.tif
# Asset key: nir08, title: NIR 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/B8A.tif
# Asset key: nir09, title: NIR 3 - 60m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/B09.tif
# Asset key: product_metadata, title: None, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/product_metadata.xml
# Asset key: red, title: Red - 10m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/B04.tif
# Asset key: rededge1, title: Red Edge 1 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/B05.tif
# Asset key: rededge2, title: Red Edge 2 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/B06.tif
# Asset key: rededge3, title: Red Edge 3 - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/B07.tif
# Asset key: scl, title: Scene classification map (SCL), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/SCL.tif
# Asset key: snow, title: Snow Probabilities, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/qi/SNW_20m.jp2
# Asset key: swir16, title: SWIR 1.6μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/B11.tif
# Asset key: swir22, title: SWIR 2.2μm - 20m, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/B12.tif
# Asset key: tileinfo_metadata, title: None, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/tileinfo_metadata.json
# Asset key: visual, title: True color image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/TCI.tif
# Asset key: wvp, title: Water Vapour (WVP), href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/WVP.tif
# Asset key: thumbnail, title: Thumbnail of preview image, href: https://sentinel-cogs.s3.us-west-2.amazonaws.com/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A/preview.jpg
# Asset key: aot-jp2, title: Aerosol optical thickness (AOT), href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/R20m/AOT.jp2
# Asset key: blue-jp2, title: Blue - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/R10m/B02.jp2
# Asset key: coastal-jp2, title: Coastal - 60m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/R60m/B01.jp2
# Asset key: green-jp2, title: Green - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/R10m/B03.jp2
# Asset key: nir-jp2, title: NIR 1 - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/R10m/B08.jp2
# Asset key: nir08-jp2, title: NIR 2 - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/R20m/B8A.jp2
# Asset key: nir09-jp2, title: NIR 3 - 60m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/R60m/B09.jp2
# Asset key: red-jp2, title: Red - 10m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/R10m/B04.jp2
# Asset key: rededge1-jp2, title: Red Edge 1 - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/R20m/B05.jp2
# Asset key: rededge2-jp2, title: Red Edge 2 - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/R20m/B06.jp2
# Asset key: rededge3-jp2, title: Red Edge 3 - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/R20m/B07.jp2
# Asset key: scl-jp2, title: Scene classification map (SCL), href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/R20m/SCL.jp2
# Asset key: swir16-jp2, title: SWIR 1.6μm - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/R20m/B11.jp2
# Asset key: swir22-jp2, title: SWIR 2.2μm - 20m, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/R20m/B12.jp2
# Asset key: visual-jp2, title: True color image, href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/R10m/TCI.jp2
# Asset key: wvp-jp2, title: Water Vapour (WVP), href: s3://sentinel-s2-l2a/tiles/18/T/VR/2025/9/11/0/R20m/WVP.jp2
# <<<<<<< The meta data associated with an item >>>>>>>
#
# Scene ID: S2C_18TVR_20250911_0_L2A
# Geometry: {'type': 'Polygon', 'coordinates': [[[-75.6135756263464, 46.05191843614681], [-75.95445711458572, 45.06128051880555], [-74.87603818430986, 45.065201721669794], [-74.87384571020863, 46.053495749294726], [-75.6135756263464, 46.05191843614681]]]}
# Bounding Box: [-75.954457, 45.061281, -74.873846, 46.053496]
# Datetime: 2025-09-11 16:00:52.735000+00:00
# cloud cover: 6.755493
# Properties:
#   <created>: 2025-09-11T21:45:21.899Z
#   <platform>: sentinel-2c
#   <constellation>: sentinel-2
#   <instruments>: ['msi']
#   <eo:cloud_cover>: 6.755493
#   <proj:centroid>: {'lat': 45.52727, 'lon': -75.3349}
#   <mgrs:utm_zone>: 18
#   <mgrs:latitude_band>: T
#   <mgrs:grid_square>: VR
#   <grid:code>: MGRS-18TVR
#   <view:azimuth>: 105.55259658730408
#   <view:incidence_angle>: 9.061984254750806
#   <view:sun_azimuth>: 158.626611293334
#   <view:sun_elevation>: 46.8322028488952
#   <s2:tile_id>: S2C_OPER_MSI_L2A_TL_2CPS_20250911T202913_A005315_T18TVR_N05.11
#   <s2:degraded_msi_data_percentage>: 0.0083
#   <s2:nodata_pixel_percentage>: 35.196453
#   <s2:saturated_defective_pixel_percentage>: 0
#   <s2:cloud_shadow_percentage>: 5.952482
#   <s2:vegetation_percentage>: 73.714995
#   <s2:not_vegetated_percentage>: 9.356106
#   <s2:water_percentage>: 3.015756
#   <s2:unclassified_percentage>: 1.002875
#   <s2:medium_proba_clouds_percentage>: 3.866146
#   <s2:high_proba_clouds_percentage>: 2.54983
#   <s2:thin_cirrus_percentage>: 0.339517
#   <s2:snow_ice_percentage>: 1.5e-05
#   <s2:product_type>: S2MSI2A
#   <s2:processing_baseline>: 05.11
#   <s2:product_uri>: S2C_MSIL2A_20250911T154841_N0511_R054_T18TVR_20250911T202913.SAFE
#   <s2:generation_time>: 2025-09-11T20:29:13.000000Z
#   <s2:datatake_id>: GS2C_20250911T154841_005315_N05.11
#   <s2:datatake_type>: INS-NOBS
#   <s2:datastrip_id>: S2C_OPER_MSI_L2A_DS_2CPS_20250911T202913_S20250911T160005_N05.11
#   <s2:reflectance_conversion_factor>: 0.985469250928351
#   <datetime>: 2025-09-11T16:00:52.735000Z
#   <s2:sequence>: 0
#   <earthsearch:s3_path>: s3://sentinel-cogs/sentinel-s2-l2a-cogs/18/T/VR/2025/9/S2C_18TVR_20250911_0_L2A
#   <earthsearch:payload_id>: roda-sentinel2/workflow-sentinel2-to-stac/a9cae50d0015f7936805a10e363af7c5
#   <earthsearch:boa_offset_applied>: True
#   <processing:software>: {'sentinel2-to-stac': '2025.03.06'}
#   <updated>: 2025-09-11T21:45:21.899Z
#   <proj:code>: EPSG:32618
#   <sza>: 43.1677971511048
#   <saa>: 158.626611293334
#   <vza>: 9.11863170058079
#   <vaa>: 106.160814916414
#
# <one_mosaic> based mosaic image =  <xarray.Dataset> Size: 19MB
# Dimensions:      (y: 583, x: 683)
# Coordinates:
#   * y            (y) float64 5kB -1.472e+05 -1.472e+05 ... -2.052e+05 -2.054e+05
#   * x            (x) float64 5kB 1.475e+06 1.475e+06 ... 1.543e+06 1.543e+06
#     spatial_ref  int32 4B 3979
#     time         datetime64[ns] 8B 2025-09-11T16:00:52.735000
# Data variables:
#     blue         (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     green        (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     red          (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     rededge1     (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     rededge2     (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     rededge3     (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     nir08        (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     swir16       (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     swir22       (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     scl          (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     date         (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#     score        (y, x) float32 2MB dask.array<chunksize=(583, 683), meta=np.ndarray>
#
# <one_mosaic> The number of unique granule tiles = 1
#
# <<<<<< The unique granule tiles =  ['18TVR']
